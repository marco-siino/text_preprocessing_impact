# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/text_preprocessing_impact/blob/main/PCL_DS/ANN_PCL_TextPreProImpact_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances.
# - - -
# ANN ON PCL DS EXPERIMENTS NOTEBOOK
# - - -
# Artificial Neural Network on Patronizing and Condescending Language Dataset.
# Code by M. Siino.
#
# From the paper: "Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances." by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf
import numpy as np
import pandas as pd
import nltk

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from io import open
from pathlib import Path
from urllib import request

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer
from textblob import TextBlob
nltk.download('stopwords')
nltk.download('punkt')

os.environ['TF_CUDNN_DETERMINISTIC']='false'
os.environ['TF_DETERMINISTIC_OPS']='false'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Fetch all the files needed.

# %%
urlDontPatronizeMe_PCL_tsv = "https://drive.google.com/uc?export=download&id=1KAncWruZ4OkKlvEGnxLkNbR1sxAErG8_"
urlDontPatronizeMe_categories_tsv = "https://drive.google.com/uc?export=download&id=1KMZJsskzKLbM-kgYiwXIF0h3Shj4F0mM"
urlTestSet_csv = "https://drive.google.com/uc?export=download&id=161-_6MH16_UHtLTqt0nd09l68pP5MEbQ"
urlDevSet_csv = "https://drive.google.com/uc?export=download&id=1KNuZ_h7NXTSwEz3_0XkaEd4DUAyxojAU"
urlTrainSet_csv = "https://drive.google.com/uc?export=download&id=1KVRrMC9UVwtQE9QfcLv8b11P5t2BhA8I"

tmp = tf.keras.utils.get_file("dontpatronizeme_pcl.tsv", urlDontPatronizeMe_PCL_tsv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("dontpatronizeme_categories.tsv", urlDontPatronizeMe_categories_tsv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("task4_test.csv", urlTestSet_csv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("dev_semeval_parids-labels.csv", urlDevSet_csv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("train_semeval_parids-labels.csv", urlTrainSet_csv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')

# %% [markdown]
# # Fetch Don't Patronize Me! data manager module

# %%
module_url = f"https://raw.githubusercontent.com/Perez-AlmendrosC/dontpatronizeme/master/semeval-2022/dont_patronize_me.py"
module_name = module_url.split('/')[-1]
print(f'Fetching {module_url}')
#with open("file_1.txt") as f1, open("file_2.txt") as f2
with request.urlopen(module_url) as f, open(module_name,'w') as outf:
  a = f.read()
  outf.write(a.decode('utf-8'))
# Out:
# Fetching https://raw.githubusercontent.com/Perez-AlmendrosC/dontpatronizeme/master/semeval-2022/dont_patronize_me.py

# %% [markdown]
# # Import and load dpm

# %%
from dont_patronize_me import DontPatronizeMe
dpm = DontPatronizeMe('.', '.')
dpm.load_task1()
dpm.load_task2(return_one_hot=True)
# Out:
# Map of label to numerical label:
# {'Unbalanced_power_relations': 0, 'Shallow_solution': 1, 'Presupposition': 2, 'Authority_voice': 3, 'Metaphors': 4, 'Compassion': 5, 'The_poorer_the_merrier': 6}

# %% [markdown]
# # Load paragraph IDs

# %%
trids = pd.read_csv('train_semeval_parids-labels.csv')
teids = pd.read_csv('dev_semeval_parids-labels.csv')

# %%
print(trids.head())
print(len(trids))
print(len(teids))
# Out:
#    par_id                  label
# 0    4341  [1, 0, 0, 1, 0, 0, 0]
# 1    4136  [0, 1, 0, 0, 0, 0, 0]
# 2   10352  [1, 0, 0, 0, 0, 1, 0]
# 3    8279  [0, 0, 0, 1, 0, 0, 0]
# 4    1164  [1, 0, 0, 1, 1, 1, 0]
# 8375
# 2094

# %%
trids.par_id = trids.par_id.astype(str)
teids.par_id = teids.par_id.astype(str)

# %% [markdown]
# # Rebuild training set (Task 1)

# %%
rows = [] # will contain par_id, keyword, country, label and text
for idx in range(len(trids)):  
  parid = trids.par_id[idx]
  #print(parid)
  # select row from original dataset to retrieve `text` and binary label
  text = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].text.values[0]
  label = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].label.values[0]
  #keyword = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].keyword.values[0]
  #country = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].country.values[0]
  rows.append({
      'par_id':parid,
      #'keyword':keyword,
      #'country':country,
      'text':text,
      'label':label
  })

# %%
trdf1 = pd.DataFrame(rows)

# %%
len(rows)
# Out:
# 8375

# %%
print(trdf1)
# Out:
#      par_id                                               text  label
# 0      4341  The scheme saw an estimated 150,000 children f...      1
# 1      4136  Durban 's homeless communities reconciliation ...      1
# 2     10352  The next immediate problem that cropped up was...      1
# 3      8279  Far more important than the implications for t...      1
# 4      1164  To strengthen child-sensitive social protectio...      1
# ...     ...                                                ...    ...
# 8370   8380  Rescue teams search for survivors on the rubbl...      0
# 8371   8381  The launch of ' Happy Birthday ' took place la...      0
# 8372   8382  The unrest has left at least 20,000 people dea...      0
# 8373   8383  You have to see it from my perspective . I may...      0
# 8374   8384  Yet there was one occasion when we went to the...      0
#
# [8375 rows x 3 columns]

# %%
# Next row to balance the DS.
bal_trdf1 = trdf1.drop(trdf1.index[-6787:])

print("Total number of samples is:",len(bal_trdf1))
print("Total number of class 1 samples is:",sum(bal_trdf1.label == 1))
print("Total number of class 0 samples is:",sum(bal_trdf1.label == 0))

trdf1 = bal_trdf1
# Out:
# Total number of samples is: 1588
# Total number of class 1 samples is: 794
# Total number of class 0 samples is: 794

# %% [markdown]
# # Rebuild test set (Task 1)

# %%
rows = [] # will contain par_id, label and text
for idx in range(len(teids)):  
  parid = teids.par_id[idx]
  #print(parid)
  # select row from original dataset
  text = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].text.values[0]
  label = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].label.values[0]
  #keyword = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].keyword.values[0]
  #country = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].country.values[0]
  rows.append({
      'par_id':parid,
      #'keyword':keyword,
      #'country':country,
      'text':text,
      'label':label
  })

# %%
len(rows)
# Out:
# 2094

# %%
tedf1 = pd.DataFrame(rows)

# %%
# Next row to balance the DS.
bal_tedf1 = tedf1.drop(tedf1.index[-1696:])

print("Total number of samples is:",len(bal_tedf1))
print("Total number of class 1 samples is:",sum(bal_tedf1.label == 1))
print("Total number of class 0 samples is:",sum(bal_tedf1.label == 0))

tedf1 = bal_tedf1
# Out:
# Total number of samples is: 398
# Total number of class 1 samples is: 199
# Total number of class 0 samples is: 199

# %% [markdown]
# # Preprocessing functions definitions

# %%
# Do-Nothing preprocessing function.
def DON(input_data):
  tag_open_CDATA_removed = tf.strings.regex_replace(input_data, '<\!\[CDATA\[', ' ')
  tag_closed_CDATA_removed = tf.strings.regex_replace(tag_open_CDATA_removed,'\]{1,}>', ' ')
  tag_author_lang_en_removed = tf.strings.regex_replace(tag_closed_CDATA_removed,'<author lang="en">', ' ')
  tag_closed_author_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'</author>', ' ')
  tag_open_documents_removed = tf.strings.regex_replace(tag_closed_author_removed,'<documents>\n(\t){0,2}', '')
  output_data = tf.strings.regex_replace(tag_open_documents_removed,'</documents>\n(\t){0,2}', ' ')
  return output_data

# Lowercasing preprocessing function.
def LOW(input_data):  
  return tf.strings.lower(DON(input_data))

# Removing Stop Words function.
def RSW(input_data):
  output_data = DON(input_data)

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:

      # input_string = input_string.numpy() [0]
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("Tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# Porter Stemmer preprocessing function.
def STM(input_data):
  output_data = DON(input_data)
  stemmer = PorterStemmer()

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      #print(input_string)
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:
      #input_string = input_string.numpy()[0]
      input_string = input_string.numpy()
      #print(input_string)
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# %% [markdown]
# ## Define the combined preprocessing functions. (The base functions are: DON, LOW, RSW and STM).

# %%
## SECTION WITH PAIRS OF PREPRO FUNCTIONS. APPLICATION ORDER MATTERS (...IN FOLLOWING SECTIONS TOO).
#...5
def LOW_RSW(input_data):
  return RSW(LOW(input_data))

# 6
def LOW_STM(input_data):
  return STM(LOW(input_data))

# 7
def RSW_LOW(input_data):
  return LOW(RSW(input_data))

# 8
def RSW_STM(input_data):
  return STM(RSW(input_data))

# 9
def STM_LOW(input_data):
  return LOW(STM(input_data))

# 10
def STM_RSW(input_data):
  return RSW(STM(input_data))
  
# 11
def LOW_STM_RSW(input_data):
  return RSW(STM(LOW(input_data)))

# 12
def LOW_RSW_STM(input_data):
  return STM(RSW(LOW(input_data)))

# 13
def STM_LOW_RSW(input_data):
  return RSW(LOW(STM(input_data)))

# 14
def STM_RSW_LOW(input_data):
  return LOW(RSW(STM(input_data)))

# 15
def RSW_LOW_STM(input_data):
  return STM(LOW(RSW(input_data)))

# 16
def RSW_STM_LOW(input_data):
  return LOW(STM(RSW(input_data)))

# %% [markdown]
# # Build a Tensorflow DS

# %%
tf.random.set_seed(1)

train_ds = False
for i in range(0,len(trdf1)):
  sample = [' '+trdf1['text'][i]]
  label = [trdf1['label'][i]]

  current_set = (
    tf.data.Dataset.from_tensor_slices(
        (
            [tf.cast(sample,tf.string)],
            [tf.cast(label, tf.int32)]
        )
    )
  )
  if train_ds != False:
    train_ds = train_ds.concatenate(current_set)
  else:
    train_ds = current_set
train_ds = train_ds.shuffle(len(train_ds), reshuffle_each_iteration=False)

test_ds = False
for i in range(0,len(tedf1)):
  sample = [' '+tedf1['text'][i]]
  label = [tedf1['label'][i]]

  current_set = (
    tf.data.Dataset.from_tensor_slices(
        (
            [tf.cast(sample,tf.string)],
            [tf.cast(label, tf.int32)]
        )
    )
  )
  if test_ds != False:
    test_ds = test_ds.concatenate(current_set)
  else:
    test_ds = current_set

for element in train_ds:
    authorDocument=element[0]
    label=element[1]
    print(authorDocument)
    print(label)
    break
    
print(train_ds)
# Out:
# tf.Tensor([b' LUSAKA Zambia ( Xinhua ) -- Zambia ? s Immigration Department said Wednesday that it had arrested at least 45 illegal immigrants in Lusaka , the country ? s capital .'], shape=(1,), dtype=string)
# tf.Tensor([0], shape=(1,), dtype=int32)
# <ShuffleDataset element_spec=(TensorSpec(shape=(1,), dtype=tf.string, name=None), TensorSpec(shape=(1,), dtype=tf.int32, name=None))>

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(preprocessing_function,training_set):
  # Set a very large sequence length to find the longest sample in the training set.
  sequence_length = 20000
  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    # Count the number of zeros from the last non-zero token to the end of the sample. 
    # Shortest tokenized sample has less zeros than others.
    out=model(authorDocument)
    token_nr_index=sequence_length-1
    current_sample_zeros_counter=0
    while out.numpy()[0][token_nr_index]==0:
      token_nr_index-=1
      current_sample_zeros_counter+=1

    shortest_padding_length=sequence_length-longest_sample_length
    if current_sample_zeros_counter<shortest_padding_length:
      longest_sample_length=sequence_length-current_sample_zeros_counter

  #print(out.numpy()[0][3229:3400])
  #print(longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Define a dictionary with -> function_names:prepro_function_caller. And a dictionary to store model results.

# %%
model_results = {}
prepro_functions_dict_base = {
    'DON':DON,
    'LOW':LOW,
    'RSW':RSW,
    'STM':STM
    }

# 3 prepro functions = 15 combs...+1 for do_nothing

prepro_functions_dict_comb = {
    # 1. Do nothing 
    'DON': DON,
    # 2. Lowercasing 
    'LOW':LOW,
    # 3. Removing Stopwords
    'RSW':RSW, 
    # 4. Porter Stemming
    'STM':STM,
    # 5. LOW->RSW
    'LOW_RSW':LOW_RSW, 
    # 6. LOW->STM
    'LOW_STM':LOW_STM,
    # 7. RSW->LOW
    'RSW_LOW':RSW_LOW,
    # 8. RSW->STM
    'RSW_STM':RSW_STM,
    # 9. STM->LOW
    'STM_LOW':STM_LOW,
    # 10. STM->RSW
    'STM_RSW':STM_RSW,
    # 11. LOW->STM->RSW
    'LOW_STM_RSW':LOW_STM_RSW,  
    # 12. LOW->RSW->STM
    'LOW_RSW_STM':LOW_RSW_STM,
    # 13. STM->LOW->RSW
    'STM_LOW_RSW':STM_LOW_RSW,
    # 14. STM->RSW->LOW
    'STM_RSW_LOW':STM_RSW_LOW,
    # 15. RSW->LOW->STM
    'RSW_LOW_STM':RSW_LOW_STM,
    # 16. RSW->STM->LOW
    'RSW_STM_LOW':RSW_STM_LOW
}

for key in prepro_functions_dict_comb:
  print(key)
  model_results[key]=[]
# Out:
# DON
# LOW
# RSW
# STM
# LOW_RSW
# LOW_STM
# RSW_LOW
# RSW_STM
# STM_LOW
# STM_RSW
# LOW_STM_RSW
# LOW_RSW_STM
# STM_LOW_RSW
# STM_RSW_LOW
# RSW_LOW_STM
# RSW_STM_LOW

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Models definition and evaluation.

# %%
tf.random.set_seed(0)
TF_DISABLE_SEGMENT_REDUCTION_OP_DETERMINISM_EXCEPTIONS=True

# Reset model_results list.
for key in prepro_functions_dict_comb:
  model_results[key]=[]

for key in prepro_functions_dict_comb:
  runs_accuracy = []

  print("\n\n* * * * EVALUATION USING", key, "AS PREPROCESSING FUNCTION * * * *")

  # Preprocess training set to build a dictionary.
  vectorize_layer = preprocess_and_adapt_ts(prepro_functions_dict_comb[key],train_ds)

  max_features=len(vectorize_layer.get_vocabulary()) + 1
  print("Vocabulary size is:", max_features)

  for run in range(1,(num_runs+1)):
    epochs_accuracy=[]
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    layers.Dense(512,activation='relu'),
                                    layers.Dropout(0.5),
                                    layers.Dense(256,activation='relu'),
                                    layers.Dropout(0.4),
                                    layers.Dense(128,activation='relu'),
                                    layers.Dropout(0.3),
                           
                                    layers.GlobalAveragePooling1D(),
                                    layers.Dropout(0.2),
                                    layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer=opt, metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        print("Run: ",run,"/ Accuracy at epoch ",epoch," is: ", accuracy[0],"\n")
        epochs_accuracy.append(accuracy[0])

    print("Accuracies over epochs:",epochs_accuracy,"\n\n")
    runs_accuracy.append(max(epochs_accuracy))

  runs_accuracy.sort()
  print("\n\n Over all runs maximum accuracies on English are:", runs_accuracy)
  print("The median for English is:",runs_accuracy[2],"\n\n\n")
  
  if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
    max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
  else:
    max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
  final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
  model_results[key].append(final_result)
  print("ANN Accuracy Score on Test set -> ",model_results[key])
# Out:
# Streaming output truncated to the last 5000 lines.
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2637 - binary_accuracy: 0.8929 - val_loss: 1.1986 - val_binary_accuracy: 0.6583
# Run:  4 / Accuracy at epoch  13  is:  0.6582914590835571
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2133 - binary_accuracy: 0.9150 - val_loss: 1.5871 - val_binary_accuracy: 0.6432
# Run:  4 / Accuracy at epoch  14  is:  0.643216073513031
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2328 - binary_accuracy: 0.9137 - val_loss: 1.6088 - val_binary_accuracy: 0.6382
# Run:  4 / Accuracy at epoch  15  is:  0.6381909251213074
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1960 - binary_accuracy: 0.9282 - val_loss: 1.7542 - val_binary_accuracy: 0.6508
# Run:  4 / Accuracy at epoch  16  is:  0.6507537961006165
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.1839 - binary_accuracy: 0.9370 - val_loss: 2.4986 - val_binary_accuracy: 0.6080
# Run:  4 / Accuracy at epoch  17  is:  0.6080402135848999
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1771 - binary_accuracy: 0.9364 - val_loss: 2.8713 - val_binary_accuracy: 0.6156
# Run:  4 / Accuracy at epoch  18  is:  0.6155778765678406
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1678 - binary_accuracy: 0.9408 - val_loss: 2.5778 - val_binary_accuracy: 0.6055
# Run:  4 / Accuracy at epoch  19  is:  0.6055276393890381
#
# Accuracies over epochs: [0.5, 0.6306532621383667, 0.6683416962623596, 0.6859296560287476, 0.7035176157951355, 0.7160804271697998, 0.7261306643486023, 0.7236180901527405, 0.6909547448158264, 0.7035176157951355, 0.7236180901527405, 0.6683416962623596, 0.6356784105300903, 0.6582914590835571, 0.643216073513031, 0.6381909251213074, 0.6507537961006165, 0.6080402135848999, 0.6155778765678406, 0.6055276393890381]
#
#
# 1588/1588 [==============================] - 21s 12ms/step - loss: 0.7017 - binary_accuracy: 0.4987 - val_loss: 0.6940 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.6941 - binary_accuracy: 0.5460 - val_loss: 0.6525 - val_binary_accuracy: 0.6156
# Run:  5 / Accuracy at epoch  1  is:  0.6155778765678406
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.6725 - binary_accuracy: 0.6304 - val_loss: 0.6171 - val_binary_accuracy: 0.6583
# Run:  5 / Accuracy at epoch  2  is:  0.6582914590835571
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.6626 - binary_accuracy: 0.6562 - val_loss: 0.6144 - val_binary_accuracy: 0.6809
# Run:  5 / Accuracy at epoch  3  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.6300 - binary_accuracy: 0.6851 - val_loss: 0.6119 - val_binary_accuracy: 0.7060
# Run:  5 / Accuracy at epoch  4  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6005 - binary_accuracy: 0.7217 - val_loss: 0.6153 - val_binary_accuracy: 0.7161
# Run:  5 / Accuracy at epoch  5  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5614 - binary_accuracy: 0.7450 - val_loss: 0.6106 - val_binary_accuracy: 0.7261
# Run:  5 / Accuracy at epoch  6  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5302 - binary_accuracy: 0.7620 - val_loss: 0.6354 - val_binary_accuracy: 0.7312
# Run:  5 / Accuracy at epoch  7  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4948 - binary_accuracy: 0.7979 - val_loss: 0.6873 - val_binary_accuracy: 0.7161
# Run:  5 / Accuracy at epoch  8  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4414 - binary_accuracy: 0.8029 - val_loss: 0.6387 - val_binary_accuracy: 0.7362
# Run:  5 / Accuracy at epoch  9  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.3940 - binary_accuracy: 0.8445 - val_loss: 0.7056 - val_binary_accuracy: 0.7312
# Run:  5 / Accuracy at epoch  10  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3498 - binary_accuracy: 0.8627 - val_loss: 0.7758 - val_binary_accuracy: 0.7111
# Run:  5 / Accuracy at epoch  11  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2991 - binary_accuracy: 0.8778 - val_loss: 0.7584 - val_binary_accuracy: 0.7060
# Run:  5 / Accuracy at epoch  12  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2716 - binary_accuracy: 0.8974 - val_loss: 0.9228 - val_binary_accuracy: 0.7111
# Run:  5 / Accuracy at epoch  13  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2460 - binary_accuracy: 0.9024 - val_loss: 0.8973 - val_binary_accuracy: 0.7111
# Run:  5 / Accuracy at epoch  14  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2203 - binary_accuracy: 0.9219 - val_loss: 0.9716 - val_binary_accuracy: 0.7111
# Run:  5 / Accuracy at epoch  15  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2075 - binary_accuracy: 0.9263 - val_loss: 1.0785 - val_binary_accuracy: 0.7236
# Run:  5 / Accuracy at epoch  16  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.1830 - binary_accuracy: 0.9395 - val_loss: 1.1733 - val_binary_accuracy: 0.7111
# Run:  5 / Accuracy at epoch  17  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.1988 - binary_accuracy: 0.9307 - val_loss: 1.5924 - val_binary_accuracy: 0.6809
# Run:  5 / Accuracy at epoch  18  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1704 - binary_accuracy: 0.9427 - val_loss: 1.4222 - val_binary_accuracy: 0.7010
# Run:  5 / Accuracy at epoch  19  is:  0.7010050415992737
#
# Accuracies over epochs: [0.5, 0.6155778765678406, 0.6582914590835571, 0.6809045076370239, 0.7060301303863525, 0.7160804271697998, 0.7261306643486023, 0.7311557531356812, 0.7160804271697998, 0.7361809015274048, 0.7311557531356812, 0.7110552787780762, 0.7060301303863525, 0.7110552787780762, 0.7110552787780762, 0.7110552787780762, 0.7236180901527405, 0.7110552787780762, 0.6809045076370239, 0.7010050415992737]
#
#
#
#
#  Over all runs maximum accuracies on English are: [0.7261306643486023, 0.7261306643486023, 0.733668327331543, 0.7361809015274048, 0.7386934757232666]
# The median for English is: 0.733668327331543
#
#
#
# ANN Accuracy Score on Test set ->  ['0.733668327331543 +/- 0.007537662982940674']
#
#
# * * * * EVALUATION USING LOW AS PREPROCESSING FUNCTION * * * *
# Vocabulary size is: 11297
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.7022 - binary_accuracy: 0.5000 - val_loss: 0.6844 - val_binary_accuracy: 0.5628
# Run:  1 / Accuracy at epoch  0  is:  0.5628140568733215
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6870 - binary_accuracy: 0.5901 - val_loss: 0.6310 - val_binary_accuracy: 0.6382
# Run:  1 / Accuracy at epoch  1  is:  0.6381909251213074
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6585 - binary_accuracy: 0.6574 - val_loss: 0.6098 - val_binary_accuracy: 0.6734
# Run:  1 / Accuracy at epoch  2  is:  0.6733668446540833
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6407 - binary_accuracy: 0.6770 - val_loss: 0.6093 - val_binary_accuracy: 0.6910
# Run:  1 / Accuracy at epoch  3  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6200 - binary_accuracy: 0.7078 - val_loss: 0.6171 - val_binary_accuracy: 0.7035
# Run:  1 / Accuracy at epoch  4  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5847 - binary_accuracy: 0.7343 - val_loss: 0.6179 - val_binary_accuracy: 0.7186
# Run:  1 / Accuracy at epoch  5  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5516 - binary_accuracy: 0.7576 - val_loss: 0.6083 - val_binary_accuracy: 0.7286
# Run:  1 / Accuracy at epoch  6  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5137 - binary_accuracy: 0.7771 - val_loss: 0.7355 - val_binary_accuracy: 0.7085
# Run:  1 / Accuracy at epoch  7  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4866 - binary_accuracy: 0.8029 - val_loss: 0.6413 - val_binary_accuracy: 0.7337
# Run:  1 / Accuracy at epoch  8  is:  0.733668327331543
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4307 - binary_accuracy: 0.8249 - val_loss: 0.6757 - val_binary_accuracy: 0.7211
# Run:  1 / Accuracy at epoch  9  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3964 - binary_accuracy: 0.8419 - val_loss: 0.7369 - val_binary_accuracy: 0.7060
# Run:  1 / Accuracy at epoch  10  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3616 - binary_accuracy: 0.8652 - val_loss: 0.7433 - val_binary_accuracy: 0.7035
# Run:  1 / Accuracy at epoch  11  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3136 - binary_accuracy: 0.8741 - val_loss: 0.9015 - val_binary_accuracy: 0.6884
# Run:  1 / Accuracy at epoch  12  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2713 - binary_accuracy: 0.8967 - val_loss: 0.9408 - val_binary_accuracy: 0.6734
# Run:  1 / Accuracy at epoch  13  is:  0.6733668446540833
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2524 - binary_accuracy: 0.9049 - val_loss: 1.1150 - val_binary_accuracy: 0.6658
# Run:  1 / Accuracy at epoch  14  is:  0.6658291220664978
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2290 - binary_accuracy: 0.9175 - val_loss: 1.2328 - val_binary_accuracy: 0.6683
# Run:  1 / Accuracy at epoch  15  is:  0.6683416962623596
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2028 - binary_accuracy: 0.9213 - val_loss: 1.2582 - val_binary_accuracy: 0.6834
# Run:  1 / Accuracy at epoch  16  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1877 - binary_accuracy: 0.9389 - val_loss: 1.3103 - val_binary_accuracy: 0.7010
# Run:  1 / Accuracy at epoch  17  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2173 - binary_accuracy: 0.9364 - val_loss: 1.4492 - val_binary_accuracy: 0.6633
# Run:  1 / Accuracy at epoch  18  is:  0.6633166074752808
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1701 - binary_accuracy: 0.9351 - val_loss: 1.3760 - val_binary_accuracy: 0.7010
# Run:  1 / Accuracy at epoch  19  is:  0.7010050415992737
#
# Accuracies over epochs: [0.5628140568733215, 0.6381909251213074, 0.6733668446540833, 0.6909547448158264, 0.7035176157951355, 0.7185929417610168, 0.7286432385444641, 0.7085427045822144, 0.733668327331543, 0.7211055159568787, 0.7060301303863525, 0.7035176157951355, 0.6884422302246094, 0.6733668446540833, 0.6658291220664978, 0.6683416962623596, 0.6834170818328857, 0.7010050415992737, 0.6633166074752808, 0.7010050415992737]
#
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.7017 - binary_accuracy: 0.5000 - val_loss: 0.6936 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6889 - binary_accuracy: 0.5800 - val_loss: 0.6331 - val_binary_accuracy: 0.6407
# Run:  2 / Accuracy at epoch  1  is:  0.6407034993171692
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6626 - binary_accuracy: 0.6486 - val_loss: 0.6133 - val_binary_accuracy: 0.6709
# Run:  2 / Accuracy at epoch  2  is:  0.6708542704582214
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6408 - binary_accuracy: 0.6732 - val_loss: 0.6135 - val_binary_accuracy: 0.6960
# Run:  2 / Accuracy at epoch  3  is:  0.69597989320755
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6173 - binary_accuracy: 0.6971 - val_loss: 0.6126 - val_binary_accuracy: 0.6935
# Run:  2 / Accuracy at epoch  4  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5810 - binary_accuracy: 0.7311 - val_loss: 0.6220 - val_binary_accuracy: 0.7161
# Run:  2 / Accuracy at epoch  5  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5514 - binary_accuracy: 0.7456 - val_loss: 0.6243 - val_binary_accuracy: 0.7286
# Run:  2 / Accuracy at epoch  6  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5111 - binary_accuracy: 0.7752 - val_loss: 0.6483 - val_binary_accuracy: 0.7211
# Run:  2 / Accuracy at epoch  7  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4959 - binary_accuracy: 0.8067 - val_loss: 0.6293 - val_binary_accuracy: 0.7337
# Run:  2 / Accuracy at epoch  8  is:  0.733668327331543
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.4493 - binary_accuracy: 0.8035 - val_loss: 0.6793 - val_binary_accuracy: 0.7337
# Run:  2 / Accuracy at epoch  9  is:  0.733668327331543
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3901 - binary_accuracy: 0.8470 - val_loss: 0.7217 - val_binary_accuracy: 0.7136
# Run:  2 / Accuracy at epoch  10  is:  0.713567852973938
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.3533 - binary_accuracy: 0.8684 - val_loss: 0.7368 - val_binary_accuracy: 0.7035
# Run:  2 / Accuracy at epoch  11  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.3320 - binary_accuracy: 0.8747 - val_loss: 0.8363 - val_binary_accuracy: 0.7085
# Run:  2 / Accuracy at epoch  12  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2838 - binary_accuracy: 0.8904 - val_loss: 0.8100 - val_binary_accuracy: 0.7035
# Run:  2 / Accuracy at epoch  13  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2445 - binary_accuracy: 0.9099 - val_loss: 0.9274 - val_binary_accuracy: 0.7161
# Run:  2 / Accuracy at epoch  14  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2197 - binary_accuracy: 0.9181 - val_loss: 1.2470 - val_binary_accuracy: 0.6784
# Run:  2 / Accuracy at epoch  15  is:  0.6783919334411621
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2038 - binary_accuracy: 0.9282 - val_loss: 1.3871 - val_binary_accuracy: 0.6709
# Run:  2 / Accuracy at epoch  16  is:  0.6708542704582214
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2150 - binary_accuracy: 0.9232 - val_loss: 1.2508 - val_binary_accuracy: 0.6960
# Run:  2 / Accuracy at epoch  17  is:  0.69597989320755
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1940 - binary_accuracy: 0.9320 - val_loss: 1.2764 - val_binary_accuracy: 0.7136
# Run:  2 / Accuracy at epoch  18  is:  0.713567852973938
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2020 - binary_accuracy: 0.9314 - val_loss: 1.3234 - val_binary_accuracy: 0.6884
# Run:  2 / Accuracy at epoch  19  is:  0.6884422302246094
#
# Accuracies over epochs: [0.5, 0.6407034993171692, 0.6708542704582214, 0.69597989320755, 0.6934673190116882, 0.7160804271697998, 0.7286432385444641, 0.7211055159568787, 0.733668327331543, 0.733668327331543, 0.713567852973938, 0.7035176157951355, 0.7085427045822144, 0.7035176157951355, 0.7160804271697998, 0.6783919334411621, 0.6708542704582214, 0.69597989320755, 0.713567852973938, 0.6884422302246094]
#
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.7028 - binary_accuracy: 0.4975 - val_loss: 0.6925 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6887 - binary_accuracy: 0.5680 - val_loss: 0.6367 - val_binary_accuracy: 0.6382
# Run:  3 / Accuracy at epoch  1  is:  0.6381909251213074
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.6652 - binary_accuracy: 0.6423 - val_loss: 0.6165 - val_binary_accuracy: 0.6633
# Run:  3 / Accuracy at epoch  2  is:  0.6633166074752808
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6561 - binary_accuracy: 0.6593 - val_loss: 0.6087 - val_binary_accuracy: 0.6884
# Run:  3 / Accuracy at epoch  3  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6371 - binary_accuracy: 0.6776 - val_loss: 0.6198 - val_binary_accuracy: 0.6935
# Run:  3 / Accuracy at epoch  4  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5993 - binary_accuracy: 0.7147 - val_loss: 0.6246 - val_binary_accuracy: 0.7111
# Run:  3 / Accuracy at epoch  5  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5739 - binary_accuracy: 0.7380 - val_loss: 0.6065 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  6  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5421 - binary_accuracy: 0.7632 - val_loss: 0.6529 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  7  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5025 - binary_accuracy: 0.7859 - val_loss: 0.6348 - val_binary_accuracy: 0.7312
# Run:  3 / Accuracy at epoch  8  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.4600 - binary_accuracy: 0.8035 - val_loss: 0.6955 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  9  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4054 - binary_accuracy: 0.8268 - val_loss: 0.7503 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  10  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3582 - binary_accuracy: 0.8558 - val_loss: 1.0193 - val_binary_accuracy: 0.6734
# Run:  3 / Accuracy at epoch  11  is:  0.6733668446540833
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.3268 - binary_accuracy: 0.8829 - val_loss: 0.8942 - val_binary_accuracy: 0.6935
# Run:  3 / Accuracy at epoch  12  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.3051 - binary_accuracy: 0.8766 - val_loss: 0.8931 - val_binary_accuracy: 0.6960
# Run:  3 / Accuracy at epoch  13  is:  0.69597989320755
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2585 - binary_accuracy: 0.9037 - val_loss: 1.0069 - val_binary_accuracy: 0.7085
# Run:  3 / Accuracy at epoch  14  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2522 - binary_accuracy: 0.9049 - val_loss: 1.0826 - val_binary_accuracy: 0.6985
# Run:  3 / Accuracy at epoch  15  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2228 - binary_accuracy: 0.9144 - val_loss: 1.1724 - val_binary_accuracy: 0.6834
# Run:  3 / Accuracy at epoch  16  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2123 - binary_accuracy: 0.9194 - val_loss: 1.1730 - val_binary_accuracy: 0.7060
# Run:  3 / Accuracy at epoch  17  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2327 - binary_accuracy: 0.9257 - val_loss: 1.1559 - val_binary_accuracy: 0.7035
# Run:  3 / Accuracy at epoch  18  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.1964 - binary_accuracy: 0.9320 - val_loss: 1.3730 - val_binary_accuracy: 0.6834
# Run:  3 / Accuracy at epoch  19  is:  0.6834170818328857
#
# Accuracies over epochs: [0.5, 0.6381909251213074, 0.6633166074752808, 0.6884422302246094, 0.6934673190116882, 0.7110552787780762, 0.7185929417610168, 0.7185929417610168, 0.7311557531356812, 0.7185929417610168, 0.7185929417610168, 0.6733668446540833, 0.6934673190116882, 0.69597989320755, 0.7085427045822144, 0.6984924674034119, 0.6834170818328857, 0.7060301303863525, 0.7035176157951355, 0.6834170818328857]
#
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.7027 - binary_accuracy: 0.5063 - val_loss: 0.6938 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.6907 - binary_accuracy: 0.5611 - val_loss: 0.6431 - val_binary_accuracy: 0.6181
# Run:  4 / Accuracy at epoch  1  is:  0.6180904507637024
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.6678 - binary_accuracy: 0.6335 - val_loss: 0.6209 - val_binary_accuracy: 0.6508
# Run:  4 / Accuracy at epoch  2  is:  0.6507537961006165
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.6568 - binary_accuracy: 0.6492 - val_loss: 0.6093 - val_binary_accuracy: 0.6709
# Run:  4 / Accuracy at epoch  3  is:  0.6708542704582214
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.6425 - binary_accuracy: 0.6725 - val_loss: 0.6115 - val_binary_accuracy: 0.6884
# Run:  4 / Accuracy at epoch  4  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5976 - binary_accuracy: 0.7116 - val_loss: 0.6210 - val_binary_accuracy: 0.7010
# Run:  4 / Accuracy at epoch  5  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5785 - binary_accuracy: 0.7261 - val_loss: 0.6295 - val_binary_accuracy: 0.7286
# Run:  4 / Accuracy at epoch  6  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5478 - binary_accuracy: 0.7626 - val_loss: 0.6247 - val_binary_accuracy: 0.7136
# Run:  4 / Accuracy at epoch  7  is:  0.713567852973938
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5171 - binary_accuracy: 0.7853 - val_loss: 0.6306 - val_binary_accuracy: 0.7286
# Run:  4 / Accuracy at epoch  8  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.4910 - binary_accuracy: 0.7966 - val_loss: 0.6348 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  9  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.4367 - binary_accuracy: 0.8224 - val_loss: 0.6808 - val_binary_accuracy: 0.7060
# Run:  4 / Accuracy at epoch  10  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3713 - binary_accuracy: 0.8526 - val_loss: 0.8254 - val_binary_accuracy: 0.6784
# Run:  4 / Accuracy at epoch  11  is:  0.6783919334411621
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.3203 - binary_accuracy: 0.8785 - val_loss: 0.8856 - val_binary_accuracy: 0.7060
# Run:  4 / Accuracy at epoch  12  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.3023 - binary_accuracy: 0.8854 - val_loss: 0.9917 - val_binary_accuracy: 0.7010
# Run:  4 / Accuracy at epoch  13  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2860 - binary_accuracy: 0.9011 - val_loss: 1.4996 - val_binary_accuracy: 0.6382
# Run:  4 / Accuracy at epoch  14  is:  0.6381909251213074
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2504 - binary_accuracy: 0.9112 - val_loss: 1.0525 - val_binary_accuracy: 0.7060
# Run:  4 / Accuracy at epoch  15  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2307 - binary_accuracy: 0.9156 - val_loss: 1.2733 - val_binary_accuracy: 0.6784
# Run:  4 / Accuracy at epoch  16  is:  0.6783919334411621
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2142 - binary_accuracy: 0.9244 - val_loss: 1.2385 - val_binary_accuracy: 0.6985
# Run:  4 / Accuracy at epoch  17  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2167 - binary_accuracy: 0.9175 - val_loss: 1.3702 - val_binary_accuracy: 0.6834
# Run:  4 / Accuracy at epoch  18  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.1970 - binary_accuracy: 0.9244 - val_loss: 1.9429 - val_binary_accuracy: 0.6407
# Run:  4 / Accuracy at epoch  19  is:  0.6407034993171692
#
# Accuracies over epochs: [0.5, 0.6180904507637024, 0.6507537961006165, 0.6708542704582214, 0.6884422302246094, 0.7010050415992737, 0.7286432385444641, 0.713567852973938, 0.7286432385444641, 0.7211055159568787, 0.7060301303863525, 0.6783919334411621, 0.7060301303863525, 0.7010050415992737, 0.6381909251213074, 0.7060301303863525, 0.6783919334411621, 0.6984924674034119, 0.6834170818328857, 0.6407034993171692]
#
#
# 1588/1588 [==============================] - 21s 12ms/step - loss: 0.7012 - binary_accuracy: 0.4987 - val_loss: 0.6944 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6956 - binary_accuracy: 0.5453 - val_loss: 0.6514 - val_binary_accuracy: 0.6080
# Run:  5 / Accuracy at epoch  1  is:  0.6080402135848999
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.6695 - binary_accuracy: 0.6329 - val_loss: 0.6226 - val_binary_accuracy: 0.6608
# Run:  5 / Accuracy at epoch  2  is:  0.660804033279419
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.6474 - binary_accuracy: 0.6625 - val_loss: 0.6101 - val_binary_accuracy: 0.6784
# Run:  5 / Accuracy at epoch  3  is:  0.6783919334411621
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6238 - binary_accuracy: 0.6965 - val_loss: 0.6226 - val_binary_accuracy: 0.6910
# Run:  5 / Accuracy at epoch  4  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.5720 - binary_accuracy: 0.7387 - val_loss: 0.6472 - val_binary_accuracy: 0.7010
# Run:  5 / Accuracy at epoch  5  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5569 - binary_accuracy: 0.7550 - val_loss: 0.6225 - val_binary_accuracy: 0.7312
# Run:  5 / Accuracy at epoch  6  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5174 - binary_accuracy: 0.7764 - val_loss: 0.6343 - val_binary_accuracy: 0.7261
# Run:  5 / Accuracy at epoch  7  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4897 - binary_accuracy: 0.7903 - val_loss: 0.6648 - val_binary_accuracy: 0.7136
# Run:  5 / Accuracy at epoch  8  is:  0.713567852973938
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.4573 - binary_accuracy: 0.8117 - val_loss: 0.6566 - val_binary_accuracy: 0.7261
# Run:  5 / Accuracy at epoch  9  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3917 - binary_accuracy: 0.8476 - val_loss: 0.7316 - val_binary_accuracy: 0.7060
# Run:  5 / Accuracy at epoch  10  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3509 - binary_accuracy: 0.8646 - val_loss: 0.7424 - val_binary_accuracy: 0.6985
# Run:  5 / Accuracy at epoch  11  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3016 - binary_accuracy: 0.8709 - val_loss: 0.8949 - val_binary_accuracy: 0.7035
# Run:  5 / Accuracy at epoch  12  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2642 - binary_accuracy: 0.9018 - val_loss: 1.2380 - val_binary_accuracy: 0.6709
# Run:  5 / Accuracy at epoch  13  is:  0.6708542704582214
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2629 - binary_accuracy: 0.9062 - val_loss: 1.1012 - val_binary_accuracy: 0.7060
# Run:  5 / Accuracy at epoch  14  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2410 - binary_accuracy: 0.9068 - val_loss: 1.0531 - val_binary_accuracy: 0.6734
# Run:  5 / Accuracy at epoch  15  is:  0.6733668446540833
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2251 - binary_accuracy: 0.9106 - val_loss: 1.2333 - val_binary_accuracy: 0.7085
# Run:  5 / Accuracy at epoch  16  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.1910 - binary_accuracy: 0.9320 - val_loss: 1.5206 - val_binary_accuracy: 0.6859
# Run:  5 / Accuracy at epoch  17  is:  0.6859296560287476
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1853 - binary_accuracy: 0.9345 - val_loss: 2.2701 - val_binary_accuracy: 0.6407
# Run:  5 / Accuracy at epoch  18  is:  0.6407034993171692
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1874 - binary_accuracy: 0.9358 - val_loss: 2.2235 - val_binary_accuracy: 0.6482
# Run:  5 / Accuracy at epoch  19  is:  0.6482412219047546
#
# Accuracies over epochs: [0.5, 0.6080402135848999, 0.660804033279419, 0.6783919334411621, 0.6909547448158264, 0.7010050415992737, 0.7311557531356812, 0.7261306643486023, 0.713567852973938, 0.7261306643486023, 0.7060301303863525, 0.6984924674034119, 0.7035176157951355, 0.6708542704582214, 0.7060301303863525, 0.6733668446540833, 0.7085427045822144, 0.6859296560287476, 0.6407034993171692, 0.6482412219047546]
#
#
#
#
#  Over all runs maximum accuracies on English are: [0.7286432385444641, 0.7311557531356812, 0.7311557531356812, 0.733668327331543, 0.733668327331543]
# The median for English is: 0.7311557531356812
#
#
#
# ANN Accuracy Score on Test set ->  ['0.7311557531356812 +/- 0.0025125741958618164']
#
#
# * * * * EVALUATION USING RSW AS PREPROCESSING FUNCTION * * * *
# Vocabulary size is: 12384
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.7018 - binary_accuracy: 0.4969 - val_loss: 0.6910 - val_binary_accuracy: 0.5050
# Run:  1 / Accuracy at epoch  0  is:  0.5050251483917236
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.6849 - binary_accuracy: 0.5919 - val_loss: 0.6263 - val_binary_accuracy: 0.6533
# Run:  1 / Accuracy at epoch  1  is:  0.6532663106918335
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.6551 - binary_accuracy: 0.6398 - val_loss: 0.6015 - val_binary_accuracy: 0.6734
# Run:  1 / Accuracy at epoch  2  is:  0.6733668446540833
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.6291 - binary_accuracy: 0.6820 - val_loss: 0.6057 - val_binary_accuracy: 0.7111
# Run:  1 / Accuracy at epoch  3  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.5898 - binary_accuracy: 0.7103 - val_loss: 0.6144 - val_binary_accuracy: 0.7362
# Run:  1 / Accuracy at epoch  4  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.5710 - binary_accuracy: 0.7380 - val_loss: 0.5926 - val_binary_accuracy: 0.7362
# Run:  1 / Accuracy at epoch  5  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.5172 - binary_accuracy: 0.7664 - val_loss: 0.6154 - val_binary_accuracy: 0.7286
# Run:  1 / Accuracy at epoch  6  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.4901 - binary_accuracy: 0.7991 - val_loss: 0.6330 - val_binary_accuracy: 0.7362
# Run:  1 / Accuracy at epoch  7  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.4511 - binary_accuracy: 0.8199 - val_loss: 0.6404 - val_binary_accuracy: 0.7312
# Run:  1 / Accuracy at epoch  8  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.3994 - binary_accuracy: 0.8356 - val_loss: 0.6849 - val_binary_accuracy: 0.7312
# Run:  1 / Accuracy at epoch  9  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.3304 - binary_accuracy: 0.8634 - val_loss: 0.7968 - val_binary_accuracy: 0.7211
# Run:  1 / Accuracy at epoch  10  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.3030 - binary_accuracy: 0.8804 - val_loss: 0.7931 - val_binary_accuracy: 0.7111
# Run:  1 / Accuracy at epoch  11  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.2710 - binary_accuracy: 0.8980 - val_loss: 0.8860 - val_binary_accuracy: 0.7010
# Run:  1 / Accuracy at epoch  12  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.2276 - binary_accuracy: 0.9055 - val_loss: 1.0451 - val_binary_accuracy: 0.6985
# Run:  1 / Accuracy at epoch  13  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 22s 14ms/step - loss: 0.2403 - binary_accuracy: 0.9144 - val_loss: 1.3375 - val_binary_accuracy: 0.6884
# Run:  1 / Accuracy at epoch  14  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 22s 14ms/step - loss: 0.2120 - binary_accuracy: 0.9295 - val_loss: 1.2964 - val_binary_accuracy: 0.6884
# Run:  1 / Accuracy at epoch  15  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.1877 - binary_accuracy: 0.9276 - val_loss: 1.6166 - val_binary_accuracy: 0.6809
# Run:  1 / Accuracy at epoch  16  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.1717 - binary_accuracy: 0.9377 - val_loss: 1.3810 - val_binary_accuracy: 0.6935
# Run:  1 / Accuracy at epoch  17  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.1612 - binary_accuracy: 0.9452 - val_loss: 1.4661 - val_binary_accuracy: 0.7060
# Run:  1 / Accuracy at epoch  18  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.1695 - binary_accuracy: 0.9452 - val_loss: 1.4186 - val_binary_accuracy: 0.7111
# Run:  1 / Accuracy at epoch  19  is:  0.7110552787780762
#
# Accuracies over epochs: [0.5050251483917236, 0.6532663106918335, 0.6733668446540833, 0.7110552787780762, 0.7361809015274048, 0.7361809015274048, 0.7286432385444641, 0.7361809015274048, 0.7311557531356812, 0.7311557531356812, 0.7211055159568787, 0.7110552787780762, 0.7010050415992737, 0.6984924674034119, 0.6884422302246094, 0.6884422302246094, 0.6809045076370239, 0.6934673190116882, 0.7060301303863525, 0.7110552787780762]
#
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.7027 - binary_accuracy: 0.5000 - val_loss: 0.6922 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.6932 - binary_accuracy: 0.5529 - val_loss: 0.6434 - val_binary_accuracy: 0.6181
# Run:  2 / Accuracy at epoch  1  is:  0.6180904507637024
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.6630 - binary_accuracy: 0.6348 - val_loss: 0.6166 - val_binary_accuracy: 0.6583
# Run:  2 / Accuracy at epoch  2  is:  0.6582914590835571
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.6374 - binary_accuracy: 0.6700 - val_loss: 0.6158 - val_binary_accuracy: 0.7035
# Run:  2 / Accuracy at epoch  3  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.5991 - binary_accuracy: 0.7084 - val_loss: 0.6329 - val_binary_accuracy: 0.6834
# Run:  2 / Accuracy at epoch  4  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.5627 - binary_accuracy: 0.7286 - val_loss: 0.6203 - val_binary_accuracy: 0.7136
# Run:  2 / Accuracy at epoch  5  is:  0.713567852973938
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.5265 - binary_accuracy: 0.7683 - val_loss: 0.6822 - val_binary_accuracy: 0.6985
# Run:  2 / Accuracy at epoch  6  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.4932 - binary_accuracy: 0.7846 - val_loss: 0.6468 - val_binary_accuracy: 0.7412
# Run:  2 / Accuracy at epoch  7  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.4383 - binary_accuracy: 0.8073 - val_loss: 0.6731 - val_binary_accuracy: 0.7362
# Run:  2 / Accuracy at epoch  8  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.4139 - binary_accuracy: 0.8268 - val_loss: 0.7825 - val_binary_accuracy: 0.7136
# Run:  2 / Accuracy at epoch  9  is:  0.713567852973938
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.3418 - binary_accuracy: 0.8665 - val_loss: 0.7573 - val_binary_accuracy: 0.7312
# Run:  2 / Accuracy at epoch  10  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.2959 - binary_accuracy: 0.8860 - val_loss: 0.8866 - val_binary_accuracy: 0.7161
# Run:  2 / Accuracy at epoch  11  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 46s 28ms/step - loss: 0.2908 - binary_accuracy: 0.8848 - val_loss: 0.8689 - val_binary_accuracy: 0.7085
# Run:  2 / Accuracy at epoch  12  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 58s 36ms/step - loss: 0.2499 - binary_accuracy: 0.9037 - val_loss: 0.9437 - val_binary_accuracy: 0.7060
# Run:  2 / Accuracy at epoch  13  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 19s 11ms/step - loss: 0.2175 - binary_accuracy: 0.9219 - val_loss: 1.0915 - val_binary_accuracy: 0.7085
# Run:  2 / Accuracy at epoch  14  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.2140 - binary_accuracy: 0.9389 - val_loss: 1.4072 - val_binary_accuracy: 0.7060
# Run:  2 / Accuracy at epoch  15  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.2087 - binary_accuracy: 0.9314 - val_loss: 1.5338 - val_binary_accuracy: 0.6910
# Run:  2 / Accuracy at epoch  16  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1797 - binary_accuracy: 0.9414 - val_loss: 1.4784 - val_binary_accuracy: 0.6935
# Run:  2 / Accuracy at epoch  17  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 19s 11ms/step - loss: 0.1902 - binary_accuracy: 0.9446 - val_loss: 2.0050 - val_binary_accuracy: 0.6683
# Run:  2 / Accuracy at epoch  18  is:  0.6683416962623596
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.1836 - binary_accuracy: 0.9440 - val_loss: 2.1730 - val_binary_accuracy: 0.6482
# Run:  2 / Accuracy at epoch  19  is:  0.6482412219047546
#
# Accuracies over epochs: [0.5, 0.6180904507637024, 0.6582914590835571, 0.7035176157951355, 0.6834170818328857, 0.713567852973938, 0.6984924674034119, 0.7412060499191284, 0.7361809015274048, 0.713567852973938, 0.7311557531356812, 0.7160804271697998, 0.7085427045822144, 0.7060301303863525, 0.7085427045822144, 0.7060301303863525, 0.6909547448158264, 0.6934673190116882, 0.6683416962623596, 0.6482412219047546]
#
#
# 1588/1588 [==============================] - 23s 14ms/step - loss: 0.7015 - binary_accuracy: 0.4874 - val_loss: 0.6911 - val_binary_accuracy: 0.5075
# Run:  3 / Accuracy at epoch  0  is:  0.5075376629829407
#
# 1588/1588 [==============================] - 22s 14ms/step - loss: 0.6866 - binary_accuracy: 0.5882 - val_loss: 0.6343 - val_binary_accuracy: 0.6432
# Run:  3 / Accuracy at epoch  1  is:  0.643216073513031
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.6619 - binary_accuracy: 0.6511 - val_loss: 0.6140 - val_binary_accuracy: 0.6608
# Run:  3 / Accuracy at epoch  2  is:  0.660804033279419
#
# 1588/1588 [==============================] - 22s 14ms/step - loss: 0.6346 - binary_accuracy: 0.6839 - val_loss: 0.6246 - val_binary_accuracy: 0.7035
# Run:  3 / Accuracy at epoch  3  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 22s 14ms/step - loss: 0.6081 - binary_accuracy: 0.7135 - val_loss: 0.6284 - val_binary_accuracy: 0.7060
# Run:  3 / Accuracy at epoch  4  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 22s 14ms/step - loss: 0.5806 - binary_accuracy: 0.7198 - val_loss: 0.6171 - val_binary_accuracy: 0.7085
# Run:  3 / Accuracy at epoch  5  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5317 - binary_accuracy: 0.7601 - val_loss: 0.6387 - val_binary_accuracy: 0.7387
# Run:  3 / Accuracy at epoch  6  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 22s 13ms/step - loss: 0.5162 - binary_accuracy: 0.7802 - val_loss: 0.6561 - val_binary_accuracy: 0.7286
# Run:  3 / Accuracy at epoch  7  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 22s 14ms/step - loss: 0.4808 - binary_accuracy: 0.8048 - val_loss: 0.6521 - val_binary_accuracy: 0.7362
# Run:  3 / Accuracy at epoch  8  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 26s 16ms/step - loss: 0.4166 - binary_accuracy: 0.8306 - val_loss: 0.7385 - val_binary_accuracy: 0.7236
# Run:  3 / Accuracy at epoch  9  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.3560 - binary_accuracy: 0.8526 - val_loss: 0.8406 - val_binary_accuracy: 0.7211
# Run:  3 / Accuracy at epoch  10  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.3149 - binary_accuracy: 0.8741 - val_loss: 0.9316 - val_binary_accuracy: 0.6985
# Run:  3 / Accuracy at epoch  11  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2769 - binary_accuracy: 0.9005 - val_loss: 1.1634 - val_binary_accuracy: 0.6734
# Run:  3 / Accuracy at epoch  12  is:  0.6733668446540833
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2563 - binary_accuracy: 0.9068 - val_loss: 1.2638 - val_binary_accuracy: 0.6834
# Run:  3 / Accuracy at epoch  13  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.2212 - binary_accuracy: 0.9219 - val_loss: 1.4704 - val_binary_accuracy: 0.6533
# Run:  3 / Accuracy at epoch  14  is:  0.6532663106918335
#
# 1588/1588 [==============================] - 22s 14ms/step - loss: 0.2062 - binary_accuracy: 0.9301 - val_loss: 1.7725 - val_binary_accuracy: 0.6407
# Run:  3 / Accuracy at epoch  15  is:  0.6407034993171692
#
# 1588/1588 [==============================] - 18s 11ms/step - loss: 0.1858 - binary_accuracy: 0.9326 - val_loss: 1.5838 - val_binary_accuracy: 0.6683
# Run:  3 / Accuracy at epoch  16  is:  0.6683416962623596
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.1863 - binary_accuracy: 0.9440 - val_loss: 1.9949 - val_binary_accuracy: 0.6533
# Run:  3 / Accuracy at epoch  17  is:  0.6532663106918335
#
# 1588/1588 [==============================] - 22s 14ms/step - loss: 0.1791 - binary_accuracy: 0.9383 - val_loss: 2.0349 - val_binary_accuracy: 0.6432
# Run:  3 / Accuracy at epoch  18  is:  0.643216073513031
#
# 1588/1588 [==============================] - 23s 14ms/step - loss: 0.1601 - binary_accuracy: 0.9528 - val_loss: 2.1756 - val_binary_accuracy: 0.6633
# Run:  3 / Accuracy at epoch  19  is:  0.6633166074752808
#
# Accuracies over epochs: [0.5075376629829407, 0.643216073513031, 0.660804033279419, 0.7035176157951355, 0.7060301303863525, 0.7085427045822144, 0.7386934757232666, 0.7286432385444641, 0.7361809015274048, 0.7236180901527405, 0.7211055159568787, 0.6984924674034119, 0.6733668446540833, 0.6834170818328857, 0.6532663106918335, 0.6407034993171692, 0.6683416962623596, 0.6532663106918335, 0.643216073513031, 0.6633166074752808]
#
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.7009 - binary_accuracy: 0.4899 - val_loss: 0.6942 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.6907 - binary_accuracy: 0.5466 - val_loss: 0.6436 - val_binary_accuracy: 0.6307
# Run:  4 / Accuracy at epoch  1  is:  0.6306532621383667
#
# 1588/1588 [==============================] - 18s 11ms/step - loss: 0.6654 - binary_accuracy: 0.6278 - val_loss: 0.6122 - val_binary_accuracy: 0.6558
# Run:  4 / Accuracy at epoch  2  is:  0.6557788848876953
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.6417 - binary_accuracy: 0.6662 - val_loss: 0.6074 - val_binary_accuracy: 0.6784
# Run:  4 / Accuracy at epoch  3  is:  0.6783919334411621
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.6107 - binary_accuracy: 0.7091 - val_loss: 0.5995 - val_binary_accuracy: 0.7035
# Run:  4 / Accuracy at epoch  4  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5782 - binary_accuracy: 0.7330 - val_loss: 0.5873 - val_binary_accuracy: 0.7261
# Run:  4 / Accuracy at epoch  5  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 22s 14ms/step - loss: 0.5214 - binary_accuracy: 0.7651 - val_loss: 0.6268 - val_binary_accuracy: 0.7286
# Run:  4 / Accuracy at epoch  6  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.5052 - binary_accuracy: 0.7821 - val_loss: 0.6125 - val_binary_accuracy: 0.7261
# Run:  4 / Accuracy at epoch  7  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 23s 14ms/step - loss: 0.4682 - binary_accuracy: 0.8067 - val_loss: 0.6684 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  8  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.4164 - binary_accuracy: 0.8268 - val_loss: 0.6842 - val_binary_accuracy: 0.7312
# Run:  4 / Accuracy at epoch  9  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.3512 - binary_accuracy: 0.8621 - val_loss: 0.7229 - val_binary_accuracy: 0.7286
# Run:  4 / Accuracy at epoch  10  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 18s 11ms/step - loss: 0.3242 - binary_accuracy: 0.8665 - val_loss: 0.7856 - val_binary_accuracy: 0.7111
# Run:  4 / Accuracy at epoch  11  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 20s 13ms/step - loss: 0.2785 - binary_accuracy: 0.8898 - val_loss: 0.8080 - val_binary_accuracy: 0.7085
# Run:  4 / Accuracy at epoch  12  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 22s 14ms/step - loss: 0.2469 - binary_accuracy: 0.9011 - val_loss: 0.8787 - val_binary_accuracy: 0.7161
# Run:  4 / Accuracy at epoch  13  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 30s 19ms/step - loss: 0.2430 - binary_accuracy: 0.9118 - val_loss: 1.0122 - val_binary_accuracy: 0.6935
# Run:  4 / Accuracy at epoch  14  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2085 - binary_accuracy: 0.9232 - val_loss: 1.5937 - val_binary_accuracy: 0.6482
# Run:  4 / Accuracy at epoch  15  is:  0.6482412219047546
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.1699 - binary_accuracy: 0.9421 - val_loss: 1.3739 - val_binary_accuracy: 0.6960
# Run:  4 / Accuracy at epoch  16  is:  0.69597989320755
#
# 1588/1588 [==============================] - 21s 13ms/step - loss: 0.1775 - binary_accuracy: 0.9345 - val_loss: 1.4567 - val_binary_accuracy: 0.6884
# Run:  4 / Accuracy at epoch  17  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 27s 17ms/step - loss: 0.1931 - binary_accuracy: 0.9503 - val_loss: 1.8696 - val_binary_accuracy: 0.6533
# Run:  4 / Accuracy at epoch  18  is:  0.6532663106918335
#
# 1588/1588 [==============================] - 19s 12ms/step - loss: 0.1697 - binary_accuracy: 0.9465 - val_loss: 2.2950 - val_binary_accuracy: 0.6332
# Run:  4 / Accuracy at epoch  19  is:  0.6331658363342285
#
# ...
# Run:  2 / Accuracy at epoch  12  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3023 - binary_accuracy: 0.8885 - val_loss: 0.8809 - val_binary_accuracy: 0.6834
# Run:  2 / Accuracy at epoch  13  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2538 - binary_accuracy: 0.9068 - val_loss: 1.1593 - val_binary_accuracy: 0.6608
# Run:  2 / Accuracy at epoch  14  is:  0.660804033279419
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2395 - binary_accuracy: 0.9144 - val_loss: 1.1181 - val_binary_accuracy: 0.6809
# Run:  2 / Accuracy at epoch  15  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2186 - binary_accuracy: 0.9225 - val_loss: 1.1743 - val_binary_accuracy: 0.6834
# Run:  2 / Accuracy at epoch  16  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1967 - binary_accuracy: 0.9370 - val_loss: 1.4655 - val_binary_accuracy: 0.6683
# Run:  2 / Accuracy at epoch  17  is:  0.6683416962623596
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2115 - binary_accuracy: 0.9320 - val_loss: 1.3676 - val_binary_accuracy: 0.6910
# Run:  2 / Accuracy at epoch  18  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1706 - binary_accuracy: 0.9446 - val_loss: 1.3562 - val_binary_accuracy: 0.6809
# Run:  2 / Accuracy at epoch  19  is:  0.6809045076370239
#
# Accuracies over epochs: [0.5, 0.6507537961006165, 0.660804033279419, 0.6909547448158264, 0.7010050415992737, 0.7085427045822144, 0.7236180901527405, 0.7361809015274048, 0.733668327331543, 0.7185929417610168, 0.7160804271697998, 0.6884422302246094, 0.6834170818328857, 0.6834170818328857, 0.660804033279419, 0.6809045076370239, 0.6834170818328857, 0.6683416962623596, 0.6909547448158264, 0.6809045076370239]
#
#
# 1588/1588 [==============================] - 21s 12ms/step - loss: 0.7009 - binary_accuracy: 0.4924 - val_loss: 0.6937 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6914 - binary_accuracy: 0.5686 - val_loss: 0.6451 - val_binary_accuracy: 0.6181
# Run:  3 / Accuracy at epoch  1  is:  0.6180904507637024
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6671 - binary_accuracy: 0.6316 - val_loss: 0.6146 - val_binary_accuracy: 0.6633
# Run:  3 / Accuracy at epoch  2  is:  0.6633166074752808
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6361 - binary_accuracy: 0.6902 - val_loss: 0.6161 - val_binary_accuracy: 0.6985
# Run:  3 / Accuracy at epoch  3  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6171 - binary_accuracy: 0.7059 - val_loss: 0.6282 - val_binary_accuracy: 0.6910
# Run:  3 / Accuracy at epoch  4  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5743 - binary_accuracy: 0.7336 - val_loss: 0.6117 - val_binary_accuracy: 0.7211
# Run:  3 / Accuracy at epoch  5  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5363 - binary_accuracy: 0.7626 - val_loss: 0.6746 - val_binary_accuracy: 0.7111
# Run:  3 / Accuracy at epoch  6  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5117 - binary_accuracy: 0.7865 - val_loss: 0.6952 - val_binary_accuracy: 0.7035
# Run:  3 / Accuracy at epoch  7  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4763 - binary_accuracy: 0.8035 - val_loss: 0.8026 - val_binary_accuracy: 0.6884
# Run:  3 / Accuracy at epoch  8  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4398 - binary_accuracy: 0.8230 - val_loss: 0.8549 - val_binary_accuracy: 0.6834
# Run:  3 / Accuracy at epoch  9  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3622 - binary_accuracy: 0.8438 - val_loss: 0.7621 - val_binary_accuracy: 0.7060
# Run:  3 / Accuracy at epoch  10  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3148 - binary_accuracy: 0.8728 - val_loss: 1.0032 - val_binary_accuracy: 0.6859
# Run:  3 / Accuracy at epoch  11  is:  0.6859296560287476
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2924 - binary_accuracy: 0.8810 - val_loss: 1.0963 - val_binary_accuracy: 0.6809
# Run:  3 / Accuracy at epoch  12  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2649 - binary_accuracy: 0.9018 - val_loss: 1.4552 - val_binary_accuracy: 0.6533
# Run:  3 / Accuracy at epoch  13  is:  0.6532663106918335
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2512 - binary_accuracy: 0.9055 - val_loss: 1.2449 - val_binary_accuracy: 0.6834
# Run:  3 / Accuracy at epoch  14  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2316 - binary_accuracy: 0.9144 - val_loss: 1.5766 - val_binary_accuracy: 0.6809
# Run:  3 / Accuracy at epoch  15  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2126 - binary_accuracy: 0.9207 - val_loss: 1.9213 - val_binary_accuracy: 0.6382
# Run:  3 / Accuracy at epoch  16  is:  0.6381909251213074
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2112 - binary_accuracy: 0.9295 - val_loss: 1.6925 - val_binary_accuracy: 0.6884
# Run:  3 / Accuracy at epoch  17  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1911 - binary_accuracy: 0.9364 - val_loss: 2.2988 - val_binary_accuracy: 0.6382
# Run:  3 / Accuracy at epoch  18  is:  0.6381909251213074
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2004 - binary_accuracy: 0.9370 - val_loss: 1.5306 - val_binary_accuracy: 0.6784
# Run:  3 / Accuracy at epoch  19  is:  0.6783919334411621
#
# Accuracies over epochs: [0.5, 0.6180904507637024, 0.6633166074752808, 0.6984924674034119, 0.6909547448158264, 0.7211055159568787, 0.7110552787780762, 0.7035176157951355, 0.6884422302246094, 0.6834170818328857, 0.7060301303863525, 0.6859296560287476, 0.6809045076370239, 0.6532663106918335, 0.6834170818328857, 0.6809045076370239, 0.6381909251213074, 0.6884422302246094, 0.6381909251213074, 0.6783919334411621]
#
#
# 1588/1588 [==============================] - 21s 12ms/step - loss: 0.7009 - binary_accuracy: 0.5031 - val_loss: 0.6941 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6910 - binary_accuracy: 0.5516 - val_loss: 0.6411 - val_binary_accuracy: 0.6281
# Run:  4 / Accuracy at epoch  1  is:  0.6281406879425049
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6670 - binary_accuracy: 0.6379 - val_loss: 0.6122 - val_binary_accuracy: 0.6608
# Run:  4 / Accuracy at epoch  2  is:  0.660804033279419
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6426 - binary_accuracy: 0.6858 - val_loss: 0.6093 - val_binary_accuracy: 0.6859
# Run:  4 / Accuracy at epoch  3  is:  0.6859296560287476
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6194 - binary_accuracy: 0.6965 - val_loss: 0.6047 - val_binary_accuracy: 0.7035
# Run:  4 / Accuracy at epoch  4  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5766 - binary_accuracy: 0.7361 - val_loss: 0.6088 - val_binary_accuracy: 0.7136
# Run:  4 / Accuracy at epoch  5  is:  0.713567852973938
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5458 - binary_accuracy: 0.7550 - val_loss: 0.6380 - val_binary_accuracy: 0.7337
# Run:  4 / Accuracy at epoch  6  is:  0.733668327331543
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5088 - binary_accuracy: 0.7815 - val_loss: 0.6417 - val_binary_accuracy: 0.7286
# Run:  4 / Accuracy at epoch  7  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4733 - binary_accuracy: 0.7953 - val_loss: 0.6396 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  8  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4279 - binary_accuracy: 0.8369 - val_loss: 0.7008 - val_binary_accuracy: 0.7186
# Run:  4 / Accuracy at epoch  9  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3735 - binary_accuracy: 0.8526 - val_loss: 0.7459 - val_binary_accuracy: 0.6985
# Run:  4 / Accuracy at epoch  10  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3223 - binary_accuracy: 0.8741 - val_loss: 0.9949 - val_binary_accuracy: 0.6658
# Run:  4 / Accuracy at epoch  11  is:  0.6658291220664978
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3076 - binary_accuracy: 0.8791 - val_loss: 0.9544 - val_binary_accuracy: 0.6834
# Run:  4 / Accuracy at epoch  12  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2693 - binary_accuracy: 0.8923 - val_loss: 1.2827 - val_binary_accuracy: 0.6809
# Run:  4 / Accuracy at epoch  13  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2403 - binary_accuracy: 0.9162 - val_loss: 1.3546 - val_binary_accuracy: 0.6683
# Run:  4 / Accuracy at epoch  14  is:  0.6683416962623596
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2252 - binary_accuracy: 0.9181 - val_loss: 1.7099 - val_binary_accuracy: 0.6457
# Run:  4 / Accuracy at epoch  15  is:  0.6457286477088928
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2269 - binary_accuracy: 0.9238 - val_loss: 1.4812 - val_binary_accuracy: 0.6633
# Run:  4 / Accuracy at epoch  16  is:  0.6633166074752808
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2047 - binary_accuracy: 0.9270 - val_loss: 2.1058 - val_binary_accuracy: 0.6332
# Run:  4 / Accuracy at epoch  17  is:  0.6331658363342285
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1879 - binary_accuracy: 0.9288 - val_loss: 2.2635 - val_binary_accuracy: 0.6256
# Run:  4 / Accuracy at epoch  18  is:  0.6256281137466431
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1913 - binary_accuracy: 0.9320 - val_loss: 2.6191 - val_binary_accuracy: 0.6256
# Run:  4 / Accuracy at epoch  19  is:  0.6256281137466431
#
# Accuracies over epochs: [0.5, 0.6281406879425049, 0.660804033279419, 0.6859296560287476, 0.7035176157951355, 0.713567852973938, 0.733668327331543, 0.7286432385444641, 0.7211055159568787, 0.7185929417610168, 0.6984924674034119, 0.6658291220664978, 0.6834170818328857, 0.6809045076370239, 0.6683416962623596, 0.6457286477088928, 0.6633166074752808, 0.6331658363342285, 0.6256281137466431, 0.6256281137466431]
#
#
# 1588/1588 [==============================] - 21s 12ms/step - loss: 0.7022 - binary_accuracy: 0.4887 - val_loss: 0.6865 - val_binary_accuracy: 0.5402
# Run:  5 / Accuracy at epoch  0  is:  0.5402010083198547
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6832 - binary_accuracy: 0.6014 - val_loss: 0.6278 - val_binary_accuracy: 0.6382
# Run:  5 / Accuracy at epoch  1  is:  0.6381909251213074
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6569 - binary_accuracy: 0.6455 - val_loss: 0.6077 - val_binary_accuracy: 0.6834
# Run:  5 / Accuracy at epoch  2  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.6195 - binary_accuracy: 0.6933 - val_loss: 0.6149 - val_binary_accuracy: 0.6884
# Run:  5 / Accuracy at epoch  3  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5968 - binary_accuracy: 0.7254 - val_loss: 0.6382 - val_binary_accuracy: 0.6935
# Run:  5 / Accuracy at epoch  4  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5551 - binary_accuracy: 0.7531 - val_loss: 0.6255 - val_binary_accuracy: 0.7186
# Run:  5 / Accuracy at epoch  5  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5316 - binary_accuracy: 0.7664 - val_loss: 0.6407 - val_binary_accuracy: 0.7186
# Run:  5 / Accuracy at epoch  6  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.5026 - binary_accuracy: 0.7834 - val_loss: 0.6287 - val_binary_accuracy: 0.7186
# Run:  5 / Accuracy at epoch  7  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4612 - binary_accuracy: 0.8136 - val_loss: 0.6724 - val_binary_accuracy: 0.7211
# Run:  5 / Accuracy at epoch  8  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.4068 - binary_accuracy: 0.8382 - val_loss: 0.7825 - val_binary_accuracy: 0.7060
# Run:  5 / Accuracy at epoch  9  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3492 - binary_accuracy: 0.8526 - val_loss: 0.8829 - val_binary_accuracy: 0.6910
# Run:  5 / Accuracy at epoch  10  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.3281 - binary_accuracy: 0.8722 - val_loss: 0.8809 - val_binary_accuracy: 0.6859
# Run:  5 / Accuracy at epoch  11  is:  0.6859296560287476
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2895 - binary_accuracy: 0.8923 - val_loss: 1.0818 - val_binary_accuracy: 0.6734
# Run:  5 / Accuracy at epoch  12  is:  0.6733668446540833
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2636 - binary_accuracy: 0.8999 - val_loss: 1.1727 - val_binary_accuracy: 0.6734
# Run:  5 / Accuracy at epoch  13  is:  0.6733668446540833
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2373 - binary_accuracy: 0.9087 - val_loss: 1.0420 - val_binary_accuracy: 0.7035
# Run:  5 / Accuracy at epoch  14  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2532 - binary_accuracy: 0.9074 - val_loss: 1.2156 - val_binary_accuracy: 0.6683
# Run:  5 / Accuracy at epoch  15  is:  0.6683416962623596
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.2182 - binary_accuracy: 0.9232 - val_loss: 1.1149 - val_binary_accuracy: 0.7060
# Run:  5 / Accuracy at epoch  16  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1905 - binary_accuracy: 0.9370 - val_loss: 1.5312 - val_binary_accuracy: 0.6558
# Run:  5 / Accuracy at epoch  17  is:  0.6557788848876953
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1961 - binary_accuracy: 0.9282 - val_loss: 1.3681 - val_binary_accuracy: 0.6759
# Run:  5 / Accuracy at epoch  18  is:  0.6758794188499451
#
# 1588/1588 [==============================] - 20s 12ms/step - loss: 0.1954 - binary_accuracy: 0.9402 - val_loss: 1.9164 - val_binary_accuracy: 0.6256
# Run:  5 / Accuracy at epoch  19  is:  0.6256281137466431
#
# Accuracies over epochs: [0.5402010083198547, 0.6381909251213074, 0.6834170818328857, 0.6884422302246094, 0.6934673190116882, 0.7185929417610168, 0.7185929417610168, 0.7185929417610168, 0.7211055159568787, 0.7060301303863525, 0.6909547448158264, 0.6859296560287476, 0.6733668446540833, 0.6733668446540833, 0.7035176157951355, 0.6683416962623596, 0.7060301303863525, 0.6557788848876953, 0.6758794188499451, 0.6256281137466431]
#
#
#
#
#  Over all runs maximum accuracies on English are: [0.7211055159568787, 0.7211055159568787, 0.733668327331543, 0.733668327331543, 0.7361809015274048]
# The median for English is: 0.733668327331543
#
#
#
# ANN Accuracy Score on Test set ->  ['0.733668327331543 +/- 0.012562811374664307']

# %% [markdown]
# ## Now show compact results in a table.

# %%
print(" PREPRO FUNCTION    |  Test Accuracy   |",end = '')

print("\n")
for prepro_func in prepro_functions_dict_comb:
  #print(prepro_func,"\t\t\t",format(round(model_results[prepro_func][0],4),'.4f'),"\t\t",end='')
  result = model_results[prepro_func][0]
  # result = format(round(model_results[prepro_func][0],4),'.4f')
  print(f'{prepro_func:27}{ result :12}')
  print("\n")
# Out:
#  PREPRO FUNCTION    |  Test Accuracy   |
#
# DON                        0.733668327331543 +/- 0.007537662982940674
#
#
# LOW                        0.7311557531356812 +/- 0.0025125741958618164
#
#
# RSW                        0.7386934757232666 +/- 0.007537722587585449
#
#
# STM                        0.733668327331543 +/- 0.005025088787078857
#
#
# LOW_RSW                    0.7311557531356812 +/- 0.010050296783447266
#
#
# LOW_STM                    0.7361809015274048 +/- 0.007537662982940674
#
#
# RSW_LOW                    0.7286432385444641 +/- 0.005025088787078857
#
#
# RSW_STM                    0.733668327331543 +/- 0.007537722587585449
#
#
# STM_LOW                    0.7286432385444641 +/- 0.012562811374664307
#
#
# STM_RSW                    0.7361809015274048 +/- 0.01005023717880249
#
#
# LOW_STM_RSW                0.7211055159568787 +/- 0.020100533962249756
#
#
# LOW_RSW_STM                0.7311557531356812 +/- 0.010050296783447266
#
#
# STM_LOW_RSW                0.7236180901527405 +/- 0.012562811374664307
#
#
# STM_RSW_LOW                0.733668327331543 +/- 0.012562811374664307
#
#
# RSW_LOW_STM                0.7361809015274048 +/- 0.01005023717880249
#
#
# RSW_STM_LOW                0.733668327331543 +/- 0.012562811374664307
