# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/text_preprocessing_impact/blob/main/PCL_DS/BiLSTM_PCL_TextPreProImpact_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances.
# - - -
# BiLSTM ON PCL DS EXPERIMENTS NOTEBOOK
# - - -
# Bidirectional Long Short-Term Memory Network on Patronizing and Condescending Language Dataset.
# Code by M. Siino.
#
# From the paper: "Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances." by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf
import numpy as np
import pandas as pd
import nltk

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from io import open
from pathlib import Path
from urllib import request

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer
from textblob import TextBlob
nltk.download('stopwords')
nltk.download('punkt')

os.environ['TF_CUDNN_DETERMINISTIC']='false'
os.environ['TF_DETERMINISTIC_OPS']='false'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Fetch all the files needed.

# %%
urlDontPatronizeMe_PCL_tsv = "https://drive.google.com/uc?export=download&id=1KAncWruZ4OkKlvEGnxLkNbR1sxAErG8_"
urlDontPatronizeMe_categories_tsv = "https://drive.google.com/uc?export=download&id=1KMZJsskzKLbM-kgYiwXIF0h3Shj4F0mM"
urlTestSet_csv = "https://drive.google.com/uc?export=download&id=161-_6MH16_UHtLTqt0nd09l68pP5MEbQ"
urlDevSet_csv = "https://drive.google.com/uc?export=download&id=1KNuZ_h7NXTSwEz3_0XkaEd4DUAyxojAU"
urlTrainSet_csv = "https://drive.google.com/uc?export=download&id=1KVRrMC9UVwtQE9QfcLv8b11P5t2BhA8I"

tmp = tf.keras.utils.get_file("dontpatronizeme_pcl.tsv", urlDontPatronizeMe_PCL_tsv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("dontpatronizeme_categories.tsv", urlDontPatronizeMe_categories_tsv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("task4_test.csv", urlTestSet_csv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("dev_semeval_parids-labels.csv", urlDevSet_csv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("train_semeval_parids-labels.csv", urlTrainSet_csv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')

# %% [markdown]
# ## Fetch Don't Patronize Me! data manager module

# %%
module_url = f"https://raw.githubusercontent.com/Perez-AlmendrosC/dontpatronizeme/master/semeval-2022/dont_patronize_me.py"
module_name = module_url.split('/')[-1]
print(f'Fetching {module_url}')
#with open("file_1.txt") as f1, open("file_2.txt") as f2
with request.urlopen(module_url) as f, open(module_name,'w') as outf:
  a = f.read()
  outf.write(a.decode('utf-8'))
# Out:
# Fetching https://raw.githubusercontent.com/Perez-AlmendrosC/dontpatronizeme/master/semeval-2022/dont_patronize_me.py

# %% [markdown]
# ## Import and load dpm

# %%
from dont_patronize_me import DontPatronizeMe
dpm = DontPatronizeMe('.', '.')
dpm.load_task1()
dpm.load_task2(return_one_hot=True)
# Out:
# Map of label to numerical label:
# {'Unbalanced_power_relations': 0, 'Shallow_solution': 1, 'Presupposition': 2, 'Authority_voice': 3, 'Metaphors': 4, 'Compassion': 5, 'The_poorer_the_merrier': 6}

# %% [markdown]
# ## Load paragraph IDs

# %%
trids = pd.read_csv('train_semeval_parids-labels.csv')
teids = pd.read_csv('dev_semeval_parids-labels.csv')

# %%
print(trids.head())
print(len(trids))
print(len(teids))
# Out:
#    par_id                  label
# 0    4341  [1, 0, 0, 1, 0, 0, 0]
# 1    4136  [0, 1, 0, 0, 0, 0, 0]
# 2   10352  [1, 0, 0, 0, 0, 1, 0]
# 3    8279  [0, 0, 0, 1, 0, 0, 0]
# 4    1164  [1, 0, 0, 1, 1, 1, 0]
# 8375
# 2094

# %%
trids.par_id = trids.par_id.astype(str)
teids.par_id = teids.par_id.astype(str)

# %% [markdown]
# ## Rebuild training set (Task 1)

# %%
rows = [] # will contain par_id, keyword, country, label and text
for idx in range(len(trids)):  
  parid = trids.par_id[idx]
  #print(parid)
  # select row from original dataset to retrieve `text` and binary label
  text = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].text.values[0]
  label = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].label.values[0]
  #keyword = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].keyword.values[0]
  #country = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].country.values[0]
  rows.append({
      'par_id':parid,
      #'keyword':keyword,
      #'country':country,
      'text':text,
      'label':label
  })

# %%
trdf1 = pd.DataFrame(rows)

# %%
len(rows)
# Out:
# 8375

# %%
print(trdf1)
# Out:
#      par_id                                               text  label
# 0      4341  The scheme saw an estimated 150,000 children f...      1
# 1      4136  Durban 's homeless communities reconciliation ...      1
# 2     10352  The next immediate problem that cropped up was...      1
# 3      8279  Far more important than the implications for t...      1
# 4      1164  To strengthen child-sensitive social protectio...      1
# ...     ...                                                ...    ...
# 8370   8380  Rescue teams search for survivors on the rubbl...      0
# 8371   8381  The launch of ' Happy Birthday ' took place la...      0
# 8372   8382  The unrest has left at least 20,000 people dea...      0
# 8373   8383  You have to see it from my perspective . I may...      0
# 8374   8384  Yet there was one occasion when we went to the...      0
#
# [8375 rows x 3 columns]

# %%
# Next row to balance the DS.
bal_trdf1 = trdf1.drop(trdf1.index[-6787:])

print("Total number of samples is:",len(bal_trdf1))
print("Total number of class 1 samples is:",sum(bal_trdf1.label == 1))
print("Total number of class 0 samples is:",sum(bal_trdf1.label == 0))

trdf1 = bal_trdf1
# Out:
# Total number of samples is: 1588
# Total number of class 1 samples is: 794
# Total number of class 0 samples is: 794

# %% [markdown]
# ## Rebuild test set (Task 1)

# %%
rows = [] # will contain par_id, label and text
for idx in range(len(teids)):  
  parid = teids.par_id[idx]
  #print(parid)
  # select row from original dataset
  text = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].text.values[0]
  label = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].label.values[0]
  #keyword = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].keyword.values[0]
  #country = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].country.values[0]
  rows.append({
      'par_id':parid,
      #'keyword':keyword,
      #'country':country,
      'text':text,
      'label':label
  })

# %%
len(rows)
# Out:
# 2094

# %%
tedf1 = pd.DataFrame(rows)

# %%
# Next row to balance the DS.
bal_tedf1 = tedf1.drop(tedf1.index[-1696:])

print("Total number of samples is:",len(bal_tedf1))
print("Total number of class 1 samples is:",sum(bal_tedf1.label == 1))
print("Total number of class 0 samples is:",sum(bal_tedf1.label == 0))

tedf1 = bal_tedf1
# Out:
# Total number of samples is: 398
# Total number of class 1 samples is: 199
# Total number of class 0 samples is: 199

# %% [markdown]
# ## Preprocessing functions definitions

# %%
# Do-Nothing preprocessing function.
def DON(input_data):
  tag_open_CDATA_removed = tf.strings.regex_replace(input_data, '<\!\[CDATA\[', ' ')
  tag_closed_CDATA_removed = tf.strings.regex_replace(tag_open_CDATA_removed,'\]{1,}>', ' ')
  tag_author_lang_en_removed = tf.strings.regex_replace(tag_closed_CDATA_removed,'<author lang="en">', ' ')
  tag_closed_author_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'</author>', ' ')
  tag_open_documents_removed = tf.strings.regex_replace(tag_closed_author_removed,'<documents>\n(\t){0,2}', '')
  output_data = tf.strings.regex_replace(tag_open_documents_removed,'</documents>\n(\t){0,2}', ' ')
  return output_data

# Lowercasing preprocessing function.
def LOW(input_data):  
  return tf.strings.lower(DON(input_data))

# Removing Stop Words function.
def RSW(input_data):
  output_data = DON(input_data)

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:

      # input_string = input_string.numpy() [0]
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("Tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# Porter Stemmer preprocessing function.
def STM(input_data):
  output_data = DON(input_data)
  stemmer = PorterStemmer()

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      #print(input_string)
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:
      #input_string = input_string.numpy()[0]
      input_string = input_string.numpy()
      #print(input_string)
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# %% [markdown]
# ## Define the combined preprocessing functions. (The base functions are: DON, LOW, RSW and STM).

# %%
## SECTION WITH PAIRS OF PREPRO FUNCTIONS. APPLICATION ORDER MATTERS (...IN FOLLOWING SECTIONS TOO).
#...5
def LOW_RSW(input_data):
  return RSW(LOW(input_data))

# 6
def LOW_STM(input_data):
  return STM(LOW(input_data))

# 7
def RSW_LOW(input_data):
  return LOW(RSW(input_data))

# 8
def RSW_STM(input_data):
  return STM(RSW(input_data))

# 9
def STM_LOW(input_data):
  return LOW(STM(input_data))

# 10
def STM_RSW(input_data):
  return RSW(STM(input_data))
  
# 11
def LOW_STM_RSW(input_data):
  return RSW(STM(LOW(input_data)))

# 12
def LOW_RSW_STM(input_data):
  return STM(RSW(LOW(input_data)))

# 13
def STM_LOW_RSW(input_data):
  return RSW(LOW(STM(input_data)))

# 14
def STM_RSW_LOW(input_data):
  return LOW(RSW(STM(input_data)))

# 15
def RSW_LOW_STM(input_data):
  return STM(LOW(RSW(input_data)))

# 16
def RSW_STM_LOW(input_data):
  return LOW(STM(RSW(input_data)))

# %% [markdown]
# ## Build a Tensorflow DS

# %%
tf.random.set_seed(1)

train_ds = False
for i in range(0,len(trdf1)):
  sample = [' '+trdf1['text'][i]]
  label = [trdf1['label'][i]]

  current_set = (
    tf.data.Dataset.from_tensor_slices(
        (
            [tf.cast(sample,tf.string)],
            [tf.cast(label, tf.int32)]
        )
    )
  )
  if train_ds != False:
    train_ds = train_ds.concatenate(current_set)
  else:
    train_ds = current_set
train_ds = train_ds.shuffle(len(train_ds), reshuffle_each_iteration=False)

test_ds = False
for i in range(0,len(tedf1)):
  sample = [' '+tedf1['text'][i]]
  label = [tedf1['label'][i]]

  current_set = (
    tf.data.Dataset.from_tensor_slices(
        (
            [tf.cast(sample,tf.string)],
            [tf.cast(label, tf.int32)]
        )
    )
  )
  if test_ds != False:
    test_ds = test_ds.concatenate(current_set)
  else:
    test_ds = current_set

for element in train_ds:
    authorDocument=element[0]
    label=element[1]
    print(authorDocument)
    print(label)
    break
    
print(train_ds)
# Out:
# tf.Tensor([b' LUSAKA Zambia ( Xinhua ) -- Zambia ? s Immigration Department said Wednesday that it had arrested at least 45 illegal immigrants in Lusaka , the country ? s capital .'], shape=(1,), dtype=string)
# tf.Tensor([0], shape=(1,), dtype=int32)
# <ShuffleDataset element_spec=(TensorSpec(shape=(1,), dtype=tf.string, name=None), TensorSpec(shape=(1,), dtype=tf.int32, name=None))>

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(preprocessing_function,training_set):
  # Set a very large sequence length to find the longest sample in the training set.
  sequence_length = 20000
  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    # Count the number of zeros from the last non-zero token to the end of the sample. 
    # Shortest tokenized sample has less zeros than others.
    out=model(authorDocument)
    token_nr_index=sequence_length-1
    current_sample_zeros_counter=0
    while out.numpy()[0][token_nr_index]==0:
      token_nr_index-=1
      current_sample_zeros_counter+=1

    shortest_padding_length=sequence_length-longest_sample_length
    if current_sample_zeros_counter<shortest_padding_length:
      longest_sample_length=sequence_length-current_sample_zeros_counter

  #print(out.numpy()[0][3229:3400])
  #print(longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Define a dictionary with -> function_names:prepro_function_caller. And a dictionary to store model results.

# %%
model_results = {}
prepro_functions_dict_base = {
    'DON':DON,
    'LOW':LOW,
    'RSW':RSW,
    'STM':STM
    }

# 3 prepro functions = 15 combs...+1 for do_nothing

prepro_functions_dict_comb = {
    # 1. Do nothing 
    'DON': DON,
    # 2. Lowercasing 
    'LOW':LOW,
    # 3. Removing Stopwords
    'RSW':RSW, 
    # 4. Porter Stemming
    'STM':STM,
    # 5. LOW->RSW
    'LOW_RSW':LOW_RSW, 
    # 6. LOW->STM
    'LOW_STM':LOW_STM,
    # 7. RSW->LOW
    'RSW_LOW':RSW_LOW,
    # 8. RSW->STM
    'RSW_STM':RSW_STM,
    # 9. STM->LOW
    'STM_LOW':STM_LOW,
    # 10. STM->RSW
    'STM_RSW':STM_RSW,
    # 11. LOW->STM->RSW
    'LOW_STM_RSW':LOW_STM_RSW,  
    # 12. LOW->RSW->STM
    'LOW_RSW_STM':LOW_RSW_STM,
    # 13. STM->LOW->RSW
    'STM_LOW_RSW':STM_LOW_RSW,
    # 14. STM->RSW->LOW
    'STM_RSW_LOW':STM_RSW_LOW,
    # 15. RSW->LOW->STM
    'RSW_LOW_STM':RSW_LOW_STM,
    # 16. RSW->STM->LOW
    'RSW_STM_LOW':RSW_STM_LOW
}

for key in prepro_functions_dict_comb:
  print(key)
  model_results[key]=[]
# Out:
# DON
# LOW
# RSW
# STM
# LOW_RSW
# LOW_STM
# RSW_LOW
# RSW_STM
# STM_LOW
# STM_RSW
# LOW_STM_RSW
# LOW_RSW_STM
# STM_LOW_RSW
# STM_RSW_LOW
# RSW_LOW_STM
# RSW_STM_LOW

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Models definition and evaluation.

# %%
tf.random.set_seed(0)
TF_DISABLE_SEGMENT_REDUCTION_OP_DETERMINISM_EXCEPTIONS=True

# Reset model_results list.
for key in prepro_functions_dict_comb:
  model_results[key]=[]

for key in prepro_functions_dict_comb:
  runs_accuracy = []

  print("\n\n* * * * EVALUATION USING", key, "AS PREPROCESSING FUNCTION * * * *")

  # Preprocess training set to build a dictionary.
  vectorize_layer = preprocess_and_adapt_ts(prepro_functions_dict_comb[key],train_ds)

  max_features=len(vectorize_layer.get_vocabulary()) + 1
  print("Vocabulary size is:", max_features)

  for run in range(1,(num_runs+1)):
    epochs_accuracy=[]
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,  return_sequences=True)),
                                    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
                                    tf.keras.layers.Dense(64, activation='relu'),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer=opt, metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        print("Run: ",run,"/ Accuracy at epoch ",epoch," is: ", accuracy[0],"\n")
        epochs_accuracy.append(accuracy[0])

    print("Accuracies over epochs:",epochs_accuracy,"\n\n")
    runs_accuracy.append(max(epochs_accuracy))

  runs_accuracy.sort()
  print("\n\n Over all runs maximum accuracies on English are:", runs_accuracy)
  print("The median for English is:",runs_accuracy[2],"\n\n\n")
  
  if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
    max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
  else:
    max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
  final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
  model_results[key].append(final_result)
  print("BiLSTM Accuracy Score on Test set -> ",model_results[key])
# Out:
# Streaming output truncated to the last 5000 lines.
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.3398 - binary_accuracy: 0.9125 - val_loss: 0.9905 - val_binary_accuracy: 0.7085
# Run:  4 / Accuracy at epoch  13  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2603 - binary_accuracy: 0.9263 - val_loss: 1.7023 - val_binary_accuracy: 0.6809
# Run:  4 / Accuracy at epoch  14  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2697 - binary_accuracy: 0.9307 - val_loss: 1.0348 - val_binary_accuracy: 0.6985
# Run:  4 / Accuracy at epoch  15  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2432 - binary_accuracy: 0.9503 - val_loss: 1.3799 - val_binary_accuracy: 0.7136
# Run:  4 / Accuracy at epoch  16  is:  0.713567852973938
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.1907 - binary_accuracy: 0.9521 - val_loss: 2.0807 - val_binary_accuracy: 0.6206
# Run:  4 / Accuracy at epoch  17  is:  0.6206030249595642
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.1873 - binary_accuracy: 0.9565 - val_loss: 1.5036 - val_binary_accuracy: 0.6683
# Run:  4 / Accuracy at epoch  18  is:  0.6683416962623596
#
# 1588/1588 [==============================] - 79s 49ms/step - loss: 0.2158 - binary_accuracy: 0.9540 - val_loss: 1.9069 - val_binary_accuracy: 0.6709
# Run:  4 / Accuracy at epoch  19  is:  0.6708542704582214
#
# Accuracies over epochs: [0.5025125741958618, 0.5929648280143738, 0.6683416962623596, 0.6532663106918335, 0.6758794188499451, 0.7185929417610168, 0.7160804271697998, 0.7185929417610168, 0.7311557531356812, 0.7261306643486023, 0.7361809015274048, 0.733668327331543, 0.7211055159568787, 0.7085427045822144, 0.6809045076370239, 0.6984924674034119, 0.713567852973938, 0.6206030249595642, 0.6683416962623596, 0.6708542704582214]
#
#
# 1588/1588 [==============================] - 85s 51ms/step - loss: 0.7057 - binary_accuracy: 0.5183 - val_loss: 0.6940 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.6990 - binary_accuracy: 0.5699 - val_loss: 0.6306 - val_binary_accuracy: 0.6533
# Run:  5 / Accuracy at epoch  1  is:  0.6532663106918335
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.6742 - binary_accuracy: 0.6196 - val_loss: 0.6087 - val_binary_accuracy: 0.6759
# Run:  5 / Accuracy at epoch  2  is:  0.6758794188499451
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.6358 - binary_accuracy: 0.7084 - val_loss: 0.6713 - val_binary_accuracy: 0.6809
# Run:  5 / Accuracy at epoch  3  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.5987 - binary_accuracy: 0.7412 - val_loss: 0.6463 - val_binary_accuracy: 0.6181
# Run:  5 / Accuracy at epoch  4  is:  0.6180904507637024
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.5701 - binary_accuracy: 0.7620 - val_loss: 0.6217 - val_binary_accuracy: 0.7437
# Run:  5 / Accuracy at epoch  5  is:  0.7437185645103455
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.5412 - binary_accuracy: 0.7865 - val_loss: 0.7301 - val_binary_accuracy: 0.7462
# Run:  5 / Accuracy at epoch  6  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.4887 - binary_accuracy: 0.8180 - val_loss: 0.7754 - val_binary_accuracy: 0.7161
# Run:  5 / Accuracy at epoch  7  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.4626 - binary_accuracy: 0.8312 - val_loss: 0.9029 - val_binary_accuracy: 0.7261
# Run:  5 / Accuracy at epoch  8  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.4490 - binary_accuracy: 0.8407 - val_loss: 0.8348 - val_binary_accuracy: 0.7236
# Run:  5 / Accuracy at epoch  9  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.4157 - binary_accuracy: 0.8564 - val_loss: 0.9019 - val_binary_accuracy: 0.6960
# Run:  5 / Accuracy at epoch  10  is:  0.69597989320755
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.3702 - binary_accuracy: 0.8785 - val_loss: 0.9693 - val_binary_accuracy: 0.7060
# Run:  5 / Accuracy at epoch  11  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.3582 - binary_accuracy: 0.8936 - val_loss: 0.9971 - val_binary_accuracy: 0.6709
# Run:  5 / Accuracy at epoch  12  is:  0.6708542704582214
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.3168 - binary_accuracy: 0.9169 - val_loss: 0.9776 - val_binary_accuracy: 0.6633
# Run:  5 / Accuracy at epoch  13  is:  0.6633166074752808
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2660 - binary_accuracy: 0.9207 - val_loss: 1.0583 - val_binary_accuracy: 0.6910
# Run:  5 / Accuracy at epoch  14  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2537 - binary_accuracy: 0.9364 - val_loss: 1.5058 - val_binary_accuracy: 0.7085
# Run:  5 / Accuracy at epoch  15  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2497 - binary_accuracy: 0.9314 - val_loss: 1.4159 - val_binary_accuracy: 0.7136
# Run:  5 / Accuracy at epoch  16  is:  0.713567852973938
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.1923 - binary_accuracy: 0.9547 - val_loss: 1.8471 - val_binary_accuracy: 0.7010
# Run:  5 / Accuracy at epoch  17  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2077 - binary_accuracy: 0.9515 - val_loss: 2.0257 - val_binary_accuracy: 0.6960
# Run:  5 / Accuracy at epoch  18  is:  0.69597989320755
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2090 - binary_accuracy: 0.9610 - val_loss: 2.2046 - val_binary_accuracy: 0.6784
# Run:  5 / Accuracy at epoch  19  is:  0.6783919334411621
#
# Accuracies over epochs: [0.5, 0.6532663106918335, 0.6758794188499451, 0.6809045076370239, 0.6180904507637024, 0.7437185645103455, 0.7462311387062073, 0.7160804271697998, 0.7261306643486023, 0.7236180901527405, 0.69597989320755, 0.7060301303863525, 0.6708542704582214, 0.6633166074752808, 0.6909547448158264, 0.7085427045822144, 0.713567852973938, 0.7010050415992737, 0.69597989320755, 0.6783919334411621]
#
#
#
#
#  Over all runs maximum accuracies on English are: [0.7261306643486023, 0.7361809015274048, 0.7462311387062073, 0.7487437129020691, 0.7512562870979309]
# The median for English is: 0.7462311387062073
#
#
#
# BiLSTM Accuracy Score on Test set ->  ['0.7462311387062073 +/- 0.02010047435760498']
#
#
# * * * * EVALUATION USING LOW AS PREPROCESSING FUNCTION * * * *
# Vocabulary size is: 11297
# 1588/1588 [==============================] - 84s 50ms/step - loss: 0.7099 - binary_accuracy: 0.5082 - val_loss: 0.6948 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.6976 - binary_accuracy: 0.5466 - val_loss: 0.6930 - val_binary_accuracy: 0.5025
# Run:  1 / Accuracy at epoch  1  is:  0.5025125741958618
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.6911 - binary_accuracy: 0.6322 - val_loss: 0.6919 - val_binary_accuracy: 0.4950
# Run:  1 / Accuracy at epoch  2  is:  0.49497488141059875
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.6466 - binary_accuracy: 0.6713 - val_loss: 0.6287 - val_binary_accuracy: 0.6809
# Run:  1 / Accuracy at epoch  3  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.6187 - binary_accuracy: 0.7128 - val_loss: 0.6275 - val_binary_accuracy: 0.7111
# Run:  1 / Accuracy at epoch  4  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.5710 - binary_accuracy: 0.7582 - val_loss: 0.5747 - val_binary_accuracy: 0.7312
# Run:  1 / Accuracy at epoch  5  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.5466 - binary_accuracy: 0.7557 - val_loss: 0.6678 - val_binary_accuracy: 0.7387
# Run:  1 / Accuracy at epoch  6  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.5189 - binary_accuracy: 0.7941 - val_loss: 0.8441 - val_binary_accuracy: 0.7236
# Run:  1 / Accuracy at epoch  7  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.4933 - binary_accuracy: 0.8010 - val_loss: 0.6875 - val_binary_accuracy: 0.7337
# Run:  1 / Accuracy at epoch  8  is:  0.733668327331543
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.4640 - binary_accuracy: 0.8375 - val_loss: 0.8241 - val_binary_accuracy: 0.7538
# Run:  1 / Accuracy at epoch  9  is:  0.7537688612937927
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.4205 - binary_accuracy: 0.8583 - val_loss: 0.8039 - val_binary_accuracy: 0.7362
# Run:  1 / Accuracy at epoch  10  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.3979 - binary_accuracy: 0.8703 - val_loss: 0.9266 - val_binary_accuracy: 0.7337
# Run:  1 / Accuracy at epoch  11  is:  0.733668327331543
#
# 1588/1588 [==============================] - 82s 51ms/step - loss: 0.3582 - binary_accuracy: 0.8785 - val_loss: 1.0810 - val_binary_accuracy: 0.7337
# Run:  1 / Accuracy at epoch  12  is:  0.733668327331543
#
# 1588/1588 [==============================] - 83s 52ms/step - loss: 0.3324 - binary_accuracy: 0.9030 - val_loss: 1.1002 - val_binary_accuracy: 0.7261
# Run:  1 / Accuracy at epoch  13  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 83s 52ms/step - loss: 0.2883 - binary_accuracy: 0.9156 - val_loss: 1.1766 - val_binary_accuracy: 0.7186
# Run:  1 / Accuracy at epoch  14  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.2819 - binary_accuracy: 0.9332 - val_loss: 1.1776 - val_binary_accuracy: 0.7186
# Run:  1 / Accuracy at epoch  15  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 79s 49ms/step - loss: 0.2363 - binary_accuracy: 0.9446 - val_loss: 1.9719 - val_binary_accuracy: 0.6960
# Run:  1 / Accuracy at epoch  16  is:  0.69597989320755
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.2153 - binary_accuracy: 0.9395 - val_loss: 1.2561 - val_binary_accuracy: 0.7563
# Run:  1 / Accuracy at epoch  17  is:  0.7562814354896545
#
# 1588/1588 [==============================] - 79s 49ms/step - loss: 0.1922 - binary_accuracy: 0.9547 - val_loss: 1.6249 - val_binary_accuracy: 0.7161
# Run:  1 / Accuracy at epoch  18  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.1779 - binary_accuracy: 0.9565 - val_loss: 1.4889 - val_binary_accuracy: 0.6985
# Run:  1 / Accuracy at epoch  19  is:  0.6984924674034119
#
# Accuracies over epochs: [0.5, 0.5025125741958618, 0.49497488141059875, 0.6809045076370239, 0.7110552787780762, 0.7311557531356812, 0.7386934757232666, 0.7236180901527405, 0.733668327331543, 0.7537688612937927, 0.7361809015274048, 0.733668327331543, 0.733668327331543, 0.7261306643486023, 0.7185929417610168, 0.7185929417610168, 0.69597989320755, 0.7562814354896545, 0.7160804271697998, 0.6984924674034119]
#
#
# 1588/1588 [==============================] - 84s 50ms/step - loss: 0.7056 - binary_accuracy: 0.5044 - val_loss: 0.6951 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.7041 - binary_accuracy: 0.5586 - val_loss: 0.6650 - val_binary_accuracy: 0.5729
# Run:  2 / Accuracy at epoch  1  is:  0.572864294052124
#
# 1588/1588 [==============================] - 78s 49ms/step - loss: 0.6648 - binary_accuracy: 0.6618 - val_loss: 0.6300 - val_binary_accuracy: 0.6533
# Run:  2 / Accuracy at epoch  2  is:  0.6532663106918335
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.6497 - binary_accuracy: 0.6921 - val_loss: 0.6755 - val_binary_accuracy: 0.7060
# Run:  2 / Accuracy at epoch  3  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.6083 - binary_accuracy: 0.7267 - val_loss: 0.7218 - val_binary_accuracy: 0.7111
# Run:  2 / Accuracy at epoch  4  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.5714 - binary_accuracy: 0.7594 - val_loss: 0.6545 - val_binary_accuracy: 0.7462
# Run:  2 / Accuracy at epoch  5  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.5457 - binary_accuracy: 0.7827 - val_loss: 0.6506 - val_binary_accuracy: 0.7286
# Run:  2 / Accuracy at epoch  6  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.5265 - binary_accuracy: 0.7953 - val_loss: 0.7221 - val_binary_accuracy: 0.7412
# Run:  2 / Accuracy at epoch  7  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 83s 52ms/step - loss: 0.4868 - binary_accuracy: 0.8123 - val_loss: 0.6575 - val_binary_accuracy: 0.7236
# Run:  2 / Accuracy at epoch  8  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 82s 51ms/step - loss: 0.4681 - binary_accuracy: 0.8344 - val_loss: 0.8633 - val_binary_accuracy: 0.7462
# Run:  2 / Accuracy at epoch  9  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 83s 52ms/step - loss: 0.4119 - binary_accuracy: 0.8722 - val_loss: 0.7846 - val_binary_accuracy: 0.7236
# Run:  2 / Accuracy at epoch  10  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 82s 52ms/step - loss: 0.3996 - binary_accuracy: 0.8696 - val_loss: 0.9161 - val_binary_accuracy: 0.7186
# Run:  2 / Accuracy at epoch  11  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 82s 51ms/step - loss: 0.3516 - binary_accuracy: 0.8892 - val_loss: 1.2580 - val_binary_accuracy: 0.7060
# Run:  2 / Accuracy at epoch  12  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 82s 52ms/step - loss: 0.3165 - binary_accuracy: 0.9043 - val_loss: 0.8393 - val_binary_accuracy: 0.7286
# Run:  2 / Accuracy at epoch  13  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.2945 - binary_accuracy: 0.9106 - val_loss: 1.5434 - val_binary_accuracy: 0.6960
# Run:  2 / Accuracy at epoch  14  is:  0.69597989320755
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.2668 - binary_accuracy: 0.9364 - val_loss: 1.7379 - val_binary_accuracy: 0.7337
# Run:  2 / Accuracy at epoch  15  is:  0.733668327331543
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.2391 - binary_accuracy: 0.9402 - val_loss: 1.2804 - val_binary_accuracy: 0.6834
# Run:  2 / Accuracy at epoch  16  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.2390 - binary_accuracy: 0.9370 - val_loss: 2.2497 - val_binary_accuracy: 0.6809
# Run:  2 / Accuracy at epoch  17  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.2109 - binary_accuracy: 0.9597 - val_loss: 1.9480 - val_binary_accuracy: 0.6985
# Run:  2 / Accuracy at epoch  18  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.1761 - binary_accuracy: 0.9654 - val_loss: 1.7587 - val_binary_accuracy: 0.6683
# Run:  2 / Accuracy at epoch  19  is:  0.6683416962623596
#
# Accuracies over epochs: [0.5, 0.572864294052124, 0.6532663106918335, 0.7060301303863525, 0.7110552787780762, 0.7462311387062073, 0.7286432385444641, 0.7412060499191284, 0.7236180901527405, 0.7462311387062073, 0.7236180901527405, 0.7185929417610168, 0.7060301303863525, 0.7286432385444641, 0.69597989320755, 0.733668327331543, 0.6834170818328857, 0.6809045076370239, 0.6984924674034119, 0.6683416962623596]
#
#
# 1588/1588 [==============================] - 87s 51ms/step - loss: 0.7039 - binary_accuracy: 0.5031 - val_loss: 0.6934 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.7040 - binary_accuracy: 0.5485 - val_loss: 0.6631 - val_binary_accuracy: 0.6055
# Run:  3 / Accuracy at epoch  1  is:  0.6055276393890381
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.6709 - binary_accuracy: 0.6329 - val_loss: 0.6903 - val_binary_accuracy: 0.5126
# Run:  3 / Accuracy at epoch  2  is:  0.5125628113746643
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.6499 - binary_accuracy: 0.6927 - val_loss: 0.6269 - val_binary_accuracy: 0.6884
# Run:  3 / Accuracy at epoch  3  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.5980 - binary_accuracy: 0.7324 - val_loss: 0.5912 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  4  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.5712 - binary_accuracy: 0.7538 - val_loss: 0.6427 - val_binary_accuracy: 0.6809
# Run:  3 / Accuracy at epoch  5  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.5573 - binary_accuracy: 0.7752 - val_loss: 0.6651 - val_binary_accuracy: 0.7286
# Run:  3 / Accuracy at epoch  6  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.5210 - binary_accuracy: 0.7966 - val_loss: 0.7973 - val_binary_accuracy: 0.7136
# Run:  3 / Accuracy at epoch  7  is:  0.713567852973938
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.4847 - binary_accuracy: 0.8212 - val_loss: 0.7076 - val_binary_accuracy: 0.7261
# Run:  3 / Accuracy at epoch  8  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.4571 - binary_accuracy: 0.8369 - val_loss: 1.0051 - val_binary_accuracy: 0.7111
# Run:  3 / Accuracy at epoch  9  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 79s 49ms/step - loss: 0.4160 - binary_accuracy: 0.8489 - val_loss: 0.7326 - val_binary_accuracy: 0.7538
# Run:  3 / Accuracy at epoch  10  is:  0.7537688612937927
#
# 1588/1588 [==============================] - 78s 49ms/step - loss: 0.3897 - binary_accuracy: 0.8684 - val_loss: 0.9722 - val_binary_accuracy: 0.7035
# Run:  3 / Accuracy at epoch  11  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 78s 49ms/step - loss: 0.3490 - binary_accuracy: 0.8980 - val_loss: 1.2750 - val_binary_accuracy: 0.7236
# Run:  3 / Accuracy at epoch  12  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 78s 49ms/step - loss: 0.3134 - binary_accuracy: 0.9099 - val_loss: 1.0347 - val_binary_accuracy: 0.6859
# Run:  3 / Accuracy at epoch  13  is:  0.6859296560287476
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2962 - binary_accuracy: 0.9131 - val_loss: 1.1192 - val_binary_accuracy: 0.6884
# Run:  3 / Accuracy at epoch  14  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2729 - binary_accuracy: 0.9257 - val_loss: 1.0747 - val_binary_accuracy: 0.6859
# Run:  3 / Accuracy at epoch  15  is:  0.6859296560287476
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2283 - binary_accuracy: 0.9421 - val_loss: 1.9103 - val_binary_accuracy: 0.6935
# Run:  3 / Accuracy at epoch  16  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.2022 - binary_accuracy: 0.9540 - val_loss: 1.7464 - val_binary_accuracy: 0.6734
# Run:  3 / Accuracy at epoch  17  is:  0.6733668446540833
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.1725 - binary_accuracy: 0.9565 - val_loss: 1.7988 - val_binary_accuracy: 0.6935
# Run:  3 / Accuracy at epoch  18  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.1933 - binary_accuracy: 0.9597 - val_loss: 2.3486 - val_binary_accuracy: 0.6985
# Run:  3 / Accuracy at epoch  19  is:  0.6984924674034119
#
# Accuracies over epochs: [0.5, 0.6055276393890381, 0.5125628113746643, 0.6884422302246094, 0.7185929417610168, 0.6809045076370239, 0.7286432385444641, 0.713567852973938, 0.7261306643486023, 0.7110552787780762, 0.7537688612937927, 0.7035176157951355, 0.7236180901527405, 0.6859296560287476, 0.6884422302246094, 0.6859296560287476, 0.6934673190116882, 0.6733668446540833, 0.6934673190116882, 0.6984924674034119]
#
#
# 1588/1588 [==============================] - 87s 51ms/step - loss: 0.7021 - binary_accuracy: 0.4924 - val_loss: 0.6935 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.7018 - binary_accuracy: 0.5397 - val_loss: 0.6950 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy at epoch  1  is:  0.5
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.6936 - binary_accuracy: 0.5800 - val_loss: 0.6800 - val_binary_accuracy: 0.5980
# Run:  4 / Accuracy at epoch  2  is:  0.5979899764060974
#
# 1588/1588 [==============================] - 85s 54ms/step - loss: 0.6666 - binary_accuracy: 0.6694 - val_loss: 0.6298 - val_binary_accuracy: 0.6683
# Run:  4 / Accuracy at epoch  3  is:  0.6683416962623596
#
# 1588/1588 [==============================] - 82s 52ms/step - loss: 0.6213 - binary_accuracy: 0.7116 - val_loss: 0.7251 - val_binary_accuracy: 0.6482
# Run:  4 / Accuracy at epoch  4  is:  0.6482412219047546
#
# 1588/1588 [==============================] - 82s 51ms/step - loss: 0.5956 - binary_accuracy: 0.7368 - val_loss: 0.6531 - val_binary_accuracy: 0.7161
# Run:  4 / Accuracy at epoch  5  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.5612 - binary_accuracy: 0.7702 - val_loss: 0.7444 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  6  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 82s 51ms/step - loss: 0.5434 - binary_accuracy: 0.7878 - val_loss: 0.6680 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  7  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 82s 51ms/step - loss: 0.4949 - binary_accuracy: 0.8016 - val_loss: 0.6218 - val_binary_accuracy: 0.7060
# Run:  4 / Accuracy at epoch  8  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 82s 52ms/step - loss: 0.4874 - binary_accuracy: 0.8237 - val_loss: 0.8028 - val_binary_accuracy: 0.7286
# Run:  4 / Accuracy at epoch  9  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.4422 - binary_accuracy: 0.8407 - val_loss: 0.8490 - val_binary_accuracy: 0.7337
# Run:  4 / Accuracy at epoch  10  is:  0.733668327331543
#
# 1588/1588 [==============================] - 81s 51ms/step - loss: 0.3966 - binary_accuracy: 0.8646 - val_loss: 0.8829 - val_binary_accuracy: 0.7312
# Run:  4 / Accuracy at epoch  11  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 81s 50ms/step - loss: 0.3637 - binary_accuracy: 0.8816 - val_loss: 0.8410 - val_binary_accuracy: 0.7261
# Run:  4 / Accuracy at epoch  12  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.3404 - binary_accuracy: 0.8873 - val_loss: 0.8581 - val_binary_accuracy: 0.7186
# Run:  4 / Accuracy at epoch  13  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.3082 - binary_accuracy: 0.9118 - val_loss: 0.9900 - val_binary_accuracy: 0.7337
# Run:  4 / Accuracy at epoch  14  is:  0.733668327331543
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2828 - binary_accuracy: 0.9213 - val_loss: 1.0897 - val_binary_accuracy: 0.6884
# Run:  4 / Accuracy at epoch  15  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2414 - binary_accuracy: 0.9440 - val_loss: 1.6204 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  16  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2301 - binary_accuracy: 0.9364 - val_loss: 1.5601 - val_binary_accuracy: 0.7161
# Run:  4 / Accuracy at epoch  17  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.2190 - binary_accuracy: 0.9515 - val_loss: 1.2773 - val_binary_accuracy: 0.7161
# Run:  4 / Accuracy at epoch  18  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.2206 - binary_accuracy: 0.9553 - val_loss: 1.7936 - val_binary_accuracy: 0.6985
# Run:  4 / Accuracy at epoch  19  is:  0.6984924674034119
#
# Accuracies over epochs: [0.5, 0.5, 0.5979899764060974, 0.6683416962623596, 0.6482412219047546, 0.7160804271697998, 0.7211055159568787, 0.7211055159568787, 0.7060301303863525, 0.7286432385444641, 0.733668327331543, 0.7311557531356812, 0.7261306643486023, 0.7185929417610168, 0.733668327331543, 0.6884422302246094, 0.7211055159568787, 0.7160804271697998, 0.7160804271697998, 0.6984924674034119]
#
#
# 1588/1588 [==============================] - 86s 51ms/step - loss: 0.7075 - binary_accuracy: 0.4956 - val_loss: 0.6941 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.7005 - binary_accuracy: 0.5309 - val_loss: 0.6807 - val_binary_accuracy: 0.5980
# Run:  5 / Accuracy at epoch  1  is:  0.5979899764060974
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.6734 - binary_accuracy: 0.6291 - val_loss: 0.6406 - val_binary_accuracy: 0.6407
# Run:  5 / Accuracy at epoch  2  is:  0.6407034993171692
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.6306 - binary_accuracy: 0.6858 - val_loss: 0.6015 - val_binary_accuracy: 0.7060
# Run:  5 / Accuracy at epoch  3  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.6127 - binary_accuracy: 0.7204 - val_loss: 0.6165 - val_binary_accuracy: 0.7010
# Run:  5 / Accuracy at epoch  4  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.5816 - binary_accuracy: 0.7487 - val_loss: 0.6146 - val_binary_accuracy: 0.7010
# Run:  5 / Accuracy at epoch  5  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.5253 - binary_accuracy: 0.7739 - val_loss: 0.6558 - val_binary_accuracy: 0.7085
# Run:  5 / Accuracy at epoch  6  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.5013 - binary_accuracy: 0.7972 - val_loss: 0.8507 - val_binary_accuracy: 0.7337
# Run:  5 / Accuracy at epoch  7  is:  0.733668327331543
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.4693 - binary_accuracy: 0.8174 - val_loss: 0.7222 - val_binary_accuracy: 0.7487
# Run:  5 / Accuracy at epoch  8  is:  0.7487437129020691
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.4375 - binary_accuracy: 0.8363 - val_loss: 0.8613 - val_binary_accuracy: 0.7261
# Run:  5 / Accuracy at epoch  9  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.4321 - binary_accuracy: 0.8602 - val_loss: 0.9657 - val_binary_accuracy: 0.7312
# Run:  5 / Accuracy at epoch  10  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 80s 50ms/step - loss: 0.3798 - binary_accuracy: 0.8640 - val_loss: 0.9195 - val_binary_accuracy: 0.7412
# Run:  5 / Accuracy at epoch  11  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.3281 - binary_accuracy: 0.8829 - val_loss: 0.9515 - val_binary_accuracy: 0.7236
# Run:  5 / Accuracy at epoch  12  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 79s 49ms/step - loss: 0.2899 - binary_accuracy: 0.9162 - val_loss: 1.7106 - val_binary_accuracy: 0.6985
# Run:  5 / Accuracy at epoch  13  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 79s 49ms/step - loss: 0.2427 - binary_accuracy: 0.9320 - val_loss: 1.2641 - val_binary_accuracy: 0.6910
# Run:  5 / Accuracy at epoch  14  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 79s 49ms/step - loss: 0.2383 - binary_accuracy: 0.9301 - val_loss: 1.5058 - val_binary_accuracy: 0.6935
# Run:  5 / Accuracy at epoch  15  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 79s 50ms/step - loss: 0.2276 - binary_accuracy: 0.9339 - val_loss: 1.4863 - val_binary_accuracy: 0.7010
# Run:  5 / Accuracy at epoch  16  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 79s 49ms/step - loss: 0.2236 - binary_accuracy: 0.9540 - val_loss: 1.5866 - val_binary_accuracy: 0.6935
# Run:  5 / Accuracy at epoch  17  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 79s 49ms/step - loss: 0.1852 - binary_accuracy: 0.9622 - val_loss: 2.0472 - val_binary_accuracy: 0.6935
# Run:  5 / Accuracy at epoch  18  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 86s 54ms/step - loss: 0.1589 - binary_accuracy: 0.9685 - val_loss: 2.2090 - val_binary_accuracy: 0.7010
# Run:  5 / Accuracy at epoch  19  is:  0.7010050415992737
#
# Accuracies over epochs: [0.5, 0.5979899764060974, 0.6407034993171692, 0.7060301303863525, 0.7010050415992737, 0.7010050415992737, 0.7085427045822144, 0.733668327331543, 0.7487437129020691, 0.7261306643486023, 0.7311557531356812, 0.7412060499191284, 0.7236180901527405, 0.6984924674034119, 0.6909547448158264, 0.6934673190116882, 0.7010050415992737, 0.6934673190116882, 0.6934673190116882, 0.7010050415992737]
#
#
#
#
#  Over all runs maximum accuracies on English are: [0.733668327331543, 0.7462311387062073, 0.7487437129020691, 0.7537688612937927, 0.7562814354896545]
# The median for English is: 0.7487437129020691
#
#
#
# BiLSTM Accuracy Score on Test set ->  ['0.7487437129020691 +/- 0.015075385570526123']
#
#
# * * * * EVALUATION USING RSW AS PREPROCESSING FUNCTION * * * *
# Vocabulary size is: 12384
# 1588/1588 [==============================] - 60s 34ms/step - loss: 0.7074 - binary_accuracy: 0.5195 - val_loss: 0.6901 - val_binary_accuracy: 0.5226
# Run:  1 / Accuracy at epoch  0  is:  0.5226130485534668
#
# 1588/1588 [==============================] - 54s 34ms/step - loss: 0.6982 - binary_accuracy: 0.5699 - val_loss: 0.6774 - val_binary_accuracy: 0.5955
# Run:  1 / Accuracy at epoch  1  is:  0.5954774022102356
#
# 1588/1588 [==============================] - 54s 34ms/step - loss: 0.6449 - binary_accuracy: 0.6757 - val_loss: 0.6057 - val_binary_accuracy: 0.6809
# Run:  1 / Accuracy at epoch  2  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 54s 33ms/step - loss: 0.6439 - binary_accuracy: 0.6984 - val_loss: 0.6043 - val_binary_accuracy: 0.7035
# Run:  1 / Accuracy at epoch  3  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 55s 34ms/step - loss: 0.5909 - binary_accuracy: 0.7424 - val_loss: 0.7159 - val_binary_accuracy: 0.7136
# Run:  1 / Accuracy at epoch  4  is:  0.713567852973938
#
# 1588/1588 [==============================] - 54s 34ms/step - loss: 0.5842 - binary_accuracy: 0.7563 - val_loss: 0.6556 - val_binary_accuracy: 0.7136
# Run:  1 / Accuracy at epoch  5  is:  0.713567852973938
#
# 1588/1588 [==============================] - 54s 34ms/step - loss: 0.5274 - binary_accuracy: 0.8048 - val_loss: 0.7724 - val_binary_accuracy: 0.7136
# Run:  1 / Accuracy at epoch  6  is:  0.713567852973938
#
# 1588/1588 [==============================] - 54s 34ms/step - loss: 0.5126 - binary_accuracy: 0.8142 - val_loss: 0.7261 - val_binary_accuracy: 0.7111
# Run:  1 / Accuracy at epoch  7  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 54s 34ms/step - loss: 0.4546 - binary_accuracy: 0.8218 - val_loss: 0.7824 - val_binary_accuracy: 0.7060
# Run:  1 / Accuracy at epoch  8  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 54s 34ms/step - loss: 0.4499 - binary_accuracy: 0.8350 - val_loss: 0.7244 - val_binary_accuracy: 0.7161
# Run:  1 / Accuracy at epoch  9  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 53s 33ms/step - loss: 0.4054 - binary_accuracy: 0.8753 - val_loss: 0.9927 - val_binary_accuracy: 0.7010
# Run:  1 / Accuracy at epoch  10  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.3781 - binary_accuracy: 0.8841 - val_loss: 0.8338 - val_binary_accuracy: 0.7211
# Run:  1 / Accuracy at epoch  11  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.3267 - binary_accuracy: 0.9125 - val_loss: 0.8456 - val_binary_accuracy: 0.7035
# Run:  1 / Accuracy at epoch  12  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2708 - binary_accuracy: 0.9244 - val_loss: 1.3640 - val_binary_accuracy: 0.6985
# Run:  1 / Accuracy at epoch  13  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.2374 - binary_accuracy: 0.9257 - val_loss: 1.1981 - val_binary_accuracy: 0.6834
# Run:  1 / Accuracy at epoch  14  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.2020 - binary_accuracy: 0.9496 - val_loss: 1.5112 - val_binary_accuracy: 0.7010
# Run:  1 / Accuracy at epoch  15  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.1911 - binary_accuracy: 0.9547 - val_loss: 1.7698 - val_binary_accuracy: 0.7060
# Run:  1 / Accuracy at epoch  16  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.1893 - binary_accuracy: 0.9528 - val_loss: 1.4735 - val_binary_accuracy: 0.6658
# Run:  1 / Accuracy at epoch  17  is:  0.6658291220664978
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.1807 - binary_accuracy: 0.9616 - val_loss: 2.0110 - val_binary_accuracy: 0.6910
# Run:  1 / Accuracy at epoch  18  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.1659 - binary_accuracy: 0.9666 - val_loss: 2.2330 - val_binary_accuracy: 0.6558
# Run:  1 / Accuracy at epoch  19  is:  0.6557788848876953
#
# Accuracies over epochs: [0.5226130485534668, 0.5954774022102356, 0.6809045076370239, 0.7035176157951355, 0.713567852973938, 0.713567852973938, 0.713567852973938, 0.7110552787780762, 0.7060301303863525, 0.7160804271697998, 0.7010050415992737, 0.7211055159568787, 0.7035176157951355, 0.6984924674034119, 0.6834170818328857, 0.7010050415992737, 0.7060301303863525, 0.6658291220664978, 0.6909547448158264, 0.6557788848876953]
#
#
# 1588/1588 [==============================] - 58s 33ms/step - loss: 0.7028 - binary_accuracy: 0.5019 - val_loss: 0.6916 - val_binary_accuracy: 0.5050
# Run:  2 / Accuracy at epoch  0  is:  0.5050251483917236
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.7031 - binary_accuracy: 0.5460 - val_loss: 0.7116 - val_binary_accuracy: 0.5226
# Run:  2 / Accuracy at epoch  1  is:  0.5226130485534668
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.6787 - binary_accuracy: 0.6366 - val_loss: 0.6178 - val_binary_accuracy: 0.6608
# Run:  2 / Accuracy at epoch  2  is:  0.660804033279419
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.6317 - binary_accuracy: 0.7028 - val_loss: 0.6046 - val_binary_accuracy: 0.7312
# Run:  2 / Accuracy at epoch  3  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.5848 - binary_accuracy: 0.7349 - val_loss: 0.7497 - val_binary_accuracy: 0.7437
# Run:  2 / Accuracy at epoch  4  is:  0.7437185645103455
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.5701 - binary_accuracy: 0.7657 - val_loss: 0.5800 - val_binary_accuracy: 0.7437
# Run:  2 / Accuracy at epoch  5  is:  0.7437185645103455
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.5255 - binary_accuracy: 0.7878 - val_loss: 0.7970 - val_binary_accuracy: 0.7387
# Run:  2 / Accuracy at epoch  6  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.5020 - binary_accuracy: 0.8079 - val_loss: 0.7010 - val_binary_accuracy: 0.7312
# Run:  2 / Accuracy at epoch  7  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.4399 - binary_accuracy: 0.8287 - val_loss: 0.9518 - val_binary_accuracy: 0.7387
# Run:  2 / Accuracy at epoch  8  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.4087 - binary_accuracy: 0.8520 - val_loss: 0.9192 - val_binary_accuracy: 0.7412
# Run:  2 / Accuracy at epoch  9  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.3673 - binary_accuracy: 0.8684 - val_loss: 0.8315 - val_binary_accuracy: 0.7462
# Run:  2 / Accuracy at epoch  10  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.3382 - binary_accuracy: 0.8898 - val_loss: 0.9781 - val_binary_accuracy: 0.7462
# Run:  2 / Accuracy at epoch  11  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2955 - binary_accuracy: 0.9024 - val_loss: 1.1458 - val_binary_accuracy: 0.7186
# Run:  2 / Accuracy at epoch  12  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.2579 - binary_accuracy: 0.9232 - val_loss: 1.0238 - val_binary_accuracy: 0.7111
# Run:  2 / Accuracy at epoch  13  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.2370 - binary_accuracy: 0.9358 - val_loss: 1.3376 - val_binary_accuracy: 0.7312
# Run:  2 / Accuracy at epoch  14  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2300 - binary_accuracy: 0.9408 - val_loss: 1.3064 - val_binary_accuracy: 0.6935
# Run:  2 / Accuracy at epoch  15  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.1973 - binary_accuracy: 0.9578 - val_loss: 2.0255 - val_binary_accuracy: 0.6985
# Run:  2 / Accuracy at epoch  16  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.1727 - binary_accuracy: 0.9660 - val_loss: 1.7767 - val_binary_accuracy: 0.7111
# Run:  2 / Accuracy at epoch  17  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.1694 - binary_accuracy: 0.9622 - val_loss: 2.4593 - val_binary_accuracy: 0.7261
# Run:  2 / Accuracy at epoch  18  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.1715 - binary_accuracy: 0.9641 - val_loss: 1.3883 - val_binary_accuracy: 0.6809
# Run:  2 / Accuracy at epoch  19  is:  0.6809045076370239
#
# Accuracies over epochs: [0.5050251483917236, 0.5226130485534668, 0.660804033279419, 0.7311557531356812, 0.7437185645103455, 0.7437185645103455, 0.7386934757232666, 0.7311557531356812, 0.7386934757232666, 0.7412060499191284, 0.7462311387062073, 0.7462311387062073, 0.7185929417610168, 0.7110552787780762, 0.7311557531356812, 0.6934673190116882, 0.6984924674034119, 0.7110552787780762, 0.7261306643486023, 0.6809045076370239]
#
#
# 1588/1588 [==============================] - 59s 34ms/step - loss: 0.7044 - binary_accuracy: 0.5126 - val_loss: 0.6867 - val_binary_accuracy: 0.5528
# Run:  3 / Accuracy at epoch  0  is:  0.552763819694519
#
# 1588/1588 [==============================] - 52s 33ms/step - loss: 0.6936 - binary_accuracy: 0.5800 - val_loss: 0.6545 - val_binary_accuracy: 0.6407
# Run:  3 / Accuracy at epoch  1  is:  0.6407034993171692
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.6556 - binary_accuracy: 0.6770 - val_loss: 0.6364 - val_binary_accuracy: 0.6910
# Run:  3 / Accuracy at epoch  2  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.6253 - binary_accuracy: 0.7160 - val_loss: 0.5993 - val_binary_accuracy: 0.7362
# Run:  3 / Accuracy at epoch  3  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 52s 33ms/step - loss: 0.5987 - binary_accuracy: 0.7519 - val_loss: 0.7596 - val_binary_accuracy: 0.7362
# Run:  3 / Accuracy at epoch  4  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.5728 - binary_accuracy: 0.7689 - val_loss: 0.7635 - val_binary_accuracy: 0.7462
# Run:  3 / Accuracy at epoch  5  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.5374 - binary_accuracy: 0.7865 - val_loss: 0.6865 - val_binary_accuracy: 0.7462
# Run:  3 / Accuracy at epoch  6  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 52s 33ms/step - loss: 0.5063 - binary_accuracy: 0.8023 - val_loss: 0.8029 - val_binary_accuracy: 0.7337
# Run:  3 / Accuracy at epoch  7  is:  0.733668327331543
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.4637 - binary_accuracy: 0.8344 - val_loss: 0.8558 - val_binary_accuracy: 0.7362
# Run:  3 / Accuracy at epoch  8  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 52s 33ms/step - loss: 0.4386 - binary_accuracy: 0.8526 - val_loss: 0.7741 - val_binary_accuracy: 0.7563
# Run:  3 / Accuracy at epoch  9  is:  0.7562814354896545
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.4210 - binary_accuracy: 0.8589 - val_loss: 0.8276 - val_binary_accuracy: 0.7211
# Run:  3 / Accuracy at epoch  10  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.3633 - binary_accuracy: 0.8848 - val_loss: 0.8129 - val_binary_accuracy: 0.7387
# Run:  3 / Accuracy at epoch  11  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 52s 33ms/step - loss: 0.3128 - binary_accuracy: 0.8999 - val_loss: 0.9880 - val_binary_accuracy: 0.7387
# Run:  3 / Accuracy at epoch  12  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 52s 33ms/step - loss: 0.2639 - binary_accuracy: 0.9200 - val_loss: 0.9931 - val_binary_accuracy: 0.7337
# Run:  3 / Accuracy at epoch  13  is:  0.733668327331543
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2381 - binary_accuracy: 0.9288 - val_loss: 1.5329 - val_binary_accuracy: 0.7060
# Run:  3 / Accuracy at epoch  14  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.2513 - binary_accuracy: 0.9427 - val_loss: 1.8308 - val_binary_accuracy: 0.7236
# Run:  3 / Accuracy at epoch  15  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2321 - binary_accuracy: 0.9471 - val_loss: 1.8622 - val_binary_accuracy: 0.7136
# Run:  3 / Accuracy at epoch  16  is:  0.713567852973938
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.1992 - binary_accuracy: 0.9565 - val_loss: 1.6494 - val_binary_accuracy: 0.7161
# Run:  3 / Accuracy at epoch  17  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.1860 - binary_accuracy: 0.9603 - val_loss: 1.5901 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  18  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.1819 - binary_accuracy: 0.9610 - val_loss: 2.0190 - val_binary_accuracy: 0.7111
# Run:  3 / Accuracy at epoch  19  is:  0.7110552787780762
#
# Accuracies over epochs: [0.552763819694519, 0.6407034993171692, 0.6909547448158264, 0.7361809015274048, 0.7361809015274048, 0.7462311387062073, 0.7462311387062073, 0.733668327331543, 0.7361809015274048, 0.7562814354896545, 0.7211055159568787, 0.7386934757232666, 0.7386934757232666, 0.733668327331543, 0.7060301303863525, 0.7236180901527405, 0.713567852973938, 0.7160804271697998, 0.7185929417610168, 0.7110552787780762]
#
#
# 1588/1588 [==============================] - 58s 33ms/step - loss: 0.7044 - binary_accuracy: 0.4924 - val_loss: 0.6943 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.7024 - binary_accuracy: 0.5535 - val_loss: 0.6859 - val_binary_accuracy: 0.5327
# Run:  4 / Accuracy at epoch  1  is:  0.5326633453369141
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.6705 - binary_accuracy: 0.6379 - val_loss: 0.7183 - val_binary_accuracy: 0.6256
# Run:  4 / Accuracy at epoch  2  is:  0.6256281137466431
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.6404 - binary_accuracy: 0.7097 - val_loss: 0.5974 - val_binary_accuracy: 0.7010
# Run:  4 / Accuracy at epoch  3  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.6176 - binary_accuracy: 0.7191 - val_loss: 0.7094 - val_binary_accuracy: 0.7337
# Run:  4 / Accuracy at epoch  4  is:  0.733668327331543
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.5703 - binary_accuracy: 0.7645 - val_loss: 0.6791 - val_binary_accuracy: 0.7286
# Run:  4 / Accuracy at epoch  5  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.5290 - binary_accuracy: 0.7985 - val_loss: 0.7014 - val_binary_accuracy: 0.7337
# Run:  4 / Accuracy at epoch  6  is:  0.733668327331543
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.4958 - binary_accuracy: 0.8237 - val_loss: 0.7235 - val_binary_accuracy: 0.7412
# Run:  4 / Accuracy at epoch  7  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.4393 - binary_accuracy: 0.8300 - val_loss: 0.7614 - val_binary_accuracy: 0.7563
# Run:  4 / Accuracy at epoch  8  is:  0.7562814354896545
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.4073 - binary_accuracy: 0.8489 - val_loss: 0.9546 - val_binary_accuracy: 0.7563
# Run:  4 / Accuracy at epoch  9  is:  0.7562814354896545
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.3707 - binary_accuracy: 0.8753 - val_loss: 0.7867 - val_binary_accuracy: 0.7513
# Run:  4 / Accuracy at epoch  10  is:  0.7512562870979309
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.3344 - binary_accuracy: 0.8948 - val_loss: 0.9060 - val_binary_accuracy: 0.7060
# Run:  4 / Accuracy at epoch  11  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.2967 - binary_accuracy: 0.9081 - val_loss: 0.8832 - val_binary_accuracy: 0.7085
# Run:  4 / Accuracy at epoch  12  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.2790 - binary_accuracy: 0.9162 - val_loss: 1.4397 - val_binary_accuracy: 0.7161
# Run:  4 / Accuracy at epoch  13  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.2236 - binary_accuracy: 0.9414 - val_loss: 1.3731 - val_binary_accuracy: 0.7111
# Run:  4 / Accuracy at epoch  14  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.2088 - binary_accuracy: 0.9395 - val_loss: 1.6152 - val_binary_accuracy: 0.7387
# Run:  4 / Accuracy at epoch  15  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.1806 - binary_accuracy: 0.9528 - val_loss: 1.8903 - val_binary_accuracy: 0.7286
# Run:  4 / Accuracy at epoch  16  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.1841 - binary_accuracy: 0.9591 - val_loss: 1.7127 - val_binary_accuracy: 0.6859
# Run:  4 / Accuracy at epoch  17  is:  0.6859296560287476
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.1697 - binary_accuracy: 0.9628 - val_loss: 2.0089 - val_binary_accuracy: 0.6834
# Run:  4 / Accuracy at epoch  18  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.1536 - binary_accuracy: 0.9685 - val_loss: 2.0247 - val_binary_accuracy: 0.6985
# Run:  4 / Accuracy at epoch  19  is:  0.6984924674034119
#
# ...
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.3364 - binary_accuracy: 0.8961 - val_loss: 1.0247 - val_binary_accuracy: 0.7035
# Run:  2 / Accuracy at epoch  12  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.3105 - binary_accuracy: 0.9043 - val_loss: 0.9544 - val_binary_accuracy: 0.7060
# Run:  2 / Accuracy at epoch  13  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.2847 - binary_accuracy: 0.9244 - val_loss: 1.0392 - val_binary_accuracy: 0.7085
# Run:  2 / Accuracy at epoch  14  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.2505 - binary_accuracy: 0.9326 - val_loss: 1.3510 - val_binary_accuracy: 0.7286
# Run:  2 / Accuracy at epoch  15  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.2232 - binary_accuracy: 0.9458 - val_loss: 1.7816 - val_binary_accuracy: 0.6910
# Run:  2 / Accuracy at epoch  16  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.2253 - binary_accuracy: 0.9553 - val_loss: 1.2715 - val_binary_accuracy: 0.7111
# Run:  2 / Accuracy at epoch  17  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.1912 - binary_accuracy: 0.9496 - val_loss: 1.4140 - val_binary_accuracy: 0.6859
# Run:  2 / Accuracy at epoch  18  is:  0.6859296560287476
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.1893 - binary_accuracy: 0.9547 - val_loss: 1.7576 - val_binary_accuracy: 0.7035
# Run:  2 / Accuracy at epoch  19  is:  0.7035176157951355
#
# Accuracies over epochs: [0.5, 0.5226130485534668, 0.5804020166397095, 0.6809045076370239, 0.7035176157951355, 0.7211055159568787, 0.7311557531356812, 0.7160804271697998, 0.7035176157951355, 0.733668327331543, 0.6884422302246094, 0.7236180901527405, 0.7035176157951355, 0.7060301303863525, 0.7085427045822144, 0.7286432385444641, 0.6909547448158264, 0.7110552787780762, 0.6859296560287476, 0.7035176157951355]
#
#
# 1588/1588 [==============================] - 56s 32ms/step - loss: 0.7078 - binary_accuracy: 0.5107 - val_loss: 0.6927 - val_binary_accuracy: 0.5578
# Run:  3 / Accuracy at epoch  0  is:  0.5577889680862427
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.7010 - binary_accuracy: 0.5523 - val_loss: 0.6425 - val_binary_accuracy: 0.6382
# Run:  3 / Accuracy at epoch  1  is:  0.6381909251213074
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.6713 - binary_accuracy: 0.6379 - val_loss: 0.5938 - val_binary_accuracy: 0.6884
# Run:  3 / Accuracy at epoch  2  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.6188 - binary_accuracy: 0.7097 - val_loss: 0.5754 - val_binary_accuracy: 0.7111
# Run:  3 / Accuracy at epoch  3  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.6004 - binary_accuracy: 0.7456 - val_loss: 0.7074 - val_binary_accuracy: 0.7412
# Run:  3 / Accuracy at epoch  4  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.5701 - binary_accuracy: 0.7613 - val_loss: 0.5793 - val_binary_accuracy: 0.7312
# Run:  3 / Accuracy at epoch  5  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.5425 - binary_accuracy: 0.7783 - val_loss: 0.5673 - val_binary_accuracy: 0.7312
# Run:  3 / Accuracy at epoch  6  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.5161 - binary_accuracy: 0.7979 - val_loss: 0.7616 - val_binary_accuracy: 0.7337
# Run:  3 / Accuracy at epoch  7  is:  0.733668327331543
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.4795 - binary_accuracy: 0.8205 - val_loss: 0.7859 - val_binary_accuracy: 0.7387
# Run:  3 / Accuracy at epoch  8  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.4505 - binary_accuracy: 0.8268 - val_loss: 0.6033 - val_binary_accuracy: 0.7462
# Run:  3 / Accuracy at epoch  9  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 50s 31ms/step - loss: 0.4413 - binary_accuracy: 0.8533 - val_loss: 0.6694 - val_binary_accuracy: 0.7412
# Run:  3 / Accuracy at epoch  10  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 54s 34ms/step - loss: 0.4232 - binary_accuracy: 0.8621 - val_loss: 0.7878 - val_binary_accuracy: 0.7563
# Run:  3 / Accuracy at epoch  11  is:  0.7562814354896545
#
# 1588/1588 [==============================] - 55s 34ms/step - loss: 0.3897 - binary_accuracy: 0.8785 - val_loss: 0.9464 - val_binary_accuracy: 0.7513
# Run:  3 / Accuracy at epoch  12  is:  0.7512562870979309
#
# 1588/1588 [==============================] - 55s 35ms/step - loss: 0.3449 - binary_accuracy: 0.9037 - val_loss: 0.8991 - val_binary_accuracy: 0.7161
# Run:  3 / Accuracy at epoch  13  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 55s 34ms/step - loss: 0.3023 - binary_accuracy: 0.9118 - val_loss: 1.1940 - val_binary_accuracy: 0.7060
# Run:  3 / Accuracy at epoch  14  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 55s 34ms/step - loss: 0.2971 - binary_accuracy: 0.9219 - val_loss: 1.1218 - val_binary_accuracy: 0.7211
# Run:  3 / Accuracy at epoch  15  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 55s 34ms/step - loss: 0.2742 - binary_accuracy: 0.9332 - val_loss: 1.2094 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  16  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 55s 34ms/step - loss: 0.2473 - binary_accuracy: 0.9395 - val_loss: 1.3291 - val_binary_accuracy: 0.6834
# Run:  3 / Accuracy at epoch  17  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 55s 34ms/step - loss: 0.2284 - binary_accuracy: 0.9433 - val_loss: 1.6837 - val_binary_accuracy: 0.7085
# Run:  3 / Accuracy at epoch  18  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 55s 34ms/step - loss: 0.2199 - binary_accuracy: 0.9547 - val_loss: 2.0731 - val_binary_accuracy: 0.7111
# Run:  3 / Accuracy at epoch  19  is:  0.7110552787780762
#
# Accuracies over epochs: [0.5577889680862427, 0.6381909251213074, 0.6884422302246094, 0.7110552787780762, 0.7412060499191284, 0.7311557531356812, 0.7311557531356812, 0.733668327331543, 0.7386934757232666, 0.7462311387062073, 0.7412060499191284, 0.7562814354896545, 0.7512562870979309, 0.7160804271697998, 0.7060301303863525, 0.7211055159568787, 0.7185929417610168, 0.6834170818328857, 0.7085427045822144, 0.7110552787780762]
#
#
# 1588/1588 [==============================] - 57s 33ms/step - loss: 0.7071 - binary_accuracy: 0.4969 - val_loss: 0.6933 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.7032 - binary_accuracy: 0.5019 - val_loss: 0.6934 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy at epoch  1  is:  0.5
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.6811 - binary_accuracy: 0.6190 - val_loss: 0.6329 - val_binary_accuracy: 0.6658
# Run:  4 / Accuracy at epoch  2  is:  0.6658291220664978
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.6401 - binary_accuracy: 0.6826 - val_loss: 0.6953 - val_binary_accuracy: 0.6960
# Run:  4 / Accuracy at epoch  3  is:  0.69597989320755
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.6086 - binary_accuracy: 0.7128 - val_loss: 0.6816 - val_binary_accuracy: 0.7186
# Run:  4 / Accuracy at epoch  4  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.5867 - binary_accuracy: 0.7393 - val_loss: 0.7763 - val_binary_accuracy: 0.7035
# Run:  4 / Accuracy at epoch  5  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.5456 - binary_accuracy: 0.7802 - val_loss: 0.7837 - val_binary_accuracy: 0.7312
# Run:  4 / Accuracy at epoch  6  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.5354 - binary_accuracy: 0.7909 - val_loss: 0.8026 - val_binary_accuracy: 0.7387
# Run:  4 / Accuracy at epoch  7  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.5001 - binary_accuracy: 0.8060 - val_loss: 0.6934 - val_binary_accuracy: 0.7437
# Run:  4 / Accuracy at epoch  8  is:  0.7437185645103455
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.4765 - binary_accuracy: 0.8268 - val_loss: 0.9181 - val_binary_accuracy: 0.7261
# Run:  4 / Accuracy at epoch  9  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.4276 - binary_accuracy: 0.8545 - val_loss: 0.7973 - val_binary_accuracy: 0.7462
# Run:  4 / Accuracy at epoch  10  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.3963 - binary_accuracy: 0.8722 - val_loss: 0.7843 - val_binary_accuracy: 0.7236
# Run:  4 / Accuracy at epoch  11  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.3464 - binary_accuracy: 0.8885 - val_loss: 0.7625 - val_binary_accuracy: 0.7236
# Run:  4 / Accuracy at epoch  12  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.3533 - binary_accuracy: 0.8992 - val_loss: 0.7447 - val_binary_accuracy: 0.6960
# Run:  4 / Accuracy at epoch  13  is:  0.69597989320755
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2969 - binary_accuracy: 0.9125 - val_loss: 1.0056 - val_binary_accuracy: 0.7186
# Run:  4 / Accuracy at epoch  14  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2974 - binary_accuracy: 0.9225 - val_loss: 1.1006 - val_binary_accuracy: 0.6834
# Run:  4 / Accuracy at epoch  15  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2497 - binary_accuracy: 0.9332 - val_loss: 1.7845 - val_binary_accuracy: 0.6985
# Run:  4 / Accuracy at epoch  16  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2499 - binary_accuracy: 0.9408 - val_loss: 1.4367 - val_binary_accuracy: 0.6533
# Run:  4 / Accuracy at epoch  17  is:  0.6532663106918335
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2027 - binary_accuracy: 0.9515 - val_loss: 2.0170 - val_binary_accuracy: 0.6482
# Run:  4 / Accuracy at epoch  18  is:  0.6482412219047546
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.1807 - binary_accuracy: 0.9578 - val_loss: 2.1107 - val_binary_accuracy: 0.6935
# Run:  4 / Accuracy at epoch  19  is:  0.6934673190116882
#
# Accuracies over epochs: [0.5, 0.5, 0.6658291220664978, 0.69597989320755, 0.7185929417610168, 0.7035176157951355, 0.7311557531356812, 0.7386934757232666, 0.7437185645103455, 0.7261306643486023, 0.7462311387062073, 0.7236180901527405, 0.7236180901527405, 0.69597989320755, 0.7185929417610168, 0.6834170818328857, 0.6984924674034119, 0.6532663106918335, 0.6482412219047546, 0.6934673190116882]
#
#
# 1588/1588 [==============================] - 57s 33ms/step - loss: 0.7072 - binary_accuracy: 0.4893 - val_loss: 0.6940 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy at epoch  0  is:  0.5
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.7051 - binary_accuracy: 0.5063 - val_loss: 0.6870 - val_binary_accuracy: 0.5879
# Run:  5 / Accuracy at epoch  1  is:  0.5879396796226501
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.6919 - binary_accuracy: 0.5989 - val_loss: 0.6191 - val_binary_accuracy: 0.6558
# Run:  5 / Accuracy at epoch  2  is:  0.6557788848876953
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.6601 - binary_accuracy: 0.6675 - val_loss: 0.6481 - val_binary_accuracy: 0.6884
# Run:  5 / Accuracy at epoch  3  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.6359 - binary_accuracy: 0.7103 - val_loss: 0.6136 - val_binary_accuracy: 0.7060
# Run:  5 / Accuracy at epoch  4  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.5972 - binary_accuracy: 0.7317 - val_loss: 0.6203 - val_binary_accuracy: 0.7136
# Run:  5 / Accuracy at epoch  5  is:  0.713567852973938
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.5518 - binary_accuracy: 0.7632 - val_loss: 0.6884 - val_binary_accuracy: 0.7136
# Run:  5 / Accuracy at epoch  6  is:  0.713567852973938
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.5246 - binary_accuracy: 0.7922 - val_loss: 0.8691 - val_binary_accuracy: 0.7211
# Run:  5 / Accuracy at epoch  7  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.4946 - binary_accuracy: 0.8130 - val_loss: 0.7349 - val_binary_accuracy: 0.6935
# Run:  5 / Accuracy at epoch  8  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.4810 - binary_accuracy: 0.8287 - val_loss: 0.9410 - val_binary_accuracy: 0.7412
# Run:  5 / Accuracy at epoch  9  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.4391 - binary_accuracy: 0.8589 - val_loss: 0.8619 - val_binary_accuracy: 0.7236
# Run:  5 / Accuracy at epoch  10  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.4086 - binary_accuracy: 0.8583 - val_loss: 0.9604 - val_binary_accuracy: 0.7236
# Run:  5 / Accuracy at epoch  11  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.3700 - binary_accuracy: 0.8728 - val_loss: 0.9960 - val_binary_accuracy: 0.7312
# Run:  5 / Accuracy at epoch  12  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.3417 - binary_accuracy: 0.8904 - val_loss: 1.2441 - val_binary_accuracy: 0.7035
# Run:  5 / Accuracy at epoch  13  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.3004 - binary_accuracy: 0.9106 - val_loss: 1.2963 - val_binary_accuracy: 0.6859
# Run:  5 / Accuracy at epoch  14  is:  0.6859296560287476
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2868 - binary_accuracy: 0.9244 - val_loss: 1.2432 - val_binary_accuracy: 0.7362
# Run:  5 / Accuracy at epoch  15  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2553 - binary_accuracy: 0.9339 - val_loss: 1.8145 - val_binary_accuracy: 0.7136
# Run:  5 / Accuracy at epoch  16  is:  0.713567852973938
#
# 1588/1588 [==============================] - 52s 32ms/step - loss: 0.2812 - binary_accuracy: 0.9377 - val_loss: 1.1741 - val_binary_accuracy: 0.6910
# Run:  5 / Accuracy at epoch  17  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.2573 - binary_accuracy: 0.9389 - val_loss: 1.3340 - val_binary_accuracy: 0.7186
# Run:  5 / Accuracy at epoch  18  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 51s 32ms/step - loss: 0.2306 - binary_accuracy: 0.9427 - val_loss: 1.5876 - val_binary_accuracy: 0.7035
# Run:  5 / Accuracy at epoch  19  is:  0.7035176157951355
#
# Accuracies over epochs: [0.5, 0.5879396796226501, 0.6557788848876953, 0.6884422302246094, 0.7060301303863525, 0.713567852973938, 0.713567852973938, 0.7211055159568787, 0.6934673190116882, 0.7412060499191284, 0.7236180901527405, 0.7236180901527405, 0.7311557531356812, 0.7035176157951355, 0.6859296560287476, 0.7361809015274048, 0.713567852973938, 0.6909547448158264, 0.7185929417610168, 0.7035176157951355]
#
#
#
#
#  Over all runs maximum accuracies on English are: [0.733668327331543, 0.7412060499191284, 0.7437185645103455, 0.7462311387062073, 0.7562814354896545]
# The median for English is: 0.7437185645103455
#
#
#
# BiLSTM Accuracy Score on Test set ->  ['0.7437185645103455 +/- 0.012562870979309082']

# %% [markdown]
# ## Now show compact results in a table.

# %%
print(" PREPRO FUNCTION    |  Test Accuracy   |",end = '')

print("\n")
for prepro_func in prepro_functions_dict_comb:
  #print(prepro_func,"\t\t\t",format(round(model_results[prepro_func][0],4),'.4f'),"\t\t",end='')
  result = model_results[prepro_func][0]
  # result = format(round(model_results[prepro_func][0],4),'.4f')
  print(f'{prepro_func:27}{ result :12}')
  print("\n")
# Out:
#  PREPRO FUNCTION    |  Test Accuracy   |
#
# DON                        0.7462311387062073 +/- 0.02010047435760498
#
#
# LOW                        0.7487437129020691 +/- 0.015075385570526123
#
#
# RSW                        0.7562814354896545 +/- 0.03517591953277588
#
#
# STM                        0.7487437129020691 +/- 0.022613048553466797
#
#
# LOW_RSW                    0.7512562870979309 +/- 0.007537722587585449
#
#
# LOW_STM                    0.7487437129020691 +/- 0.02010047435760498
#
#
# RSW_LOW                    0.7437185645103455 +/- 0.007537662982940674
#
#
# RSW_STM                    0.7512562870979309 +/- 0.020100533962249756
#
#
# STM_LOW                    0.7462311387062073 +/- 0.012562811374664307
#
#
# STM_RSW                    0.7487437129020691 +/- 0.01005023717880249
#
#
# LOW_STM_RSW                0.7487437129020691 +/- 0.007537722587585449
#
#
# LOW_RSW_STM                0.7512562870979309 +/- 0.012562811374664307
#
#
# STM_LOW_RSW                0.7512562870979309 +/- 0.005025148391723633
#
#
# STM_RSW_LOW                0.7462311387062073 +/- 0.0025125741958618164
#
#
# RSW_LOW_STM                0.7437185645103455 +/- 0.012562870979309082
#
#
# RSW_STM_LOW                0.7437185645103455 +/- 0.012562870979309082
