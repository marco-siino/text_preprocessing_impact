# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/text_preprocessing_impact/blob/main/PCL_DS/CNN_PCL_TextPreProImpact_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances.
# - - -
# CNN ON PCL DS EXPERIMENTS NOTEBOOK
# - - -
# Convolutional Neural Network on Patronizing and Condescending Language Dataset.
# Code by M. Siino.
#
# From the paper: "Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances." by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf
import numpy as np
import pandas as pd
import nltk

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from io import open
from pathlib import Path
from urllib import request

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer
from textblob import TextBlob
nltk.download('stopwords')
nltk.download('punkt')

os.environ['TF_CUDNN_DETERMINISTIC']='false'
os.environ['TF_DETERMINISTIC_OPS']='false'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Fetch all the files needed.

# %%
urlDontPatronizeMe_PCL_tsv = "https://drive.google.com/uc?export=download&id=1KAncWruZ4OkKlvEGnxLkNbR1sxAErG8_"
urlDontPatronizeMe_categories_tsv = "https://drive.google.com/uc?export=download&id=1KMZJsskzKLbM-kgYiwXIF0h3Shj4F0mM"
urlTestSet_csv = "https://drive.google.com/uc?export=download&id=161-_6MH16_UHtLTqt0nd09l68pP5MEbQ"
urlDevSet_csv = "https://drive.google.com/uc?export=download&id=1KNuZ_h7NXTSwEz3_0XkaEd4DUAyxojAU"
urlTrainSet_csv = "https://drive.google.com/uc?export=download&id=1KVRrMC9UVwtQE9QfcLv8b11P5t2BhA8I"

tmp = tf.keras.utils.get_file("dontpatronizeme_pcl.tsv", urlDontPatronizeMe_PCL_tsv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("dontpatronizeme_categories.tsv", urlDontPatronizeMe_categories_tsv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("task4_test.csv", urlTestSet_csv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("dev_semeval_parids-labels.csv", urlDevSet_csv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')
tmp = tf.keras.utils.get_file("train_semeval_parids-labels.csv", urlTrainSet_csv,
                                    extract=False, cache_dir='.',
                                    cache_subdir='')

# %% [markdown]
# ## Fetch Don't Patronize Me! data manager module

# %%
module_url = f"https://raw.githubusercontent.com/Perez-AlmendrosC/dontpatronizeme/master/semeval-2022/dont_patronize_me.py"
module_name = module_url.split('/')[-1]
print(f'Fetching {module_url}')
#with open("file_1.txt") as f1, open("file_2.txt") as f2
with request.urlopen(module_url) as f, open(module_name,'w') as outf:
  a = f.read()
  outf.write(a.decode('utf-8'))
# Out:
# Fetching https://raw.githubusercontent.com/Perez-AlmendrosC/dontpatronizeme/master/semeval-2022/dont_patronize_me.py

# %% [markdown]
# ## Import and load dpm

# %%
from dont_patronize_me import DontPatronizeMe
dpm = DontPatronizeMe('.', '.')
dpm.load_task1()
dpm.load_task2(return_one_hot=True)
# Out:
# Map of label to numerical label:
# {'Unbalanced_power_relations': 0, 'Shallow_solution': 1, 'Presupposition': 2, 'Authority_voice': 3, 'Metaphors': 4, 'Compassion': 5, 'The_poorer_the_merrier': 6}

# %% [markdown]
# ## Load paragraph IDs

# %%
trids = pd.read_csv('train_semeval_parids-labels.csv')
teids = pd.read_csv('dev_semeval_parids-labels.csv')

# %%
print(trids.head())
print(len(trids))
print(len(teids))
# Out:
#    par_id                  label
# 0    4341  [1, 0, 0, 1, 0, 0, 0]
# 1    4136  [0, 1, 0, 0, 0, 0, 0]
# 2   10352  [1, 0, 0, 0, 0, 1, 0]
# 3    8279  [0, 0, 0, 1, 0, 0, 0]
# 4    1164  [1, 0, 0, 1, 1, 1, 0]
# 8375
# 2094

# %%
trids.par_id = trids.par_id.astype(str)
teids.par_id = teids.par_id.astype(str)

# %% [markdown]
# ## Rebuild training set (Task 1)

# %%
rows = [] # will contain par_id, keyword, country, label and text
for idx in range(len(trids)):  
  parid = trids.par_id[idx]
  #print(parid)
  # select row from original dataset to retrieve `text` and binary label
  text = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].text.values[0]
  label = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].label.values[0]
  #keyword = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].keyword.values[0]
  #country = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].country.values[0]
  rows.append({
      'par_id':parid,
      #'keyword':keyword,
      #'country':country,
      'text':text,
      'label':label
  })

# %%
trdf1 = pd.DataFrame(rows)

# %%
len(rows)
# Out:
# 8375

# %%
print(trdf1)
# Out:
#      par_id                                               text  label
# 0      4341  The scheme saw an estimated 150,000 children f...      1
# 1      4136  Durban 's homeless communities reconciliation ...      1
# 2     10352  The next immediate problem that cropped up was...      1
# 3      8279  Far more important than the implications for t...      1
# 4      1164  To strengthen child-sensitive social protectio...      1
# ...     ...                                                ...    ...
# 8370   8380  Rescue teams search for survivors on the rubbl...      0
# 8371   8381  The launch of ' Happy Birthday ' took place la...      0
# 8372   8382  The unrest has left at least 20,000 people dea...      0
# 8373   8383  You have to see it from my perspective . I may...      0
# 8374   8384  Yet there was one occasion when we went to the...      0
#
# [8375 rows x 3 columns]

# %%
# Next row to balance the DS.
bal_trdf1 = trdf1.drop(trdf1.index[-6787:])

print("Total number of samples is:",len(bal_trdf1))
print("Total number of class 1 samples is:",sum(bal_trdf1.label == 1))
print("Total number of class 0 samples is:",sum(bal_trdf1.label == 0))

trdf1 = bal_trdf1
# Out:
# Total number of samples is: 1588
# Total number of class 1 samples is: 794
# Total number of class 0 samples is: 794

# %% [markdown]
# ## Rebuild test set (Task 1)

# %%
rows = [] # will contain par_id, label and text
for idx in range(len(teids)):  
  parid = teids.par_id[idx]
  #print(parid)
  # select row from original dataset
  text = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].text.values[0]
  label = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].label.values[0]
  #keyword = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].keyword.values[0]
  #country = dpm.train_task1_df.loc[dpm.train_task1_df.par_id == parid].country.values[0]
  rows.append({
      'par_id':parid,
      #'keyword':keyword,
      #'country':country,
      'text':text,
      'label':label
  })

# %%
len(rows)
# Out:
# 2094

# %%
tedf1 = pd.DataFrame(rows)

# %%
# Next row to balance the DS.
bal_tedf1 = tedf1.drop(tedf1.index[-1696:])

print("Total number of samples is:",len(bal_tedf1))
print("Total number of class 1 samples is:",sum(bal_tedf1.label == 1))
print("Total number of class 0 samples is:",sum(bal_tedf1.label == 0))

tedf1 = bal_tedf1
# Out:
# Total number of samples is: 398
# Total number of class 1 samples is: 199
# Total number of class 0 samples is: 199

# %% [markdown]
# ## Preprocessing functions definitions

# %%
# Do-Nothing preprocessing function.
def DON(input_data):
  tag_open_CDATA_removed = tf.strings.regex_replace(input_data, '<\!\[CDATA\[', ' ')
  tag_closed_CDATA_removed = tf.strings.regex_replace(tag_open_CDATA_removed,'\]{1,}>', ' ')
  tag_author_lang_en_removed = tf.strings.regex_replace(tag_closed_CDATA_removed,'<author lang="en">', ' ')
  tag_closed_author_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'</author>', ' ')
  tag_open_documents_removed = tf.strings.regex_replace(tag_closed_author_removed,'<documents>\n(\t){0,2}', '')
  output_data = tf.strings.regex_replace(tag_open_documents_removed,'</documents>\n(\t){0,2}', ' ')
  return output_data

# Lowercasing preprocessing function.
def LOW(input_data):  
  return tf.strings.lower(DON(input_data))

# Removing Stop Words function.
def RSW(input_data):
  output_data = DON(input_data)

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:

      # input_string = input_string.numpy() [0]
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("Tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# Porter Stemmer preprocessing function.
def STM(input_data):
  output_data = DON(input_data)
  stemmer = PorterStemmer()

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      #print(input_string)
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:
      #input_string = input_string.numpy()[0]
      input_string = input_string.numpy()
      #print(input_string)
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# %% [markdown]
# ## Define the combined preprocessing functions. (The base functions are: DON, LOW, RSW and STM).

# %%
## SECTION WITH PAIRS OF PREPRO FUNCTIONS. APPLICATION ORDER MATTERS (...IN FOLLOWING SECTIONS TOO).
#...5
def LOW_RSW(input_data):
  return RSW(LOW(input_data))

# 6
def LOW_STM(input_data):
  return STM(LOW(input_data))

# 7
def RSW_LOW(input_data):
  return LOW(RSW(input_data))

# 8
def RSW_STM(input_data):
  return STM(RSW(input_data))

# 9
def STM_LOW(input_data):
  return LOW(STM(input_data))

# 10
def STM_RSW(input_data):
  return RSW(STM(input_data))
  
# 11
def LOW_STM_RSW(input_data):
  return RSW(STM(LOW(input_data)))

# 12
def LOW_RSW_STM(input_data):
  return STM(RSW(LOW(input_data)))

# 13
def STM_LOW_RSW(input_data):
  return RSW(LOW(STM(input_data)))

# 14
def STM_RSW_LOW(input_data):
  return LOW(RSW(STM(input_data)))

# 15
def RSW_LOW_STM(input_data):
  return STM(LOW(RSW(input_data)))

# 16
def RSW_STM_LOW(input_data):
  return LOW(STM(RSW(input_data)))

# %% [markdown]
# ## Build a Tensorflow DS

# %%
tf.random.set_seed(1)

train_ds = False
for i in range(0,len(trdf1)):
  sample = [' '+trdf1['text'][i]]
  label = [trdf1['label'][i]]

  current_set = (
    tf.data.Dataset.from_tensor_slices(
        (
            [tf.cast(sample,tf.string)],
            [tf.cast(label, tf.int32)]
        )
    )
  )
  if train_ds != False:
    train_ds = train_ds.concatenate(current_set)
  else:
    train_ds = current_set
train_ds = train_ds.shuffle(len(train_ds), reshuffle_each_iteration=False)

test_ds = False
for i in range(0,len(tedf1)):
  sample = [' '+tedf1['text'][i]]
  label = [tedf1['label'][i]]

  current_set = (
    tf.data.Dataset.from_tensor_slices(
        (
            [tf.cast(sample,tf.string)],
            [tf.cast(label, tf.int32)]
        )
    )
  )
  if test_ds != False:
    test_ds = test_ds.concatenate(current_set)
  else:
    test_ds = current_set

for element in train_ds:
    authorDocument=element[0]
    label=element[1]
    print(authorDocument)
    print(label)
    break
    
print(train_ds)
# Out:
# tf.Tensor([b' LUSAKA Zambia ( Xinhua ) -- Zambia ? s Immigration Department said Wednesday that it had arrested at least 45 illegal immigrants in Lusaka , the country ? s capital .'], shape=(1,), dtype=string)
# tf.Tensor([0], shape=(1,), dtype=int32)
# <ShuffleDataset element_spec=(TensorSpec(shape=(1,), dtype=tf.string, name=None), TensorSpec(shape=(1,), dtype=tf.int32, name=None))>

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(preprocessing_function,training_set):
  # Set a very large sequence length to find the longest sample in the training set.
  sequence_length = 30000
  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    # Count the number of zeros from the last non-zero token to the end of the sample. 
    # Shortest tokenized sample has less zeros than others.
    out=model(authorDocument)
    token_nr_index=sequence_length-1
    current_sample_zeros_counter=0
    while out.numpy()[0][token_nr_index]==0:
      token_nr_index-=1
      current_sample_zeros_counter+=1

    shortest_padding_length=sequence_length-longest_sample_length
    if current_sample_zeros_counter<shortest_padding_length:
      longest_sample_length=sequence_length-current_sample_zeros_counter

  #print(out.numpy()[0][3229:3400])
  #print(longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Define a dictionary with -> function_names:prepro_function_caller. And a dictionary to store model results.

# %%
model_results = {}
prepro_functions_dict_base = {
    'DON':DON,
    'LOW':LOW,
    'RSW':RSW,
    'STM':STM
    }

# 3 prepro functions = 15 combs...+1 for do_nothing

prepro_functions_dict_comb = {
    # 1. Do nothing 
    'DON': DON,
    # 2. Lowercasing 
    'LOW':LOW,
    # 3. Removing Stopwords
    'RSW':RSW, 
    # 4. Porter Stemming
    'STM':STM,
    # 5. LOW->RSW
    'LOW_RSW':LOW_RSW, 
    # 6. LOW->STM
    'LOW_STM':LOW_STM,
    # 7. RSW->LOW
    'RSW_LOW':RSW_LOW,
    # 8. RSW->STM
    'RSW_STM':RSW_STM,
    # 9. STM->LOW
    'STM_LOW':STM_LOW,
    # 10. STM->RSW
    'STM_RSW':STM_RSW,
    # 11. LOW->STM->RSW
    'LOW_STM_RSW':LOW_STM_RSW,  
    # 12. LOW->RSW->STM
    'LOW_RSW_STM':LOW_RSW_STM,
    # 13. STM->LOW->RSW
    'STM_LOW_RSW':STM_LOW_RSW,
    # 14. STM->RSW->LOW
    'STM_RSW_LOW':STM_RSW_LOW,
    # 15. RSW->LOW->STM
    'RSW_LOW_STM':RSW_LOW_STM,
    # 16. RSW->STM->LOW
    'RSW_STM_LOW':RSW_STM_LOW
}

for key in prepro_functions_dict_comb:
  print(key)
  model_results[key]=[]
# Out:
# DON
# LOW
# RSW
# STM
# LOW_RSW
# LOW_STM
# RSW_LOW
# RSW_STM
# STM_LOW
# STM_RSW
# LOW_STM_RSW
# LOW_RSW_STM
# STM_LOW_RSW
# STM_RSW_LOW
# RSW_LOW_STM
# RSW_STM_LOW

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Models definition and evaluation.

# %%
tf.random.set_seed(0)
TF_DISABLE_SEGMENT_REDUCTION_OP_DETERMINISM_EXCEPTIONS=True

# Reset model_results list.
for key in prepro_functions_dict_comb:
  model_results[key]=[]

for key in prepro_functions_dict_comb:
  runs_accuracy = []

  print("\n\n* * * * EVALUATION USING", key, "AS PREPROCESSING FUNCTION * * * *")

  # Preprocess training set to build a dictionary.
  vectorize_layer = preprocess_and_adapt_ts(prepro_functions_dict_comb[key],train_ds)

  max_features=len(vectorize_layer.get_vocabulary()) + 1
  print("Vocabulary size is:", max_features)

  for run in range(1,(num_runs+1)):
    epochs_accuracy=[]
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    layers.Conv1D(256,16,activation='relu'),
                                    layers.MaxPooling1D(),
                                    layers.Dropout(0.6),

                                    layers.Dense(512,activation='relu'),
                           
                                    layers.GlobalAveragePooling1D(),
                                    layers.Dropout(0.2),
                                    layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer=opt, metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        print("Run: ",run,"/ Accuracy at epoch ",epoch," is: ", accuracy[0],"\n")
        epochs_accuracy.append(accuracy[0])

    print("Accuracies over epochs:",epochs_accuracy,"\n\n")
    runs_accuracy.append(max(epochs_accuracy))

  runs_accuracy.sort()
  print("\n\n Over all runs maximum accuracies on English are:", runs_accuracy)
  print("The median for English is:",runs_accuracy[2],"\n\n\n")
  
  if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
    max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
  else:
    max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
  final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
  model_results[key].append(final_result)
  print("CNN Accuracy Score on Test set -> ",model_results[key])
# Out:
# * * * * EVALUATION USING DON AS PREPROCESSING FUNCTION * * * *
# Vocabulary size is: 12384
# 1588/1588 [==============================] - 21s 9ms/step - loss: 0.7016 - binary_accuracy: 0.5460 - val_loss: 0.6380 - val_binary_accuracy: 0.6407
# Run:  1 / Accuracy at epoch  0  is:  0.6407034993171692
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6627 - binary_accuracy: 0.6568 - val_loss: 0.5997 - val_binary_accuracy: 0.6960
# Run:  1 / Accuracy at epoch  1  is:  0.69597989320755
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6238 - binary_accuracy: 0.7179 - val_loss: 0.6574 - val_binary_accuracy: 0.7010
# Run:  1 / Accuracy at epoch  2  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5995 - binary_accuracy: 0.7462 - val_loss: 0.6603 - val_binary_accuracy: 0.7186
# Run:  1 / Accuracy at epoch  3  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5702 - binary_accuracy: 0.7601 - val_loss: 0.7512 - val_binary_accuracy: 0.7136
# Run:  1 / Accuracy at epoch  4  is:  0.713567852973938
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5412 - binary_accuracy: 0.7897 - val_loss: 0.7693 - val_binary_accuracy: 0.7186
# Run:  1 / Accuracy at epoch  5  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5542 - binary_accuracy: 0.7916 - val_loss: 0.7753 - val_binary_accuracy: 0.7060
# Run:  1 / Accuracy at epoch  6  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5069 - binary_accuracy: 0.8086 - val_loss: 0.8620 - val_binary_accuracy: 0.7060
# Run:  1 / Accuracy at epoch  7  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5047 - binary_accuracy: 0.8060 - val_loss: 0.8625 - val_binary_accuracy: 0.7111
# Run:  1 / Accuracy at epoch  8  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4974 - binary_accuracy: 0.8205 - val_loss: 0.8560 - val_binary_accuracy: 0.7186
# Run:  1 / Accuracy at epoch  9  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4689 - binary_accuracy: 0.8117 - val_loss: 0.7609 - val_binary_accuracy: 0.7211
# Run:  1 / Accuracy at epoch  10  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4769 - binary_accuracy: 0.8300 - val_loss: 0.8114 - val_binary_accuracy: 0.7236
# Run:  1 / Accuracy at epoch  11  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4748 - binary_accuracy: 0.8445 - val_loss: 0.7709 - val_binary_accuracy: 0.7312
# Run:  1 / Accuracy at epoch  12  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4463 - binary_accuracy: 0.8407 - val_loss: 0.7612 - val_binary_accuracy: 0.7462
# Run:  1 / Accuracy at epoch  13  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4388 - binary_accuracy: 0.8589 - val_loss: 0.7735 - val_binary_accuracy: 0.7362
# Run:  1 / Accuracy at epoch  14  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4216 - binary_accuracy: 0.8571 - val_loss: 0.8024 - val_binary_accuracy: 0.7337
# Run:  1 / Accuracy at epoch  15  is:  0.733668327331543
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4279 - binary_accuracy: 0.8709 - val_loss: 0.8471 - val_binary_accuracy: 0.7236
# Run:  1 / Accuracy at epoch  16  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4071 - binary_accuracy: 0.8634 - val_loss: 0.8528 - val_binary_accuracy: 0.7236
# Run:  1 / Accuracy at epoch  17  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.3904 - binary_accuracy: 0.8671 - val_loss: 0.8194 - val_binary_accuracy: 0.7286
# Run:  1 / Accuracy at epoch  18  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4124 - binary_accuracy: 0.8747 - val_loss: 0.8791 - val_binary_accuracy: 0.7261
# Run:  1 / Accuracy at epoch  19  is:  0.7261306643486023
#
# Accuracies over epochs: [0.6407034993171692, 0.69597989320755, 0.7010050415992737, 0.7185929417610168, 0.713567852973938, 0.7185929417610168, 0.7060301303863525, 0.7060301303863525, 0.7110552787780762, 0.7185929417610168, 0.7211055159568787, 0.7236180901527405, 0.7311557531356812, 0.7462311387062073, 0.7361809015274048, 0.733668327331543, 0.7236180901527405, 0.7236180901527405, 0.7286432385444641, 0.7261306643486023]
#
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.7032 - binary_accuracy: 0.5435 - val_loss: 0.6319 - val_binary_accuracy: 0.6533
# Run:  2 / Accuracy at epoch  0  is:  0.6532663106918335
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6468 - binary_accuracy: 0.6637 - val_loss: 0.5936 - val_binary_accuracy: 0.7010
# Run:  2 / Accuracy at epoch  1  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6263 - binary_accuracy: 0.7059 - val_loss: 0.5787 - val_binary_accuracy: 0.7236
# Run:  2 / Accuracy at epoch  2  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5868 - binary_accuracy: 0.7418 - val_loss: 0.6106 - val_binary_accuracy: 0.7286
# Run:  2 / Accuracy at epoch  3  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5754 - binary_accuracy: 0.7576 - val_loss: 0.6710 - val_binary_accuracy: 0.7111
# Run:  2 / Accuracy at epoch  4  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5508 - binary_accuracy: 0.7746 - val_loss: 0.7561 - val_binary_accuracy: 0.7161
# Run:  2 / Accuracy at epoch  5  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5294 - binary_accuracy: 0.8035 - val_loss: 0.8118 - val_binary_accuracy: 0.7211
# Run:  2 / Accuracy at epoch  6  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5156 - binary_accuracy: 0.7979 - val_loss: 0.7635 - val_binary_accuracy: 0.7161
# Run:  2 / Accuracy at epoch  7  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5031 - binary_accuracy: 0.8042 - val_loss: 0.8140 - val_binary_accuracy: 0.7136
# Run:  2 / Accuracy at epoch  8  is:  0.713567852973938
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5005 - binary_accuracy: 0.8105 - val_loss: 0.8015 - val_binary_accuracy: 0.7161
# Run:  2 / Accuracy at epoch  9  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4633 - binary_accuracy: 0.8331 - val_loss: 0.8327 - val_binary_accuracy: 0.7261
# Run:  2 / Accuracy at epoch  10  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4800 - binary_accuracy: 0.8338 - val_loss: 0.8462 - val_binary_accuracy: 0.7211
# Run:  2 / Accuracy at epoch  11  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4715 - binary_accuracy: 0.8218 - val_loss: 0.7740 - val_binary_accuracy: 0.7337
# Run:  2 / Accuracy at epoch  12  is:  0.733668327331543
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4402 - binary_accuracy: 0.8445 - val_loss: 0.8603 - val_binary_accuracy: 0.7286
# Run:  2 / Accuracy at epoch  13  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4481 - binary_accuracy: 0.8463 - val_loss: 0.7654 - val_binary_accuracy: 0.7362
# Run:  2 / Accuracy at epoch  14  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4189 - binary_accuracy: 0.8558 - val_loss: 0.8590 - val_binary_accuracy: 0.7286
# Run:  2 / Accuracy at epoch  15  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4287 - binary_accuracy: 0.8589 - val_loss: 0.8447 - val_binary_accuracy: 0.7286
# Run:  2 / Accuracy at epoch  16  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4037 - binary_accuracy: 0.8671 - val_loss: 0.8849 - val_binary_accuracy: 0.7312
# Run:  2 / Accuracy at epoch  17  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4100 - binary_accuracy: 0.8690 - val_loss: 0.8253 - val_binary_accuracy: 0.7236
# Run:  2 / Accuracy at epoch  18  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4100 - binary_accuracy: 0.8734 - val_loss: 0.8273 - val_binary_accuracy: 0.7312
# Run:  2 / Accuracy at epoch  19  is:  0.7311557531356812
#
# Accuracies over epochs: [0.6532663106918335, 0.7010050415992737, 0.7236180901527405, 0.7286432385444641, 0.7110552787780762, 0.7160804271697998, 0.7211055159568787, 0.7160804271697998, 0.713567852973938, 0.7160804271697998, 0.7261306643486023, 0.7211055159568787, 0.733668327331543, 0.7286432385444641, 0.7361809015274048, 0.7286432385444641, 0.7286432385444641, 0.7311557531356812, 0.7236180901527405, 0.7311557531356812]
#
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.7011 - binary_accuracy: 0.5416 - val_loss: 0.6380 - val_binary_accuracy: 0.6080
# Run:  3 / Accuracy at epoch  0  is:  0.6080402135848999
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6557 - binary_accuracy: 0.6662 - val_loss: 0.5947 - val_binary_accuracy: 0.7085
# Run:  3 / Accuracy at epoch  1  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6193 - binary_accuracy: 0.7273 - val_loss: 0.6031 - val_binary_accuracy: 0.7161
# Run:  3 / Accuracy at epoch  2  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5931 - binary_accuracy: 0.7330 - val_loss: 0.6371 - val_binary_accuracy: 0.7211
# Run:  3 / Accuracy at epoch  3  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5682 - binary_accuracy: 0.7613 - val_loss: 0.6557 - val_binary_accuracy: 0.7136
# Run:  3 / Accuracy at epoch  4  is:  0.713567852973938
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5527 - binary_accuracy: 0.7827 - val_loss: 0.7117 - val_binary_accuracy: 0.7085
# Run:  3 / Accuracy at epoch  5  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5289 - binary_accuracy: 0.7897 - val_loss: 0.7148 - val_binary_accuracy: 0.7161
# Run:  3 / Accuracy at epoch  6  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5142 - binary_accuracy: 0.7935 - val_loss: 0.7531 - val_binary_accuracy: 0.7161
# Run:  3 / Accuracy at epoch  7  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5033 - binary_accuracy: 0.8111 - val_loss: 0.7875 - val_binary_accuracy: 0.7136
# Run:  3 / Accuracy at epoch  8  is:  0.713567852973938
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4882 - binary_accuracy: 0.8224 - val_loss: 0.8128 - val_binary_accuracy: 0.7161
# Run:  3 / Accuracy at epoch  9  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4500 - binary_accuracy: 0.8319 - val_loss: 0.7303 - val_binary_accuracy: 0.7337
# Run:  3 / Accuracy at epoch  10  is:  0.733668327331543
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4561 - binary_accuracy: 0.8419 - val_loss: 0.8673 - val_binary_accuracy: 0.7236
# Run:  3 / Accuracy at epoch  11  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4719 - binary_accuracy: 0.8438 - val_loss: 0.7301 - val_binary_accuracy: 0.7487
# Run:  3 / Accuracy at epoch  12  is:  0.7487437129020691
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4428 - binary_accuracy: 0.8432 - val_loss: 0.8717 - val_binary_accuracy: 0.7286
# Run:  3 / Accuracy at epoch  13  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4589 - binary_accuracy: 0.8520 - val_loss: 0.7574 - val_binary_accuracy: 0.7337
# Run:  3 / Accuracy at epoch  14  is:  0.733668327331543
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4101 - binary_accuracy: 0.8621 - val_loss: 0.8148 - val_binary_accuracy: 0.7362
# Run:  3 / Accuracy at epoch  15  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4252 - binary_accuracy: 0.8640 - val_loss: 0.7577 - val_binary_accuracy: 0.7487
# Run:  3 / Accuracy at epoch  16  is:  0.7487437129020691
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4077 - binary_accuracy: 0.8741 - val_loss: 0.8287 - val_binary_accuracy: 0.7337
# Run:  3 / Accuracy at epoch  17  is:  0.733668327331543
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4065 - binary_accuracy: 0.8690 - val_loss: 0.8911 - val_binary_accuracy: 0.7337
# Run:  3 / Accuracy at epoch  18  is:  0.733668327331543
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4026 - binary_accuracy: 0.8715 - val_loss: 1.0157 - val_binary_accuracy: 0.7312
# Run:  3 / Accuracy at epoch  19  is:  0.7311557531356812
#
# Accuracies over epochs: [0.6080402135848999, 0.7085427045822144, 0.7160804271697998, 0.7211055159568787, 0.713567852973938, 0.7085427045822144, 0.7160804271697998, 0.7160804271697998, 0.713567852973938, 0.7160804271697998, 0.733668327331543, 0.7236180901527405, 0.7487437129020691, 0.7286432385444641, 0.733668327331543, 0.7361809015274048, 0.7487437129020691, 0.733668327331543, 0.733668327331543, 0.7311557531356812]
#
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.7019 - binary_accuracy: 0.5447 - val_loss: 0.6363 - val_binary_accuracy: 0.6357
# Run:  4 / Accuracy at epoch  0  is:  0.6356784105300903
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6538 - binary_accuracy: 0.6694 - val_loss: 0.6181 - val_binary_accuracy: 0.6809
# Run:  4 / Accuracy at epoch  1  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6135 - binary_accuracy: 0.7154 - val_loss: 0.6600 - val_binary_accuracy: 0.6759
# Run:  4 / Accuracy at epoch  2  is:  0.6758794188499451
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5964 - binary_accuracy: 0.7387 - val_loss: 0.6599 - val_binary_accuracy: 0.7085
# Run:  4 / Accuracy at epoch  3  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5727 - binary_accuracy: 0.7576 - val_loss: 0.6817 - val_binary_accuracy: 0.7085
# Run:  4 / Accuracy at epoch  4  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5374 - binary_accuracy: 0.7935 - val_loss: 0.8131 - val_binary_accuracy: 0.6935
# Run:  4 / Accuracy at epoch  5  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5385 - binary_accuracy: 0.7916 - val_loss: 0.7222 - val_binary_accuracy: 0.7035
# Run:  4 / Accuracy at epoch  6  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5065 - binary_accuracy: 0.8004 - val_loss: 0.8039 - val_binary_accuracy: 0.7111
# Run:  4 / Accuracy at epoch  7  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4866 - binary_accuracy: 0.8067 - val_loss: 0.7853 - val_binary_accuracy: 0.7136
# Run:  4 / Accuracy at epoch  8  is:  0.713567852973938
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5041 - binary_accuracy: 0.8123 - val_loss: 0.7692 - val_binary_accuracy: 0.7136
# Run:  4 / Accuracy at epoch  9  is:  0.713567852973938
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4705 - binary_accuracy: 0.8230 - val_loss: 0.7840 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  10  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4740 - binary_accuracy: 0.8401 - val_loss: 0.9107 - val_binary_accuracy: 0.7136
# Run:  4 / Accuracy at epoch  11  is:  0.713567852973938
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4761 - binary_accuracy: 0.8356 - val_loss: 0.8124 - val_binary_accuracy: 0.7161
# Run:  4 / Accuracy at epoch  12  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4450 - binary_accuracy: 0.8407 - val_loss: 0.8087 - val_binary_accuracy: 0.7186
# Run:  4 / Accuracy at epoch  13  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4475 - binary_accuracy: 0.8476 - val_loss: 0.8472 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  14  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4280 - binary_accuracy: 0.8558 - val_loss: 0.8361 - val_binary_accuracy: 0.7236
# Run:  4 / Accuracy at epoch  15  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4385 - binary_accuracy: 0.8596 - val_loss: 0.9868 - val_binary_accuracy: 0.7186
# Run:  4 / Accuracy at epoch  16  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4032 - binary_accuracy: 0.8596 - val_loss: 0.8475 - val_binary_accuracy: 0.7261
# Run:  4 / Accuracy at epoch  17  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4155 - binary_accuracy: 0.8640 - val_loss: 0.8345 - val_binary_accuracy: 0.7312
# Run:  4 / Accuracy at epoch  18  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4189 - binary_accuracy: 0.8835 - val_loss: 0.9204 - val_binary_accuracy: 0.7261
# Run:  4 / Accuracy at epoch  19  is:  0.7261306643486023
#
# Accuracies over epochs: [0.6356784105300903, 0.6809045076370239, 0.6758794188499451, 0.7085427045822144, 0.7085427045822144, 0.6934673190116882, 0.7035176157951355, 0.7110552787780762, 0.713567852973938, 0.713567852973938, 0.7211055159568787, 0.713567852973938, 0.7160804271697998, 0.7185929417610168, 0.7211055159568787, 0.7236180901527405, 0.7185929417610168, 0.7261306643486023, 0.7311557531356812, 0.7261306643486023]
#
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.7018 - binary_accuracy: 0.5239 - val_loss: 0.6499 - val_binary_accuracy: 0.6382
# Run:  5 / Accuracy at epoch  0  is:  0.6381909251213074
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6568 - binary_accuracy: 0.6593 - val_loss: 0.5984 - val_binary_accuracy: 0.7035
# Run:  5 / Accuracy at epoch  1  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6204 - binary_accuracy: 0.7084 - val_loss: 0.6562 - val_binary_accuracy: 0.7010
# Run:  5 / Accuracy at epoch  2  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5894 - binary_accuracy: 0.7380 - val_loss: 0.6475 - val_binary_accuracy: 0.7211
# Run:  5 / Accuracy at epoch  3  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5690 - binary_accuracy: 0.7531 - val_loss: 0.6979 - val_binary_accuracy: 0.7186
# Run:  5 / Accuracy at epoch  4  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5448 - binary_accuracy: 0.7720 - val_loss: 0.6781 - val_binary_accuracy: 0.7136
# Run:  5 / Accuracy at epoch  5  is:  0.713567852973938
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5194 - binary_accuracy: 0.7928 - val_loss: 0.7201 - val_binary_accuracy: 0.7186
# Run:  5 / Accuracy at epoch  6  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5019 - binary_accuracy: 0.7909 - val_loss: 0.7177 - val_binary_accuracy: 0.7261
# Run:  5 / Accuracy at epoch  7  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5121 - binary_accuracy: 0.7991 - val_loss: 0.7777 - val_binary_accuracy: 0.7111
# Run:  5 / Accuracy at epoch  8  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4809 - binary_accuracy: 0.8111 - val_loss: 0.7655 - val_binary_accuracy: 0.7337
# Run:  5 / Accuracy at epoch  9  is:  0.733668327331543
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4727 - binary_accuracy: 0.8230 - val_loss: 0.7291 - val_binary_accuracy: 0.7362
# Run:  5 / Accuracy at epoch  10  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4740 - binary_accuracy: 0.8363 - val_loss: 0.8158 - val_binary_accuracy: 0.7412
# Run:  5 / Accuracy at epoch  11  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4802 - binary_accuracy: 0.8356 - val_loss: 0.7634 - val_binary_accuracy: 0.7387
# Run:  5 / Accuracy at epoch  12  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4547 - binary_accuracy: 0.8407 - val_loss: 0.7052 - val_binary_accuracy: 0.7462
# Run:  5 / Accuracy at epoch  13  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4548 - binary_accuracy: 0.8426 - val_loss: 0.7247 - val_binary_accuracy: 0.7462
# Run:  5 / Accuracy at epoch  14  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4202 - binary_accuracy: 0.8501 - val_loss: 0.7745 - val_binary_accuracy: 0.7362
# Run:  5 / Accuracy at epoch  15  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4357 - binary_accuracy: 0.8545 - val_loss: 0.7367 - val_binary_accuracy: 0.7387
# Run:  5 / Accuracy at epoch  16  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4092 - binary_accuracy: 0.8621 - val_loss: 0.8478 - val_binary_accuracy: 0.7437
# Run:  5 / Accuracy at epoch  17  is:  0.7437185645103455
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4204 - binary_accuracy: 0.8621 - val_loss: 0.8130 - val_binary_accuracy: 0.7387
# Run:  5 / Accuracy at epoch  18  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4122 - binary_accuracy: 0.8703 - val_loss: 0.9204 - val_binary_accuracy: 0.7286
# Run:  5 / Accuracy at epoch  19  is:  0.7286432385444641
#
# Accuracies over epochs: [0.6381909251213074, 0.7035176157951355, 0.7010050415992737, 0.7211055159568787, 0.7185929417610168, 0.713567852973938, 0.7185929417610168, 0.7261306643486023, 0.7110552787780762, 0.733668327331543, 0.7361809015274048, 0.7412060499191284, 0.7386934757232666, 0.7462311387062073, 0.7462311387062073, 0.7361809015274048, 0.7386934757232666, 0.7437185645103455, 0.7386934757232666, 0.7286432385444641]
#
#
#
#
#  Over all runs maximum accuracies on English are: [0.7311557531356812, 0.7361809015274048, 0.7462311387062073, 0.7462311387062073, 0.7487437129020691]
# The median for English is: 0.7462311387062073
#
#
#
# CNN Accuracy Score on Test set ->  ['0.7462311387062073 +/- 0.015075385570526123']
#
#
# * * * * EVALUATION USING LOW AS PREPROCESSING FUNCTION * * * *
# Vocabulary size is: 11297
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.7025 - binary_accuracy: 0.5510 - val_loss: 0.6283 - val_binary_accuracy: 0.6281
# Run:  1 / Accuracy at epoch  0  is:  0.6281406879425049
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6744 - binary_accuracy: 0.6524 - val_loss: 0.5834 - val_binary_accuracy: 0.6985
# Run:  1 / Accuracy at epoch  1  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6221 - binary_accuracy: 0.7003 - val_loss: 0.6066 - val_binary_accuracy: 0.7035
# Run:  1 / Accuracy at epoch  2  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6043 - binary_accuracy: 0.7324 - val_loss: 0.6198 - val_binary_accuracy: 0.7286
# Run:  1 / Accuracy at epoch  3  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5860 - binary_accuracy: 0.7462 - val_loss: 0.6307 - val_binary_accuracy: 0.7211
# Run:  1 / Accuracy at epoch  4  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5579 - binary_accuracy: 0.7664 - val_loss: 0.6666 - val_binary_accuracy: 0.7337
# Run:  1 / Accuracy at epoch  5  is:  0.733668327331543
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5453 - binary_accuracy: 0.7890 - val_loss: 0.6888 - val_binary_accuracy: 0.7211
# Run:  1 / Accuracy at epoch  6  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5130 - binary_accuracy: 0.7953 - val_loss: 0.6933 - val_binary_accuracy: 0.7060
# Run:  1 / Accuracy at epoch  7  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5091 - binary_accuracy: 0.8023 - val_loss: 0.7252 - val_binary_accuracy: 0.7211
# Run:  1 / Accuracy at epoch  8  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4957 - binary_accuracy: 0.8117 - val_loss: 0.7522 - val_binary_accuracy: 0.7261
# Run:  1 / Accuracy at epoch  9  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4857 - binary_accuracy: 0.8193 - val_loss: 0.7200 - val_binary_accuracy: 0.7236
# Run:  1 / Accuracy at epoch  10  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4842 - binary_accuracy: 0.8268 - val_loss: 0.7118 - val_binary_accuracy: 0.7186
# Run:  1 / Accuracy at epoch  11  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4698 - binary_accuracy: 0.8256 - val_loss: 0.6918 - val_binary_accuracy: 0.7211
# Run:  1 / Accuracy at epoch  12  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4435 - binary_accuracy: 0.8382 - val_loss: 0.7847 - val_binary_accuracy: 0.7261
# Run:  1 / Accuracy at epoch  13  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4727 - binary_accuracy: 0.8401 - val_loss: 0.7191 - val_binary_accuracy: 0.7312
# Run:  1 / Accuracy at epoch  14  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4330 - binary_accuracy: 0.8445 - val_loss: 0.7925 - val_binary_accuracy: 0.7337
# Run:  1 / Accuracy at epoch  15  is:  0.733668327331543
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4433 - binary_accuracy: 0.8489 - val_loss: 0.7799 - val_binary_accuracy: 0.7261
# Run:  1 / Accuracy at epoch  16  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4128 - binary_accuracy: 0.8407 - val_loss: 0.7922 - val_binary_accuracy: 0.7337
# Run:  1 / Accuracy at epoch  17  is:  0.733668327331543
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4283 - binary_accuracy: 0.8564 - val_loss: 0.7901 - val_binary_accuracy: 0.7337
# Run:  1 / Accuracy at epoch  18  is:  0.733668327331543
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4329 - binary_accuracy: 0.8741 - val_loss: 0.8365 - val_binary_accuracy: 0.7261
# Run:  1 / Accuracy at epoch  19  is:  0.7261306643486023
#
# Accuracies over epochs: [0.6281406879425049, 0.6984924674034119, 0.7035176157951355, 0.7286432385444641, 0.7211055159568787, 0.733668327331543, 0.7211055159568787, 0.7060301303863525, 0.7211055159568787, 0.7261306643486023, 0.7236180901527405, 0.7185929417610168, 0.7211055159568787, 0.7261306643486023, 0.7311557531356812, 0.733668327331543, 0.7261306643486023, 0.733668327331543, 0.733668327331543, 0.7261306643486023]
#
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.7019 - binary_accuracy: 0.5340 - val_loss: 0.6345 - val_binary_accuracy: 0.6482
# Run:  2 / Accuracy at epoch  0  is:  0.6482412219047546
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6631 - binary_accuracy: 0.6662 - val_loss: 0.6122 - val_binary_accuracy: 0.6859
# Run:  2 / Accuracy at epoch  1  is:  0.6859296560287476
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6185 - binary_accuracy: 0.7229 - val_loss: 0.6417 - val_binary_accuracy: 0.6884
# Run:  2 / Accuracy at epoch  2  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5964 - binary_accuracy: 0.7469 - val_loss: 0.7108 - val_binary_accuracy: 0.6809
# Run:  2 / Accuracy at epoch  3  is:  0.6809045076370239
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5860 - binary_accuracy: 0.7380 - val_loss: 0.6870 - val_binary_accuracy: 0.7060
# Run:  2 / Accuracy at epoch  4  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5449 - binary_accuracy: 0.7802 - val_loss: 0.7598 - val_binary_accuracy: 0.7111
# Run:  2 / Accuracy at epoch  5  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5386 - binary_accuracy: 0.8004 - val_loss: 0.7503 - val_binary_accuracy: 0.7136
# Run:  2 / Accuracy at epoch  6  is:  0.713567852973938
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5384 - binary_accuracy: 0.7991 - val_loss: 0.7088 - val_binary_accuracy: 0.7286
# Run:  2 / Accuracy at epoch  7  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5107 - binary_accuracy: 0.8023 - val_loss: 0.7062 - val_binary_accuracy: 0.7261
# Run:  2 / Accuracy at epoch  8  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5112 - binary_accuracy: 0.8161 - val_loss: 0.7646 - val_binary_accuracy: 0.7236
# Run:  2 / Accuracy at epoch  9  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4785 - binary_accuracy: 0.8212 - val_loss: 0.7160 - val_binary_accuracy: 0.7312
# Run:  2 / Accuracy at epoch  10  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4870 - binary_accuracy: 0.8312 - val_loss: 0.7533 - val_binary_accuracy: 0.7412
# Run:  2 / Accuracy at epoch  11  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4701 - binary_accuracy: 0.8350 - val_loss: 0.7025 - val_binary_accuracy: 0.7261
# Run:  2 / Accuracy at epoch  12  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4520 - binary_accuracy: 0.8394 - val_loss: 0.7814 - val_binary_accuracy: 0.7437
# Run:  2 / Accuracy at epoch  13  is:  0.7437185645103455
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4708 - binary_accuracy: 0.8445 - val_loss: 0.6841 - val_binary_accuracy: 0.7186
# Run:  2 / Accuracy at epoch  14  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4384 - binary_accuracy: 0.8545 - val_loss: 0.7711 - val_binary_accuracy: 0.7387
# Run:  2 / Accuracy at epoch  15  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4405 - binary_accuracy: 0.8621 - val_loss: 0.7674 - val_binary_accuracy: 0.7362
# Run:  2 / Accuracy at epoch  16  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4008 - binary_accuracy: 0.8583 - val_loss: 0.7542 - val_binary_accuracy: 0.7337
# Run:  2 / Accuracy at epoch  17  is:  0.733668327331543
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4146 - binary_accuracy: 0.8608 - val_loss: 0.8226 - val_binary_accuracy: 0.7286
# Run:  2 / Accuracy at epoch  18  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4192 - binary_accuracy: 0.8734 - val_loss: 0.7911 - val_binary_accuracy: 0.7161
# Run:  2 / Accuracy at epoch  19  is:  0.7160804271697998
#
# Accuracies over epochs: [0.6482412219047546, 0.6859296560287476, 0.6884422302246094, 0.6809045076370239, 0.7060301303863525, 0.7110552787780762, 0.713567852973938, 0.7286432385444641, 0.7261306643486023, 0.7236180901527405, 0.7311557531356812, 0.7412060499191284, 0.7261306643486023, 0.7437185645103455, 0.7185929417610168, 0.7386934757232666, 0.7361809015274048, 0.733668327331543, 0.7286432385444641, 0.7160804271697998]
#
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6989 - binary_accuracy: 0.5510 - val_loss: 0.6381 - val_binary_accuracy: 0.6206
# Run:  3 / Accuracy at epoch  0  is:  0.6206030249595642
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6787 - binary_accuracy: 0.6637 - val_loss: 0.5990 - val_binary_accuracy: 0.6910
# Run:  3 / Accuracy at epoch  1  is:  0.6909547448158264
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6181 - binary_accuracy: 0.7116 - val_loss: 0.5944 - val_binary_accuracy: 0.7111
# Run:  3 / Accuracy at epoch  2  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6047 - binary_accuracy: 0.7267 - val_loss: 0.6138 - val_binary_accuracy: 0.7211
# Run:  3 / Accuracy at epoch  3  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5804 - binary_accuracy: 0.7506 - val_loss: 0.6379 - val_binary_accuracy: 0.7312
# Run:  3 / Accuracy at epoch  4  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5429 - binary_accuracy: 0.7815 - val_loss: 0.7341 - val_binary_accuracy: 0.7312
# Run:  3 / Accuracy at epoch  5  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5292 - binary_accuracy: 0.7997 - val_loss: 0.6721 - val_binary_accuracy: 0.7161
# Run:  3 / Accuracy at epoch  6  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5218 - binary_accuracy: 0.7953 - val_loss: 0.6657 - val_binary_accuracy: 0.7161
# Run:  3 / Accuracy at epoch  7  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5170 - binary_accuracy: 0.8060 - val_loss: 0.7279 - val_binary_accuracy: 0.7412
# Run:  3 / Accuracy at epoch  8  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4871 - binary_accuracy: 0.8161 - val_loss: 0.7240 - val_binary_accuracy: 0.7437
# Run:  3 / Accuracy at epoch  9  is:  0.7437185645103455
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4858 - binary_accuracy: 0.8218 - val_loss: 0.7189 - val_binary_accuracy: 0.7412
# Run:  3 / Accuracy at epoch  10  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4756 - binary_accuracy: 0.8451 - val_loss: 0.7555 - val_binary_accuracy: 0.7437
# Run:  3 / Accuracy at epoch  11  is:  0.7437185645103455
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4743 - binary_accuracy: 0.8344 - val_loss: 0.7360 - val_binary_accuracy: 0.7437
# Run:  3 / Accuracy at epoch  12  is:  0.7437185645103455
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4647 - binary_accuracy: 0.8419 - val_loss: 0.7367 - val_binary_accuracy: 0.7286
# Run:  3 / Accuracy at epoch  13  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4601 - binary_accuracy: 0.8413 - val_loss: 0.7047 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  14  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4298 - binary_accuracy: 0.8495 - val_loss: 0.7499 - val_binary_accuracy: 0.7236
# Run:  3 / Accuracy at epoch  15  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4407 - binary_accuracy: 0.8564 - val_loss: 0.7416 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  16  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4000 - binary_accuracy: 0.8558 - val_loss: 0.7462 - val_binary_accuracy: 0.7236
# Run:  3 / Accuracy at epoch  17  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4111 - binary_accuracy: 0.8652 - val_loss: 0.7850 - val_binary_accuracy: 0.7312
# Run:  3 / Accuracy at epoch  18  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4318 - binary_accuracy: 0.8621 - val_loss: 0.7547 - val_binary_accuracy: 0.7312
# Run:  3 / Accuracy at epoch  19  is:  0.7311557531356812
#
# Accuracies over epochs: [0.6206030249595642, 0.6909547448158264, 0.7110552787780762, 0.7211055159568787, 0.7311557531356812, 0.7311557531356812, 0.7160804271697998, 0.7160804271697998, 0.7412060499191284, 0.7437185645103455, 0.7412060499191284, 0.7437185645103455, 0.7437185645103455, 0.7286432385444641, 0.7185929417610168, 0.7236180901527405, 0.7185929417610168, 0.7236180901527405, 0.7311557531356812, 0.7311557531356812]
#
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.7017 - binary_accuracy: 0.5485 - val_loss: 0.6368 - val_binary_accuracy: 0.6357
# Run:  4 / Accuracy at epoch  0  is:  0.6356784105300903
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6678 - binary_accuracy: 0.6681 - val_loss: 0.6025 - val_binary_accuracy: 0.6935
# Run:  4 / Accuracy at epoch  1  is:  0.6934673190116882
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6239 - binary_accuracy: 0.7166 - val_loss: 0.6346 - val_binary_accuracy: 0.7035
# Run:  4 / Accuracy at epoch  2  is:  0.7035176157951355
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6045 - binary_accuracy: 0.7349 - val_loss: 0.6394 - val_binary_accuracy: 0.7111
# Run:  4 / Accuracy at epoch  3  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5811 - binary_accuracy: 0.7487 - val_loss: 0.6658 - val_binary_accuracy: 0.7010
# Run:  4 / Accuracy at epoch  4  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5476 - binary_accuracy: 0.7683 - val_loss: 0.7176 - val_binary_accuracy: 0.7060
# Run:  4 / Accuracy at epoch  5  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5375 - binary_accuracy: 0.7853 - val_loss: 0.7377 - val_binary_accuracy: 0.7085
# Run:  4 / Accuracy at epoch  6  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5285 - binary_accuracy: 0.7928 - val_loss: 0.7284 - val_binary_accuracy: 0.7111
# Run:  4 / Accuracy at epoch  7  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5119 - binary_accuracy: 0.8048 - val_loss: 0.7629 - val_binary_accuracy: 0.7186
# Run:  4 / Accuracy at epoch  8  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4929 - binary_accuracy: 0.7979 - val_loss: 0.7644 - val_binary_accuracy: 0.7236
# Run:  4 / Accuracy at epoch  9  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4829 - binary_accuracy: 0.8212 - val_loss: 0.7043 - val_binary_accuracy: 0.7337
# Run:  4 / Accuracy at epoch  10  is:  0.733668327331543
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4694 - binary_accuracy: 0.8319 - val_loss: 0.7988 - val_binary_accuracy: 0.7236
# Run:  4 / Accuracy at epoch  11  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4787 - binary_accuracy: 0.8275 - val_loss: 0.7273 - val_binary_accuracy: 0.7312
# Run:  4 / Accuracy at epoch  12  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4530 - binary_accuracy: 0.8407 - val_loss: 0.7794 - val_binary_accuracy: 0.7362
# Run:  4 / Accuracy at epoch  13  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4570 - binary_accuracy: 0.8432 - val_loss: 0.7353 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  14  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4472 - binary_accuracy: 0.8413 - val_loss: 0.7721 - val_binary_accuracy: 0.7186
# Run:  4 / Accuracy at epoch  15  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4573 - binary_accuracy: 0.8495 - val_loss: 0.7678 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  16  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4328 - binary_accuracy: 0.8627 - val_loss: 0.7474 - val_binary_accuracy: 0.7161
# Run:  4 / Accuracy at epoch  17  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4299 - binary_accuracy: 0.8545 - val_loss: 0.7486 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  18  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4220 - binary_accuracy: 0.8728 - val_loss: 0.7978 - val_binary_accuracy: 0.7186
# Run:  4 / Accuracy at epoch  19  is:  0.7185929417610168
#
# Accuracies over epochs: [0.6356784105300903, 0.6934673190116882, 0.7035176157951355, 0.7110552787780762, 0.7010050415992737, 0.7060301303863525, 0.7085427045822144, 0.7110552787780762, 0.7185929417610168, 0.7236180901527405, 0.733668327331543, 0.7236180901527405, 0.7311557531356812, 0.7361809015274048, 0.7211055159568787, 0.7185929417610168, 0.7211055159568787, 0.7160804271697998, 0.7211055159568787, 0.7185929417610168]
#
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.7029 - binary_accuracy: 0.5573 - val_loss: 0.6423 - val_binary_accuracy: 0.6307
# Run:  5 / Accuracy at epoch  0  is:  0.6306532621383667
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6668 - binary_accuracy: 0.6618 - val_loss: 0.5918 - val_binary_accuracy: 0.6985
# Run:  5 / Accuracy at epoch  1  is:  0.6984924674034119
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6264 - binary_accuracy: 0.7236 - val_loss: 0.6130 - val_binary_accuracy: 0.7085
# Run:  5 / Accuracy at epoch  2  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5925 - binary_accuracy: 0.7500 - val_loss: 0.6271 - val_binary_accuracy: 0.7136
# Run:  5 / Accuracy at epoch  3  is:  0.713567852973938
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5688 - binary_accuracy: 0.7639 - val_loss: 0.6419 - val_binary_accuracy: 0.7211
# Run:  5 / Accuracy at epoch  4  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5415 - binary_accuracy: 0.7815 - val_loss: 0.6724 - val_binary_accuracy: 0.7186
# Run:  5 / Accuracy at epoch  5  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5323 - binary_accuracy: 0.7916 - val_loss: 0.6741 - val_binary_accuracy: 0.7362
# Run:  5 / Accuracy at epoch  6  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5194 - binary_accuracy: 0.7941 - val_loss: 0.6775 - val_binary_accuracy: 0.7236
# Run:  5 / Accuracy at epoch  7  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5021 - binary_accuracy: 0.8054 - val_loss: 0.6743 - val_binary_accuracy: 0.7186
# Run:  5 / Accuracy at epoch  8  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4940 - binary_accuracy: 0.8130 - val_loss: 0.6985 - val_binary_accuracy: 0.7211
# Run:  5 / Accuracy at epoch  9  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4822 - binary_accuracy: 0.8155 - val_loss: 0.6976 - val_binary_accuracy: 0.7211
# Run:  5 / Accuracy at epoch  10  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4676 - binary_accuracy: 0.8243 - val_loss: 0.7898 - val_binary_accuracy: 0.7412
# Run:  5 / Accuracy at epoch  11  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4732 - binary_accuracy: 0.8363 - val_loss: 0.7301 - val_binary_accuracy: 0.7236
# Run:  5 / Accuracy at epoch  12  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4426 - binary_accuracy: 0.8476 - val_loss: 0.7450 - val_binary_accuracy: 0.7211
# Run:  5 / Accuracy at epoch  13  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4454 - binary_accuracy: 0.8457 - val_loss: 0.6966 - val_binary_accuracy: 0.7211
# Run:  5 / Accuracy at epoch  14  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4241 - binary_accuracy: 0.8545 - val_loss: 0.7577 - val_binary_accuracy: 0.7312
# Run:  5 / Accuracy at epoch  15  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4416 - binary_accuracy: 0.8589 - val_loss: 0.7527 - val_binary_accuracy: 0.7136
# Run:  5 / Accuracy at epoch  16  is:  0.713567852973938
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4091 - binary_accuracy: 0.8514 - val_loss: 0.8000 - val_binary_accuracy: 0.7337
# Run:  5 / Accuracy at epoch  17  is:  0.733668327331543
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4291 - binary_accuracy: 0.8640 - val_loss: 0.8023 - val_binary_accuracy: 0.7236
# Run:  5 / Accuracy at epoch  18  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.4259 - binary_accuracy: 0.8678 - val_loss: 0.7745 - val_binary_accuracy: 0.7161
# Run:  5 / Accuracy at epoch  19  is:  0.7160804271697998
#
# Accuracies over epochs: [0.6306532621383667, 0.6984924674034119, 0.7085427045822144, 0.713567852973938, 0.7211055159568787, 0.7185929417610168, 0.7361809015274048, 0.7236180901527405, 0.7185929417610168, 0.7211055159568787, 0.7211055159568787, 0.7412060499191284, 0.7236180901527405, 0.7211055159568787, 0.7211055159568787, 0.7311557531356812, 0.713567852973938, 0.733668327331543, 0.7236180901527405, 0.7160804271697998]
#
#
#
#
#  Over all runs maximum accuracies on English are: [0.733668327331543, 0.7361809015274048, 0.7412060499191284, 0.7437185645103455, 0.7437185645103455]
# The median for English is: 0.7412060499191284
#
#
#
# CNN Accuracy Score on Test set ->  ['0.7412060499191284 +/- 0.007537722587585449']
#
#
# * * * * EVALUATION USING RSW AS PREPROCESSING FUNCTION * * * *
# Vocabulary size is: 12384
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.7023 - binary_accuracy: 0.5372 - val_loss: 0.6383 - val_binary_accuracy: 0.6382
# Run:  1 / Accuracy at epoch  0  is:  0.6381909251213074
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6504 - binary_accuracy: 0.6662 - val_loss: 0.5864 - val_binary_accuracy: 0.7010
# Run:  1 / Accuracy at epoch  1  is:  0.7010050415992737
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.6090 - binary_accuracy: 0.7204 - val_loss: 0.5839 - val_binary_accuracy: 0.7211
# Run:  1 / Accuracy at epoch  2  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5788 - binary_accuracy: 0.7399 - val_loss: 0.6467 - val_binary_accuracy: 0.7161
# Run:  1 / Accuracy at epoch  3  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5629 - binary_accuracy: 0.7620 - val_loss: 0.6260 - val_binary_accuracy: 0.7412
# Run:  1 / Accuracy at epoch  4  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5355 - binary_accuracy: 0.7746 - val_loss: 0.6391 - val_binary_accuracy: 0.7136
# Run:  1 / Accuracy at epoch  5  is:  0.713567852973938
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5189 - binary_accuracy: 0.8029 - val_loss: 0.8008 - val_binary_accuracy: 0.7186
# Run:  1 / Accuracy at epoch  6  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 14s 9ms/step - loss: 0.5096 - binary_accuracy: 0.8010 - val_loss: 0.7200 - val_binary_accuracy: 0.7161
# ...
# Run:  2 / Accuracy at epoch  12  is:  0.733668327331543
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4583 - binary_accuracy: 0.8363 - val_loss: 0.6900 - val_binary_accuracy: 0.7236
# Run:  2 / Accuracy at epoch  13  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4259 - binary_accuracy: 0.8508 - val_loss: 0.7423 - val_binary_accuracy: 0.7261
# Run:  2 / Accuracy at epoch  14  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4141 - binary_accuracy: 0.8545 - val_loss: 0.7344 - val_binary_accuracy: 0.7236
# Run:  2 / Accuracy at epoch  15  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4268 - binary_accuracy: 0.8520 - val_loss: 0.8136 - val_binary_accuracy: 0.7337
# Run:  2 / Accuracy at epoch  16  is:  0.733668327331543
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4060 - binary_accuracy: 0.8602 - val_loss: 0.7317 - val_binary_accuracy: 0.7412
# Run:  2 / Accuracy at epoch  17  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4054 - binary_accuracy: 0.8627 - val_loss: 0.8044 - val_binary_accuracy: 0.7261
# Run:  2 / Accuracy at epoch  18  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4053 - binary_accuracy: 0.8659 - val_loss: 0.7440 - val_binary_accuracy: 0.7236
# Run:  2 / Accuracy at epoch  19  is:  0.7236180901527405
#
# Accuracies over epochs: [0.6407034993171692, 0.7035176157951355, 0.7160804271697998, 0.7035176157951355, 0.7236180901527405, 0.7261306643486023, 0.7236180901527405, 0.7211055159568787, 0.7311557531356812, 0.733668327331543, 0.733668327331543, 0.7160804271697998, 0.733668327331543, 0.7236180901527405, 0.7261306643486023, 0.7236180901527405, 0.733668327331543, 0.7412060499191284, 0.7261306643486023, 0.7236180901527405]
#
#
# 1588/1588 [==============================] - 17s 10ms/step - loss: 0.7037 - binary_accuracy: 0.5548 - val_loss: 0.6243 - val_binary_accuracy: 0.6683
# Run:  3 / Accuracy at epoch  0  is:  0.6683416962623596
#
# 1588/1588 [==============================] - 15s 10ms/step - loss: 0.6502 - binary_accuracy: 0.6782 - val_loss: 0.5978 - val_binary_accuracy: 0.7060
# Run:  3 / Accuracy at epoch  1  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6117 - binary_accuracy: 0.7254 - val_loss: 0.7096 - val_binary_accuracy: 0.7060
# Run:  3 / Accuracy at epoch  2  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5869 - binary_accuracy: 0.7399 - val_loss: 0.8479 - val_binary_accuracy: 0.6834
# Run:  3 / Accuracy at epoch  3  is:  0.6834170818328857
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5788 - binary_accuracy: 0.7607 - val_loss: 0.7279 - val_binary_accuracy: 0.6960
# Run:  3 / Accuracy at epoch  4  is:  0.69597989320755
#
# 1588/1588 [==============================] - 16s 10ms/step - loss: 0.5246 - binary_accuracy: 0.7815 - val_loss: 0.7412 - val_binary_accuracy: 0.7085
# Run:  3 / Accuracy at epoch  5  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5164 - binary_accuracy: 0.7935 - val_loss: 0.7452 - val_binary_accuracy: 0.7085
# Run:  3 / Accuracy at epoch  6  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 15s 10ms/step - loss: 0.5275 - binary_accuracy: 0.8060 - val_loss: 0.7171 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  7  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4971 - binary_accuracy: 0.8149 - val_loss: 0.7166 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  8  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4895 - binary_accuracy: 0.8123 - val_loss: 0.7698 - val_binary_accuracy: 0.7161
# Run:  3 / Accuracy at epoch  9  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4683 - binary_accuracy: 0.8256 - val_loss: 0.7514 - val_binary_accuracy: 0.7337
# Run:  3 / Accuracy at epoch  10  is:  0.733668327331543
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4740 - binary_accuracy: 0.8281 - val_loss: 0.8312 - val_binary_accuracy: 0.7186
# Run:  3 / Accuracy at epoch  11  is:  0.7185929417610168
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4465 - binary_accuracy: 0.8312 - val_loss: 0.7198 - val_binary_accuracy: 0.7412
# Run:  3 / Accuracy at epoch  12  is:  0.7412060499191284
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4598 - binary_accuracy: 0.8407 - val_loss: 0.6831 - val_binary_accuracy: 0.7387
# Run:  3 / Accuracy at epoch  13  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 16s 10ms/step - loss: 0.4393 - binary_accuracy: 0.8495 - val_loss: 0.7660 - val_binary_accuracy: 0.7462
# Run:  3 / Accuracy at epoch  14  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4375 - binary_accuracy: 0.8432 - val_loss: 0.7011 - val_binary_accuracy: 0.7261
# Run:  3 / Accuracy at epoch  15  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 16s 10ms/step - loss: 0.4277 - binary_accuracy: 0.8489 - val_loss: 0.8063 - val_binary_accuracy: 0.7362
# Run:  3 / Accuracy at epoch  16  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 16s 10ms/step - loss: 0.4246 - binary_accuracy: 0.8545 - val_loss: 0.7446 - val_binary_accuracy: 0.7286
# Run:  3 / Accuracy at epoch  17  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.3954 - binary_accuracy: 0.8621 - val_loss: 0.7335 - val_binary_accuracy: 0.7236
# Run:  3 / Accuracy at epoch  18  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4110 - binary_accuracy: 0.8602 - val_loss: 0.7193 - val_binary_accuracy: 0.7161
# Run:  3 / Accuracy at epoch  19  is:  0.7160804271697998
#
# Accuracies over epochs: [0.6683416962623596, 0.7060301303863525, 0.7060301303863525, 0.6834170818328857, 0.69597989320755, 0.7085427045822144, 0.7085427045822144, 0.7185929417610168, 0.7185929417610168, 0.7160804271697998, 0.733668327331543, 0.7185929417610168, 0.7412060499191284, 0.7386934757232666, 0.7462311387062073, 0.7261306643486023, 0.7361809015274048, 0.7286432385444641, 0.7236180901527405, 0.7160804271697998]
#
#
# 1588/1588 [==============================] - 16s 9ms/step - loss: 0.7031 - binary_accuracy: 0.5479 - val_loss: 0.6301 - val_binary_accuracy: 0.6407
# Run:  4 / Accuracy at epoch  0  is:  0.6407034993171692
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6502 - binary_accuracy: 0.6732 - val_loss: 0.6005 - val_binary_accuracy: 0.6884
# Run:  4 / Accuracy at epoch  1  is:  0.6884422302246094
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6148 - binary_accuracy: 0.7261 - val_loss: 0.6127 - val_binary_accuracy: 0.7085
# Run:  4 / Accuracy at epoch  2  is:  0.7085427045822144
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5992 - binary_accuracy: 0.7431 - val_loss: 0.6651 - val_binary_accuracy: 0.7161
# Run:  4 / Accuracy at epoch  3  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5718 - binary_accuracy: 0.7613 - val_loss: 0.7193 - val_binary_accuracy: 0.7161
# Run:  4 / Accuracy at epoch  4  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5518 - binary_accuracy: 0.7702 - val_loss: 0.6891 - val_binary_accuracy: 0.7261
# Run:  4 / Accuracy at epoch  5  is:  0.7261306643486023
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5241 - binary_accuracy: 0.7859 - val_loss: 0.7620 - val_binary_accuracy: 0.7111
# Run:  4 / Accuracy at epoch  6  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5161 - binary_accuracy: 0.7953 - val_loss: 0.7647 - val_binary_accuracy: 0.7161
# Run:  4 / Accuracy at epoch  7  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4974 - binary_accuracy: 0.8142 - val_loss: 0.8147 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  8  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4879 - binary_accuracy: 0.8155 - val_loss: 0.7329 - val_binary_accuracy: 0.7312
# Run:  4 / Accuracy at epoch  9  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4654 - binary_accuracy: 0.8287 - val_loss: 0.7355 - val_binary_accuracy: 0.7286
# Run:  4 / Accuracy at epoch  10  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4783 - binary_accuracy: 0.8312 - val_loss: 0.6951 - val_binary_accuracy: 0.7437
# Run:  4 / Accuracy at epoch  11  is:  0.7437185645103455
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4629 - binary_accuracy: 0.8237 - val_loss: 0.7195 - val_binary_accuracy: 0.7437
# Run:  4 / Accuracy at epoch  12  is:  0.7437185645103455
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4632 - binary_accuracy: 0.8375 - val_loss: 0.6951 - val_binary_accuracy: 0.7362
# Run:  4 / Accuracy at epoch  13  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4478 - binary_accuracy: 0.8432 - val_loss: 0.7251 - val_binary_accuracy: 0.7362
# Run:  4 / Accuracy at epoch  14  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4223 - binary_accuracy: 0.8514 - val_loss: 0.7372 - val_binary_accuracy: 0.7337
# Run:  4 / Accuracy at epoch  15  is:  0.733668327331543
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4175 - binary_accuracy: 0.8533 - val_loss: 0.7654 - val_binary_accuracy: 0.7312
# Run:  4 / Accuracy at epoch  16  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4208 - binary_accuracy: 0.8508 - val_loss: 0.7176 - val_binary_accuracy: 0.7211
# Run:  4 / Accuracy at epoch  17  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.3999 - binary_accuracy: 0.8615 - val_loss: 0.7750 - val_binary_accuracy: 0.7286
# Run:  4 / Accuracy at epoch  18  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4175 - binary_accuracy: 0.8583 - val_loss: 0.7191 - val_binary_accuracy: 0.7236
# Run:  4 / Accuracy at epoch  19  is:  0.7236180901527405
#
# Accuracies over epochs: [0.6407034993171692, 0.6884422302246094, 0.7085427045822144, 0.7160804271697998, 0.7160804271697998, 0.7261306643486023, 0.7110552787780762, 0.7160804271697998, 0.7211055159568787, 0.7311557531356812, 0.7286432385444641, 0.7437185645103455, 0.7437185645103455, 0.7361809015274048, 0.7361809015274048, 0.733668327331543, 0.7311557531356812, 0.7211055159568787, 0.7286432385444641, 0.7236180901527405]
#
#
# 1588/1588 [==============================] - 16s 9ms/step - loss: 0.7008 - binary_accuracy: 0.5447 - val_loss: 0.6337 - val_binary_accuracy: 0.6156
# Run:  5 / Accuracy at epoch  0  is:  0.6155778765678406
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6597 - binary_accuracy: 0.6839 - val_loss: 0.5899 - val_binary_accuracy: 0.7111
# Run:  5 / Accuracy at epoch  1  is:  0.7110552787780762
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.6060 - binary_accuracy: 0.7185 - val_loss: 0.6045 - val_binary_accuracy: 0.7211
# Run:  5 / Accuracy at epoch  2  is:  0.7211055159568787
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5831 - binary_accuracy: 0.7569 - val_loss: 0.7119 - val_binary_accuracy: 0.7060
# Run:  5 / Accuracy at epoch  3  is:  0.7060301303863525
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5639 - binary_accuracy: 0.7657 - val_loss: 0.6661 - val_binary_accuracy: 0.7161
# Run:  5 / Accuracy at epoch  4  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5490 - binary_accuracy: 0.7853 - val_loss: 0.7041 - val_binary_accuracy: 0.7286
# Run:  5 / Accuracy at epoch  5  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5224 - binary_accuracy: 0.7872 - val_loss: 0.7420 - val_binary_accuracy: 0.7286
# Run:  5 / Accuracy at epoch  6  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5194 - binary_accuracy: 0.8010 - val_loss: 0.6764 - val_binary_accuracy: 0.7387
# Run:  5 / Accuracy at epoch  7  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.5056 - binary_accuracy: 0.7991 - val_loss: 0.7067 - val_binary_accuracy: 0.7286
# Run:  5 / Accuracy at epoch  8  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4878 - binary_accuracy: 0.8086 - val_loss: 0.6981 - val_binary_accuracy: 0.7462
# Run:  5 / Accuracy at epoch  9  is:  0.7462311387062073
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4768 - binary_accuracy: 0.8249 - val_loss: 0.7083 - val_binary_accuracy: 0.7337
# Run:  5 / Accuracy at epoch  10  is:  0.733668327331543
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4779 - binary_accuracy: 0.8268 - val_loss: 0.6988 - val_binary_accuracy: 0.7337
# Run:  5 / Accuracy at epoch  11  is:  0.733668327331543
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4606 - binary_accuracy: 0.8243 - val_loss: 0.6622 - val_binary_accuracy: 0.7236
# Run:  5 / Accuracy at epoch  12  is:  0.7236180901527405
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4648 - binary_accuracy: 0.8394 - val_loss: 0.6611 - val_binary_accuracy: 0.7312
# Run:  5 / Accuracy at epoch  13  is:  0.7311557531356812
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4426 - binary_accuracy: 0.8407 - val_loss: 0.7230 - val_binary_accuracy: 0.7387
# Run:  5 / Accuracy at epoch  14  is:  0.7386934757232666
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4310 - binary_accuracy: 0.8476 - val_loss: 0.7445 - val_binary_accuracy: 0.7362
# Run:  5 / Accuracy at epoch  15  is:  0.7361809015274048
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4247 - binary_accuracy: 0.8526 - val_loss: 0.7309 - val_binary_accuracy: 0.7337
# Run:  5 / Accuracy at epoch  16  is:  0.733668327331543
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4152 - binary_accuracy: 0.8627 - val_loss: 0.7371 - val_binary_accuracy: 0.7161
# Run:  5 / Accuracy at epoch  17  is:  0.7160804271697998
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4024 - binary_accuracy: 0.8634 - val_loss: 0.7675 - val_binary_accuracy: 0.7286
# Run:  5 / Accuracy at epoch  18  is:  0.7286432385444641
#
# 1588/1588 [==============================] - 15s 9ms/step - loss: 0.4128 - binary_accuracy: 0.8634 - val_loss: 0.6945 - val_binary_accuracy: 0.7211
# Run:  5 / Accuracy at epoch  19  is:  0.7211055159568787
#
# Accuracies over epochs: [0.6155778765678406, 0.7110552787780762, 0.7211055159568787, 0.7060301303863525, 0.7160804271697998, 0.7286432385444641, 0.7286432385444641, 0.7386934757232666, 0.7286432385444641, 0.7462311387062073, 0.733668327331543, 0.733668327331543, 0.7236180901527405, 0.7311557531356812, 0.7386934757232666, 0.7361809015274048, 0.733668327331543, 0.7160804271697998, 0.7286432385444641, 0.7211055159568787]
#
#
#
#
#  Over all runs maximum accuracies on English are: [0.7412060499191284, 0.7437185645103455, 0.7462311387062073, 0.7462311387062073, 0.7462311387062073]
# The median for English is: 0.7462311387062073
#
#
#
# CNN Accuracy Score on Test set ->  ['0.7462311387062073 +/- 0.005025088787078857']

# %% [markdown]
# ## Now show compact results in a table.

# %%
print(" PREPRO FUNCTION    |  Test Accuracy   |",end = '')

print("\n")
for prepro_func in prepro_functions_dict_comb:
  #print(prepro_func,"\t\t\t",format(round(model_results[prepro_func][0],4),'.4f'),"\t\t",end='')
  result = model_results[prepro_func][0]
  # result = format(round(model_results[prepro_func][0],4),'.4f')
  print(f'{prepro_func:27}{ result :12}')
  print("\n")
# Out:
#  PREPRO FUNCTION    |  Test Accuracy   |
#
# DON                        0.7462311387062073 +/- 0.015075385570526123
#
#
# LOW                        0.7412060499191284 +/- 0.007537722587585449
#
#
# RSW                        0.7412060499191284 +/- 0.007537662982940674
#
#
# STM                        0.7512562870979309 +/- 0.01005023717880249
#
#
# LOW_RSW                    0.7412060499191284 +/- 0.007537662982940674
#
#
# LOW_STM                    0.7386934757232666 +/- 0.01005023717880249
#
#
# RSW_LOW                    0.7386934757232666 +/- 0.012562811374664307
#
#
# RSW_STM                    0.7437185645103455 +/- 0.012562870979309082
#
#
# STM_LOW                    0.7412060499191284 +/- 0.007537662982940674
#
#
# STM_RSW                    0.7412060499191284 +/- 0.012562811374664307
#
#
# LOW_STM_RSW                0.7386934757232666 +/- 0.01758795976638794
#
#
# LOW_RSW_STM                0.7487437129020691 +/- 0.007537662982940674
#
#
# STM_LOW_RSW                0.7437185645103455 +/- 0.007537662982940674
#
#
# STM_RSW_LOW                0.7361809015274048 +/- 0.005025148391723633
#
#
# RSW_LOW_STM                0.7412060499191284 +/- 0.007537662982940674
#
#
# RSW_STM_LOW                0.7462311387062073 +/- 0.005025088787078857
