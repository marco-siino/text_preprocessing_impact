# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/text_preprocessing_impact/blob/main/FNS_DS/ANN_FNS_TextPreProImpact_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances.
# - - -
# ANN ON FNS DS EXPERIMENTS NOTEBOOK
# - - -
# Artificial Neural Network on Fake News Spreaders Dataset.
# Code by M. Siino.
#
# From the paper: "Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances." by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf
import nltk
import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer
from textblob import TextBlob
nltk.download('stopwords')
nltk.download('punkt')

os.environ['TF_CUDNN_DETERMINISTIC']='true'
os.environ['TF_DETERMINISTIC_OPS']='true'
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
# Url obtained starting from this: https://drive.google.com/file/d/19ZcqEv88euKB71HfAWjTGN3uCKp2qsfP/ and forcing export=download.
urlTrainingSet = "https://github.com/marco-siino/fake_news_spreaders_detection/raw/main/dataset/pan20-author-profiling-training-2020-02-23.zip"
urlTestSet="https://github.com/marco-siino/fake_news_spreaders_detection/raw/main/dataset/pan20-author-profiling-test-2020-02-23.zip"

training_set = tf.keras.utils.get_file("pan20-author-profiling-training-2020-02-23.zip", urlTrainingSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')
test_set = tf.keras.utils.get_file("pan20-author-profiling-test-2020-02-23.zip", urlTestSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

training_set_dir = os.path.join(os.path.dirname(training_set), 'pan20-author-profiling-training-2020-02-23')
test_set_dir = os.path.join(os.path.dirname(test_set), 'pan20-author-profiling-test-2020-02-23')

print(training_set)
print(training_set_dir)

# !ls -A
# Out:
# Downloading data from https://github.com/marco-siino/fake_news_spreaders_detection/raw/main/dataset/pan20-author-profiling-training-2020-02-23.zip
# 3096576/3094459 [==============================] - 0s 0us/step
# 3104768/3094459 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/fake_news_spreaders_detection/raw/main/dataset/pan20-author-profiling-test-2020-02-23.zip
# 2138112/2135236 [==============================] - 0s 0us/step
# 2146304/2135236 [==============================] - 0s 0us/step
# ./pan20-author-profiling-training-2020-02-23.zip
# ./pan20-author-profiling-training-2020-02-23
# .config
# __MACOSX
# pan20-author-profiling-test-2020-02-23
# pan20-author-profiling-test-2020-02-23.zip
# pan20-author-profiling-training-2020-02-23
# pan20-author-profiling-training-2020-02-23.zip
# sample_data

# %% [markdown]
# ## Build folders hierarchy to use Keras folders preprocessing function.

# %%
### Training Folders. ###

# First level directory.
if not os.path.exists('train_dir_en'):
    os.makedirs('train_dir_en')

# Class labels directory.
if not os.path.exists('train_dir_en/0'):
    os.makedirs('train_dir_en/0')
if not os.path.exists('train_dir_en/1'):
    os.makedirs('train_dir_en/1')

# Make Py variables.
train_dir='train_dir_'

## Test Folders. ##
# First level directory.
if not os.path.exists('test_dir_en'):
    os.makedirs('test_dir_en')

# Class labels directory.
if not os.path.exists('test_dir_en/0'):
    os.makedirs('test_dir_en/0')
if not os.path.exists('test_dir_en/1'):
    os.makedirs('test_dir_en/1')

# Make Py variables.
test_dir='test_dir_'

# !ls -A
# Out:
# .config
# __MACOSX
# pan20-author-profiling-test-2020-02-23
# pan20-author-profiling-test-2020-02-23.zip
# pan20-author-profiling-training-2020-02-23
# pan20-author-profiling-training-2020-02-23.zip
# sample_data
# test_dir_en
# train_dir_en

# %% [markdown]
# ## Set language and directory paths.

# %%
# Set en and es ground truth file path for train_dir. We haven't a ground truth file for the test set.
language='en'

truth_file_training_dir_en=training_set_dir+'/'+language+'/'
truth_file_training_path_en = truth_file_training_dir_en+'truth.txt'

truth_file_test_dir=test_set_dir
truth_file_test_path_en = truth_file_test_dir+'/'+language+'.txt'

# %% [markdown]
# ## Read truth.txt to organize training and test dataset folders.

# %%
# Open the file truth.txt with read only permit.
f = open(truth_file_training_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_training_dir_en+fNameXml):
      os.rename(truth_file_training_dir_en+fNameXml, './train_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# Open the file truth.txt with read only permit.
f = open(truth_file_test_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_dir+'/'+language+'/'+fNameXml, './test_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# %% [markdown]
# ## Generate full training set.

# %%
# Generate full randomized training set.
batch_size=1

en_train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    train_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

en_test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    test_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

train_ds=en_train_ds.shuffle(300,seed=1, reshuffle_each_iteration=False)
test_ds=en_test_ds.shuffle(200,seed=1, reshuffle_each_iteration=False)

train_ds_size=len(train_ds)
test_ds_size=len(test_ds)
# Out:
# Found 300 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.

# %% [markdown]
# ## Functions to pre-process source text. (A detailed discussion on our paper)

# %%
# Do-Nothing preprocessing function.
def DON(input_data):
  tag_open_CDATA_removed = tf.strings.regex_replace(input_data, '<\!\[CDATA\[', ' ')
  tag_closed_CDATA_removed = tf.strings.regex_replace(tag_open_CDATA_removed,'\]{1,}>', ' ')
  tag_author_lang_en_removed = tf.strings.regex_replace(tag_closed_CDATA_removed,'<author lang="en">', ' ')
  tag_closed_author_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'</author>', ' ')
  tag_open_documents_removed = tf.strings.regex_replace(tag_closed_author_removed,'<documents>\n(\t){0,2}', '')
  output_data = tf.strings.regex_replace(tag_open_documents_removed,'</documents>\n(\t){0,2}', ' ')
  return output_data

# Lowercasing preprocessing function.
def LOW(input_data):  
  return tf.strings.lower(DON(input_data))

# Removing Stop Words function.
def RSW(input_data):
  output_data = DON(input_data)

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:

      # input_string = input_string.numpy() [0]
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("Tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# Porter Stemmer preprocessing function.
def STM(input_data):
  output_data = DON(input_data)
  stemmer = PorterStemmer()

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      #print(input_string)
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:
      #input_string = input_string.numpy()[0]
      input_string = input_string.numpy()
      #print(input_string)
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# %% [markdown]
# ## Define the combined preprocessing functions. (The base functions are: DON, LOW, RSW and STM).

# %%
## SECTION WITH PAIRS OF PREPRO FUNCTIONS. APPLICATION ORDER MATTERS (...IN FOLLOWING SECTIONS TOO).
#...5
def LOW_RSW(input_data):
  return RSW(LOW(input_data))

# 6
def LOW_STM(input_data):
  return STM(LOW(input_data))

# 7
def RSW_LOW(input_data):
  return LOW(RSW(input_data))

# 8
def RSW_STM(input_data):
  return STM(RSW(input_data))

# 9
def STM_LOW(input_data):
  return LOW(STM(input_data))

# 10
def STM_RSW(input_data):
  return RSW(STM(input_data))
  
# 11
def LOW_STM_RSW(input_data):
  return RSW(STM(LOW(input_data)))

# 12
def LOW_RSW_STM(input_data):
  return STM(RSW(LOW(input_data)))

# 13
def STM_LOW_RSW(input_data):
  return RSW(LOW(STM(input_data)))

# 14
def STM_RSW_LOW(input_data):
  return LOW(RSW(STM(input_data)))

# 15
def RSW_LOW_STM(input_data):
  return STM(LOW(RSW(input_data)))

# 16
def RSW_STM_LOW(input_data):
  return LOW(STM(RSW(input_data)))

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(preprocessing_function,training_set):
  # Set a large sequence length to find the longest sample in the training set.
  sequence_length = 3000
  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    out=model(authorDocument)
    # Convert token list to numpy array.
    token_list = out.numpy()[0]
    token_list = np.trim_zeros(token_list,'b')
    if longest_sample_length < len(token_list):
      longest_sample_length = len(token_list)

  print("Length of the longest sample is:", longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Define a dictionary with -> function_names:prepro_function_caller. And a dictionary to store model results.

# %%
model_results = {}
prepro_functions_dict_base = {
    'DON':DON,
    'LOW':LOW,
    'RSW':RSW,
    'STM':STM
    }

# 3 prepro functions = 15 combs...+1 for do_nothing

prepro_functions_dict_comb = {
    # 1. Do nothing 
    'DON': DON,
    # 2. Lowercasing 
    'LOW':LOW,
    # 3. Removing Stopwords
    'RSW':RSW, 
    # 4. Porter Stemming
    'STM':STM,
    # 5. LOW->RSW
    'LOW_RSW':LOW_RSW, 
    # 6. LOW->STM
    'LOW_STM':LOW_STM,
    # 7. RSW->LOW
    'RSW_LOW':RSW_LOW,
    # 8. RSW->STM
    'RSW_STM':RSW_STM,
    # 9. STM->LOW
    'STM_LOW':STM_LOW,
    # 10. STM->RSW
    'STM_RSW':STM_RSW,
    # 11. LOW->STM->RSW
    'LOW_STM_RSW':LOW_STM_RSW,  
    # 12. LOW->RSW->STM
    'LOW_RSW_STM':LOW_RSW_STM,
    # 13. STM->LOW->RSW
    'STM_LOW_RSW':STM_LOW_RSW,
    # 14. STM->RSW->LOW
    'STM_RSW_LOW':STM_RSW_LOW,
    # 15. RSW->LOW->STM
    'RSW_LOW_STM':RSW_LOW_STM,
    # 16. RSW->STM->LOW
    'RSW_STM_LOW':RSW_STM_LOW
}

for key in prepro_functions_dict_comb:
  print(key)
  model_results[key]=[]
# Out:
# DON
# LOW
# RSW
# STM
# LOW_RSW
# LOW_STM
# RSW_LOW
# RSW_STM
# STM_LOW
# STM_RSW
# LOW_STM_RSW
# LOW_RSW_STM
# STM_LOW_RSW
# STM_RSW_LOW
# RSW_LOW_STM
# RSW_STM_LOW

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Models definition and evaluation.

# %%
runs_accuracy = []
tf.random.set_seed(1)

# Reset model_results list.
for key in prepro_functions_dict_comb:
  model_results[key]=[]

for key in prepro_functions_dict_comb:

  print("\n\n* * * * EVALUATION USING", key, "AS PREPROCESSING FUNCTION * * * *")

  # Preprocess training set to build a dictionary.
  vectorize_layer = preprocess_and_adapt_ts(prepro_functions_dict_comb[key],train_ds)

  max_features=len(vectorize_layer.get_vocabulary()) + 1
  print("Vocabulary size is:", max_features)

  for run in range(1,(num_runs+1)):
    epochs_accuracy=[]
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    layers.Dense(512,activation='relu'),
                                    layers.Dropout(0.5),
                                    layers.Dense(256,activation='relu'),
                                    layers.Dropout(0.4),
                                    layers.Dense(128,activation='relu'),
                                    layers.Dropout(0.3),
                           
                                    layers.GlobalAveragePooling1D(),
                                    layers.Dropout(0.2),
                                    layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer=opt, metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        print("Run: ",run,"/ Accuracy at epoch ",epoch," is: ", accuracy[0],"\n")
        epochs_accuracy.append(accuracy[0])

    print("Accuracies over epochs:",epochs_accuracy,"\n\n")
    runs_accuracy.append(max(epochs_accuracy))

  runs_accuracy.sort()
  print("\n\n Over all runs maximum accuracies are:", runs_accuracy)
  print("The median is:",runs_accuracy[2],"\n\n\n")
  
  if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
    max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
  else:
    max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
  final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
  model_results[key].append(final_result)
  print("ANN Accuracy Score on Test set -> ",model_results[key])
# Out:
# Streaming output truncated to the last 5000 lines.
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0138 - binary_accuracy: 0.9967 - val_loss: 2.2533 - val_binary_accuracy: 0.7050
# Run:  4 / Accuracy at epoch  18  is:  0.7049999833106995
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0255 - binary_accuracy: 0.9967 - val_loss: 2.2781 - val_binary_accuracy: 0.6900
# Run:  4 / Accuracy at epoch  19  is:  0.6899999976158142
#
# Accuracies over epochs: [0.5, 0.5299999713897705, 0.550000011920929, 0.6299999952316284, 0.7049999833106995, 0.7149999737739563, 0.7250000238418579, 0.7099999785423279, 0.6949999928474426, 0.699999988079071, 0.7099999785423279, 0.699999988079071, 0.5899999737739563, 0.6899999976158142, 0.6899999976158142, 0.6850000023841858, 0.6899999976158142, 0.6850000023841858, 0.7049999833106995, 0.6899999976158142]
#
#
# 300/300 [==============================] - 7s 20ms/step - loss: 0.7076 - binary_accuracy: 0.4833 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy at epoch  0  is:  0.5
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.7004 - binary_accuracy: 0.4833 - val_loss: 0.6925 - val_binary_accuracy: 0.5450
# Run:  5 / Accuracy at epoch  1  is:  0.5450000166893005
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.6903 - binary_accuracy: 0.5533 - val_loss: 0.6972 - val_binary_accuracy: 0.5450
# Run:  5 / Accuracy at epoch  2  is:  0.5450000166893005
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.6074 - binary_accuracy: 0.7033 - val_loss: 0.7207 - val_binary_accuracy: 0.6300
# Run:  5 / Accuracy at epoch  3  is:  0.6299999952316284
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.4840 - binary_accuracy: 0.7900 - val_loss: 0.7983 - val_binary_accuracy: 0.6800
# Run:  5 / Accuracy at epoch  4  is:  0.6800000071525574
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.3863 - binary_accuracy: 0.8633 - val_loss: 0.8736 - val_binary_accuracy: 0.7000
# Run:  5 / Accuracy at epoch  5  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.3075 - binary_accuracy: 0.8967 - val_loss: 1.1274 - val_binary_accuracy: 0.6700
# Run:  5 / Accuracy at epoch  6  is:  0.6700000166893005
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.2475 - binary_accuracy: 0.9033 - val_loss: 1.0651 - val_binary_accuracy: 0.7200
# Run:  5 / Accuracy at epoch  7  is:  0.7200000286102295
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.2392 - binary_accuracy: 0.9200 - val_loss: 1.1846 - val_binary_accuracy: 0.7050
# Run:  5 / Accuracy at epoch  8  is:  0.7049999833106995
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1720 - binary_accuracy: 0.9333 - val_loss: 1.3573 - val_binary_accuracy: 0.6950
# Run:  5 / Accuracy at epoch  9  is:  0.6949999928474426
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1420 - binary_accuracy: 0.9500 - val_loss: 1.3715 - val_binary_accuracy: 0.7000
# Run:  5 / Accuracy at epoch  10  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1327 - binary_accuracy: 0.9400 - val_loss: 1.5020 - val_binary_accuracy: 0.6950
# Run:  5 / Accuracy at epoch  11  is:  0.6949999928474426
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1139 - binary_accuracy: 0.9667 - val_loss: 1.3866 - val_binary_accuracy: 0.7100
# Run:  5 / Accuracy at epoch  12  is:  0.7099999785423279
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1290 - binary_accuracy: 0.9700 - val_loss: 1.5095 - val_binary_accuracy: 0.7100
# Run:  5 / Accuracy at epoch  13  is:  0.7099999785423279
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0635 - binary_accuracy: 0.9867 - val_loss: 1.5862 - val_binary_accuracy: 0.7150
# Run:  5 / Accuracy at epoch  14  is:  0.7149999737739563
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0640 - binary_accuracy: 0.9833 - val_loss: 1.9159 - val_binary_accuracy: 0.6800
# Run:  5 / Accuracy at epoch  15  is:  0.6800000071525574
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0484 - binary_accuracy: 0.9800 - val_loss: 2.1004 - val_binary_accuracy: 0.6650
# Run:  5 / Accuracy at epoch  16  is:  0.6650000214576721
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0500 - binary_accuracy: 0.9900 - val_loss: 2.1723 - val_binary_accuracy: 0.6600
# Run:  5 / Accuracy at epoch  17  is:  0.6600000262260437
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0206 - binary_accuracy: 0.9867 - val_loss: 1.7498 - val_binary_accuracy: 0.7000
# Run:  5 / Accuracy at epoch  18  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0459 - binary_accuracy: 0.9867 - val_loss: 1.7255 - val_binary_accuracy: 0.7000
# Run:  5 / Accuracy at epoch  19  is:  0.699999988079071
#
# Accuracies over epochs: [0.5, 0.5450000166893005, 0.5450000166893005, 0.6299999952316284, 0.6800000071525574, 0.699999988079071, 0.6700000166893005, 0.7200000286102295, 0.7049999833106995, 0.6949999928474426, 0.699999988079071, 0.6949999928474426, 0.7099999785423279, 0.7099999785423279, 0.7149999737739563, 0.6800000071525574, 0.6650000214576721, 0.6600000262260437, 0.699999988079071, 0.699999988079071]
#
#
#
#
#  Over all runs maximum accuracies are: [0.7149999737739563, 0.7200000286102295, 0.7200000286102295, 0.7250000238418579, 0.7250000238418579]
# The median is: 0.7200000286102295
#
#
#
# ANN Accuracy Score on Test set ->  ['0.7200000286102295 +/- 0.005000054836273193']
#
#
# * * * * EVALUATION USING LOW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 2415
# Vocabulary size is: 56838
# 300/300 [==============================] - 7s 19ms/step - loss: 0.7107 - binary_accuracy: 0.4700 - val_loss: 0.6931 - val_binary_accuracy: 0.5600
# Run:  1 / Accuracy at epoch  0  is:  0.5600000023841858
#
# 300/300 [==============================] - 5s 18ms/step - loss: 0.7010 - binary_accuracy: 0.5033 - val_loss: 0.6854 - val_binary_accuracy: 0.5800
# Run:  1 / Accuracy at epoch  1  is:  0.5799999833106995
#
# 300/300 [==============================] - 5s 18ms/step - loss: 0.6747 - binary_accuracy: 0.6067 - val_loss: 0.8129 - val_binary_accuracy: 0.5400
# Run:  1 / Accuracy at epoch  2  is:  0.5400000214576721
#
# 300/300 [==============================] - 5s 18ms/step - loss: 0.6175 - binary_accuracy: 0.7167 - val_loss: 0.8423 - val_binary_accuracy: 0.5700
# Run:  1 / Accuracy at epoch  3  is:  0.5699999928474426
#
# 300/300 [==============================] - 6s 18ms/step - loss: 0.5109 - binary_accuracy: 0.7800 - val_loss: 0.7696 - val_binary_accuracy: 0.6850
# Run:  1 / Accuracy at epoch  4  is:  0.6850000023841858
#
# 300/300 [==============================] - 5s 18ms/step - loss: 0.4060 - binary_accuracy: 0.8467 - val_loss: 0.8299 - val_binary_accuracy: 0.7200
# Run:  1 / Accuracy at epoch  5  is:  0.7200000286102295
#
# 300/300 [==============================] - 5s 18ms/step - loss: 0.3345 - binary_accuracy: 0.8767 - val_loss: 0.9145 - val_binary_accuracy: 0.7050
# Run:  1 / Accuracy at epoch  6  is:  0.7049999833106995
#
# 300/300 [==============================] - 6s 18ms/step - loss: 0
- val_binary_accuracy: 0.7150
# Run:  4 / Accuracy at epoch  19  is:  0.7149999737739563
#
# Accuracies over epochs: [0.5, 0.5699999928474426, 0.5400000214576721, 0.5849999785423279, 0.675000011920929, 0.7250000238418579, 0.699999988079071, 0.7200000286102295, 0.7400000095367432, 0.7300000190734863, 0.7250000238418579, 0.7149999737739563, 0.7149999737739563, 0.699999988079071, 0.7250000238418579, 0.6800000071525574, 0.6600000262260437, 0.7049999833106995, 0.7250000238418579, 0.7149999737739563]
#
#
# 300/300 [==============================] - 7s 19ms/step - loss: 0.7095 - binary_accuracy: 0.4900 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy at epoch  0  is:  0.5
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.6980 - binary_accuracy: 0.4700 - val_loss: 0.6911 - val_binary_accuracy: 0.5750
# Run:  5 / Accuracy at epoch  1  is:  0.574999988079071
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.6854 - binary_accuracy: 0.5667 - val_loss: 0.7232 - val_binary_accuracy: 0.5250
# Run:  5 / Accuracy at epoch  2  is:  0.5249999761581421
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.6498 - binary_accuracy: 0.6633 - val_loss: 0.7708 - val_binary_accuracy: 0.5650
# Run:  5 / Accuracy at epoch  3  is:  0.5649999976158142
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.5407 - binary_accuracy: 0.7700 - val_loss: 0.7874 - val_binary_accuracy: 0.6650
# Run:  5 / Accuracy at epoch  4  is:  0.6650000214576721
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.4313 - binary_accuracy: 0.8400 - val_loss: 0.8128 - val_binary_accuracy: 0.7200
# Run:  5 / Accuracy at epoch  5  is:  0.7200000286102295
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.3494 - binary_accuracy: 0.8800 - val_loss: 0.8879 - val_binary_accuracy: 0.7100
# Run:  5 / Accuracy at epoch  6  is:  0.7099999785423279
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.2826 - binary_accuracy: 0.9100 - val_loss: 0.9857 - val_binary_accuracy: 0.7250
# Run:  5 / Accuracy at epoch  7  is:  0.7250000238418579
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.2238 - binary_accuracy: 0.9200 - val_loss: 1.0842 - val_binary_accuracy: 0.7100
# Run:  5 / Accuracy at epoch  8  is:  0.7099999785423279
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.2071 - binary_accuracy: 0.9267 - val_loss: 1.1091 - val_binary_accuracy: 0.7150
# Run:  5 / Accuracy at epoch  9  is:  0.7149999737739563
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.1594 - binary_accuracy: 0.9400 - val_loss: 1.2282 - val_binary_accuracy: 0.7150
# Run:  5 / Accuracy at epoch  10  is:  0.7149999737739563
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.1306 - binary_accuracy: 0.9567 - val_loss: 1.3400 - val_binary_accuracy: 0.7150
# Run:  5 / Accuracy at epoch  11  is:  0.7149999737739563
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.1020 - binary_accuracy: 0.9633 - val_loss: 1.6551 - val_binary_accuracy: 0.6700
# Run:  5 / Accuracy at epoch  12  is:  0.6700000166893005
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0820 - binary_accuracy: 0.9733 - val_loss: 1.7507 - val_binary_accuracy: 0.6700
# Run:  5 / Accuracy at epoch  13  is:  0.6700000166893005
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0957 - binary_accuracy: 0.9733 - val_loss: 1.5881 - val_binary_accuracy: 0.6750
# Run:  5 / Accuracy at epoch  14  is:  0.675000011920929
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0934 - binary_accuracy: 0.9767 - val_loss: 1.6374 - val_binary_accuracy: 0.7050
# Run:  5 / Accuracy at epoch  15  is:  0.7049999833106995
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0607 - binary_accuracy: 0.9867 - val_loss: 1.6798 - val_binary_accuracy: 0.7200
# Run:  5 / Accuracy at epoch  16  is:  0.7200000286102295
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0554 - binary_accuracy: 0.9900 - val_loss: 1.6930 - val_binary_accuracy: 0.7200
# Run:  5 / Accuracy at epoch  17  is:  0.7200000286102295
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0310 - binary_accuracy: 0.9933 - val_loss: 2.3024 - val_binary_accuracy: 0.6950
# Run:  5 / Accuracy at epoch  18  is:  0.6949999928474426
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0591 - binary_accuracy: 0.9867 - val_loss: 1.8372 - val_binary_accuracy: 0.7050
# Run:  5 / Accuracy at epoch  19  is:  0.7049999833106995
#
# Accuracies over epochs: [0.5, 0.574999988079071, 0.5249999761581421, 0.5649999976158142, 0.6650000214576721, 0.7200000286102295, 0.7099999785423279, 0.7250000238418579, 0.7099999785423279, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.6700000166893005, 0.6700000166893005, 0.675000011920929, 0.7049999833106995, 0.7200000286102295, 0.7200000286102295, 0.6949999928474426, 0.7049999833106995]
#
#
#
#
#  Over all runs maximum accuracies are: [0.7149999737739563, 0.7200000286102295, 0.7200000286102295, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7300000190734863, 0.7350000143051147, 0.7400000095367432]
# The median is: 0.7200000286102295
#
#
#
# ANN Accuracy Score on Test set ->  ['0.7200000286102295 +/- 0.005000054836273193']
#
#
# * * * * EVALUATION USING RSW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 2043
# Vocabulary size is: 68043
# 300/300 [==============================] - 7s 21ms/step - loss: 0.7089 - binary_accuracy: 0.4533 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy at epoch  0  is:  0.5
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.7020 - binary_accuracy: 0.4600 - val_loss: 0.6919 - val_binary_accuracy: 0.5100
# Run:  1 / Accuracy at epoch  1  is:  0.5099999904632568
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.6848 - binary_accuracy: 0.5767 - val_loss: 0.7221 - val_binary_accuracy: 0.5500
# Run:  1 / Accuracy at epoch  2  is:  0.550000011920929
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.6135 - binary_accuracy: 0.7000 - val_loss: 0.7310 - val_binary_accuracy: 0.6350
# Run:  1 / Accuracy at epoch  3  is:  0.6349999904632568
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.4643 - binary_accuracy: 0.7933 - val_loss: 0.8071 - val_binary_accuracy: 0.7000
# Run:  1 / Accuracy at epoch  4  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.3805 - binary_accuracy: 0.8733 - val_loss: 0.8836 - val_binary_accuracy: 0.7250
# Run:  1 / Accuracy at epoch  5  is:  0.7250000238418579
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.3175 - binary_accuracy: 0.8867 - val_loss: 1.0144 - val_binary_accuracy: 0.7150
# Run:  1 / Accuracy at epoch  6  is:  0.7149999737739563
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.2342 - binary_accuracy: 0.9233 - val_loss: 1.2376 - val_binary_accuracy: 0.6950
# Run:  1 / Accuracy at epoch  7  is:  0.6949999928474426
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.2285 - binary_accuracy: 0.9233 - val_loss: 1.2202 - val_binary_accuracy: 0.6950
# Run:  1 / Accuracy at epoch  8  is:  0.6949999928474426
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.1912 - binary_accuracy: 0.9433 - val_loss: 1.3078 - val_binary_accuracy: 0.7100
# Run:  1 / Accuracy at epoch  9  is:  0.7099999785423279
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.1250 - binary_accuracy: 0.9667 - val_loss: 1.5757 - val_binary_accuracy: 0.7000
# Run:  1 / Accuracy at epoch  10  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.1127 - binary_accuracy: 0.9600 - val_loss: 1.4723 - val_binary_accuracy: 0.7000
# Run:  1 / Accuracy at epoch  11  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.1079 - binary_accuracy: 0.9667 - val_loss: 2.1384 - val_binary_accuracy: 0.6150
# Run:  1 / Accuracy at epoch  12  is:  0.6150000095367432
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0769 - binary_accuracy: 0.9733 - val_loss: 1.8388 - val_binary_accuracy: 0.6850
# Run:  1 / Accuracy at epoch  13  is:  0.6850000023841858
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0874 - binary_accuracy: 0.9867 - val_loss: 1.7101 - val_binary_accuracy: 0.7000
# Run:  1 / Accuracy at epoch  14  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0813 - binary_accuracy: 0.9800 - val_loss: 1.7497 - val_binary_accuracy: 0.7000
# Run:  1 / Accuracy at epoch  15  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0480 - binary_accuracy: 0.9867 - val_loss: 1.9655 - val_binary_accuracy: 0.6850
# Run:  1 / Accuracy at epoch  16  is:  0.6850000023841858
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.0776 - binary_accuracy: 0.9867 - val_loss: 2.1373 - val_binary_accuracy: 0.7000
# Run:  1 / Accuracy at epoch  17  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.
- val_binary_accuracy: 0.7150
# Run:  4 / Accuracy at epoch  19  is:  0.7149999737739563
#
# Accuracies over epochs: [0.5299999713897705, 0.5299999713897705, 0.5450000166893005, 0.6299999952316284, 0.7099999785423279, 0.7099999785423279, 0.7200000286102295, 0.7099999785423279, 0.699999988079071, 0.6899999976158142, 0.6800000071525574, 0.6949999928474426, 0.699999988079071, 0.699999988079071, 0.6549999713897705, 0.7049999833106995, 0.6949999928474426, 0.7149999737739563, 0.7200000286102295, 0.7149999737739563]
#
#
# 300/300 [==============================] - 8s 22ms/step - loss: 0.7102 - binary_accuracy: 0.4467 - val_loss: 0.6931 - val_binary_accuracy: 0.5250
# Run:  5 / Accuracy at epoch  0  is:  0.5249999761581421
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.6999 - binary_accuracy: 0.4733 - val_loss: 0.6914 - val_binary_accuracy: 0.5550
# Run:  5 / Accuracy at epoch  1  is:  0.5550000071525574
#
# 300/300 [==============================] - 7s 21ms/step - loss: 0.6858 - binary_accuracy: 0.5833 - val_loss: 0.7102 - val_binary_accuracy: 0.5550
# Run:  5 / Accuracy at epoch  2  is:  0.5550000071525574
#
# 300/300 [==============================] - 7s 21ms/step - loss: 0.6067 - binary_accuracy: 0.7300 - val_loss: 0.7271 - val_binary_accuracy: 0.6250
# Run:  5 / Accuracy at epoch  3  is:  0.625
#
# 300/300 [==============================] - 7s 22ms/step - loss: 0.4700 - binary_accuracy: 0.7833 - val_loss: 0.7800 - val_binary_accuracy: 0.6800
# Run:  5 / Accuracy at epoch  4  is:  0.6800000071525574
#
# 300/300 [==============================] - 7s 21ms/step - loss: 0.3805 - binary_accuracy: 0.8567 - val_loss: 0.8512 - val_binary_accuracy: 0.7050
# Run:  5 / Accuracy at epoch  5  is:  0.7049999833106995
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.3224 - binary_accuracy: 0.8767 - val_loss: 0.9219 - val_binary_accuracy: 0.7150
# ...
# Run:  2 / Accuracy at epoch  18  is:  0.7099999785423279
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0503 - binary_accuracy: 0.9933 - val_loss: 2.3538 - val_binary_accuracy: 0.6800
# Run:  2 / Accuracy at epoch  19  is:  0.6800000071525574
#
# Accuracies over epochs: [0.5, 0.550000011920929, 0.5450000166893005, 0.6299999952316284, 0.675000011920929, 0.7200000286102295, 0.6850000023841858, 0.6899999976158142, 0.699999988079071, 0.7049999833106995, 0.7200000286102295, 0.7049999833106995, 0.7149999737739563, 0.7049999833106995, 0.7350000143051147, 0.7149999737739563, 0.6650000214576721, 0.699999988079071, 0.7099999785423279, 0.6800000071525574]
#
#
# 300/300 [==============================] - 7s 20ms/step - loss: 0.7108 - binary_accuracy: 0.4767 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy at epoch  0  is:  0.5
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.7009 - binary_accuracy: 0.4733 - val_loss: 0.6929 - val_binary_accuracy: 0.5050
# Run:  3 / Accuracy at epoch  1  is:  0.5049999952316284
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.6932 - binary_accuracy: 0.5167 - val_loss: 0.7053 - val_binary_accuracy: 0.5500
# Run:  3 / Accuracy at epoch  2  is:  0.550000011920929
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.6516 - binary_accuracy: 0.6533 - val_loss: 0.7306 - val_binary_accuracy: 0.5850
# Run:  3 / Accuracy at epoch  3  is:  0.5849999785423279
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.5205 - binary_accuracy: 0.7600 - val_loss: 0.7479 - val_binary_accuracy: 0.6750
# Run:  3 / Accuracy at epoch  4  is:  0.675000011920929
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.4009 - binary_accuracy: 0.8500 - val_loss: 0.8159 - val_binary_accuracy: 0.7350
# Run:  3 / Accuracy at epoch  5  is:  0.7350000143051147
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.3462 - binary_accuracy: 0.8900 - val_loss: 1.0014 - val_binary_accuracy: 0.6950
# Run:  3 / Accuracy at epoch  6  is:  0.6949999928474426
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.2808 - binary_accuracy: 0.9000 - val_loss: 1.0387 - val_binary_accuracy: 0.7000
# Run:  3 / Accuracy at epoch  7  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.2321 - binary_accuracy: 0.9067 - val_loss: 1.1798 - val_binary_accuracy: 0.7050
# Run:  3 / Accuracy at epoch  8  is:  0.7049999833106995
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1847 - binary_accuracy: 0.9333 - val_loss: 1.2256 - val_binary_accuracy: 0.7050
# Run:  3 / Accuracy at epoch  9  is:  0.7049999833106995
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.1342 - binary_accuracy: 0.9500 - val_loss: 1.3225 - val_binary_accuracy: 0.7200
# Run:  3 / Accuracy at epoch  10  is:  0.7200000286102295
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.1231 - binary_accuracy: 0.9433 - val_loss: 1.3864 - val_binary_accuracy: 0.7200
# Run:  3 / Accuracy at epoch  11  is:  0.7200000286102295
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1315 - binary_accuracy: 0.9600 - val_loss: 1.8789 - val_binary_accuracy: 0.6550
# Run:  3 / Accuracy at epoch  12  is:  0.6549999713897705
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0849 - binary_accuracy: 0.9800 - val_loss: 1.6430 - val_binary_accuracy: 0.7200
# Run:  3 / Accuracy at epoch  13  is:  0.7200000286102295
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1077 - binary_accuracy: 0.9767 - val_loss: 1.6373 - val_binary_accuracy: 0.6950
# Run:  3 / Accuracy at epoch  14  is:  0.6949999928474426
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0908 - binary_accuracy: 0.9700 - val_loss: 1.6493 - val_binary_accuracy: 0.7000
# Run:  3 / Accuracy at epoch  15  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0660 - binary_accuracy: 0.9833 - val_loss: 2.1218 - val_binary_accuracy: 0.6700
# Run:  3 / Accuracy at epoch  16  is:  0.6700000166893005
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0617 - binary_accuracy: 0.9833 - val_loss: 2.1311 - val_binary_accuracy: 0.6800
# Run:  3 / Accuracy at epoch  17  is:  0.6800000071525574
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0344 - binary_accuracy: 0.9900 - val_loss: 1.8972 - val_binary_accuracy: 0.7150
# Run:  3 / Accuracy at epoch  18  is:  0.7149999737739563
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0742 - binary_accuracy: 0.9867 - val_loss: 2.0028 - val_binary_accuracy: 0.7200
# Run:  3 / Accuracy at epoch  19  is:  0.7200000286102295
#
# Accuracies over epochs: [0.5, 0.5049999952316284, 0.550000011920929, 0.5849999785423279, 0.675000011920929, 0.7350000143051147, 0.6949999928474426, 0.699999988079071, 0.7049999833106995, 0.7049999833106995, 0.7200000286102295, 0.7200000286102295, 0.6549999713897705, 0.7200000286102295, 0.6949999928474426, 0.699999988079071, 0.6700000166893005, 0.6800000071525574, 0.7149999737739563, 0.7200000286102295]
#
#
# 300/300 [==============================] - 7s 20ms/step - loss: 0.7075 - binary_accuracy: 0.4600 - val_loss: 0.6931 - val_binary_accuracy: 0.4950
# Run:  4 / Accuracy at epoch  0  is:  0.4950000047683716
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.7005 - binary_accuracy: 0.5000 - val_loss: 0.6902 - val_binary_accuracy: 0.5650
# Run:  4 / Accuracy at epoch  1  is:  0.5649999976158142
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.6808 - binary_accuracy: 0.6033 - val_loss: 0.7659 - val_binary_accuracy: 0.5400
# Run:  4 / Accuracy at epoch  2  is:  0.5400000214576721
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.6180 - binary_accuracy: 0.6867 - val_loss: 0.7379 - val_binary_accuracy: 0.6100
# Run:  4 / Accuracy at epoch  3  is:  0.6100000143051147
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.4791 - binary_accuracy: 0.7900 - val_loss: 0.8020 - val_binary_accuracy: 0.6700
# Run:  4 / Accuracy at epoch  4  is:  0.6700000166893005
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.4069 - binary_accuracy: 0.8433 - val_loss: 0.8095 - val_binary_accuracy: 0.7300
# Run:  4 / Accuracy at epoch  5  is:  0.7300000190734863
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.3164 - binary_accuracy: 0.8967 - val_loss: 0.9294 - val_binary_accuracy: 0.7250
# Run:  4 / Accuracy at epoch  6  is:  0.7250000238418579
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.2685 - binary_accuracy: 0.9033 - val_loss: 1.0326 - val_binary_accuracy: 0.7000
# Run:  4 / Accuracy at epoch  7  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.2090 - binary_accuracy: 0.9267 - val_loss: 1.1203 - val_binary_accuracy: 0.7200
# Run:  4 / Accuracy at epoch  8  is:  0.7200000286102295
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.2137 - binary_accuracy: 0.9267 - val_loss: 1.1935 - val_binary_accuracy: 0.7200
# Run:  4 / Accuracy at epoch  9  is:  0.7200000286102295
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.1111 - binary_accuracy: 0.9600 - val_loss: 1.4844 - val_binary_accuracy: 0.7050
# Run:  4 / Accuracy at epoch  10  is:  0.7049999833106995
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1231 - binary_accuracy: 0.9533 - val_loss: 1.4091 - val_binary_accuracy: 0.6900
# Run:  4 / Accuracy at epoch  11  is:  0.6899999976158142
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1560 - binary_accuracy: 0.9533 - val_loss: 1.8027 - val_binary_accuracy: 0.6300
# Run:  4 / Accuracy at epoch  12  is:  0.6299999952316284
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0821 - binary_accuracy: 0.9767 - val_loss: 1.5352 - val_binary_accuracy: 0.7150
# Run:  4 / Accuracy at epoch  13  is:  0.7149999737739563
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0756 - binary_accuracy: 0.9800 - val_loss: 2.0283 - val_binary_accuracy: 0.6500
# Run:  4 / Accuracy at epoch  14  is:  0.6499999761581421
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1269 - binary_accuracy: 0.9767 - val_loss: 1.5877 - val_binary_accuracy: 0.7150
# Run:  4 / Accuracy at epoch  15  is:  0.7149999737739563
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0613 - binary_accuracy: 0.9833 - val_loss: 1.6984 - val_binary_accuracy: 0.7200
# Run:  4 / Accuracy at epoch  16  is:  0.7200000286102295
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0529 - binary_accuracy: 0.9900 - val_loss: 1.8477 - val_binary_accuracy: 0.7000
# Run:  4 / Accuracy at epoch  17  is:  0.699999988079071
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0329 - binary_accuracy: 0.9900 - val_loss: 1.8603 - val_binary_accuracy: 0.7100
# Run:  4 / Accuracy at epoch  18  is:  0.7099999785423279
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0554 - binary_accuracy: 0.9900 - val_loss: 1.8793 - val_binary_accuracy: 0.6900
# Run:  4 / Accuracy at epoch  19  is:  0.6899999976158142
#
# Accuracies over epochs: [0.4950000047683716, 0.5649999976158142, 0.5400000214576721, 0.6100000143051147, 0.6700000166893005, 0.7300000190734863, 0.7250000238418579, 0.699999988079071, 0.7200000286102295, 0.7200000286102295, 0.7049999833106995, 0.6899999976158142, 0.6299999952316284, 0.7149999737739563, 0.6499999761581421, 0.7149999737739563, 0.7200000286102295, 0.699999988079071, 0.7099999785423279, 0.6899999976158142]
#
#
# 300/300 [==============================] - 7s 20ms/step - loss: 0.7092 - binary_accuracy: 0.4633 - val_loss: 0.6932 - val_binary_accuracy: 0.4950
# Run:  5 / Accuracy at epoch  0  is:  0.4950000047683716
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.7056 - binary_accuracy: 0.5000 - val_loss: 0.6917 - val_binary_accuracy: 0.5400
# Run:  5 / Accuracy at epoch  1  is:  0.5400000214576721
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.6873 - binary_accuracy: 0.5933 - val_loss: 0.7461 - val_binary_accuracy: 0.5400
# Run:  5 / Accuracy at epoch  2  is:  0.5400000214576721
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.6288 - binary_accuracy: 0.6900 - val_loss: 0.7802 - val_binary_accuracy: 0.6000
# Run:  5 / Accuracy at epoch  3  is:  0.6000000238418579
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.5000 - binary_accuracy: 0.7867 - val_loss: 0.7879 - val_binary_accuracy: 0.6750
# Run:  5 / Accuracy at epoch  4  is:  0.675000011920929
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.3966 - binary_accuracy: 0.8600 - val_loss: 0.8574 - val_binary_accuracy: 0.7100
# Run:  5 / Accuracy at epoch  5  is:  0.7099999785423279
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.3464 - binary_accuracy: 0.8933 - val_loss: 0.9648 - val_binary_accuracy: 0.7100
# Run:  5 / Accuracy at epoch  6  is:  0.7099999785423279
#
# 300/300 [==============================] - 6s 19ms/step - loss: 0.2486 - binary_accuracy: 0.9100 - val_loss: 1.1306 - val_binary_accuracy: 0.7050
# Run:  5 / Accuracy at epoch  7  is:  0.7049999833106995
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.2295 - binary_accuracy: 0.9133 - val_loss: 1.2042 - val_binary_accuracy: 0.6950
# Run:  5 / Accuracy at epoch  8  is:  0.6949999928474426
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1964 - binary_accuracy: 0.9367 - val_loss: 1.3608 - val_binary_accuracy: 0.6750
# Run:  5 / Accuracy at epoch  9  is:  0.675000011920929
#
# 300/300 [==============================] - 6s 21ms/step - loss: 0.1414 - binary_accuracy: 0.9533 - val_loss: 1.2868 - val_binary_accuracy: 0.7250
# Run:  5 / Accuracy at epoch  10  is:  0.7250000238418579
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1090 - binary_accuracy: 0.9667 - val_loss: 1.4395 - val_binary_accuracy: 0.6900
# Run:  5 / Accuracy at epoch  11  is:  0.6899999976158142
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1265 - binary_accuracy: 0.9533 - val_loss: 1.6803 - val_binary_accuracy: 0.6500
# Run:  5 / Accuracy at epoch  12  is:  0.6499999761581421
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.1070 - binary_accuracy: 0.9600 - val_loss: 1.5311 - val_binary_accuracy: 0.7150
# Run:  5 / Accuracy at epoch  13  is:  0.7149999737739563
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0732 - binary_accuracy: 0.9733 - val_loss: 1.6379 - val_binary_accuracy: 0.7050
# Run:  5 / Accuracy at epoch  14  is:  0.7049999833106995
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0932 - binary_accuracy: 0.9767 - val_loss: 1.6176 - val_binary_accuracy: 0.7050
# Run:  5 / Accuracy at epoch  15  is:  0.7049999833106995
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0698 - binary_accuracy: 0.9767 - val_loss: 2.2972 - val_binary_accuracy: 0.6650
# Run:  5 / Accuracy at epoch  16  is:  0.6650000214576721
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0574 - binary_accuracy: 0.9900 - val_loss: 1.9470 - val_binary_accuracy: 0.7100
# Run:  5 / Accuracy at epoch  17  is:  0.7099999785423279
#
# 300/300 [==============================] - 7s 22ms/step - loss: 0.0580 - binary_accuracy: 0.9900 - val_loss: 2.0087 - val_binary_accuracy: 0.7200
# Run:  5 / Accuracy at epoch  18  is:  0.7200000286102295
#
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0736 - binary_accuracy: 0.9867 - val_loss: 2.2231 - val_binary_accuracy: 0.6900
# Run:  5 / Accuracy at epoch  19  is:  0.6899999976158142
#
# Accuracies over epochs: [0.4950000047683716, 0.5400000214576721, 0.5400000214576721, 0.6000000238418579, 0.675000011920929, 0.7099999785423279, 0.7099999785423279, 0.7049999833106995, 0.6949999928474426, 0.675000011920929, 0.7250000238418579, 0.6899999976158142, 0.6499999761581421, 0.7149999737739563, 0.7049999833106995, 0.7049999833106995, 0.6650000214576721, 0.7099999785423279, 0.7200000286102295, 0.6899999976158142]
#
#
#
#
#  Over all runs maximum accuracies are: [0.6949999928474426, 0.699999988079071, 0.699999988079071, 0.7099999785423279, 0.7099999785423279, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7149999737739563, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7200000286102295, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7250000238418579, 0.7300000190734863, 0.7300000190734863, 0.7300000190734863, 0.7300000190734863, 0.7300000190734863, 0.7300000190734863, 0.7300000190734863, 0.7300000190734863, 0.7300000190734863, 0.7350000143051147, 0.7350000143051147, 0.7350000143051147, 0.7350000143051147, 0.7350000143051147, 0.7350000143051147, 0.7350000143051147, 0.7350000143051147, 0.7400000095367432, 0.7400000095367432, 0.7400000095367432]
# The median is: 0.699999988079071
#
#
#
# ANN Accuracy Score on Test set ->  ['0.699999988079071 +/- 0.009999990463256836']

# %% [markdown]
# ## Now show compact results in a table.

# %%
print(" PREPRO FUNCTION    |  Test Accuracy   |",end = '')

print("\n")
for prepro_func in prepro_functions_dict_comb:
  #print(prepro_func,"\t\t\t",format(round(model_results[prepro_func][0],4),'.4f'),"\t\t",end='')
  result = format(round(model_results[prepro_func][0],4),'.4f')
  print(f'{prepro_func:27}{ result :12}')
  print("\n")
