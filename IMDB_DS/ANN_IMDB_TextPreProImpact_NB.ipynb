# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/text_preprocessing_impact/blob/main/IMDB_DS/ANN_IMDB_TextPreProImpact_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances.
# - - -
# ANN ON IMDB DS EXPERIMENTS NOTEBOOK
# - - -
# Artificial Neural Network on Internet Movie Database Dataset.
# Code by M. Siino.
#
# From the paper: "Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances." by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf
import nltk
import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from sklearn.linear_model import LogisticRegression
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer
from textblob import TextBlob
nltk.download('stopwords')
nltk.download('punkt')

os.environ['TF_CUDNN_DETERMINISTIC']='false'
os.environ['TF_DETERMINISTIC_OPS']='false'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

dataset = tf.keras.utils.get_file("aclImdb_v1", url,
                                    untar=True, cache_dir='.',
                                    cache_subdir='')

dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')

train_set_dir = os.path.join(dataset_dir, 'train')
test_set_dir = os.path.join(dataset_dir, 'test')

remove_dir = os.path.join(train_set_dir, 'unsup')
shutil.rmtree(remove_dir)

# %% [markdown]
# ## Generate training and test set.

# %%
# Generate full randomized training set.
batch_size = 1
seed = 1

train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train', 
    batch_size=batch_size,
    shuffle=False,
    seed=seed
    )

test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/test', 
    batch_size=batch_size,
    shuffle=False,
    seed=seed
    )

train_ds = train_ds.shuffle(25000,seed=1,reshuffle_each_iteration = False)
test_ds = test_ds.shuffle(25000,seed=1,reshuffle_each_iteration = False)

train_ds = train_ds.take(5000)
test_ds = test_ds.take(5000)

train_ds_size=len(train_ds)
test_ds_size=len(test_ds)
# Out:
# Found 25000 files belonging to 2 classes.
# Found 25000 files belonging to 2 classes.

# %% [markdown]
# ## Functions to pre-process source text. (A detailed discussion on our paper)

# %%
# Do-Nothing preprocessing function.
def DON(input_data):
  tag_open_CDATA_removed = tf.strings.regex_replace(input_data, '<\!\[CDATA\[', ' ')
  tag_closed_CDATA_removed = tf.strings.regex_replace(tag_open_CDATA_removed,'\]{1,}>', ' ')
  tag_author_lang_en_removed = tf.strings.regex_replace(tag_closed_CDATA_removed,'<author lang="en">', ' ')
  tag_closed_author_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'</author>', ' ')
  tag_open_documents_removed = tf.strings.regex_replace(tag_closed_author_removed,'<documents>\n(\t){0,2}', '')
  output_data = tf.strings.regex_replace(tag_open_documents_removed,'</documents>\n(\t){0,2}', ' ')
  return output_data

# Lowercasing preprocessing function.
def LOW(input_data):  
  return tf.strings.lower(DON(input_data))

# Removing Stop Words function.
def RSW(input_data):
  output_data = DON(input_data)

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:

      # input_string = input_string.numpy() [0]
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("Tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# Porter Stemmer preprocessing function.
def STM(input_data):
  output_data = DON(input_data)
  stemmer = PorterStemmer()

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      #print(input_string)
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:
      #input_string = input_string.numpy()[0]
      input_string = input_string.numpy()
      #print(input_string)
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# %% [markdown]
# ## Define the combined preprocessing functions. (The base functions are: DON, LOW, RSW and STM).

# %%
## SECTION WITH PAIRS OF PREPRO FUNCTIONS. APPLICATION ORDER MATTERS (...IN FOLLOWING SECTIONS TOO).
#...5
def LOW_RSW(input_data):
  return RSW(LOW(input_data))

# 6
def LOW_STM(input_data):
  return STM(LOW(input_data))

# 7
def RSW_LOW(input_data):
  return LOW(RSW(input_data))

# 8
def RSW_STM(input_data):
  return STM(RSW(input_data))

# 9
def STM_LOW(input_data):
  return LOW(STM(input_data))

# 10
def STM_RSW(input_data):
  return RSW(STM(input_data))
  
# 11
def LOW_STM_RSW(input_data):
  return RSW(STM(LOW(input_data)))

# 12
def LOW_RSW_STM(input_data):
  return STM(RSW(LOW(input_data)))

# 13
def STM_LOW_RSW(input_data):
  return RSW(LOW(STM(input_data)))

# 14
def STM_RSW_LOW(input_data):
  return LOW(RSW(STM(input_data)))

# 15
def RSW_LOW_STM(input_data):
  return STM(LOW(RSW(input_data)))

# 16
def RSW_STM_LOW(input_data):
  return LOW(STM(RSW(input_data)))

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(preprocessing_function,training_set):
  # Set a large sequence length to find the longest sample in the training set.
  sequence_length = 3000
  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    out=model(authorDocument)
    # Convert token list to numpy array.
    token_list = out.numpy()[0]
    token_list = np.trim_zeros(token_list,'b')
    if longest_sample_length < len(token_list):
      longest_sample_length = len(token_list)

  print("Length of the longest sample is:", longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Define a dictionary with -> function_names:prepro_function_caller. And a dictionary to store model results.

# %%
model_results = {}
prepro_functions_dict_base = {
    'DON':DON,
    'LOW':LOW,
    'RSW':RSW,
    'STM':STM
    }

# 3 prepro functions = 15 combs...+1 for do_nothing

prepro_functions_dict_comb = {
    # 1. Do nothing 
    'DON': DON,
    # 2. Lowercasing 
    'LOW':LOW,
    # 3. Removing Stopwords
    'RSW':RSW, 
    # 4. Porter Stemming
    'STM':STM,
    # 5. LOW->RSW
    'LOW_RSW':LOW_RSW, 
    # 6. LOW->STM
    'LOW_STM':LOW_STM,
    # 7. RSW->LOW
    'RSW_LOW':RSW_LOW,
    # 8. RSW->STM
    'RSW_STM':RSW_STM,
    # 9. STM->LOW
    'STM_LOW':STM_LOW,
    # 10. STM->RSW
    'STM_RSW':STM_RSW,
    # 11. LOW->STM->RSW
    'LOW_STM_RSW':LOW_STM_RSW,  
    # 12. LOW->RSW->STM
    'LOW_RSW_STM':LOW_RSW_STM,
    # 13. STM->LOW->RSW
    'STM_LOW_RSW':STM_LOW_RSW,
    # 14. STM->RSW->LOW
    'STM_RSW_LOW':STM_RSW_LOW,
    # 15. RSW->LOW->STM
    'RSW_LOW_STM':RSW_LOW_STM,
    # 16. RSW->STM->LOW
    'RSW_STM_LOW':RSW_STM_LOW
}

for key in prepro_functions_dict_comb:
  print(key)
  model_results[key]=[]
# Out:
# DON
# LOW
# RSW
# STM
# LOW_RSW
# LOW_STM
# RSW_LOW
# RSW_STM
# STM_LOW
# STM_RSW
# LOW_STM_RSW
# LOW_RSW_STM
# STM_LOW_RSW
# STM_RSW_LOW
# RSW_LOW_STM
# RSW_STM_LOW

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Models definition and evaluation.

# %%
tf.random.set_seed(0)
TF_DISABLE_SEGMENT_REDUCTION_OP_DETERMINISM_EXCEPTIONS=True

# Reset model_results list.
for key in prepro_functions_dict_comb:
  model_results[key]=[]

for key in prepro_functions_dict_comb:
  runs_accuracy = []

  print("\n\n* * * * EVALUATION USING", key, "AS PREPROCESSING FUNCTION * * * *")

  # Preprocess training set to build a dictionary.
  vectorize_layer = preprocess_and_adapt_ts(prepro_functions_dict_comb[key],train_ds)

  max_features=len(vectorize_layer.get_vocabulary()) + 1
  print("Vocabulary size is:", max_features)

  for run in range(1,(num_runs+1)):
    epochs_accuracy=[]
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    layers.Dense(512,activation='relu'),
                                    layers.Dropout(0.5),
                                    layers.Dense(256,activation='relu'),
                                    layers.Dropout(0.4),
                                    layers.Dense(128,activation='relu'),
                                    layers.Dropout(0.3),
                           
                                    layers.GlobalAveragePooling1D(),
                                    layers.Dropout(0.2),
                                    layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer=opt, metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        print("Run: ",run,"/ Accuracy at epoch ",epoch," is: ", accuracy[0],"\n")
        epochs_accuracy.append(accuracy[0])

    print("Accuracies over epochs:",epochs_accuracy,"\n\n")
    runs_accuracy.append(max(epochs_accuracy))

  runs_accuracy.sort()
  print("\n\n Over all runs maximum accuracies are:", runs_accuracy)
  print("The median is:",runs_accuracy[2],"\n\n\n")
  
  if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
    max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
  else:
    max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
  final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
  model_results[key].append(final_result)
  print("ANN Accuracy Score on Test set -> ",model_results[key])
# Out:
# Streaming output truncated to the last 5000 lines.
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.0942 - binary_accuracy: 0.9834 - val_loss: 5.9009 - val_binary_accuracy: 0.6284
# Run:  4 / Accuracy at epoch  18  is:  0.6284000277519226
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.0925 - binary_accuracy: 0.9828 - val_loss: 2.8766 - val_binary_accuracy: 0.7176
# Run:  4 / Accuracy at epoch  19  is:  0.7175999879837036
#
# Accuracies over epochs: [0.6718000173568726, 0.7789999842643738, 0.8137999773025513, 0.8145999908447266, 0.8217999935150146, 0.8037999868392944, 0.7950000166893005, 0.7325999736785889, 0.7458000183105469, 0.6887999773025513, 0.6837999820709229, 0.7175999879837036, 0.6068000197410583, 0.6299999952316284, 0.5641999840736389, 0.7080000042915344, 0.6725999712944031, 0.6381999850273132, 0.6284000277519226, 0.7175999879837036]
#
#
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.6791 - binary_accuracy: 0.5618 - val_loss: 0.5494 - val_binary_accuracy: 0.7228
# Run:  5 / Accuracy at epoch  0  is:  0.7228000164031982
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.5780 - binary_accuracy: 0.7428 - val_loss: 0.4845 - val_binary_accuracy: 0.7790
# Run:  5 / Accuracy at epoch  1  is:  0.7789999842643738
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.5129 - binary_accuracy: 0.7882 - val_loss: 0.4662 - val_binary_accuracy: 0.8000
# Run:  5 / Accuracy at epoch  2  is:  0.800000011920929
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.4678 - binary_accuracy: 0.8182 - val_loss: 0.4207 - val_binary_accuracy: 0.8282
# Run:  5 / Accuracy at epoch  3  is:  0.8281999826431274
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.4380 - binary_accuracy: 0.8358 - val_loss: 0.4081 - val_binary_accuracy: 0.8352
# Run:  5 / Accuracy at epoch  4  is:  0.8352000117301941
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.4113 - binary_accuracy: 0.8572 - val_loss: 0.4135 - val_binary_accuracy: 0.8350
# Run:  5 / Accuracy at epoch  5  is:  0.8349999785423279
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.3768 - binary_accuracy: 0.8770 - val_loss: 0.6361 - val_binary_accuracy: 0.7928
# Run:  5 / Accuracy at epoch  6  is:  0.7928000092506409
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.3178 - binary_accuracy: 0.8962 - val_loss: 0.8857 - val_binary_accuracy: 0.7546
# Run:  5 / Accuracy at epoch  7  is:  0.7545999884605408
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.2588 - binary_accuracy: 0.9154 - val_loss: 1.5033 - val_binary_accuracy: 0.6878
# Run:  5 / Accuracy at epoch  8  is:  0.6877999901771545
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.2274 - binary_accuracy: 0.9350 - val_loss: 1.6137 - val_binary_accuracy: 0.6948
# Run:  5 / Accuracy at epoch  9  is:  0.6948000192642212
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1953 - binary_accuracy: 0.9450 - val_loss: 2.4487 - val_binary_accuracy: 0.6478
# Run:  5 / Accuracy at epoch  10  is:  0.6478000283241272
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1729 - binary_accuracy: 0.9552 - val_loss: 4.1199 - val_binary_accuracy: 0.5884
# Run:  5 / Accuracy at epoch  11  is:  0.5884000062942505
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1497 - binary_accuracy: 0.9648 - val_loss: 3.4445 - val_binary_accuracy: 0.6476
# Run:  5 / Accuracy at epoch  12  is:  0.647599995136261
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.1437 - binary_accuracy: 0.9674 - val_loss: 4.0556 - val_binary_accuracy: 0.6148
# Run:  5 / Accuracy at epoch  13  is:  0.614799976348877
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.1111 - binary_accuracy: 0.9734 - val_loss: 5.2808 - val_binary_accuracy: 0.5900
# Run:  5 / Accuracy at epoch  14  is:  0.5899999737739563
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1102 - binary_accuracy: 0.9752 - val_loss: 2.9799 - val_binary_accuracy: 0.6764
# Run:  5 / Accuracy at epoch  15  is:  0.6764000058174133
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1079 - binary_accuracy: 0.9754 - val_loss: 7.0400 - val_binary_accuracy: 0.5728
# Run:  5 / Accuracy at epoch  16  is:  0.5727999806404114
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1013 - binary_accuracy: 0.9788 - val_loss: 5.6673 - val_binary_accuracy: 0.6176
# Run:  5 / Accuracy at epoch  17  is:  0.6176000237464905
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1069 - binary_accuracy: 0.9850 - val_loss: 5.0094 - val_binary_accuracy: 0.6564
# Run:  5 / Accuracy at epoch  18  is:  0.6564000248908997
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.0959 - binary_accuracy: 0.9844 - val_loss: 9.1744 - val_binary_accuracy: 0.5664
# Run:  5 / Accuracy at epoch  19  is:  0.5663999915122986
#
# Accuracies over epochs: [0.7228000164031982, 0.7789999842643738, 0.800000011920929, 0.8281999826431274, 0.8352000117301941, 0.8349999785423279, 0.7928000092506409, 0.7545999884605408, 0.6877999901771545, 0.6948000192642212, 0.6478000283241272, 0.5884000062942505, 0.647599995136261, 0.614799976348877, 0.5899999737739563, 0.6764000058174133, 0.5727999806404114, 0.6176000237464905, 0.6564000248908997, 0.5663999915122986]
#
#
#
#
#  Over all runs maximum accuracies are: [0.8217999935150146, 0.8335999846458435, 0.8352000117301941, 0.8398000001907349, 0.8442000150680542]
# The median is: 0.8352000117301941
#
#
#
# ANN Accuracy Score on Test set ->  ['0.8352000117301941 +/- 0.013400018215179443']
#
#
# * * * * EVALUATION USING LOW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 2470
# Vocabulary size is: 94013
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.6736 - binary_accuracy: 0.5712 - val_loss: 0.5907 - val_binary_accuracy: 0.7064
# Run:  1 / Accuracy at epoch  0  is:  0.7063999772071838
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.5493 - binary_accuracy: 0.7542 - val_loss: 0.4625 - val_binary_accuracy: 0.7972
# Run:  1 / Accuracy at epoch  1  is:  0.7972000241279602
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.4915 - binary_accuracy: 0.8056 - val_loss: 0.4162 - val_binary_accuracy: 0.8258
# Run:  1 / Accuracy at epoch  2  is:  0.8258000016212463
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.4507 - binary_accuracy: 0.8356 - val_loss: 0.4133 - val_binary_accuracy: 0.8366
# Run:  1 / Accuracy at epoch  3  is:  0.8366000056266785
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.4276 - binary_accuracy: 0.8494 - val_loss: 0.4136 - val_binary_accuracy: 0.8412
# Run:  1 / Accuracy at epoch  4  is:  0.8411999940872192
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.4016 - binary_accuracy: 0.8654 - val_loss: 0.4204 - val_binary_accuracy: 0.8412
# Run:  1 / Accuracy at epoch  5  is:  0.8411999940872192
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.3748 - binary_accuracy: 0.8716 - val_loss: 0.4333 - val_binary_accuracy: 0.8398
# Run:  1 / Accuracy at epoch  6  is:  0.8398000001907349
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.3259 - binary_accuracy: 0.8898 - val_loss: 0.4494 - val_binary_accuracy: 0.8468
# Run:  1 / Accuracy at epoch  7  is:  0.8468000292778015
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.2864 - binary_accuracy: 0.9084 - val_loss: 0.5105 - val_binary_accuracy: 0.8394
# Run:  1 / Accuracy at epoch  8  is:  0.8393999934196472
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.2452 - binary_accuracy: 0.9274 - val_loss: 0.8533 - val_binary_accuracy: 0.7874
# Run:  1 / Accuracy at epoch  9  is:  0.7874000072479248
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1072 - binary_accuracy: 0.9744 - val_loss: 1.3039 - val_binary_accuracy: 0.7856
# Run:  5 / Accuracy at epoch  16  is:  0.7856000065803528
#
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.0983 - binary_accuracy: 0.9774 - val_loss: 1.3888 - val_binary_accuracy: 0.7918
# Run:  5 / Accuracy at epoch  17  is:  0.7918000221252441
#
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.1005 - binary_accuracy: 0.9764 - val_loss: 1.1998 - val_binary_accuracy: 0.8042
# Run:  5 / Accuracy at epoch  18  is:  0.8041999936103821
#
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.1035 - binary_accuracy: 0.9818 - val_loss: 1.8981 - val_binary_accuracy: 0.7560
# Run:  5 / Accuracy at epoch  19  is:  0.7559999823570251
#
# Accuracies over epochs: [0.7080000042915344, 0.7627999782562256, 0.8185999989509583, 0.8338000178337097, 0.8302000164985657, 0.8392000198364258, 0.8307999968528748, 0.8163999915122986, 0.8167999982833862, 0.8317999839782715, 0.7644000053405762, 0.8158000111579895, 0.7324000000953674, 0.7928000092506409, 0.8047999739646912, 0.7954000234603882, 0.7856000065803528, 0.7918000221252441, 0.8041999936103821, 0.7559999823570251]
#
#
#
#
#  Over all runs maximum accuracies are: [0.8303999900817871, 0.8392000198364258, 0.8416000008583069, 0.8425999879837036, 0.8468000292778015]
# The median is: 0.8416000008583069
#
#
#
# ANN Accuracy Score on Test set ->  ['0.8416000008583069 +/- 0.011200010776519775']
#
#
# * * * * EVALUATION USING RSW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 1540
# Vocabulary size is: 103029
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.6818 - binary_accuracy: 0.5522 - val_loss: 0.5582 - val_binary_accuracy: 0.7172
# Run:  1 / Accuracy at epoch  0  is:  0.717199981212616
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.5685 - binary_accuracy: 0.7414 - val_loss: 0.4547 - val_binary_accuracy: 0.8020
# Run:  1 / Accuracy at epoch  1  is:  0.8019999861717224
#
# 5000/5000 [==============================] - 77s 15ms/step - loss: 0.4907 - binary_accuracy: 0.8018 - val_loss: 0.4140 - val_binary_accuracy: 0.8246
# Run:  1 / Accuracy at epoch  2  is:  0.8245999813079834
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.4501 - binary_accuracy: 0.8332 - val_loss: 0.4195 - val_binary_accuracy: 0.8312
# Run:  1 / Accuracy at epoch  3  is:  0.8312000036239624
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.4221 - binary_accuracy: 0.8482 - val_loss: 0.5616 - val_binary_accuracy: 0.8004
# Run:  1 / Accuracy at epoch  4  is:  0.8004000186920166
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.3935 - binary_accuracy: 0.8618 - val_loss: 0.5146 - val_binary_accuracy: 0.8144
# Run:  1 / Accuracy at epoch  5  is:  0.8144000172615051
#
# 5000/5000 [==============================] - 77s 15ms/step - loss: 0.3519 - binary_accuracy: 0.8820 - val_loss: 0.4573 - val_binary_accuracy: 0.8324
# Run:  1 / Accuracy at epoch  6  is:  0.8324000239372253
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.2886 - binary_accuracy: 0.9100 - val_loss: 0.8666 - val_binary_accuracy: 0.7654
# Run:  1 / Accuracy at epoch  7  is:  0.7653999924659729
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.2415 - binary_accuracy: 0.9244 - val_loss: 1.4667 - val_binary_accuracy: 0.6936
# Run:  1 / Accuracy at epoch  8  is:  0.6935999989509583
#
# 5000/5000 [==============================] - 77s 15ms/step - loss: 0.1934 - binary_accuracy: 0.9424 - val_loss: 2.5759 - val_binary_accuracy: 0.6418
# Run:  1 / Accuracy at epoch  9  is:  0.6417999863624573
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.1826 - binary_accuracy: 0.9552 - val_loss: 1.1307 - val_binary_accuracy: 0.7694
# Run:  1 / Accuracy at epoch  10  is:  0.7694000005722046
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.0804 - binary_accuracy: 0.9862 - val_loss: 1.4148 - val_binary_accuracy: 0.8010
# Run:  4 / Accuracy at epoch  19  is:  0.8009999990463257
#
# Accuracies over epochs: [0.7275999784469604, 0.8068000078201294, 0.8241999745368958, 0.8227999806404114, 0.8327999711036682, 0.8425999879837036, 0.8416000008583069, 0.8442000150680542, 0.8149999976158142, 0.829800009727478, 0.8223999738693237, 0.7247999906539917, 0.8004000186920166, 0.7950000166893005, 0.7950000166893005, 0.7648000121116638, 0.7911999821662903, 0.8062000274658203, 0.7979999780654907, 0.8009999990463257]
#
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.6737 - binary_accuracy: 0.5836 - val_loss: 0.5461 - val_binary_accuracy: 0.7310
# Run:  5 / Accuracy at epoch  0  is:  0.7310000061988831
#
# 5000/5000 [==============================] - 77s 15ms/step - loss: 0.5602 - binary_accuracy: 0.7554 - val_loss: 0.4717 - val_binary_accuracy: 0.7910
# Run:  5 / Accuracy at epoch  1  is:  0.7910000085830688
#
# 5000/5000 [==============================] - 77s 15ms/step - loss: 0.4906 - binary_accuracy: 0.8044 - val_loss: 0.4169 - val_binary_accuracy: 0.8252
# ...
# Run:  2 / Accuracy at epoch  12  is:  0.79339998960495
#
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.1403 - binary_accuracy: 0.9652 - val_loss: 1.2330 - val_binary_accuracy: 0.7918
# Run:  2 / Accuracy at epoch  13  is:  0.7918000221252441
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1207 - binary_accuracy: 0.9718 - val_loss: 1.4654 - val_binary_accuracy: 0.7738
# Run:  2 / Accuracy at epoch  14  is:  0.7738000154495239
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1294 - binary_accuracy: 0.9742 - val_loss: 1.0824 - val_binary_accuracy: 0.7992
# Run:  2 / Accuracy at epoch  15  is:  0.7991999983787537
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1137 - binary_accuracy: 0.9772 - val_loss: 1.2769 - val_binary_accuracy: 0.7964
# Run:  2 / Accuracy at epoch  16  is:  0.7964000105857849
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1060 - binary_accuracy: 0.9794 - val_loss: 1.2527 - val_binary_accuracy: 0.7960
# Run:  2 / Accuracy at epoch  17  is:  0.7960000038146973
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.0984 - binary_accuracy: 0.9806 - val_loss: 1.4276 - val_binary_accuracy: 0.7808
# Run:  2 / Accuracy at epoch  18  is:  0.7807999849319458
#
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.0819 - binary_accuracy: 0.9830 - val_loss: 1.4808 - val_binary_accuracy: 0.7886
# Run:  2 / Accuracy at epoch  19  is:  0.7886000275611877
#
# Accuracies over epochs: [0.7260000109672546, 0.7955999970436096, 0.8163999915122986, 0.8277999758720398, 0.8299999833106995, 0.8366000056266785, 0.8349999785423279, 0.8361999988555908, 0.8343999981880188, 0.8113999962806702, 0.8040000200271606, 0.8109999895095825, 0.79339998960495, 0.7918000221252441, 0.7738000154495239, 0.7991999983787537, 0.7964000105857849, 0.7960000038146973, 0.7807999849319458, 0.7886000275611877]
#
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.6727 - binary_accuracy: 0.5844 - val_loss: 0.5443 - val_binary_accuracy: 0.7348
# Run:  3 / Accuracy at epoch  0  is:  0.7347999811172485
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.5568 - binary_accuracy: 0.7630 - val_loss: 0.4666 - val_binary_accuracy: 0.7954
# Run:  3 / Accuracy at epoch  1  is:  0.7954000234603882
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.4908 - binary_accuracy: 0.8100 - val_loss: 0.4144 - val_binary_accuracy: 0.8260
# Run:  3 / Accuracy at epoch  2  is:  0.8259999752044678
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.4573 - binary_accuracy: 0.8366 - val_loss: 0.4149 - val_binary_accuracy: 0.8362
# Run:  3 / Accuracy at epoch  3  is:  0.8361999988555908
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.0836 - binary_accuracy: 0.9834 - val_loss: 1.4016 - val_binary_accuracy: 0.7912
# Run:  4 / Accuracy at epoch  19  is:  0.7911999821662903
#
# Accuracies over epochs: [0.7143999934196472, 0.7919999957084656, 0.8248000144958496, 0.8309999704360962, 0.8371999859809875, 0.8424000144004822, 0.8414000272750854, 0.7990000247955322, 0.7318000197410583, 0.7116000056266785, 0.758400022983551, 0.7656000256538391, 0.7369999885559082, 0.70660001039505, 0.7305999994277954, 0.6916000247001648, 0.7411999702453613, 0.7462000250816345, 0.7748000025749207, 0.7911999821662903]
#
#
# 5000/5000 [==============================] - 81s 15ms/step - loss: 0.6653 - binary_accuracy: 0.5862 - val_loss: 0.5420 - val_binary_accuracy: 0.7404
# Run:  5 / Accuracy at epoch  0  is:  0.7404000163078308
#
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.5524 - binary_accuracy: 0.7676 - val_loss: 0.5049 - val_binary_accuracy: 0.7846
# Run:  5 / Accuracy at epoch  1  is:  0.784600019454956
#
# 5000/5000 [==============================] - 81s 16ms/step - loss: 0.4769 - binary_accuracy: 0.8122 - val_loss: 0.4153 - val_binary_accuracy: 0.8286
# Run:  5 / Accuracy at epoch  2  is:  0.8285999894142151
#
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.4410 - binary_accuracy: 0.8418 - val_loss: 0.4611 - val_binary_accuracy: 0.8304
# Run:  5 / Accuracy at epoch  3  is:  0.8303999900817871
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.4162 - binary_accuracy: 0.8498 - val_loss: 0.5155 - val_binary_accuracy: 0.8222
# Run:  5 / Accuracy at epoch  4  is:  0.8222000002861023
#
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.3926 - binary_accuracy: 0.8646 - val_loss: 0.5882 - val_binary_accuracy: 0.8076
# Run:  5 / Accuracy at epoch  5  is:  0.8076000213623047
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.3538 - binary_accuracy: 0.8826 - val_loss: 0.5120 - val_binary_accuracy: 0.8282
# Run:  5 / Accuracy at epoch  6  is:  0.8281999826431274
#
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.3035 - binary_accuracy: 0.9028 - val_loss: 1.0509 - val_binary_accuracy: 0.7348
# Run:  5 / Accuracy at epoch  7  is:  0.7347999811172485
#
# 5000/5000 [==============================] - 80s 15ms/step - loss: 0.2508 - binary_accuracy: 0.9216 - val_loss: 1.8508 - val_binary_accuracy: 0.6714
# Run:  5 / Accuracy at epoch  8  is:  0.6714000105857849
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.2140 - binary_accuracy: 0.9444 - val_loss: 1.2593 - val_binary_accuracy: 0.7480
# Run:  5 / Accuracy at epoch  9  is:  0.7480000257492065
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.2005 - binary_accuracy: 0.9464 - val_loss: 2.3219 - val_binary_accuracy: 0.6658
# Run:  5 / Accuracy at epoch  10  is:  0.6657999753952026
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1723 - binary_accuracy: 0.9582 - val_loss: 4.0201 - val_binary_accuracy: 0.6108
# Run:  5 / Accuracy at epoch  11  is:  0.61080002784729
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1644 - binary_accuracy: 0.9648 - val_loss: 3.4717 - val_binary_accuracy: 0.6412
# Run:  5 / Accuracy at epoch  12  is:  0.6412000060081482
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1398 - binary_accuracy: 0.9670 - val_loss: 3.9494 - val_binary_accuracy: 0.6316
# Run:  5 / Accuracy at epoch  13  is:  0.631600022315979
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1238 - binary_accuracy: 0.9762 - val_loss: 5.2507 - val_binary_accuracy: 0.6178
# Run:  5 / Accuracy at epoch  14  is:  0.6177999973297119
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1111 - binary_accuracy: 0.9794 - val_loss: 5.7025 - val_binary_accuracy: 0.6168
# Run:  5 / Accuracy at epoch  15  is:  0.6168000102043152
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1131 - binary_accuracy: 0.9812 - val_loss: 5.4659 - val_binary_accuracy: 0.6290
# Run:  5 / Accuracy at epoch  16  is:  0.6290000081062317
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1062 - binary_accuracy: 0.9848 - val_loss: 8.8254 - val_binary_accuracy: 0.5834
# Run:  5 / Accuracy at epoch  17  is:  0.5834000110626221
#
# 5000/5000 [==============================] - 79s 15ms/step - loss: 0.1148 - binary_accuracy: 0.9804 - val_loss: 6.5357 - val_binary_accuracy: 0.6260
# Run:  5 / Accuracy at epoch  18  is:  0.6259999871253967
#
# 5000/5000 [==============================] - 78s 15ms/step - loss: 0.1046 - binary_accuracy: 0.9872 - val_loss: 6.7438 - val_binary_accuracy: 0.6224
# Run:  5 / Accuracy at epoch  19  is:  0.6223999857902527
#
# Accuracies over epochs: [0.7404000163078308, 0.784600019454956, 0.8285999894142151, 0.8303999900817871, 0.8222000002861023, 0.8076000213623047, 0.8281999826431274, 0.7347999811172485, 0.6714000105857849, 0.7480000257492065, 0.6657999753952026, 0.61080002784729, 0.6412000060081482, 0.631600022315979, 0.6177999973297119, 0.6168000102043152, 0.6290000081062317, 0.5834000110626221, 0.6259999871253967, 0.6223999857902527]
#
#
#
#
#  Over all runs maximum accuracies are: [0.8303999900817871, 0.8366000056266785, 0.8379999995231628, 0.8424000144004822, 0.8425999879837036]
# The median is: 0.8379999995231628
#
#
#
# ANN Accuracy Score on Test set ->  ['0.8379999995231628 +/- 0.007600009441375732']

# %% [markdown]
# ## Now show compact results in a table.

# %%
print(" PREPRO FUNCTION    |  Test Accuracy   |",end = '')

print("\n")
for prepro_func in prepro_functions_dict_comb:
  #print(prepro_func,"\t\t\t",format(round(model_results[prepro_func][0],4),'.4f'),"\t\t",end='')
  result = model_results[prepro_func][0]
  # result = format(round(model_results[prepro_func][0],4),'.4f')
  print(f'{prepro_func:27}{ result :12}')
  print("\n")
# Out:
#  PREPRO FUNCTION    |  Test Accuracy   |
#
# DON                        0.8352000117301941 +/- 0.013400018215179443
#
#
# LOW                        0.8416000008583069 +/- 0.011200010776519775
#
#
# RSW                        0.8396000266075134 +/- 0.007200002670288086
#
#
# STM                        0.8343999981880188 +/- 0.0098000168800354
#
#
# LOW_RSW                    0.840399980545044 +/- 0.006200015544891357
#
#
# LOW_STM                    0.8447999954223633 +/- 0.0031999945640563965
#
#
# RSW_LOW                    0.8438000082969666 +/- 0.008599996566772461
#
#
# RSW_STM                    0.8393999934196472 +/- 0.00279998779296875
#
#
# STM_LOW                    0.8393999934196472 +/- 0.004999995231628418
#
#
# STM_RSW                    0.8432000279426575 +/- 0.010400056838989258
#
#
# LOW_STM_RSW                0.8371999859809875 +/- 0.007200002670288086
#
#
# LOW_RSW_STM                0.8425999879837036 +/- 0.005800008773803711
#
#
# STM_LOW_RSW                0.840399980545044 +/- 0.0073999762535095215
#
#
# STM_RSW_LOW                0.8435999751091003 +/- 0.0057999491691589355
#
#
# RSW_LOW_STM                0.8381999731063843 +/- 0.007200002670288086
#
#
# RSW_STM_LOW                0.8379999995231628 +/- 0.007600009441375732
