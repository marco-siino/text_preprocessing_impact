# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/text_preprocessing_impact/blob/main/IMDB_DS/BiLSTM_IMDB_TextPreProImpact_NB_PART_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances.
# - - -
# BiLSTM ON IMDB DS EXPERIMENTS NOTEBOOK
# - - -
# Bidirectional Long Short-Term Memory Network on Internet Movie Database Dataset.
# Code by M. Siino.
#
# From the paper: "Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances." by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf
import nltk
import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from sklearn.linear_model import LogisticRegression
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer
from textblob import TextBlob
nltk.download('stopwords')
nltk.download('punkt')

os.environ['TF_CUDNN_DETERMINISTIC']='false'
os.environ['TF_DETERMINISTIC_OPS']='false'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

dataset = tf.keras.utils.get_file("aclImdb_v1", url,
                                    untar=True, cache_dir='.',
                                    cache_subdir='')

dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')

train_set_dir = os.path.join(dataset_dir, 'train')
test_set_dir = os.path.join(dataset_dir, 'test')

remove_dir = os.path.join(train_set_dir, 'unsup')
shutil.rmtree(remove_dir)

# %% [markdown]
# ## Generate training and test set.

# %%
# Generate full randomized training set.
batch_size = 1
seed = 1

train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train', 
    batch_size=batch_size,
    shuffle=False,
    seed=seed
    )

test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/test', 
    batch_size=batch_size,
    shuffle=False,
    seed=seed
    )

train_ds = train_ds.shuffle(25000,seed=1,reshuffle_each_iteration = False)
test_ds = test_ds.shuffle(25000,seed=1,reshuffle_each_iteration = False)

train_ds = train_ds.take(5000)
test_ds = test_ds.take(5000)

train_ds_size=len(train_ds)
test_ds_size=len(test_ds)
# Out:
# Found 25000 files belonging to 2 classes.
# Found 25000 files belonging to 2 classes.

# %% [markdown]
# ## Functions to pre-process source text. (A detailed discussion on our paper)

# %%
# Do-Nothing preprocessing function.
def DON(input_data):
  tag_open_CDATA_removed = tf.strings.regex_replace(input_data, '<\!\[CDATA\[', ' ')
  tag_closed_CDATA_removed = tf.strings.regex_replace(tag_open_CDATA_removed,'\]{1,}>', ' ')
  tag_author_lang_en_removed = tf.strings.regex_replace(tag_closed_CDATA_removed,'<author lang="en">', ' ')
  tag_closed_author_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'</author>', ' ')
  tag_open_documents_removed = tf.strings.regex_replace(tag_closed_author_removed,'<documents>\n(\t){0,2}', '')
  output_data = tf.strings.regex_replace(tag_open_documents_removed,'</documents>\n(\t){0,2}', ' ')
  return output_data

# Lowercasing preprocessing function.
def LOW(input_data):  
  return tf.strings.lower(DON(input_data))

# Removing Stop Words function.
def RSW(input_data):
  output_data = DON(input_data)

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:

      # input_string = input_string.numpy() [0]
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("Tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# Porter Stemmer preprocessing function.
def STM(input_data):
  output_data = DON(input_data)
  stemmer = PorterStemmer()

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      #print(input_string)
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:
      #input_string = input_string.numpy()[0]
      input_string = input_string.numpy()
      #print(input_string)
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# %% [markdown]
# ## Define the combined preprocessing functions. (The base functions are: DON, LOW, RSW and STM).

# %%
## SECTION WITH PAIRS OF PREPRO FUNCTIONS. APPLICATION ORDER MATTERS (...IN FOLLOWING SECTIONS TOO).
#...5
def LOW_RSW(input_data):
  return RSW(LOW(input_data))

# 6
def LOW_STM(input_data):
  return STM(LOW(input_data))

# 7
def RSW_LOW(input_data):
  return LOW(RSW(input_data))

# 8
def RSW_STM(input_data):
  return STM(RSW(input_data))

# 9
def STM_LOW(input_data):
  return LOW(STM(input_data))

# 10
def STM_RSW(input_data):
  return RSW(STM(input_data))
  
# 11
def LOW_STM_RSW(input_data):
  return RSW(STM(LOW(input_data)))

# 12
def LOW_RSW_STM(input_data):
  return STM(RSW(LOW(input_data)))

# 13
def STM_LOW_RSW(input_data):
  return RSW(LOW(STM(input_data)))

# 14
def STM_RSW_LOW(input_data):
  return LOW(RSW(STM(input_data)))

# 15
def RSW_LOW_STM(input_data):
  return STM(LOW(RSW(input_data)))

# 16
def RSW_STM_LOW(input_data):
  return LOW(STM(RSW(input_data)))

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(preprocessing_function,training_set):
  # Set a large sequence length to find the longest sample in the training set.
  sequence_length = 3000
  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    out=model(authorDocument)
    # Convert token list to numpy array.
    token_list = out.numpy()[0]
    token_list = np.trim_zeros(token_list,'b')
    if longest_sample_length < len(token_list):
      longest_sample_length = len(token_list)

  print("Length of the longest sample is:", longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Define a dictionary with -> function_names:prepro_function_caller. And a dictionary to store model results.

# %%
model_results = {}
prepro_functions_dict_base = {
    'DON':DON,
    'LOW':LOW,
    'RSW':RSW,
    'STM':STM
    }

# 3 prepro functions = 15 combs...+1 for do_nothing

prepro_functions_dict_comb = {
    # 1. Do nothing 
    'DON': DON,
    # 2. Lowercasing 
    'LOW':LOW,
    # 3. Removing Stopwords
    'RSW':RSW, 
    # 4. Porter Stemming
    'STM':STM,
    # 5. LOW->RSW
    'LOW_RSW':LOW_RSW, 
    # 6. LOW->STM
    'LOW_STM':LOW_STM,
    # 7. RSW->LOW
    'RSW_LOW':RSW_LOW,
    # 8. RSW->STM
    'RSW_STM':RSW_STM,
    # 9. STM->LOW
    'STM_LOW':STM_LOW,
    # 10. STM->RSW
    'STM_RSW':STM_RSW,
    # 11. LOW->STM->RSW
    'LOW_STM_RSW':LOW_STM_RSW,  
    # 12. LOW->RSW->STM
    'LOW_RSW_STM':LOW_RSW_STM,
    # 13. STM->LOW->RSW
    'STM_LOW_RSW':STM_LOW_RSW,
    # 14. STM->RSW->LOW
    'STM_RSW_LOW':STM_RSW_LOW,
    # 15. RSW->LOW->STM
    'RSW_LOW_STM':RSW_LOW_STM,
    # 16. RSW->STM->LOW
    'RSW_STM_LOW':RSW_STM_LOW
}

for key in prepro_functions_dict_comb:
  print(key)
  model_results[key]=[]
# Out:
# DON
# LOW
# RSW
# STM
# LOW_RSW
# LOW_STM
# RSW_LOW
# RSW_STM
# STM_LOW
# STM_RSW
# LOW_STM_RSW
# LOW_RSW_STM
# STM_LOW_RSW
# STM_RSW_LOW
# RSW_LOW_STM
# RSW_STM_LOW

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Models definition and evaluation.

# %%
tf.random.set_seed(0)
TF_DISABLE_SEGMENT_REDUCTION_OP_DETERMINISM_EXCEPTIONS=True

# Reset model_results list.
for key in prepro_functions_dict_comb:
  model_results[key]=[]

for key in prepro_functions_dict_comb:
  runs_accuracy = []

  print("\n\n* * * * EVALUATION USING", key, "AS PREPROCESSING FUNCTION * * * *")

  # Preprocess training set to build a dictionary.
  vectorize_layer = preprocess_and_adapt_ts(prepro_functions_dict_comb[key],train_ds)

  max_features=len(vectorize_layer.get_vocabulary()) + 1
  print("Vocabulary size is:", max_features)

  for run in range(1,(num_runs+1)):
    epochs_accuracy=[]
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,  return_sequences=True)),
                                    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
                                    tf.keras.layers.Dense(64, activation='relu'),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer=opt, metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        print("Run: ",run,"/ Accuracy at epoch ",epoch," is: ", accuracy[0],"\n")
        epochs_accuracy.append(accuracy[0])

    print("Accuracies over epochs:",epochs_accuracy,"\n\n")
    runs_accuracy.append(max(epochs_accuracy))

  runs_accuracy.sort()
  print("\n\n Over all runs maximum accuracies are:", runs_accuracy)
  print("The median is:",runs_accuracy[2],"\n\n\n")
  
  if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
    max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
  else:
    max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
  final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
  model_results[key].append(final_result)
  print("BiLSTM Accuracy Score on Test set -> ",model_results[key])
# Out:
# * * * * EVALUATION USING DON AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 2470
# Vocabulary size is: 103029
# 5000/5000 [==============================] - 1385s 274ms/step - loss: 0.7013 - binary_accuracy: 0.4910 - val_loss: 0.6929 - val_binary_accuracy: 0.5014
# Run:  1 / Accuracy at epoch  0  is:  0.5013999938964844
#
# 5000/5000 [==============================] - 1365s 272ms/step - loss: 0.6864 - binary_accuracy: 0.5924 - val_loss: 0.6362 - val_binary_accuracy: 0.6670
# Run:  1 / Accuracy at epoch  1  is:  0.6669999957084656
#
# 5000/5000 [==============================] - 1365s 272ms/step - loss: 0.6048 - binary_accuracy: 0.7448 - val_loss: 0.5626 - val_binary_accuracy: 0.7842
# Run:  1 / Accuracy at epoch  2  is:  0.7842000126838684
#
# 5000/5000 [==============================] - 1360s 271ms/step - loss: 0.5753 - binary_accuracy: 0.7624 - val_loss: 0.5074 - val_binary_accuracy: 0.7946
# Run:  1 / Accuracy at epoch  3  is:  0.7946000099182129
#
# 5000/5000 [==============================] - 1352s 270ms/step - loss: 0.5334 - binary_accuracy: 0.8044 - val_loss: 0.9169 - val_binary_accuracy: 0.8118
# Run:  1 / Accuracy at epoch  4  is:  0.8118000030517578
#
# 5000/5000 [==============================] - 1343s 268ms/step - loss: 0.4410 - binary_accuracy: 0.8616 - val_loss: 0.9468 - val_binary_accuracy: 0.8088
# Run:  1 / Accuracy at epoch  5  is:  0.8087999820709229
#
# 5000/5000 [==============================] - 1344s 268ms/step - loss: 0.3914 - binary_accuracy: 0.8970 - val_loss: 0.6201 - val_binary_accuracy: 0.8378
# Run:  1 / Accuracy at epoch  6  is:  0.8378000259399414
#
# 5000/5000 [==============================] - 1354s 270ms/step - loss: 0.3299 - binary_accuracy: 0.9252 - val_loss: 0.6850 - val_binary_accuracy: 0.8422
# Run:  1 / Accuracy at epoch  7  is:  0.842199981212616
#
# 5000/5000 [==============================] - 1351s 269ms/step - loss: 0.3106 - binary_accuracy: 0.9392 - val_loss: 1.0289 - val_binary_accuracy: 0.8374
# Run:  1 / Accuracy at epoch  8  is:  0.8374000191688538
#
# 5000/5000 [==============================] - 1352s 270ms/step - loss: 0.3119 - binary_accuracy: 0.9492 - val_loss: 0.7545 - val_binary_accuracy: 0.8344
# Run:  1 / Accuracy at epoch  9  is:  0.8343999981880188
#
# 5000/5000 [==============================] - 1353s 270ms/step - loss: 0.2451 - binary_accuracy: 0.9592 - val_loss: 1.1872 - val_binary_accuracy: 0.8312
# Run:  1 / Accuracy at epoch  10  is:  0.8312000036239624
#
# 5000/5000 [==============================] - 1349s 269ms/step - loss: 0.2171 - binary_accuracy: 0.9694 - val_loss: 1.5437 - val_binary_accuracy: 0.8398
# Run:  1 / Accuracy at epoch  11  is:  0.8398000001907349
#
# 5000/5000 [==============================] - 1357s 271ms/step - loss: 0.2071 - binary_accuracy: 0.9768 - val_loss: 1.5246 - val_binary_accuracy: 0.8404
# Run:  1 / Accuracy at epoch  12  is:  0.840399980545044
#
# 5000/5000 [==============================] - 1346s 268ms/step - loss: 0.2324 - binary_accuracy: 0.9748 - val_loss: 1.1992 - val_binary_accuracy: 0.8370
# Run:  1 / Accuracy at epoch  13  is:  0.8370000123977661
#
# 5000/5000 [==============================] - 1351s 269ms/step - loss: 0.2051 - binary_accuracy: 0.9816 - val_loss: 1.6257 - val_binary_accuracy: 0.8282
# Run:  1 / Accuracy at epoch  14  is:  0.8281999826431274
#
# 5000/5000 [==============================] - 1351s 269ms/step - loss: 0.2044 - binary_accuracy: 0.9848 - val_loss: 2.7226 - val_binary_accuracy: 0.8186
# Run:  1 / Accuracy at epoch  15  is:  0.8185999989509583
#
# 5000/5000 [==============================] - 1349s 269ms/step - loss: 0.1445 - binary_accuracy: 0.9882 - val_loss: 1.9946 - val_binary_accuracy: 0.8314
# Run:  1 / Accuracy at epoch  16  is:  0.8313999772071838
#
# 5000/5000 [==============================] - 1340s 267ms/step - loss: 0.1170 - binary_accuracy: 0.9908 - val_loss: 3.7822 - val_binary_accuracy: 0.8210
# Run:  1 / Accuracy at epoch  17  is:  0.8209999799728394
#
# 5000/5000 [==============================] - 1342s 267ms/step - loss: 0.1504 - binary_accuracy: 0.9906 - val_loss: 3.1213 - val_binary_accuracy: 0.8292
# Run:  1 / Accuracy at epoch  18  is:  0.829200029373169
#
# 5000/5000 [==============================] - 1352s 269ms/step - loss: 0.1381 - binary_accuracy: 0.9908 - val_loss: 4.7611 - val_binary_accuracy: 0.7850
# Run:  1 / Accuracy at epoch  19  is:  0.7850000262260437
#
# Accuracies over epochs: [0.5013999938964844, 0.6669999957084656, 0.7842000126838684, 0.7946000099182129, 0.8118000030517578, 0.8087999820709229, 0.8378000259399414, 0.842199981212616, 0.8374000191688538, 0.8343999981880188, 0.8312000036239624, 0.8398000001907349, 0.840399980545044, 0.8370000123977661, 0.8281999826431274, 0.8185999989509583, 0.8313999772071838, 0.8209999799728394, 0.829200029373169, 0.7850000262260437]
#
#
# 5000/5000 [==============================] - 1344s 267ms/step - loss: 0.7020 - binary_accuracy: 0.5136 - val_loss: 0.6352 - val_binary_accuracy: 0.6438
# Run:  2 / Accuracy at epoch  0  is:  0.6438000202178955
#
# 5000/5000 [==============================] - 1337s 266ms/step - loss: 0.6511 - binary_accuracy: 0.6786 - val_loss: 0.5923 - val_binary_accuracy: 0.7060
# Run:  2 / Accuracy at epoch  1  is:  0.7059999704360962
#
# 5000/5000 [==============================] - 1351s 269ms/step - loss: 0.5885 - binary_accuracy: 0.7556 - val_loss: 0.5205 - val_binary_accuracy: 0.7698
# Run:  2 / Accuracy at epoch  2  is:  0.7698000073432922
#
# 5000/5000 [==============================] - 1346s 268ms/step - loss: 0.5509 - binary_accuracy: 0.7866 - val_loss: 0.6731 - val_binary_accuracy: 0.7796
# Run:  2 / Accuracy at epoch  3  is:  0.7796000242233276
#
# 5000/5000 [==============================] - 1347s 269ms/step - loss: 0.5131 - binary_accuracy: 0.8298 - val_loss: 0.6737 - val_binary_accuracy: 0.8260
# Run:  2 / Accuracy at epoch  4  is:  0.8259999752044678
#
# 5000/5000 [==============================] - 1354s 270ms/step - loss: 0.4110 - binary_accuracy: 0.8780 - val_loss: 0.6651 - val_binary_accuracy: 0.8374
# Run:  2 / Accuracy at epoch  5  is:  0.8374000191688538
#
# 5000/5000 [==============================] - 1361s 271ms/step - loss: 0.3360 - binary_accuracy: 0.9176 - val_loss: 0.6594 - val_binary_accuracy: 0.8158
# Run:  2 / Accuracy at epoch  6  is:  0.8158000111579895
#
# 5000/5000 [==============================] - 1358s 271ms/step - loss: 0.3150 - binary_accuracy: 0.9302 - val_loss: 0.6157 - val_binary_accuracy: 0.8484
# Run:  2 / Accuracy at epoch  7  is:  0.8483999967575073
#
# 5000/5000 [==============================] - 1342s 268ms/step - loss: 0.3124 - binary_accuracy: 0.9436 - val_loss: 0.7939 - val_binary_accuracy: 0.8470
# Run:  2 / Accuracy at epoch  8  is:  0.847000002861023
#
# 5000/5000 [==============================] - 1339s 267ms/step - loss: 0.2863 - binary_accuracy: 0.9588 - val_loss: 1.4545 - val_binary_accuracy: 0.7740
# Run:  2 / Accuracy at epoch  9  is:  0.7739999890327454
#
# 5000/5000 [==============================] - 1347s 268ms/step - loss: 0.2447 - binary_accuracy: 0.9658 - val_loss: 0.9540 - val_binary_accuracy: 0.8408
# Run:  2 / Accuracy at epoch  10  is:  0.8407999873161316
#
# 5000/5000 [==============================] - 1333s 266ms/step - loss: 0.2205 - binary_accuracy: 0.9742 - val_loss: 1.4579 - val_binary_accuracy: 0.7952
# Run:  2 / Accuracy at epoch  11  is:  0.795199990272522
#
# 5000/5000 [==============================] - 1336s 266ms/step - loss: 0.2026 - binary_accuracy: 0.9742 - val_loss: 1.8348 - val_binary_accuracy: 0.8168
# Run:  2 / Accuracy at epoch  12  is:  0.8167999982833862
#
# 5000/5000 [==============================] - 1339s 267ms/step - loss: 0.1762 - binary_accuracy: 0.9824 - val_loss: 2.0592 - val_binary_accuracy: 0.8074
# Run:  2 / Accuracy at epoch  13  is:  0.8073999881744385
#
# 5000/5000 [==============================] - 1341s 267ms/step - loss: 0.1756 - binary_accuracy: 0.9848 - val_loss: 2.3461 - val_binary_accuracy: 0.8288
# Run:  2 / Accuracy at epoch  14  is:  0.8288000226020813
#
# 5000/5000 [==============================] - 1337s 266ms/step - loss: 0.1424 - binary_accuracy: 0.9872 - val_loss: 3.1859 - val_binary_accuracy: 0.8270
# Run:  2 / Accuracy at epoch  15  is:  0.8270000219345093
#
# 5000/5000 [==============================] - 1336s 266ms/step - loss: 0.1262 - binary_accuracy: 0.9898 - val_loss: 4.1093 - val_binary_accuracy: 0.8024
# Run:  2 / Accuracy at epoch  16  is:  0.8023999929428101
#
# 5000/5000 [==============================] - 1337s 267ms/step - loss: 0.1266 - binary_accuracy: 0.9908 - val_loss: 3.3043 - val_binary_accuracy: 0.8252
# Run:  2 / Accuracy at epoch  17  is:  0.8252000212669373
#
# 5000/5000 [==============================] - 1336s 266ms/step - loss: 0.1059 - binary_accuracy: 0.9920 - val_loss: 4.3849 - val_binary_accuracy: 0.8006
# Run:  2 / Accuracy at epoch  18  is:  0.800599992275238
#
# 5000/5000 [==============================] - 1333s 266ms/step - loss: 0.0943 - binary_accuracy: 0.9938 - val_loss: 6.2123 - val_binary_accuracy: 0.8114
# Run:  2 / Accuracy at epoch  19  is:  0.8113999962806702
#
# Accuracies over epochs: [0.6438000202178955, 0.7059999704360962, 0.7698000073432922, 0.7796000242233276, 0.8259999752044678, 0.8374000191688538, 0.8158000111579895, 0.8483999967575073, 0.847000002861023, 0.7739999890327454, 0.8407999873161316, 0.795199990272522, 0.8167999982833862, 0.8073999881744385, 0.8288000226020813, 0.8270000219345093, 0.8023999929428101, 0.8252000212669373, 0.800599992275238, 0.8113999962806702]
#
#
# 5000/5000 [==============================] - 1322s 263ms/step - loss: 0.7012 - binary_accuracy: 0.5032 - val_loss: 0.6805 - val_binary_accuracy: 0.5708
# Run:  3 / Accuracy at epoch  0  is:  0.5708000063896179
#
# 5000/5000 [==============================] - 1333s 266ms/step - loss: 0.6956 - binary_accuracy: 0.5718 - val_loss: 0.6453 - val_binary_accuracy: 0.6694
# Run:  3 / Accuracy at epoch  1  is:  0.6693999767303467
#
# 5000/5000 [==============================] - 1338s 267ms/step - loss: 0.6412 - binary_accuracy: 0.6852 - val_loss: 0.5666 - val_binary_accuracy: 0.6838
# Run:  3 / Accuracy at epoch  2  is:  0.6837999820709229
#
# 5000/5000 [==============================] - 1337s 267ms/step - loss: 0.5864 - binary_accuracy: 0.7540 - val_loss: 0.7610 - val_binary_accuracy: 0.6642
# Run:  3 / Accuracy at epoch  3  is:  0.6642000079154968
#
# 5000/5000 [==============================] - 1336s 266ms/step - loss: 0.5209 - binary_accuracy: 0.8022 - val_loss: 0.7836 - val_binary_accuracy: 0.8180
# Run:  3 / Accuracy at epoch  4  is:  0.8180000185966492
#
# 5000/5000 [==============================] - 1341s 267ms/step - loss: 0.4364 - binary_accuracy: 0.8596 - val_loss: 0.5051 - val_binary_accuracy: 0.8330
# Run:  3 / Accuracy at epoch  5  is:  0.8330000042915344
#
# 5000/5000 [==============================] - 1339s 267ms/step - loss: 0.3694 - binary_accuracy: 0.8942 - val_loss: 0.5373 - val_binary_accuracy: 0.8380
# Run:  3 / Accuracy at epoch  6  is:  0.8379999995231628
#
# 5000/5000 [==============================] - 1336s 266ms/step - loss: 0.3385 - binary_accuracy: 0.9222 - val_loss: 0.5494 - val_binary_accuracy: 0.8376
# Run:  3 / Accuracy at epoch  7  is:  0.8375999927520752
#
# 5000/5000 [==============================] - 1344s 268ms/step - loss: 0.3409 - binary_accuracy: 0.9334 - val_loss: 0.7927 - val_binary_accuracy: 0.8474
# Run:  3 / Accuracy at epoch  8  is:  0.8474000096321106
#
# 5000/5000 [==============================] - 1342s 268ms/step - loss: 0.3013 - binary_accuracy: 0.9466 - val_loss: 0.7170 - val_binary_accuracy: 0.8464
# Run:  3 / Accuracy at epoch  9  is:  0.8464000225067139
#
# 5000/5000 [==============================] - 1331s 265ms/step - loss: 0.2870 - binary_accuracy: 0.9574 - val_loss: 1.0185 - val_binary_accuracy: 0.8282
# Run:  3 / Accuracy at epoch  10  is:  0.8281999826431274
#
# 5000/5000 [==============================] - 1333s 266ms/step - loss: 0.2181 - binary_accuracy: 0.9690 - val_loss: 1.3717 - val_binary_accuracy: 0.7862
# Run:  3 / Accuracy at epoch  11  is:  0.7861999869346619
#
# 5000/5000 [==============================] - 1339s 267ms/step - loss: 0.2048 - binary_accuracy: 0.9782 - val_loss: 1.8586 - val_binary_accuracy: 0.8296
# Run:  3 / Accuracy at epoch  12  is:  0.8295999765396118
#
# 5000/5000 [==============================] - 1326s 264ms/step - loss: 0.1907 - binary_accuracy: 0.9782 - val_loss: 1.7171 - val_binary_accuracy: 0.8262
# Run:  3 / Accuracy at epoch  13  is:  0.826200008392334
#
# 5000/5000 [==============================] - 1326s 264ms/step - loss: 0.2147 - binary_accuracy: 0.9832 - val_loss: 3.1694 - val_binary_accuracy: 0.7224
# Run:  3 / Accuracy at epoch  14  is:  0.7224000096321106
#
# 5000/5000 [==============================] - 1329s 265ms/step - loss: 0.1810 - binary_accuracy: 0.9854 - val_loss: 2.7668 - val_binary_accuracy: 0.7482
# Run:  3 / Accuracy at epoch  15  is:  0.748199999332428
#
# 5000/5000 [==============================] - 1339s 267ms/step - loss: 0.1713 - binary_accuracy: 0.9844 - val_loss: 2.9420 - val_binary_accuracy: 0.7158
# Run:  3 / Accuracy at epoch  16  is:  0.7157999873161316
#
# 5000/5000 [==============================] - 1351s 269ms/step - loss: 0.1724 - binary_accuracy: 0.9864 - val_loss: 3.1138 - val_binary_accuracy: 0.7414
# Run:  3 / Accuracy at epoch  17  is:  0.7414000034332275
#
# 5000/5000 [==============================] - 1348s 269ms/step - loss: 0.1563 - binary_accuracy: 0.9886 - val_loss: 5.4409 - val_binary_accuracy: 0.7018
# Run:  3 / Accuracy at epoch  18  is:  0.7017999887466431
#
# 5000/5000 [==============================] - 1351s 269ms/step - loss: 0.1547 - binary_accuracy: 0.9896 - val_loss: 5.9246 - val_binary_accuracy: 0.7004
# Run:  3 / Accuracy at epoch  19  is:  0.7003999948501587
#
# Accuracies over epochs: [0.5708000063896179, 0.6693999767303467, 0.6837999820709229, 0.6642000079154968, 0.8180000185966492, 0.8330000042915344, 0.8379999995231628, 0.8375999927520752, 0.8474000096321106, 0.8464000225067139, 0.8281999826431274, 0.7861999869346619, 0.8295999765396118, 0.826200008392334, 0.7224000096321106, 0.748199999332428, 0.7157999873161316, 0.7414000034332275, 0.7017999887466431, 0.7003999948501587]
#
#
# 5000/5000 [==============================] - 1340s 266ms/step - loss: 0.7003 - binary_accuracy: 0.5064 - val_loss: 0.6817 - val_binary_accuracy: 0.5564
# Run:  4 / Accuracy at epoch  0  is:  0.5564000010490417
#
# 5000/5000 [==============================] - 1345s 268ms/step - loss: 0.6807 - binary_accuracy: 0.6188 - val_loss: 0.6367 - val_binary_accuracy: 0.6450
# Run:  4 / Accuracy at epoch  1  is:  0.6449999809265137
#
# 5000/5000 [==============================] - 1335s 266ms/step - loss: 0.6195 - binary_accuracy: 0.7248 - val_loss: 0.6235 - val_binary_accuracy: 0.7770
# Run:  4 / Accuracy at epoch  2  is:  0.7770000100135803
#
# 5000/5000 [==============================] - 1341s 267ms/step - loss: 0.5654 - binary_accuracy: 0.7738 - val_loss: 0.5297 - val_binary_accuracy: 0.7960
# Run:  4 / Accuracy at epoch  3  is:  0.7960000038146973
#
# 5000/5000 [==============================] - 1335s 266ms/step - loss: 0.5156 - binary_accuracy: 0.8000 - val_loss: 0.6957 - val_binary_accuracy: 0.8084
# Run:  4 / Accuracy at epoch  4  is:  0.8083999752998352
#
# 5000/5000 [==============================] - 1342s 268ms/step - loss: 0.4464 - binary_accuracy: 0.8584 - val_loss: 0.7584 - val_binary_accuracy: 0.8168
# Run:  4 / Accuracy at epoch  5  is:  0.8167999982833862
#
# 5000/5000 [==============================] - 1344s 268ms/step - loss: 0.4033 - binary_accuracy: 0.8902 - val_loss: 0.6781 - val_binary_accuracy: 0.8432
# Run:  4 / Accuracy at epoch  6  is:  0.8432000279426575
#
# 5000/5000 [==============================] - 1343s 268ms/step - loss: 0.3508 - binary_accuracy: 0.9118 - val_loss: 0.7251 - val_binary_accuracy: 0.8448
# Run:  4 / Accuracy at epoch  7  is:  0.8447999954223633
#
# 5000/5000 [==============================] - 1341s 267ms/step - loss: 0.3364 - binary_accuracy: 0.9350 - val_loss: 0.7526 - val_binary_accuracy: 0.8440
# Run:  4 / Accuracy at epoch  8  is:  0.843999981880188
#
# 5000/5000 [==============================] - 1342s 268ms/step - loss: 0.2816 - binary_accuracy: 0.9492 - val_loss: 0.8369 - val_binary_accuracy: 0.8462
# Run:  4 / Accuracy at epoch  9  is:  0.8461999893188477
#
# 5000/5000 [==============================] - 1343s 268ms/step - loss: 0.2521 - binary_accuracy: 0.9576 - val_loss: 0.8673 - val_binary_accuracy: 0.8198
# Run:  4 / Accuracy at epoch  10  is:  0.8198000192642212
#
# 5000/5000 [==============================] - 1339s 267ms/step - loss: 0.2424 - binary_accuracy: 0.9630 - val_loss: 0.8781 - val_binary_accuracy: 0.8106
# Run:  4 / Accuracy at epoch  11  is:  0.8105999827384949
#
# 5000/5000 [==============================] - 1342s 268ms/step - loss: 0.2386 - binary_accuracy: 0.9674 - val_loss: 1.1028 - val_binary_accuracy: 0.8308
# Run:  4 / Accuracy at epoch  12  is:  0.8307999968528748
#
# 5000/5000 [==============================] - 1340s 267ms/step - loss: 0.2021 - binary_accuracy: 0.9718 - val_loss: 1.8914 - val_binary_accuracy: 0.7890
# Run:  4 / Accuracy at epoch  13  is:  0.7889999747276306
#
# 5000/5000 [==============================] - 1345s 268ms/step - loss: 0.1987 - binary_accuracy: 0.9752 - val_loss: 2.4324 - val_binary_accuracy: 0.7764
# Run:  4 / Accuracy at epoch  14  is:  0.7764000296592712
#
# 5000/5000 [==============================] - 1351s 269ms/step - loss: 0.1881 - binary_accuracy: 0.9792 - val_loss: 2.9510 - val_binary_accuracy: 0.7958
# Run:  4 / Accuracy at epoch  15  is:  0.795799970626831
#
# 5000/5000 [==============================] - 1351s 269ms/step - loss: 0.1606 - binary_accuracy: 0.9856 - val_loss: 2.0547 - val_binary_accuracy: 0.8278
# Run:  4 / Accuracy at epoch  16  is:  0.8277999758720398
#
# 5000/5000 [==============================] - 1347s 269ms/step - loss: 0.1877 - binary_accuracy: 0.9868 - val_loss: 2.4175 - val_binary_accuracy: 0.8156
# Run:  4 / Accuracy at epoch  17  is:  0.8155999779701233
#
# 5000/5000 [==============================] - 1351s 269ms/step - loss: 0.1373 - binary_accuracy: 0.9876 - val_loss: 2.5134 - val_binary_accuracy: 0.8252
# Run:  4 / Accuracy at epoch  18  is:  0.8252000212669373
#
# 5000/5000 [==============================] - 1354s 270ms/step - loss: 0.1146 - binary_accuracy: 0.9896 - val_loss: 3.9490 - val_binary_accuracy: 0.7832
# Run:  4 / Accuracy at epoch  19  is:  0.7832000255584717
#
# Accuracies over epochs: [0.5564000010490417, 0.6449999809265137, 0.7770000100135803, 0.7960000038146973, 0.8083999752998352, 0.8167999982833862, 0.8432000279426575, 0.8447999954223633, 0.843999981880188, 0.8461999893188477, 0.8198000192642212, 0.8105999827384949, 0.8307999968528748, 0.7889999747276306, 0.7764000296592712, 0.795799970626831, 0.8277999758720398, 0.8155999779701233, 0.8252000212669373, 0.7832000255584717]
#
#
# 5000/5000 [==============================] - 1334s 265ms/step - loss: 0.7024 - binary_accuracy: 0.4924 - val_loss: 0.6916 - val_binary_accuracy: 0.5152
# Run:  5 / Accuracy at epoch  0  is:  0.5152000188827515
#
# 5000/5000 [==============================] - 1323s 264ms/step - loss: 0.6989 - binary_accuracy: 0.4984 - val_loss: 0.6925 - val_binary_accuracy: 0.5026
# Run:  5 / Accuracy at epoch  1  is:  0.5026000142097473
#
# 5000/5000 [==============================] - 1336s 266ms/step - loss: 0.6909 - binary_accuracy: 0.5776 - val_loss: 0.6526 - val_binary_accuracy: 0.6686
# Run:  5 / Accuracy at epoch  2  is:  0.6686000227928162
#
# 5000/5000 [==============================] - 1341s 264ms/step - loss: 0.6425 - binary_accuracy: 0.6930 - val_loss: 0.5623 - val_binary_accuracy: 0.7388
# Run:  5 / Accuracy at epoch  3  is:  0.7387999892234802
#
# 5000/5000 [==============================] - 1326s 265ms/step - loss: 0.5817 - binary_accuracy: 0.7658 - val_loss: 0.5202 - val_binary_accuracy: 0.7992
# Run:  5 / Accuracy at epoch  4  is:  0.7991999983787537
#
# 5000/5000 [==============================] - 1338s 267ms/step - loss: 0.5091 - binary_accuracy: 0.8144 - val_loss: 0.6406 - val_binary_accuracy: 0.8202
# Run:  5 / Accuracy at epoch  5  is:  0.8202000260353088
#
# 5000/5000 [==============================] - 1350s 269ms/step - loss: 0.4517 - binary_accuracy: 0.8474 - val_loss: 0.5740 - val_binary_accuracy: 0.8172
# Run:  5 / Accuracy at epoch  6  is:  0.8172000050544739
#
# 5000/5000 [==============================] - 1340s 267ms/step - loss: 0.4118 - binary_accuracy: 0.8852 - val_loss: 0.7051 - val_binary_accuracy: 0.8330
# Run:  5 / Accuracy at epoch  7  is:  0.8330000042915344
#
# 5000/5000 [==============================] - 1336s 266ms/step - loss: 0.3426 - binary_accuracy: 0.9140 - val_loss: 0.5404 - val_binary_accuracy: 0.8514
# Run:  5 / Accuracy at epoch  8  is:  0.8514000177383423
#
# 5000/5000 [==============================] - 1348s 269ms/step - loss: 0.3065 - binary_accuracy: 0.9376 - val_loss: 1.0036 - val_binary_accuracy: 0.7964
# Run:  5 / Accuracy at epoch  9  is:  0.7964000105857849
#
# 5000/5000 [==============================] - 1356s 270ms/step - loss: 0.2981 - binary_accuracy: 0.9506 - val_loss: 0.8620 - val_binary_accuracy: 0.8308
# Run:  5 / Accuracy at epoch  10  is:  0.8307999968528748
#
# 5000/5000 [==============================] - 1342s 268ms/step - loss: 0.2841 - binary_accuracy: 0.9660 - val_loss: 0.9643 - val_binary_accuracy: 0.8254
# Run:  5 / Accuracy at epoch  11  is:  0.8253999948501587
#
# 5000/5000 [==============================] - 1352s 270ms/step - loss: 0.2428 - binary_accuracy: 0.9710 - val_loss: 0.8793 - val_binary_accuracy: 0.8412
# Run:  5 / Accuracy at epoch  12  is:  0.8411999940872192
#
# 5000/5000 [==============================] - 1343s 268ms/step - loss: 0.2067 - binary_accuracy: 0.9726 - val_loss: 1.4672 - val_binary_accuracy: 0.8338
# Run:  5 / Accuracy at epoch  13  is:  0.8338000178337097
#
# 5000/5000 [==============================] - 1337s 267ms/step - loss: 0.1682 - binary_accuracy: 0.9832 - val_loss: 2.0892 - val_binary_accuracy: 0.7750
# Run:  5 / Accuracy at epoch  14  is:  0.7749999761581421
#
# 5000/5000 [==============================] - 1341s 267ms/step - loss: 0.1779 - binary_accuracy: 0.9852 - val_loss: 2.7841 - val_binary_accuracy: 0.8226
# Run:  5 / Accuracy at epoch  15  is:  0.8226000070571899
#
# 5000/5000 [==============================] - 1330s 265ms/step - loss: 0.1562 - binary_accuracy: 0.9880 - val_loss: 2.4131 - val_binary_accuracy: 0.8188
# Run:  5 / Accuracy at epoch  16  is:  0.8187999725341797
#
# 5000/5000 [==============================] - 1359s 268ms/step - loss: 0.1679 - binary_accuracy: 0.9876 - val_loss: 3.2592 - val_binary_accuracy: 0.8034
# Run:  5 / Accuracy at epoch  17  is:  0.8033999800682068
#
# 5000/5000 [==============================] - 1339s 267ms/step - loss: 0.1595 - binary_accuracy: 0.9898 - val_loss: 3.7205 - val_binary_accuracy: 0.8190
# Run:  5 / Accuracy at epoch  18  is:  0.8190000057220459
#
# 5000/5000 [==============================] - 1335s 266ms/step - loss: 0.1381 - binary_accuracy: 0.9920 - val_loss: 4.0429 - val_binary_accuracy: 0.8080
# Run:  5 / Accuracy at epoch  19  is:  0.8080000281333923
#
# Accuracies over epochs: [0.5152000188827515, 0.5026000142097473, 0.6686000227928162, 0.7387999892234802, 0.7991999983787537, 0.8202000260353088, 0.8172000050544739, 0.8330000042915344, 0.8514000177383423, 0.7964000105857849, 0.8307999968528748, 0.8253999948501587, 0.8411999940872192, 0.8338000178337097, 0.7749999761581421, 0.8226000070571899, 0.8187999725341797, 0.8033999800682068, 0.8190000057220459, 0.8080000281333923]
#
#
#
#
#  Over all runs maximum accuracies are: [0.842199981212616, 0.8461999893188477, 0.8474000096321106, 0.8483999967575073, 0.8514000177383423]
# The median is: 0.8474000096321106
#
#
#
# BiLSTM Accuracy Score on Test set ->  ['0.8474000096321106 +/- 0.005200028419494629']
#
#
# * * * * EVALUATION USING LOW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 2470
# Vocabulary size is: 94013
# 5000/5000 [==============================] - 1340s 266ms/step - loss: 0.7055 - binary_accuracy: 0.5204 - val_loss: 0.6498 - val_binary_accuracy: 0.6126
# Run:  1 / Accuracy at epoch  0  is:  0.6126000285148621
#
# 5000/5000 [==============================] - 1343s 268ms/step - loss: 0.6775 - binary_accuracy: 0.6324 - val_loss: 0.6047 - val_binary_accuracy: 0.7100
# Run:  1 / Accuracy at epoch  1  is:  0.7099999785423279
#
# 5000/5000 [==============================] - 1339s 267ms/step - loss: 0.6179 - binary_accuracy: 0.7190 - val_loss: 0.5110 - val_binary_accuracy: 0.7758
# Run:  1 / Accuracy at epoch  2  is:  0.7757999897003174
#
# 5000/5000 [==============================] - 1347s 269ms/step - loss: 0.5940 - binary_accuracy: 0.7362 - val_loss: 0.6985 - val_binary_accuracy: 0.7946
# Run:  1 / Accuracy at epoch  3  is:  0.7946000099182129
#
# 5000/5000 [==============================] - 1346s 268ms/step - loss: 0.5179 - binary_accuracy: 0.8192 - val_loss: 0.7012 - val_binary_accuracy: 0.8246
# Run:  1 / Accuracy at epoch  4  is:  0.8245999813079834
#
# 5000/5000 [==============================] - 1337s 267ms/step - loss: 0.4304 - binary_accuracy: 0.8668 - val_loss: 0.6865 - val_binary_accuracy: 0.8254
# Run:  1 / Accuracy at epoch  5  is:  0.8253999948501587
#
# 5000/5000 [==============================] - 1344s 268ms/step - loss: 0.3805 - binary_accuracy: 0.8972 - val_loss: 0.8401 - val_binary_accuracy: 0.8360
# Run:  1 / Accuracy at epoch  6  is:  0.8360000252723694
#
# 5000/5000 [==============================] - 1344s 268ms/step - loss: 0.3318 - binary_accuracy: 0.9278 - val_loss: 0.9639 - val_binary_accuracy: 0.7856
# Run:  1 / Accuracy at epoch  7  is:  0.7856000065803528
#
# 5000/5000 [==============================] - 1335s 266ms/step - loss: 0.3055 - binary_accuracy: 0.9426 - val_loss: 1.0404 - val_binary_accuracy: 0.8270
# Run:  1 / Accuracy at epoch  8  is:  0.8270000219345093
#
# 5000/5000 [==============================] - 1339s 267ms/step - loss: 0.2804 - binary_accuracy: 0.9560 - val_loss: 2.1740 - val_binary_accuracy: 0.7392
# Run:  1 / Accuracy at epoch  9  is:  0.7391999959945679
#
# 5000/5000 [==============================] - 1343s 268ms/step - loss: 0.2400 - binary_accuracy: 0.9654 - val_loss: 2.4230 - val_binary_accuracy: 0.7446
# Run:  1 / Accuracy at epoch  10  is:  0.7445999979972839
#
# 5000/5000 [==============================] - 1337s 267ms/step - loss: 0.2127 - binary_accuracy: 0.9690 - val_loss: 1.6249 - val_binary_accuracy: 0.8122
# Run:  1 / Accuracy at epoch  11  is:  0.8122000098228455
#
# 5000/5000 [==============================] - 1335s 266ms/step - loss: 0.1846 - binary_accuracy: 0.9804 - val_loss: 1.8091 - val_binary_accuracy: 0.8044
# Run:  1 / Accuracy at epoch  12  is:  0.8044000267982483
#
# 5000/5000 [==============================] - 1328s 265ms/step - loss: 0.1919 - binary_accuracy: 0.9834 - val_loss: 2.2418 - val_binary_accuracy: 0.8010
# Run:  1 / Accuracy at epoch  13  is:  0.8009999990463257
#
# 5000/5000 [==============================] - 1330s 265ms/step - loss: 0.1823 - binary_accuracy: 0.9848 - val_loss: 3.2755 - val_binary_accuracy: 0.7966
# Run:  1 / Accuracy at epoch  14  is:  0.7965999841690063
#
# 5000/5000 [==============================] - 1329s 265ms/step - loss: 0.1654 - binary_accuracy: 0.9884 - val_loss: 3.1674 - val_binary_accuracy: 0.8088
# Run:  1 / Accuracy at epoch  15  is:  0.8087999820709229
#
# 5000/5000 [==============================] - 1340s 267ms/step - loss: 0.1274 - binary_accuracy: 0.9908 - val_loss: 2.2592 - val_binary_accuracy: 0.8070
# Run:  1 / Accuracy at epoch  16  is:  0.8069999814033508
#
# 5000/5000 [==============================] - 1343s 268ms/step - loss: 0.1155 - binary_accuracy: 0.9926 - val_loss: 4.0892 - val_binary_accuracy: 0.7798
# Run:  1 / Accuracy at epoch  17  is:  0.7797999978065491
#
# 5000/5000 [==============================] - 1345s 268ms/step - loss: 0.0984 - binary_accuracy: 0.9928 - val_loss: 3.3371 - val_binary_accuracy: 0.8192
# Run:  1 / Accuracy at epoch  18  is:  0.8191999793052673
#
# 5000/5000 [==============================] - 1345s 268ms/step - loss: 0.0883 - binary_accuracy: 0.9948 - val_loss: 6.1181 - val_binary_accuracy: 0.7786
# Run:  1 / Accuracy at epoch  19  is:  0.7785999774932861
#
# Accuracies over epochs: [0.6126000285148621, 0.7099999785423279, 0.7757999897003174, 0.7946000099182129, 0.8245999813079834, 0.8253999948501587, 0.8360000252723694, 0.7856000065803528, 0.8270000219345093, 0.7391999959945679, 0.7445999979972839, 0.8122000098228455, 0.8044000267982483, 0.8009999990463257, 0.7965999841690063, 0.8087999820709229, 0.8069999814033508, 0.7797999978065491, 0.8191999793052673, 0.7785999774932861]
#
#
# 5000/5000 [==============================] - 1369s 272ms/step - loss: 0.7019 - binary_accuracy: 0.5152 - val_loss: 0.6522 - val_binary_accuracy: 0.6394
# Run:  2 / Accuracy at epoch  0  is:  0.6394000053405762
#
# 5000/5000 [==============================] - 1363s 272ms/step - loss: 0.6472 - binary_accuracy: 0.6754 - val_loss: 0.5572 - val_binary_accuracy: 0.7774
# Run:  2 / Accuracy at epoch  1  is:  0.777400016784668
#
# 5000/5000 [==============================] - 1426s 284ms/step - loss: 0.6067 - binary_accuracy: 0.7430 - val_loss: 0.5866 - val_binary_accuracy: 0.7834
# Run:  2 / Accuracy at epoch  2  is:  0.7833999991416931
#
# 5000/5000 [==============================] - 1448s 289ms/step - loss: 0.5708 - binary_accuracy: 0.7846 - val_loss: 0.5024 - val_binary_accuracy: 0.7956
# Run:  2 / Accuracy at epoch  3  is:  0.7955999970436096
#
# 5000/5000 [==============================] - 1445s 288ms/step - loss: 0.4876 - binary_accuracy: 0.8286 - val_loss: 0.6790 - val_binary_accuracy: 0.8300
# Run:  2 / Accuracy at epoch  4  is:  0.8299999833106995
#
# 5000/5000 [==============================] - 1421s 283ms/step - loss: 0.4006 - binary_accuracy: 0.8778 - val_loss: 0.8315 - val_binary_accuracy: 0.8372
# Run:  2 / Accuracy at epoch  5  is:  0.8371999859809875
#
# 5000/5000 [==============================] - 1451s 289ms/step - loss: 0.3496 - binary_accuracy: 0.9108 - val_loss: 0.7790 - val_binary_accuracy: 0.8448
# Run:  2 / Accuracy at epoch  6  is:  0.8447999954223633
#
# 5000/5000 [==============================] - 1445s 288ms/step - loss: 0.3269 - binary_accuracy: 0.9292 - val_loss: 0.8572 - val_binary_accuracy: 0.8358
# Run:  2 / Accuracy at epoch  7  is:  0.8357999920845032
#
# 5000/5000 [==============================] - 1441s 287ms/step - loss: 0.2925 - binary_accuracy: 0.9420 - val_loss: 1.1970 - val_binary_accuracy: 0.8432
# Run:  2 / Accuracy at epoch  8  is:  0.8432000279426575
#
# 5000/5000 [==============================] - 1430s 285ms/step - loss: 0.2543 - binary_accuracy: 0.9556 - val_loss: 1.3664 - val_binary_accuracy: 0.8370
# Run:  2 / Accuracy at epoch  9  is:  0.8370000123977661
#
# 5000/5000 [==============================] - 1428s 285ms/step - loss: 0.2485 - binary_accuracy: 0.9632 - val_loss: 1.4936 - val_binary_accuracy: 0.8356
# Run:  2 / Accuracy at epoch  10  is:  0.8356000185012817
#
# 5000/5000 [==============================] - 1416s 282ms/step - loss: 0.2238 - binary_accuracy: 0.9742 - val_loss: 2.0471 - val_binary_accuracy: 0.8010
# Run:  2 / Accuracy at epoch  11  is:  0.8009999990463257
#
# 5000/5000 [==============================] - 1428s 285ms/step - loss: 0.2103 - binary_accuracy: 0.9774 - val_loss: 1.8398 - val_binary_accuracy: 0.8380
# Run:  2 / Accuracy at epoch  12  is:  0.8379999995231628
#
# 5000/5000 [==============================] - 1438s 287ms/step - loss: 0.2399 - binary_accuracy: 0.9818 - val_loss: 3.0066 - val_binary_accuracy: 0.7800
# Run:  2 / Accuracy at epoch  13  is:  0.7799999713897705
#
# 5000/5000 [==============================] - 1443s 288ms/step - loss: 0.1981 - binary_accuracy: 0.9860 - val_loss: 3.5674 - val_binary_accuracy: 0.8216
# Run:  2 / Accuracy at epoch  14  is:  0.8216000199317932
#
# 5000/5000 [==============================] - 1432s 285ms/step - loss: 0.2018 - binary_accuracy: 0.9860 - val_loss: 7.2740 - val_binary_accuracy: 0.8082
# Run:  2 / Accuracy at epoch  15  is:  0.8082000017166138
#
# 5000/5000 [==============================] - 1439s 287ms/step - loss: 0.2087 - binary_accuracy: 0.9902 - val_loss: 4.0108 - val_binary_accuracy: 0.8006
# Run:  2 / Accuracy at epoch  16  is:  0.800599992275238
#
# 5000/5000 [==============================] - 1430s 285ms/step - loss: 0.2060 - binary_accuracy: 0.9864 - val_loss: 3.8768 - val_binary_accuracy: 0.8240
# Run:  2 / Accuracy at epoch  17  is:  0.8240000009536743
#
# 5000/5000 [==============================] - 1430s 285ms/step - loss: 0.1495 - binary_accuracy: 0.9906 - val_loss: 3.4604 - val_binary_accuracy: 0.7902
# Run:  2 / Accuracy at epoch  18  is:  0.7901999950408936
#
# 5000/5000 [==============================] - 1430s 285ms/step - loss: 0.1868 - binary_accuracy: 0.9912 - val_loss: 4.3855 - val_binary_accuracy: 0.8224
# Run:  2 / Accuracy at epoch  19  is:  0.8223999738693237
#
# Accuracies over epochs: [0.6394000053405762, 0.777400016784668, 0.7833999991416931, 0.7955999970436096, 0.8299999833106995, 0.8371999859809875, 0.8447999954223633, 0.8357999920845032, 0.8432000279426575, 0.8370000123977661, 0.8356000185012817, 0.8009999990463257, 0.8379999995231628, 0.7799999713897705, 0.8216000199317932, 0.8082000017166138, 0.800599992275238, 0.8240000009536743, 0.7901999950408936, 0.8223999738693237]
#
#
# 5000/5000 [==============================] - 1434s 284ms/step - loss: 0.7032 - binary_accuracy: 0.5012 - val_loss: 0.7345 - val_binary_accuracy: 0.5096
# Run:  3 / Accuracy at epoch  0  is:  0.5095999836921692
#
# 5000/5000 [==============================] - 2015s 402ms/step - loss: 0.6506 - binary_accuracy: 0.6678 - val_loss: 0.5563 - val_binary_accuracy: 0.7518
# Run:  3 / Accuracy at epoch  1  is:  0.751800000667572
#
# 5000/5000 [==============================] - 2021s 397ms/step - loss: 0.6139 - binary_accuracy: 0.7256 - val_loss: 0.7138 - val_binary_accuracy: 0.7588
# Run:  3 / Accuracy at epoch  2  is:  0.7588000297546387
#
# 5000/5000 [==============================] - 2030s 398ms/step - loss: 0.5515 - binary_accuracy: 0.7914 - val_loss: 0.7462 - val_binary_accuracy: 0.7292
# Run:  3 / Accuracy at epoch  3  is:  0.729200005531311
#
# 5000/5000 [==============================] - 2056s 401ms/step - loss: 0.4692 - binary_accuracy: 0.8376 - val_loss: 0.5603 - val_binary_accuracy: 0.8250
# Run:  3 / Accuracy at epoch  4  is:  0.824999988079071
#
# 5000/5000 [==============================] - 2099s 412ms/step - loss: 0.3965 - binary_accuracy: 0.8796 - val_loss: 0.6408 - val_binary_accuracy: 0.8308
# Run:  3 / Accuracy at epoch  5  is:  0.8307999968528748
#
# 5000/5000 [==============================] - 2113s 417ms/step - loss: 0.3507 - binary_accuracy: 0.9066 - val_loss: 1.0408 - val_binary_accuracy: 0.8172
# Run:  3 / Accuracy at epoch  6  is:  0.8172000050544739
#
# 5000/5000 [==============================] - 1369s 267ms/step - loss: 0.2889 - binary_accuracy: 0.9314 - val_loss: 0.8255 - val_binary_accuracy: 0.8366
# Run:  3 / Accuracy at epoch  7  is:  0.8366000056266785
#
# 5000/5000 [==============================] - 1253s 250ms/step - loss: 0.2807 - binary_accuracy: 0.9410 - val_loss: 0.9569 - val_binary_accuracy: 0.8118
# Run:  3 / Accuracy at epoch  8  is:  0.8118000030517578
#
# 5000/5000 [==============================] - 1260s 251ms/step - loss: 0.2878 - binary_accuracy: 0.9506 - val_loss: 1.1840 - val_binary_accuracy: 0.8244
# Run:  3 / Accuracy at epoch  9  is:  0.824400007724762
#
# 5000/5000 [==============================] - 1262s 252ms/step - loss: 0.2519 - binary_accuracy: 0.9610 - val_loss: 1.1044 - val_binary_accuracy: 0.8414
# Run:  3 / Accuracy at epoch  10  is:  0.8414000272750854
#
# 5000/5000 [==============================] - 1254s 250ms/step - loss: 0.2463 - binary_accuracy: 0.9664 - val_loss: 2.1938 - val_binary_accuracy: 0.7774
# Run:  3 / Accuracy at epoch  11  is:  0.777400016784668
#
# 5000/5000 [==============================] - 1276s 251ms/step - loss: 0.2277 - binary_accuracy: 0.9698 - val_loss: 1.9051 - val_binary_accuracy: 0.8436
# Run:  3 / Accuracy at epoch  12  is:  0.8435999751091003
#
# 5000/5000 [==============================] - 1249s 249ms/step - loss: 0.2111 - binary_accuracy: 0.9766 - val_loss: 2.6625 - val_binary_accuracy: 0.7748
# Run:  3 / Accuracy at epoch  13  is:  0.7748000025749207
#
# 5000/5000 [==============================] - 1250s 249ms/step - loss: 0.2088 - binary_accuracy: 0.9808 - val_loss: 2.2793 - val_binary_accuracy: 0.8272
# Run:  3 / Accuracy at epoch  14  is:  0.8271999955177307
#
# 5000/5000 [==============================] - 1252s 250ms/step - loss: 0.1672 - binary_accuracy: 0.9848 - val_loss: 3.1968 - val_binary_accuracy: 0.8108
# Run:  3 / Accuracy at epoch  15  is:  0.8108000159263611
#
# 5000/5000 [==============================] - 1251s 249ms/step - loss: 0.1753 - binary_accuracy: 0.9856 - val_loss: 2.2083 - val_binary_accuracy: 0.8250
# Run:  3 / Accuracy at epoch  16  is:  0.824999988079071
#
# 5000/5000 [==============================] - 1245s 248ms/step - loss: 0.1552 - binary_accuracy: 0.9878 - val_loss: 3.1753 - val_binary_accuracy: 0.8322
# Run:  3 / Accuracy at epoch  17  is:  0.8321999907493591
#
# 5000/5000 [==============================] - 1241s 247ms/step - loss: 0.1369 - binary_accuracy: 0.9918 - val_loss: 3.2219 - val_binary_accuracy: 0.8340
# Run:  3 / Accuracy at epoch  18  is:  0.8339999914169312
#
# 5000/5000 [==============================] - 1243s 248ms/step - loss: 0.0900 - binary_accuracy: 0.9938 - val_loss: 4.7690 - val_binary_accuracy: 0.8292
# Run:  3 / Accuracy at epoch  19  is:  0.829200029373169
#
# Accuracies over epochs: [0.5095999836921692, 0.751800000667572, 0.7588000297546387, 0.729200005531311, 0.824999988079071, 0.8307999968528748, 0.8172000050544739, 0.8366000056266785, 0.8118000030517578, 0.824400007724762, 0.8414000272750854, 0.777400016784668, 0.8435999751091003, 0.7748000025749207, 0.8271999955177307, 0.8108000159263611, 0.824999988079071, 0.8321999907493591, 0.8339999914169312, 0.829200029373169]
#
#
# 5000/5000 [==============================] - 1235s 245ms/step - loss: 0.7049 - binary_accuracy: 0.4976 - val_loss: 0.7062 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy at epoch  0  is:  0.5
#
# 5000/5000 [==============================] - 1237s 247ms/step - loss: 0.7048 - binary_accuracy: 0.4990 - val_loss: 0.6872 - val_binary_accuracy: 0.5360
# Run:  4 / Accuracy at epoch  1  is:  0.5360000133514404
#
# 5000/5000 [==============================] - 1242s 248ms/step - loss: 0.6932 - binary_accuracy: 0.5386 - val_loss: 0.6544 - val_binary_accuracy: 0.6400
# Run:  4 / Accuracy at epoch  2  is:  0.6399999856948853
#
# 5000/5000 [==============================] - 1240s 247ms/step - loss: 0.6544 - binary_accuracy: 0.6680 - val_loss: 0.5272 - val_binary_accuracy: 0.7352
# Run:  4 / Accuracy at epoch  3  is:  0.7351999878883362
#
# 5000/5000 [==============================] - 1241s 247ms/step - loss: 0.5225 - binary_accuracy: 0.7904 - val_loss: 0.5927 - val_binary_accuracy: 0.7940
# Run:  4 / Accuracy at epoch  4  is:  0.7940000295639038
#
# 5000/5000 [==============================] - 1248s 249ms/step - loss: 0.4356 - binary_accuracy: 0.8474 - val_loss: 0.4777 - val_binary_accuracy: 0.8234
# Run:  4 / Accuracy at epoch  5  is:  0.8234000205993652
#
# 5000/5000 [==============================] - 1250s 249ms/step - loss: 0.3721 - binary_accuracy: 0.8790 - val_loss: 0.5438 - val_binary_accuracy: 0.8300
# Run:  4 / Accuracy at epoch  6  is:  0.8299999833106995
#
# 5000/5000 [==============================] - 1250s 249ms/step - loss: 0.3383 - binary_accuracy: 0.8976 - val_loss: 0.6825 - val_binary_accuracy: 0.8058
# Run:  4 / Accuracy at epoch  7  is:  0.8058000206947327
#
# 5000/5000 [==============================] - 1254s 250ms/step - loss: 0.2925 - binary_accuracy: 0.9196 - val_loss: 0.7430 - val_binary_accuracy: 0.8192
# Run:  4 / Accuracy at epoch  8  is:  0.8191999793052673
#
# 5000/5000 [==============================] - 1252s 250ms/step - loss: 0.2792 - binary_accuracy: 0.9368 - val_loss: 1.2995 - val_binary_accuracy: 0.7882
# Run:  4 / Accuracy at epoch  9  is:  0.7882000207901001
#
# 5000/5000 [==============================] - 1252s 250ms/step - loss: 0.2452 - binary_accuracy: 0.9492 - val_loss: 1.5486 - val_binary_accuracy: 0.8154
# Run:  4 / Accuracy at epoch  10  is:  0.8154000043869019
#
# 5000/5000 [==============================] - 1253s 250ms/step - loss: 0.2007 - binary_accuracy: 0.9566 - val_loss: 1.5956 - val_binary_accuracy: 0.7444
# Run:  4 / Accuracy at epoch  11  is:  0.7444000244140625
#
# 5000/5000 [==============================] - 1281s 255ms/step - loss: 0.1794 - binary_accuracy: 0.9612 - val_loss: 2.5701 - val_binary_accuracy: 0.7658
# Run:  4 / Accuracy at epoch  12  is:  0.7657999992370605
#
# 5000/5000 [==============================] - 1301s 260ms/step - loss: 0.1981 - binary_accuracy: 0.9658 - val_loss: 2.9574 - val_binary_accuracy: 0.6526
# Run:  4 / Accuracy at epoch  13  is:  0.6525999903678894
#
# 5000/5000 [==============================] - 1301s 260ms/step - loss: 0.1920 - binary_accuracy: 0.9744 - val_loss: 2.6468 - val_binary_accuracy: 0.7432
# Run:  4 / Accuracy at epoch  14  is:  0.7432000041007996
#
# 5000/5000 [==============================] - 1300s 259ms/step - loss: 0.1830 - binary_accuracy: 0.9754 - val_loss: 3.9017 - val_binary_accuracy: 0.6600
# Run:  4 / Accuracy at epoch  15  is:  0.6600000262260437
#
# 5000/5000 [==============================] - 1300s 259ms/step - loss: 0.1668 - binary_accuracy: 0.9790 - val_loss: 3.8191 - val_binary_accuracy: 0.6782
# Run:  4 / Accuracy at epoch  16  is:  0.6782000064849854
#
# 5000/5000 [==============================] - 1297s 259ms/step - loss: 0.1773 - binary_accuracy: 0.9840 - val_loss: 4.4408 - val_binary_accuracy: 0.6834
# Run:  4 / Accuracy at epoch  17  is:  0.6833999752998352
#
# 5000/5000 [==============================] - 1297s 259ms/step - loss: 0.1532 - binary_accuracy: 0.9830 - val_loss: 5.0996 - val_binary_accuracy: 0.6386
# Run:  4 / Accuracy at epoch  18  is:  0.6385999917984009
#
# 5000/5000 [==============================] - 1302s 260ms/step - loss: 0.1819 - binary_accuracy: 0.9824 - val_loss: 7.5227 - val_binary_accuracy: 0.6462
# Run:  4 / Accuracy at epoch  19  is:  0.6462000012397766
#
# Accuracies over epochs: [0.5, 0.5360000133514404, 0.6399999856948853, 0.7351999878883362, 0.7940000295639038, 0.8234000205993652, 0.8299999833106995, 0.8058000206947327, 0.8191999793052673, 0.7882000207901001, 0.8154000043869019, 0.7444000244140625, 0.7657999992370605, 0.6525999903678894, 0.7432000041007996, 0.6600000262260437, 0.6782000064849854, 0.6833999752998352, 0.6385999917984009, 0.6462000012397766]
#
#
# 5000/5000 [==============================] - 1290s 257ms/step - loss: 0.6988 - binary_accuracy: 0.4816 - val_loss: 0.6921 - val_binary_accuracy: 0.5356
# Run:  5 / Accuracy at epoch  0  is:  0.5356000065803528
#
# 5000/5000 [==============================] - 1349s 269ms/step - loss: 0.6984 - binary_accuracy: 0.5370 - val_loss: 0.6589 - val_binary_accuracy: 0.6966
# Run:  5 / Accuracy at epoch  1  is:  0.6966000199317932
#
# 5000/5000 [==============================] - 1302s 260ms/step - loss: 0.6368 - binary_accuracy: 0.6936 - val_loss: 0.5366 - val_binary_accuracy: 0.7824
# Run:  5 / Accuracy at epoch  2  is:  0.7824000120162964
#
# 5000/5000 [==============================] - 1270s 253ms/step - loss: 0.5768 - binary_accuracy: 0.7620 - val_loss: 0.4964 - val_binary_accuracy: 0.7952
# Run:  5 / Accuracy at epoch  3  is:  0.795199990272522
#
# 5000/5000 [==============================] - 1336s 267ms/step - loss: 0.5310 - binary_accuracy: 0.7992 - val_loss: 0.6557 - val_binary_accuracy: 0.8116
# Run:  5 / Accuracy at epoch  4  is:  0.8116000294685364
#
# 5000/5000 [==============================] - 1515s 302ms/step - loss: 0.4444 - binary_accuracy: 0.8622 - val_loss: 0.6453 - val_binary_accuracy: 0.8022
# Run:  5 / Accuracy at epoch  5  is:  0.8022000193595886
#
# 5000/5000 [==============================] - 1583s 316ms/step - loss: 0.3680 - binary_accuracy: 0.8986 - val_loss: 0.6710 - val_binary_accuracy: 0.8428
# Run:  5 / Accuracy at epoch  6  is:  0.8428000211715698
#
# 5000/5000 [==============================] - 1631s 325ms/step - loss: 0.3266 - binary_accuracy: 0.9166 - val_loss: 0.8120 - val_binary_accuracy: 0.8150
# Run:  5 / Accuracy at epoch  7  is:  0.8149999976158142
#
# 5000/5000 [==============================] - 1603s 319ms/step - loss: 0.3037 - binary_accuracy: 0.9372 - val_loss: 1.0096 - val_binary_accuracy: 0.8408
# Run:  5 / Accuracy at epoch  8  is:  0.8407999873161316
#
# 5000/5000 [==============================] - 1595s 318ms/step - loss: 0.2713 - binary_accuracy: 0.9526 - val_loss: 1.1369 - val_binary_accuracy: 0.8054
# Run:  5 / Accuracy at epoch  9  is:  0.805400013923645
#
# 5000/5000 [==============================] - 1533s 306ms/step - loss: 0.2417 - binary_accuracy: 0.9590 - val_loss: 1.4089 - val_binary_accuracy: 0.7924
# Run:  5 / Accuracy at epoch  10  is:  0.7924000024795532
#
# 5000/5000 [==============================] - 1526s 304ms/step - loss: 0.2330 - binary_accuracy: 0.9680 - val_loss: 1.0837 - val_binary_accuracy: 0.7998
# Run:  5 / Accuracy at epoch  11  is:  0.7997999787330627
#
# 5000/5000 [==============================] - 1527s 304ms/step - loss: 0.2149 - binary_accuracy: 0.9718 - val_loss: 1.2600 - val_binary_accuracy: 0.7936
# Run:  5 / Accuracy at epoch  12  is:  0.7936000227928162
#
# 5000/5000 [==============================] - 1513s 301ms/step - loss: 0.2249 - binary_accuracy: 0.9734 - val_loss: 2.2499 - val_binary_accuracy: 0.7806
# Run:  5 / Accuracy at epoch  13  is:  0.7806000113487244
#
# 5000/5000 [==============================] - 1505s 300ms/step - loss: 0.2073 - binary_accuracy: 0.9782 - val_loss: 2.9810 - val_binary_accuracy: 0.7712
# Run:  5 / Accuracy at epoch  14  is:  0.7712000012397766
#
# 5000/5000 [==============================] - 1527s 304ms/step - loss: 0.1846 - binary_accuracy: 0.9840 - val_loss: 3.3339 - val_binary_accuracy: 0.7804
# Run:  5 / Accuracy at epoch  15  is:  0.7803999781608582
#
# 5000/5000 [==============================] - 1510s 301ms/step - loss: 0.1915 - binary_accuracy: 0.9862 - val_loss: 2.7835 - val_binary_accuracy: 0.8076
# Run:  5 / Accuracy at epoch  16  is:  0.8076000213623047
#
# 5000/5000 [==============================] - 1517s 302ms/step - loss: 0.1562 - binary_accuracy: 0.9900 - val_loss: 4.2876 - val_binary_accuracy: 0.7794
# Run:  5 / Accuracy at epoch  17  is:  0.7793999910354614
#
# 5000/5000 [==============================] - 1521s 303ms/step - loss: 0.1575 - binary_accuracy: 0.9892 - val_loss: 3.0505 - val_binary_accuracy: 0.7958
# Run:  5 / Accuracy at epoch  18  is:  0.795799970626831
#
# 5000/5000 [==============================] - 1518s 302ms/step - loss: 0.1214 - binary_accuracy: 0.9908 - val_loss: 7.0877 - val_binary_accuracy: 0.7378
# Run:  5 / Accuracy at epoch  19  is:  0.7378000020980835
#
# Accuracies over epochs: [0.5356000065803528, 0.6966000199317932, 0.7824000120162964, 0.795199990272522, 0.8116000294685364, 0.8022000193595886, 0.8428000211715698, 0.8149999976158142, 0.8407999873161316, 0.805400013923645, 0.7924000024795532, 0.7997999787330627, 0.7936000227928162, 0.7806000113487244, 0.7712000012397766, 0.7803999781608582, 0.8076000213623047, 0.7793999910354614, 0.795799970626831, 0.7378000020980835]
#
#
#
#
#  Over all runs maximum accuracies are: [0.8299999833106995, 0.8360000252723694, 0.8428000211715698, 0.8435999751091003, 0.8447999954223633]
# The median is: 0.8428000211715698
#
#
#
# BiLSTM Accuracy Score on Test set ->  ['0.8428000211715698 +/- 0.012800037860870361']
#
#
# * * * * EVALUATION USING RSW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 1540
# Vocabulary size is: 103029
# 5000/5000 [==============================] - 997s 197ms/step - loss: 0.7029 - binary_accuracy: 0.4856 - val_loss: 0.6933 - val_binary_accuracy: 0.4972
# Run:  1 / Accuracy at epoch  0  is:  0.49720001220703125
#
# 5000/5000 [==============================] - 987s 196ms/step - loss: 0.7018 - binary_accuracy: 0.4854 - val_loss: 0.6898 - val_binary_accuracy: 0.5356
# Run:  1 / Accuracy at epoch  1  is:  0.5356000065803528
#
# 5000/5000 [==============================] - 981s 195ms/step - loss: 0.6867 - binary_accuracy: 0.5884 - val_loss: 0.5976 - val_binary_accuracy: 0.6954
# Run:  1 / Accuracy at epoch  2  is:  0.6953999996185303
#
# ...
#
# 5000/5000 [==============================] - 846s 169ms/step - loss: 0.1227 - binary_accuracy: 0.9916 - val_loss: 3.6335 - val_binary_accuracy: 0.8316
# Run:  5 / Accuracy at epoch  19  is:  0.83160001039505
#
# Accuracies over epochs: [0.5350000262260437, 0.625, 0.7382000088691711, 0.7868000268936157, 0.7739999890327454, 0.8212000131607056, 0.8321999907493591, 0.8438000082969666, 0.8438000082969666, 0.8004000186920166, 0.840399980545044, 0.7893999814987183, 0.79339998960495, 0.8220000267028809, 0.7612000107765198, 0.8041999936103821, 0.7911999821662903, 0.8184000253677368, 0.8367999792098999, 0.83160001039505]
#
#
#
#
#  Over all runs maximum accuracies are: [0.8271999955177307, 0.8428000211715698, 0.8438000082969666, 0.8471999764442444, 0.8518000245094299]
# The median is: 0.8438000082969666
#
#
#
# BiLSTM Accuracy Score on Test set ->  ['0.8438000082969666 +/- 0.01660001277923584']
#
#
# * * * * EVALUATION USING STM_LOW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 2502
# Vocabulary size is: 94013
# 5000/5000 [==============================] - 1301s 259ms/step - loss: 0.7036 - binary_accuracy: 0.5338 - val_loss: 0.6035 - val_binary_accuracy: 0.6856
# Run:  1 / Accuracy at epoch  0  is:  0.6855999827384949
#
# 5000/5000 [==============================] - 1307s 261ms/step - loss: 0.6353 - binary_accuracy: 0.6976 - val_loss: 0.5175 - val_binary_accuracy: 0.7518
# Run:  1 / Accuracy at epoch  1  is:  0.751800000667572
#
# 5000/5000 [==============================] - 1320s 263ms/step - loss: 0.5669 - binary_accuracy: 0.7710 - val_loss: 0.6228 - val_binary_accuracy: 0.7940
# Run:  1 / Accuracy at epoch  2  is:  0.7940000295639038
#
# 5000/5000 [==============================] - 1325s 264ms/step - loss: 0.5173 - binary_accuracy: 0.8182 - val_loss: 0.5930 - val_binary_accuracy: 0.8218
# Run:  1 / Accuracy at epoch  3  is:  0.8217999935150146
#
# 5000/5000 [==============================] - 1319s 263ms/step - loss: 0.4425 - binary_accuracy: 0.8552 - val_loss: 0.6537 - val_binary_accuracy: 0.8302
# Run:  1 / Accuracy at epoch  4  is:  0.8302000164985657
#
# 5000/5000 [==============================] - 1333s 266ms/step - loss: 0.3934 - binary_accuracy: 0.8930 - val_loss: 0.7046 - val_binary_accuracy: 0.8460
# Run:  1 / Accuracy at epoch  5  is:  0.8460000157356262
#
# 5000/5000 [==============================] - 1326s 262ms/step - loss: 0.3495 - binary_accuracy: 0.9162 - val_loss: 0.5949 - val_binary_accuracy: 0.8418
# Run:  1 / Accuracy at epoch  6  is:  0.8417999744415283
#
# 5000/5000 [==============================] - 1320s 263ms/step - loss: 0.3133 - binary_accuracy: 0.9336 - val_loss: 0.8875 - val_binary_accuracy: 0.8076
# Run:  1 / Accuracy at epoch  7  is:  0.8076000213623047
#
# 5000/5000 [==============================] - 1322s 264ms/step - loss: 0.2772 - binary_accuracy: 0.9496 - val_loss: 0.8243 - val_binary_accuracy: 0.8462
# Run:  1 / Accuracy at epoch  8  is:  0.8461999893188477
#
# 5000/5000 [==============================] - 1321s 264ms/step - loss: 0.2669 - binary_accuracy: 0.9590 - val_loss: 0.9398 - val_binary_accuracy: 0.8346
# Run:  1 / Accuracy at epoch  9  is:  0.8345999717712402
#
# 5000/5000 [==============================] - 1315s 263ms/step - loss: 0.2666 - binary_accuracy: 0.9636 - val_loss: 1.3695 - val_binary_accuracy: 0.8122
# Run:  1 / Accuracy at epoch  10  is:  0.8122000098228455
#
# 5000/5000 [==============================] - 1315s 262ms/step - loss: 0.2360 - binary_accuracy: 0.9698 - val_loss: 1.2872 - val_binary_accuracy: 0.8374
# Run:  1 / Accuracy at epoch  11  is:  0.8374000191688538
#
# 5000/5000 [==============================] - 1315s 262ms/step - loss: 0.2271 - binary_accuracy: 0.9712 - val_loss: 1.5967 - val_binary_accuracy: 0.7840
# Run:  1 / Accuracy at epoch  12  is:  0.7839999794960022
#
# 5000/5000 [==============================] - 1322s 264ms/step - loss: 0.2165 - binary_accuracy: 0.9756 - val_loss: 2.1791 - val_binary_accuracy: 0.7674
# Run:  1 / Accuracy at epoch  13  is:  0.7674000263214111
#
# 5000/5000 [==============================] - 1320s 264ms/step - loss: 0.1985 - binary_accuracy: 0.9796 - val_loss: 2.5282 - val_binary_accuracy: 0.7396
# Run:  1 / Accuracy at epoch  14  is:  0.7396000027656555
#
# 5000/5000 [==============================] - 1318s 263ms/step - loss: 0.2081 - binary_accuracy: 0.9802 - val_loss: 2.6955 - val_binary_accuracy: 0.7758
# Run:  1 / Accuracy at epoch  15  is:  0.7757999897003174
#
# 5000/5000 [==============================] - 1315s 262ms/step - loss: 0.1986 - binary_accuracy: 0.9816 - val_loss: 2.3028 - val_binary_accuracy: 0.7530
# Run:  1 / Accuracy at epoch  16  is:  0.753000020980835
#
# 5000/5000 [==============================] - 1315s 262ms/step - loss: 0.1956 - binary_accuracy: 0.9854 - val_loss: 3.8763 - val_binary_accuracy: 0.7832
# Run:  1 / Accuracy at epoch  17  is:  0.7832000255584717
#
# 5000/5000 [==============================] - 1323s 264ms/step - loss: 0.1692 - binary_accuracy: 0.9874 - val_loss: 3.5507 - val_binary_accuracy: 0.7790
# Run:  1 / Accuracy at epoch  18  is:  0.7789999842643738
#
# 5000/5000 [==============================] - 1351s 267ms/step - loss: 0.1640 - binary_accuracy: 0.9876 - val_loss: 3.8695 - val_binary_accuracy: 0.7754
# Run:  1 / Accuracy at epoch  19  is:  0.7753999829292297
#
# Accuracies over epochs: [0.6855999827384949, 0.751800000667572, 0.7940000295639038, 0.8217999935150146, 0.8302000164985657, 0.8460000157356262, 0.8417999744415283, 0.8076000213623047, 0.8461999893188477, 0.8345999717712402, 0.8122000098228455, 0.8374000191688538, 0.7839999794960022, 0.7674000263214111, 0.7396000027656555, 0.7757999897003174, 0.753000020980835, 0.7832000255584717, 0.7789999842643738, 0.7753999829292297]
#
#
# 5000/5000 [==============================] - 1307s 260ms/step - loss: 0.7061 - binary_accuracy: 0.5036 - val_loss: 0.6912 - val_binary_accuracy: 0.5174
# Run:  2 / Accuracy at epoch  0  is:  0.5174000263214111
#
# 5000/5000 [==============================] - 1303s 260ms/step - loss: 0.6783 - binary_accuracy: 0.6130 - val_loss: 0.5804 - val_binary_accuracy: 0.7478
# Run:  2 / Accuracy at epoch  1  is:  0.7477999925613403
#
# 5000/5000 [==============================] - 1313s 262ms/step - loss: 0.5929 - binary_accuracy: 0.7400 - val_loss: 0.6654 - val_binary_accuracy: 0.7224
# Run:  2 / Accuracy at epoch  2  is:  0.7224000096321106
#
# 5000/5000 [==============================] - 1315s 262ms/step - loss: 0.5538 - binary_accuracy: 0.7784 - val_loss: 0.6094 - val_binary_accuracy: 0.7984
# Run:  2 / Accuracy at epoch  3  is:  0.7983999848365784
#
# 5000/5000 [==============================] - 1318s 263ms/step - loss: 0.5023 - binary_accuracy: 0.8224 - val_loss: 0.5558 - val_binary_accuracy: 0.8204
# Run:  2 / Accuracy at epoch  4  is:  0.8203999996185303
#
# 5000/5000 [==============================] - 1321s 264ms/step - loss: 0.4293 - binary_accuracy: 0.8576 - val_loss: 0.6955 - val_binary_accuracy: 0.8420
# Run:  2 / Accuracy at epoch  5  is:  0.8420000076293945
#
# 5000/5000 [==============================] - 1316s 263ms/step - loss: 0.3571 - binary_accuracy: 0.8974 - val_loss: 0.5629 - val_binary_accuracy: 0.8330
# Run:  2 / Accuracy at epoch  6  is:  0.8330000042915344
#
# 5000/5000 [==============================] - 1312s 262ms/step - loss: 0.3202 - binary_accuracy: 0.9208 - val_loss: 0.6976 - val_binary_accuracy: 0.8434
# Run:  2 / Accuracy at epoch  7  is:  0.8434000015258789
#
# 5000/5000 [==============================] - 1314s 262ms/step - loss: 0.3025 - binary_accuracy: 0.9378 - val_loss: 0.9796 - val_binary_accuracy: 0.8214
# Run:  2 / Accuracy at epoch  8  is:  0.821399986743927
#
# 5000/5000 [==============================] - 1320s 263ms/step - loss: 0.2699 - binary_accuracy: 0.9488 - val_loss: 1.1149 - val_binary_accuracy: 0.8354
# Run:  2 / Accuracy at epoch  9  is:  0.8353999853134155
#
# 5000/5000 [==============================] - 1318s 263ms/step - loss: 0.2692 - binary_accuracy: 0.9574 - val_loss: 1.4526 - val_binary_accuracy: 0.8092
# Run:  2 / Accuracy at epoch  10  is:  0.8091999888420105
#
# 5000/5000 [==============================] - 1322s 264ms/step - loss: 0.2237 - binary_accuracy: 0.9678 - val_loss: 1.5448 - val_binary_accuracy: 0.7970
# Run:  2 / Accuracy at epoch  11  is:  0.796999990940094
#
# 5000/5000 [==============================] - 1311s 262ms/step - loss: 0.2278 - binary_accuracy: 0.9686 - val_loss: 1.7497 - val_binary_accuracy: 0.7590
# Run:  2 / Accuracy at epoch  12  is:  0.7590000033378601
#
# 5000/5000 [==============================] - 1312s 262ms/step - loss: 0.2034 - binary_accuracy: 0.9744 - val_loss: 2.2898 - val_binary_accuracy: 0.7462
# Run:  2 / Accuracy at epoch  13  is:  0.7462000250816345
#
# 5000/5000 [==============================] - 1311s 262ms/step - loss: 0.1784 - binary_accuracy: 0.9770 - val_loss: 2.0760 - val_binary_accuracy: 0.7658
# Run:  2 / Accuracy at epoch  14  is:  0.7657999992370605
#
# 5000/5000 [==============================] - 1319s 263ms/step - loss: 0.1840 - binary_accuracy: 0.9832 - val_loss: 3.6635 - val_binary_accuracy: 0.7072
# Run:  2 / Accuracy at epoch  15  is:  0.7071999907493591
#
# 5000/5000 [==============================] - 1319s 263ms/step - loss: 0.1597 - binary_accuracy: 0.9824 - val_loss: 2.7875 - val_binary_accuracy: 0.7714
# Run:  2 / Accuracy at epoch  16  is:  0.771399974822998
#
# 5000/5000 [==============================] - 1318s 263ms/step - loss: 0.1461 - binary_accuracy: 0.9884 - val_loss: 4.0299 - val_binary_accuracy: 0.7746
# Run:  2 / Accuracy at epoch  17  is:  0.7746000289916992
#
# 5000/5000 [==============================] - 1311s 262ms/step - loss: 0.1270 - binary_accuracy: 0.9876 - val_loss: 4.7890 - val_binary_accuracy: 0.8112
# Run:  2 / Accuracy at epoch  18  is:  0.8112000226974487
#
# 5000/5000 [==============================] - 1311s 262ms/step - loss: 0.1070 - binary_accuracy: 0.9930 - val_loss: 7.3443 - val_binary_accuracy: 0.7480
# Run:  2 / Accuracy at epoch  19  is:  0.7480000257492065
#
# Accuracies over epochs: [0.5174000263214111, 0.7477999925613403, 0.7224000096321106, 0.7983999848365784, 0.8203999996185303, 0.8420000076293945, 0.8330000042915344, 0.8434000015258789, 0.821399986743927, 0.8353999853134155, 0.8091999888420105, 0.796999990940094, 0.7590000033378601, 0.7462000250816345, 0.7657999992370605, 0.7071999907493591, 0.771399974822998, 0.7746000289916992, 0.8112000226974487, 0.7480000257492065]
#
#
# 5000/5000 [==============================] - 1314s 261ms/step - loss: 0.7053 - binary_accuracy: 0.4980 - val_loss: 0.6932 - val_binary_accuracy: 0.5014
# Run:  3 / Accuracy at epoch  0  is:  0.5013999938964844
#
# 5000/5000 [==============================] - 1320s 263ms/step - loss: 0.6964 - binary_accuracy: 0.4924 - val_loss: 0.6932 - val_binary_accuracy: 0.5122
# Run:  3 / Accuracy at epoch  1  is:  0.5121999979019165
#
# 5000/5000 [==============================] - 1324s 264ms/step - loss: 0.6954 - binary_accuracy: 0.5416 - val_loss: 0.6673 - val_binary_accuracy: 0.6072
# Run:  3 / Accuracy at epoch  2  is:  0.607200026512146
#
# 5000/5000 [==============================] - 1312s 262ms/step - loss: 0.6517 - binary_accuracy: 0.6624 - val_loss: 0.5484 - val_binary_accuracy: 0.7390
# Run:  3 / Accuracy at epoch  3  is:  0.7390000224113464
#
# 5000/5000 [==============================] - 1310s 261ms/step - loss: 0.5840 - binary_accuracy: 0.7664 - val_loss: 0.5353 - val_binary_accuracy: 0.8128
# Run:  3 / Accuracy at epoch  4  is:  0.8127999901771545
#
# 5000/5000 [==============================] - 1311s 262ms/step - loss: 0.5000 - binary_accuracy: 0.8290 - val_loss: 0.6705 - val_binary_accuracy: 0.8284
# Run:  3 / Accuracy at epoch  5  is:  0.8284000158309937
#
# 5000/5000 [==============================] - 1322s 264ms/step - loss: 0.4236 - binary_accuracy: 0.8742 - val_loss: 0.5232 - val_binary_accuracy: 0.8426
# Run:  3 / Accuracy at epoch  6  is:  0.8425999879837036
#
# 5000/5000 [==============================] - 1341s 268ms/step - loss: 0.3723 - binary_accuracy: 0.9050 - val_loss: 0.6182 - val_binary_accuracy: 0.8336
# Run:  3 / Accuracy at epoch  7  is:  0.8335999846458435
#
# 5000/5000 [==============================] - 1328s 265ms/step - loss: 0.3273 - binary_accuracy: 0.9210 - val_loss: 0.7771 - val_binary_accuracy: 0.8372
# Run:  3 / Accuracy at epoch  8  is:  0.8371999859809875
#
# 5000/5000 [==============================] - 1315s 262ms/step - loss: 0.3147 - binary_accuracy: 0.9370 - val_loss: 0.8157 - val_binary_accuracy: 0.8182
# Run:  3 / Accuracy at epoch  9  is:  0.8181999921798706
#
# 5000/5000 [==============================] - 1314s 262ms/step - loss: 0.2713 - binary_accuracy: 0.9494 - val_loss: 1.1657 - val_binary_accuracy: 0.8016
# Run:  3 / Accuracy at epoch  10  is:  0.8015999794006348
#
# 5000/5000 [==============================] - 1325s 264ms/step - loss: 0.2221 - binary_accuracy: 0.9598 - val_loss: 2.1966 - val_binary_accuracy: 0.7080
# Run:  3 / Accuracy at epoch  11  is:  0.7080000042915344
#
# 5000/5000 [==============================] - 1328s 265ms/step - loss: 0.2242 - binary_accuracy: 0.9614 - val_loss: 2.3008 - val_binary_accuracy: 0.7264
# Run:  3 / Accuracy at epoch  12  is:  0.7264000177383423
#
# 5000/5000 [==============================] - 1324s 264ms/step - loss: 0.2190 - binary_accuracy: 0.9688 - val_loss: 4.0998 - val_binary_accuracy: 0.6588
# Run:  3 / Accuracy at epoch  13  is:  0.6588000059127808
#
# 5000/5000 [==============================] - 1317s 263ms/step - loss: 0.2485 - binary_accuracy: 0.9710 - val_loss: 1.8065 - val_binary_accuracy: 0.7810
# Run:  3 / Accuracy at epoch  14  is:  0.781000018119812
#
# 5000/5000 [==============================] - 1310s 261ms/step - loss: 0.2142 - binary_accuracy: 0.9756 - val_loss: 2.7192 - val_binary_accuracy: 0.7316
# Run:  3 / Accuracy at epoch  15  is:  0.7315999865531921
#
# 5000/5000 [==============================] - 1313s 262ms/step - loss: 0.1903 - binary_accuracy: 0.9804 - val_loss: 4.1669 - val_binary_accuracy: 0.7182
# Run:  3 / Accuracy at epoch  16  is:  0.7182000279426575
#
# 5000/5000 [==============================] - ETA: 0s - loss: 0.2332 - binary_accuracy: 0.9794
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Input In [10], in <cell line: 8>()
#      33 model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer=opt, metrics=tf.metrics.BinaryAccuracy(threshold=0.0))
#      35 for epoch in range (0,num_epochs_per_run):
# ---> 36     history = model.fit(
#      37       train_ds,
#      38       validation_data = test_ds,
#      39       epochs=1,
#      40       shuffle=False,
#      41       # Comment the following line to do not save and download the model.
#      42       #callbacks=[callbacks]
#      43       )
#      44     accuracy = history.history['val_binary_accuracy']
#      45     print("Run: ",run,"/ Accuracy at epoch ",epoch," is: ", accuracy[0],"\n")
#
# File ~\.conda\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\.conda\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InternalError: Graph execution error:
#
# Failed to call ThenRnnForward with model config: [rnn_mode, rnn_input_mode, rnn_direction_mode]: 2, 0, 0 , [num_layers, input_size, num_units, dir_count, max_seq_length, batch_size, cell_num_units]: [1, 100, 64, 1, 2502, 1, 64]
# 	 [[{{node CudnnRNN}}]]
# 	 [[sequential_52/bidirectional_84/backward_lstm_84/PartitionedCall]] [Op:__inference_test_function_37391391]

# %% [markdown]
# ## Now show compact results in a table.

# %%
print(" PREPRO FUNCTION    |  Test Accuracy   |",end = '')

print("\n")
for prepro_func in prepro_functions_dict_comb:
  #print(prepro_func,"\t\t\t",format(round(model_results[prepro_func][0],4),'.4f'),"\t\t",end='')
  result = format(round(model_results[prepro_func][0],4),'.4f')
  print(f'{prepro_func:27}{ result :12}')
  print("\n")
