# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/text_preprocessing_impact/blob/main/IMDB_DS/CNN_IMDB_TextPreProImpact_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances.
# - - -
# CNN ON IMDB DS EXPERIMENTS NOTEBOOK
# - - -
# Convolutional Neural Network on Internet Movie Database Dataset.
# Code by M. Siino.
#
# From the paper: "Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances." by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf
import nltk
import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from sklearn.linear_model import LogisticRegression
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer
from textblob import TextBlob
nltk.download('stopwords')
nltk.download('punkt')

os.environ['TF_CUDNN_DETERMINISTIC']='false'
os.environ['TF_DETERMINISTIC_OPS']='false'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

dataset = tf.keras.utils.get_file("aclImdb_v1", url,
                                    untar=True, cache_dir='.',
                                    cache_subdir='')

dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')

train_set_dir = os.path.join(dataset_dir, 'train')
test_set_dir = os.path.join(dataset_dir, 'test')

remove_dir = os.path.join(train_set_dir, 'unsup')
shutil.rmtree(remove_dir)

# %% [markdown]
# ## Generate training and test set.

# %%
# Generate full randomized training set.
batch_size = 1
seed = 1

train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train', 
    batch_size=batch_size,
    shuffle=False,
    seed=seed
    )

test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/test', 
    batch_size=batch_size,
    shuffle=False,
    seed=seed
    )

train_ds = train_ds.shuffle(25000,seed=1,reshuffle_each_iteration = False)
test_ds = test_ds.shuffle(25000,seed=1,reshuffle_each_iteration = False)

train_ds = train_ds.take(5000)
test_ds = test_ds.take(5000)

train_ds_size=len(train_ds)
test_ds_size=len(test_ds)
# Out:
# Found 25000 files belonging to 2 classes.
# Found 25000 files belonging to 2 classes.

# %% [markdown]
# ## Functions to pre-process source text. (A detailed discussion on our paper)

# %%
# Do-Nothing preprocessing function.
def DON(input_data):
  tag_open_CDATA_removed = tf.strings.regex_replace(input_data, '<\!\[CDATA\[', ' ')
  tag_closed_CDATA_removed = tf.strings.regex_replace(tag_open_CDATA_removed,'\]{1,}>', ' ')
  tag_author_lang_en_removed = tf.strings.regex_replace(tag_closed_CDATA_removed,'<author lang="en">', ' ')
  tag_closed_author_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'</author>', ' ')
  tag_open_documents_removed = tf.strings.regex_replace(tag_closed_author_removed,'<documents>\n(\t){0,2}', '')
  output_data = tf.strings.regex_replace(tag_open_documents_removed,'</documents>\n(\t){0,2}', ' ')
  return output_data

# Lowercasing preprocessing function.
def LOW(input_data):  
  return tf.strings.lower(DON(input_data))

# Removing Stop Words function.
def RSW(input_data):
  output_data = DON(input_data)

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:

      # input_string = input_string.numpy() [0]
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("Tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# Porter Stemmer preprocessing function.
def STM(input_data):
  output_data = DON(input_data)
  stemmer = PorterStemmer()

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      #print(input_string)
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:
      #input_string = input_string.numpy()[0]
      input_string = input_string.numpy()
      #print(input_string)
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# %% [markdown]
# ## Define the combined preprocessing functions. (The base functions are: DON, LOW, RSW and STM).

# %%
## SECTION WITH PAIRS OF PREPRO FUNCTIONS. APPLICATION ORDER MATTERS (...IN FOLLOWING SECTIONS TOO).
#...5
def LOW_RSW(input_data):
  return RSW(LOW(input_data))

# 6
def LOW_STM(input_data):
  return STM(LOW(input_data))

# 7
def RSW_LOW(input_data):
  return LOW(RSW(input_data))

# 8
def RSW_STM(input_data):
  return STM(RSW(input_data))

# 9
def STM_LOW(input_data):
  return LOW(STM(input_data))

# 10
def STM_RSW(input_data):
  return RSW(STM(input_data))
  
# 11
def LOW_STM_RSW(input_data):
  return RSW(STM(LOW(input_data)))

# 12
def LOW_RSW_STM(input_data):
  return STM(RSW(LOW(input_data)))

# 13
def STM_LOW_RSW(input_data):
  return RSW(LOW(STM(input_data)))

# 14
def STM_RSW_LOW(input_data):
  return LOW(RSW(STM(input_data)))

# 15
def RSW_LOW_STM(input_data):
  return STM(LOW(RSW(input_data)))

# 16
def RSW_STM_LOW(input_data):
  return LOW(STM(RSW(input_data)))

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(preprocessing_function,training_set):
  # Set a large sequence length to find the longest sample in the training set.
  sequence_length = 3000
  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    out=model(authorDocument)
    # Convert token list to numpy array.
    token_list = out.numpy()[0]
    token_list = np.trim_zeros(token_list,'b')
    if longest_sample_length < len(token_list):
      longest_sample_length = len(token_list)

  print("Length of the longest sample is:", longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Define a dictionary with -> function_names:prepro_function_caller. And a dictionary to store model results.

# %%
model_results = {}
prepro_functions_dict_base = {
    'DON':DON,
    'LOW':LOW,
    'RSW':RSW,
    'STM':STM
    }

# 3 prepro functions = 15 combs...+1 for do_nothing

prepro_functions_dict_comb = {
    # 1. Do nothing 
    'DON': DON,
    # 2. Lowercasing 
    'LOW':LOW,
    # 3. Removing Stopwords
    'RSW':RSW, 
    # 4. Porter Stemming
    'STM':STM,
    # 5. LOW->RSW
    'LOW_RSW':LOW_RSW, 
    # 6. LOW->STM
    'LOW_STM':LOW_STM,
    # 7. RSW->LOW
    'RSW_LOW':RSW_LOW,
    # 8. RSW->STM
    'RSW_STM':RSW_STM,
    # 9. STM->LOW
    'STM_LOW':STM_LOW,
    # 10. STM->RSW
    'STM_RSW':STM_RSW,
    # 11. LOW->STM->RSW
    'LOW_STM_RSW':LOW_STM_RSW,  
    # 12. LOW->RSW->STM
    'LOW_RSW_STM':LOW_RSW_STM,
    # 13. STM->LOW->RSW
    'STM_LOW_RSW':STM_LOW_RSW,
    # 14. STM->RSW->LOW
    'STM_RSW_LOW':STM_RSW_LOW,
    # 15. RSW->LOW->STM
    'RSW_LOW_STM':RSW_LOW_STM,
    # 16. RSW->STM->LOW
    'RSW_STM_LOW':RSW_STM_LOW
}

for key in prepro_functions_dict_comb:
  print(key)
  model_results[key]=[]
# Out:
# DON
# LOW
# RSW
# STM
# LOW_RSW
# LOW_STM
# RSW_LOW
# RSW_STM
# STM_LOW
# STM_RSW
# LOW_STM_RSW
# LOW_RSW_STM
# STM_LOW_RSW
# STM_RSW_LOW
# RSW_LOW_STM
# RSW_STM_LOW

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Models definition and evaluation.

# %%
tf.random.set_seed(0)
TF_DISABLE_SEGMENT_REDUCTION_OP_DETERMINISM_EXCEPTIONS=True

# Reset model_results list.
for key in prepro_functions_dict_comb:
  model_results[key]=[]

for key in prepro_functions_dict_comb:
  runs_accuracy = []

  print("\n\n* * * * EVALUATION USING", key, "AS PREPROCESSING FUNCTION * * * *")

  # Preprocess training set to build a dictionary.
  vectorize_layer = preprocess_and_adapt_ts(prepro_functions_dict_comb[key],train_ds)

  max_features=len(vectorize_layer.get_vocabulary()) + 1
  print("Vocabulary size is:", max_features)

  for run in range(1,(num_runs+1)):
    epochs_accuracy=[]
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    layers.Conv1D(256,16,activation='relu'),
                                    layers.MaxPooling1D(),
                                    layers.Dropout(0.6),

                                    layers.Dense(512,activation='relu'),
                           
                                    layers.GlobalAveragePooling1D(),
                                    layers.Dropout(0.2),
                                    layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer=opt, metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        print("Run: ",run,"/ Accuracy at epoch ",epoch," is: ", accuracy[0],"\n")
        epochs_accuracy.append(accuracy[0])

    print("Accuracies over epochs:",epochs_accuracy,"\n\n")
    runs_accuracy.append(max(epochs_accuracy))

  runs_accuracy.sort()
  print("\n\n Over all runs maximum accuracies are:", runs_accuracy)
  print("The median is:",runs_accuracy[2],"\n\n\n")
  
  if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
    max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
  else:
    max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
  final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
  model_results[key].append(final_result)
  print("CNN Accuracy Score on Test set -> ",model_results[key])
# Out:
# Streaming output truncated to the last 5000 lines.
# 5000/5000 [==============================] - 72s 14ms/step - loss: 0.2499 - binary_accuracy: 0.9332 - val_loss: 0.5835 - val_binary_accuracy: 0.8564
# Run:  4 / Accuracy at epoch  18  is:  0.8564000129699707
#
# 5000/5000 [==============================] - 72s 14ms/step - loss: 0.2548 - binary_accuracy: 0.9344 - val_loss: 0.7869 - val_binary_accuracy: 0.8298
# Run:  4 / Accuracy at epoch  19  is:  0.829800009727478
#
# Accuracies over epochs: [0.7688000202178955, 0.8155999779701233, 0.803600013256073, 0.8263999819755554, 0.8342000246047974, 0.8155999779701233, 0.8230000138282776, 0.8325999975204468, 0.8374000191688538, 0.8367999792098999, 0.8500000238418579, 0.8489999771118164, 0.847599983215332, 0.8550000190734863, 0.8537999987602234, 0.8507999777793884, 0.8551999926567078, 0.8485999703407288, 0.8564000129699707, 0.829800009727478]
#
#
# 5000/5000 [==============================] - 72s 14ms/step - loss: 0.6568 - binary_accuracy: 0.6550 - val_loss: 0.5171 - val_binary_accuracy: 0.7712
# Run:  5 / Accuracy at epoch  0  is:  0.7712000012397766
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.5058 - binary_accuracy: 0.8086 - val_loss: 0.4634 - val_binary_accuracy: 0.8182
# Run:  5 / Accuracy at epoch  1  is:  0.8181999921798706
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.4483 - binary_accuracy: 0.8490 - val_loss: 0.4946 - val_binary_accuracy: 0.8180
# Run:  5 / Accuracy at epoch  2  is:  0.8180000185966492
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.4118 - binary_accuracy: 0.8628 - val_loss: 0.5190 - val_binary_accuracy: 0.8248
# Run:  5 / Accuracy at epoch  3  is:  0.8248000144958496
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.3805 - binary_accuracy: 0.8774 - val_loss: 0.6176 - val_binary_accuracy: 0.8170
# Run:  5 / Accuracy at epoch  4  is:  0.8169999718666077
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.3663 - binary_accuracy: 0.8834 - val_loss: 0.6273 - val_binary_accuracy: 0.8188
# Run:  5 / Accuracy at epoch  5  is:  0.8187999725341797
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.3585 - binary_accuracy: 0.8862 - val_loss: 0.6391 - val_binary_accuracy: 0.8176
# Run:  5 / Accuracy at epoch  6  is:  0.8176000118255615
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.3337 - binary_accuracy: 0.8960 - val_loss: 0.6993 - val_binary_accuracy: 0.8192
# Run:  5 / Accuracy at epoch  7  is:  0.8191999793052673
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.3292 - binary_accuracy: 0.9032 - val_loss: 0.5567 - val_binary_accuracy: 0.8416
# Run:  5 / Accuracy at epoch  8  is:  0.8416000008583069
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.3239 - binary_accuracy: 0.9030 - val_loss: 0.5424 - val_binary_accuracy: 0.8428
# Run:  5 / Accuracy at epoch  9  is:  0.8428000211715698
#
# 5000/5000 [==============================] - 72s 14ms/step - loss: 0.3055 - binary_accuracy: 0.9032 - val_loss: 0.5238 - val_binary_accuracy: 0.8482
# Run:  5 / Accuracy at epoch  10  is:  0.8482000231742859
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2924 - binary_accuracy: 0.9110 - val_loss: 0.5615 - val_binary_accuracy: 0.8454
# Run:  5 / Accuracy at epoch  11  is:  0.8453999757766724
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2878 - binary_accuracy: 0.9130 - val_loss: 0.5420 - val_binary_accuracy: 0.8502
# Run:  5 / Accuracy at epoch  12  is:  0.8501999974250793
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2823 - binary_accuracy: 0.9180 - val_loss: 0.5374 - val_binary_accuracy: 0.8554
# Run:  5 / Accuracy at epoch  13  is:  0.855400025844574
#
# 5000/5000 [==============================] - 72s 14ms/step - loss: 0.2640 - binary_accuracy: 0.9234 - val_loss: 0.5361 - val_binary_accuracy: 0.8538
# Run:  5 / Accuracy at epoch  14  is:  0.8537999987602234
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2638 - binary_accuracy: 0.9294 - val_loss: 0.6038 - val_binary_accuracy: 0.8474
# Run:  5 / Accuracy at epoch  15  is:  0.8474000096321106
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2628 - binary_accuracy: 0.9322 - val_loss: 0.5837 - val_binary_accuracy: 0.8536
# Run:  5 / Accuracy at epoch  16  is:  0.853600025177002
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2577 - binary_accuracy: 0.9340 - val_loss: 0.6870 - val_binary_accuracy: 0.8332
# Run:  5 / Accuracy at epoch  17  is:  0.8331999778747559
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2500 - binary_accuracy: 0.9396 - val_loss: 0.7041 - val_binary_accuracy: 0.8452
# Run:  5 / Accuracy at epoch  18  is:  0.8452000021934509
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2538 - binary_accuracy: 0.9412 - val_loss: 0.9296 - val_binary_accuracy: 0.8172
# Run:  5 / Accuracy at epoch  19  is:  0.8172000050544739
#
# Accuracies over epochs: [0.7712000012397766, 0.8181999921798706, 0.8180000185966492, 0.8248000144958496, 0.8169999718666077, 0.8187999725341797, 0.8176000118255615, 0.8191999793052673, 0.8416000008583069, 0.8428000211715698, 0.8482000231742859, 0.8453999757766724, 0.8501999974250793, 0.855400025844574, 0.8537999987602234, 0.8474000096321106, 0.853600025177002, 0.8331999778747559, 0.8452000021934509, 0.8172000050544739]
#
#
#
#
#  Over all runs maximum accuracies are: [0.8537999987602234, 0.855400025844574, 0.8564000129699707, 0.8564000129699707, 0.857200026512146]
# The median is: 0.8564000129699707
#
#
#
# CNN Accuracy Score on Test set ->  ['0.8564000129699707 +/- 0.0026000142097473145']
#
#
# * * * * EVALUATION USING LOW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 2470
# Vocabulary size is: 94013
# 5000/5000 [==============================] - 71s 13ms/step - loss: 0.6412 - binary_accuracy: 0.6742 - val_loss: 0.5569 - val_binary_accuracy: 0.7612
# Run:  1 / Accuracy at epoch  0  is:  0.7612000107765198
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.4976 - binary_accuracy: 0.8106 - val_loss: 0.4560 - val_binary_accuracy: 0.8174
# Run:  1 / Accuracy at epoch  1  is:  0.8173999786376953
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.4451 - binary_accuracy: 0.8490 - val_loss: 0.6091 - val_binary_accuracy: 0.8004
# Run:  1 / Accuracy at epoch  2  is:  0.8004000186920166
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.4092 - binary_accuracy: 0.8688 - val_loss: 0.5353 - val_binary_accuracy: 0.8224
# Run:  1 / Accuracy at epoch  3  is:  0.8223999738693237
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.3986 - binary_accuracy: 0.8734 - val_loss: 0.5683 - val_binary_accuracy: 0.8278
# Run:  1 / Accuracy at epoch  4  is:  0.8277999758720398
#
# 5000/5000 [==============================] - 72s 14ms/step - loss: 0.3776 - binary_accuracy: 0.8834 - val_loss: 0.7247 - val_binary_accuracy: 0.8068
# Run:  1 / Accuracy at epoch  5  is:  0.8068000078201294
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.3655 - binary_accuracy: 0.8912 - val_loss: 0.7141 - val_binary_accuracy: 0.8130
# Run:  1 / Accuracy at epoch  6  is:  0.8130000233650208
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.3160 - binary_accuracy: 0.9078 - val_loss: 0.5819 - val_binary_accuracy: 0.8412
# Run:  5 / Accuracy at epoch  10  is:  0.8411999940872192
#
# 5000/5000 [==============================] - 71s 13ms/step - loss: 0.3050 - binary_accuracy: 0.9100 - val_loss: 0.5613 - val_binary_accuracy: 0.8460
# Run:  5 / Accuracy at epoch  11  is:  0.8460000157356262
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.2983 - binary_accuracy: 0.9144 - val_loss: 0.5579 - val_binary_accuracy: 0.8522
# Run:  5 / Accuracy at epoch  12  is:  0.8521999716758728
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.3025 - binary_accuracy: 0.9194 - val_loss: 0.5513 - val_binary_accuracy: 0.8540
# Run:  5 / Accuracy at epoch  13  is:  0.8539999723434448
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2845 - binary_accuracy: 0.9190 - val_loss: 0.5430 - val_binary_accuracy: 0.8528
# Run:  5 / Accuracy at epoch  14  is:  0.8528000116348267
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.2791 - binary_accuracy: 0.9252 - val_loss: 0.5709 - val_binary_accuracy: 0.8538
# Run:  5 / Accuracy at epoch  15  is:  0.8537999987602234
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2736 - binary_accuracy: 0.9296 - val_loss: 0.5911 - val_binary_accuracy: 0.8576
# Run:  5 / Accuracy at epoch  16  is:  0.8575999736785889
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.2724 - binary_accuracy: 0.9342 - val_loss: 0.6935 - val_binary_accuracy: 0.8508
# Run:  5 / Accuracy at epoch  17  is:  0.8507999777793884
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.2645 - binary_accuracy: 0.9346 - val_loss: 0.5798 - val_binary_accuracy: 0.8570
# Run:  5 / Accuracy at epoch  18  is:  0.8569999933242798
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2534 - binary_accuracy: 0.9378 - val_loss: 0.7817 - val_binary_accuracy: 0.8366
# Run:  5 / Accuracy at epoch  19  is:  0.8366000056266785
#
# Accuracies over epochs: [0.7635999917984009, 0.821399986743927, 0.7990000247955322, 0.8209999799728394, 0.8266000151634216, 0.8109999895095825, 0.8245999813079834, 0.8256000280380249, 0.8321999907493591, 0.8307999968528748, 0.8411999940872192, 0.8460000157356262, 0.8521999716758728, 0.8539999723434448, 0.8528000116348267, 0.8537999987602234, 0.8575999736785889, 0.8507999777793884, 0.8569999933242798, 0.8366000056266785]
#
#
#
#
#  Over all runs maximum accuracies are: [0.8533999919891357, 0.8560000061988831, 0.8574000000953674, 0.8574000000953674, 0.8575999736785889]
# The median is: 0.8574000000953674
#
#
#
# CNN Accuracy Score on Test set ->  ['0.8574000000953674 +/- 0.0040000081062316895']
#
#
# * * * * EVALUATION USING RSW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 1540
# Vocabulary size is: 103029
# 5000/5000 [==============================] - 71s 13ms/step - loss: 0.6332 - binary_accuracy: 0.6758 - val_loss: 0.5763 - val_binary_accuracy: 0.7492
# Run:  1 / Accuracy at epoch  0  is:  0.7491999864578247
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.4935 - binary_accuracy: 0.8154 - val_loss: 0.5178 - val_binary_accuracy: 0.8052
# Run:  1 / Accuracy at epoch  1  is:  0.8051999807357788
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.4456 - binary_accuracy: 0.8472 - val_loss: 0.5049 - val_binary_accuracy: 0.8188
# Run:  1 / Accuracy at epoch  2  is:  0.8187999725341797
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.2875 - binary_accuracy: 0.9238 - val_loss: 0.5597 - val_binary_accuracy: 0.8460
# Run:  3 / Accuracy at epoch  14  is:  0.8460000157356262
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.2651 - binary_accuracy: 0.9280 - val_loss: 0.5707 - val_binary_accuracy: 0.8524
# Run:  3 / Accuracy at epoch  15  is:  0.852400004863739
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.2686 - binary_accuracy: 0.9310 - val_loss: 0.6030 - val_binary_accuracy: 0.8504
# Run:  3 / Accuracy at epoch  16  is:  0.8503999710083008
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2529 - binary_accuracy: 0.9334 - val_loss: 0.6945 - val_binary_accuracy: 0.8406
# Run:  3 / Accuracy at epoch  17  is:  0.8406000137329102
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2503 - binary_accuracy: 0.9340 - val_loss: 0.6412 - val_binary_accuracy: 0.8504
# Run:  3 / Accuracy at epoch  18  is:  0.8503999710083008
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2403 - binary_accuracy: 0.9394 - val_loss: 0.8711 - val_binary_accuracy: 0.8320
# Run:  3 / Accuracy at epoch  19  is:  0.8320000171661377
#
# Accuracies over epochs: [0.7603999972343445, 0.7748000025749207, 0.795199990272522, 0.7936000227928162, 0.8131999969482422, 0.8116000294685364, 0.8223999738693237, 0.8162000179290771, 0.8223999738693237, 0.847000002861023, 0.8482000231742859, 0.8479999899864197, 0.8529999852180481, 0.8533999919891357, 0.8460000157356262, 0.852400004863739, 0.8503999710083008, 0.8406000137329102, 0.8503999710083008, 0.8320000171661377]
#
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.6287 - binary_accuracy: 0.6814 - val_loss: 0.6022 - val_binary_accuracy: 0.7456
# Run:  4 / Accuracy at epoch  0  is:  0.7455999851226807
#
# 5000/5000 [==============================] - 68s 13ms/step - loss: 0.4884 - binary_accuracy: 0.8134 - val_loss: 0.4794 - val_binary_accuracy: 0.8124
# Run:  4 / Accuracy at epoch  1  is:  0.8123999834060669
#
# 5000/5000 [==============================] - 68s 13ms/step - loss: 0.4396 - binary_accuracy: 0.8464 - val_loss: 0.6014 - val_binary_accuracy: 0.8012
# Run:  4 / Accuracy at epoch  2  is:  0.8011999726295471
#
# 5000/5000 [==============================] - 68s 13ms/step - loss: 0.4162 - binary_accuracy: 0.8666 - val_loss: 0.6338 - val_binary_accuracy: 0.8066
# Run:  4 / Accuracy at epoch  3  is:  0.8065999746322632
#
# 5000/5000 [==============================] - 68s 13ms/step - loss: 0.3859 - binary_accuracy: 0.8782 - val_loss: 0.5922 - val_binary_accuracy: 0.8168
# Run:  4 / Accuracy at epoch  4  is:  0.8167999982833862
#
# 5000/5000 [==============================] - 68s 13ms/step - loss: 0.3543 - binary_accuracy: 0.8828 - val_loss: 0.6546 - val_binary_accuracy: 0.8168
# Run:  4 / Accuracy at epoch  5  is:  0.8167999982833862
#
# 5000/5000 [==============================] - 68s 13ms/step - loss: 0.3539 - binary_accuracy: 0.8924 - val_loss: 0.5625 - val_binary_accuracy: 0.8346
# Run:  4 / Accuracy at epoch  6  is:  0.8345999717712402
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.3422 - binary_accuracy: 0.8994 - val_loss: 0.7485 - val_binary_accuracy: 0.8104
# Run:  4 / Accuracy at epoch  7  is:  0.8104000091552734
#
# 5000/5000 [==============================] - 68s 13ms/step - loss: 0.3275 - binary_accuracy: 0.8982 - val_loss: 0.5720 - val_binary_accuracy: 0.8380
# Run:  4 / Accuracy at epoch  8  is:  0.8379999995231628
#
# 5000/5000 [==============================] - 68s 13ms/step - loss: 0.3091 - binary_accuracy: 0.9058 - val_loss: 0.6636 - val_binary_accuracy: 0.8318
# Run:  4 / Accuracy at epoch  9  is:  0.8317999839782715
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.3234 - binary_accuracy: 0.9100 - val_loss: 0.5395 - val_binary_accuracy: 0.8454
# Run:  4 / Accuracy at epoch  10  is:  0.8453999757766724
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.3019 - binary_accuracy: 0.9148 - val_loss: 0.5481 - val_binary_accuracy: 0.8440
# Run:  4 / Accuracy at epoch  11  is:  0.843999981880188
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.2903 - binary_accuracy: 0.9148 - val_loss: 0.5149 - val_binary_accuracy: 0.8500
# Run:  4 / Accuracy at epoch  12  is:  0.8500000238418579
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.2885 - binary_accuracy: 0.9154 - val_loss: 0.5107 - val_binary_accuracy: 0.8516
# Run:  4 / Accuracy at epoch  13  is:  0.8515999913215637
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.2861 - binary_accuracy: 0.9226 - val_loss: 0.6229 - val_binary_accuracy: 0.8396
# Run:  4 / Accuracy at epoch  14  is:  0.8396000266075134
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.2647 - binary_accuracy: 0.9292 - val_loss: 0.5650 - val_binary_accuracy: 0.8496
# Run:  4 / Accuracy at epoch  15  is:  0.8496000170707703
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.2700 - binary_accuracy: 0.9274 - val_loss: 0.5732 - val_binary_accuracy: 0.8552
# Run:  4 / Accuracy at epoch  16  is:  0.8551999926567078
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.2672 - binary_accuracy: 0.9300 - val_loss: 0.6465 - val_binary_accuracy: 0.8512
# Run:  4 / Accuracy at epoch  17  is:  0.8511999845504761
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.2610 - binary_accuracy: 0.9326 - val_loss: 0.6044 - val_binary_accuracy: 0.8522
# Run:  4 / Accuracy at epoch  18  is:  0.8521999716758728
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.2418 - binary_accuracy: 0.9370 - val_loss: 0.7670 - val_binary_accuracy: 0.8430
# Run:  4 / Accuracy at epoch  19  is:  0.8429999947547913
#
# Accuracies over epochs: [0.7455999851226807, 0.8123999834060669, 0.8011999726295471, 0.8065999746322632, 0.8167999982833862, 0.8167999982833862, 0.8345999717712402, 0.8104000091552734, 0.8379999995231628, 0.8317999839782715, 0.8453999757766724, 0.843999981880188, 0.8500000238418579, 0.8515999913215637, 0.8396000266075134, 0.8496000170707703, 0.8551999926567078, 0.8511999845504761, 0.8521999716758728, 0.8429999947547913]
#
#
# 5000/5000 [==============================] - 83s 16ms/step - loss: 0.6477 - binary_accuracy: 0.6664 - val_loss: 0.5596 - val_binary_accuracy: 0.7544
# Run:  5 / Accuracy at epoch  0  is:  0.7544000148773193
#
# 5000/5000 [==============================] - 81s 13ms/step - loss: 0.4940 - binary_accuracy: 0.8116 - val_loss: 0.5970 - val_binary_accuracy: 0.7762
# Run:  5 / Accuracy at epoch  1  is:  0.776199996471405
#
# 5000/5000 [==============================] - 68s 13ms/step - loss: 0.4454 - binary_accuracy: 0.8468 - val_loss: 0.5607 - val_binary_accuracy: 0.8032
# ...
# Run:  2 / Accuracy at epoch  12  is:  0.8519999980926514
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.3027 - binary_accuracy: 0.9138 - val_loss: 0.5400 - val_binary_accuracy: 0.8544
# Run:  2 / Accuracy at epoch  13  is:  0.8543999791145325
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.2844 - binary_accuracy: 0.9204 - val_loss: 0.5529 - val_binary_accuracy: 0.8552
# Run:  2 / Accuracy at epoch  14  is:  0.8551999926567078
#
# 5000/5000 [==============================] - 70s 14ms/step - loss: 0.2873 - binary_accuracy: 0.9226 - val_loss: 0.5325 - val_binary_accuracy: 0.8526
# Run:  2 / Accuracy at epoch  15  is:  0.8525999784469604
#
# 5000/5000 [==============================] - 70s 14ms/step - loss: 0.2837 - binary_accuracy: 0.9268 - val_loss: 0.5447 - val_binary_accuracy: 0.8564
# Run:  2 / Accuracy at epoch  16  is:  0.8564000129699707
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.2867 - binary_accuracy: 0.9300 - val_loss: 0.6935 - val_binary_accuracy: 0.8438
# Run:  2 / Accuracy at epoch  17  is:  0.8438000082969666
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.2774 - binary_accuracy: 0.9304 - val_loss: 0.5703 - val_binary_accuracy: 0.8582
# Run:  2 / Accuracy at epoch  18  is:  0.8582000136375427
#
# 5000/5000 [==============================] - 71s 13ms/step - loss: 0.2738 - binary_accuracy: 0.9340 - val_loss: 0.7305 - val_binary_accuracy: 0.8478
# Run:  2 / Accuracy at epoch  19  is:  0.8478000164031982
#
# Accuracies over epochs: [0.7405999898910522, 0.79339998960495, 0.7991999983787537, 0.8055999875068665, 0.8187999725341797, 0.8082000017166138, 0.8385999798774719, 0.8370000123977661, 0.8360000252723694, 0.8339999914169312, 0.840399980545044, 0.8496000170707703, 0.8519999980926514, 0.8543999791145325, 0.8551999926567078, 0.8525999784469604, 0.8564000129699707, 0.8438000082969666, 0.8582000136375427, 0.8478000164031982]
#
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.6313 - binary_accuracy: 0.6684 - val_loss: 0.6275 - val_binary_accuracy: 0.7284
# Run:  3 / Accuracy at epoch  0  is:  0.7283999919891357
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.4878 - binary_accuracy: 0.8180 - val_loss: 0.7513 - val_binary_accuracy: 0.7542
# Run:  3 / Accuracy at epoch  1  is:  0.7541999816894531
#
# 5000/5000 [==============================] - 70s 14ms/step - loss: 0.4436 - binary_accuracy: 0.8474 - val_loss: 0.6061 - val_binary_accuracy: 0.7990
# Run:  3 / Accuracy at epoch  2  is:  0.7990000247955322
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.4154 - binary_accuracy: 0.8658 - val_loss: 0.6642 - val_binary_accuracy: 0.8078
# Run:  3 / Accuracy at epoch  3  is:  0.8077999949455261
#
# 5000/5000 [==============================] - 71s 14ms/step - loss: 0.3936 - binary_accuracy: 0.8768 - val_loss: 0.7309 - val_binary_accuracy: 0.7978
# Run:  3 / Accuracy at epoch  4  is:  0.7978000044822693
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.3727 - binary_accuracy: 0.8870 - val_loss: 0.6585 - val_binary_accuracy: 0.8214
# Run:  3 / Accuracy at epoch  5  is:  0.821399986743927
#
# 5000/5000 [==============================] - 70s 14ms/step - loss: 0.3557 - binary_accuracy: 0.8886 - val_loss: 0.6020 - val_binary_accuracy: 0.8294
# Run:  3 / Accuracy at epoch  6  is:  0.8294000029563904
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.3425 - binary_accuracy: 0.8986 - val_loss: 0.6123 - val_binary_accuracy: 0.8320
# Run:  3 / Accuracy at epoch  7  is:  0.8320000171661377
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.
# Accuracies over epochs: [0.7221999764442444, 0.8041999936103821, 0.8065999746322632, 0.8339999914169312, 0.8116000294685364, 0.8234000205993652, 0.8209999799728394, 0.8140000104904175, 0.8356000185012817, 0.8420000076293945, 0.8392000198364258, 0.8434000015258789, 0.8546000123023987, 0.853600025177002, 0.8569999933242798, 0.854200005531311, 0.854200005531311, 0.854200005531311, 0.8452000021934509, 0.8406000137329102]
#
#
# 5000/5000 [==============================] - 71s 13ms/step - loss: 0.6216 - binary_accuracy: 0.6750 - val_loss: 0.5636 - val_binary_accuracy: 0.7564
# Run:  5 / Accuracy at epoch  0  is:  0.7563999891281128
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.4965 - binary_accuracy: 0.8168 - val_loss: 0.4943 - val_binary_accuracy: 0.8120
# Run:  5 / Accuracy at epoch  1  is:  0.8119999766349792
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.4518 - binary_accuracy: 0.8452 - val_loss: 0.5461 - val_binary_accuracy: 0.8110
# Run:  5 / Accuracy at epoch  2  is:  0.8109999895095825
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.4226 - binary_accuracy: 0.8614 - val_loss: 0.6023 - val_binary_accuracy: 0.8138
# Run:  5 / Accuracy at epoch  3  is:  0.8137999773025513
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.4047 - binary_accuracy: 0.8698 - val_loss: 0.5553 - val_binary_accuracy: 0.8256
# Run:  5 / Accuracy at epoch  4  is:  0.8256000280380249
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.3782 - binary_accuracy: 0.8846 - val_loss: 0.6525 - val_binary_accuracy: 0.8196
# Run:  5 / Accuracy at epoch  5  is:  0.819599986076355
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.3662 - binary_accuracy: 0.8884 - val_loss: 0.6775 - val_binary_accuracy: 0.8164
# Run:  5 / Accuracy at epoch  6  is:  0.8163999915122986
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.3458 - binary_accuracy: 0.8924 - val_loss: 0.6803 - val_binary_accuracy: 0.8164
# Run:  5 / Accuracy at epoch  7  is:  0.8163999915122986
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.3428 - binary_accuracy: 0.8994 - val_loss: 0.6053 - val_binary_accuracy: 0.8368
# Run:  5 / Accuracy at epoch  8  is:  0.8367999792098999
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.3247 - binary_accuracy: 0.9008 - val_loss: 0.6718 - val_binary_accuracy: 0.8348
# Run:  5 / Accuracy at epoch  9  is:  0.8348000049591064
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.3303 - binary_accuracy: 0.9050 - val_loss: 0.5277 - val_binary_accuracy: 0.8504
# Run:  5 / Accuracy at epoch  10  is:  0.8503999710083008
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.3149 - binary_accuracy: 0.9122 - val_loss: 0.6225 - val_binary_accuracy: 0.8444
# Run:  5 / Accuracy at epoch  11  is:  0.8443999886512756
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.3121 - binary_accuracy: 0.9156 - val_loss: 0.5327 - val_binary_accuracy: 0.8532
# Run:  5 / Accuracy at epoch  12  is:  0.8532000184059143
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.3023 - binary_accuracy: 0.9178 - val_loss: 0.5240 - val_binary_accuracy: 0.8520
# Run:  5 / Accuracy at epoch  13  is:  0.8519999980926514
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.3023 - binary_accuracy: 0.9234 - val_loss: 0.5638 - val_binary_accuracy: 0.8550
# Run:  5 / Accuracy at epoch  14  is:  0.8550000190734863
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.2808 - binary_accuracy: 0.9238 - val_loss: 0.5333 - val_binary_accuracy: 0.8562
# Run:  5 / Accuracy at epoch  15  is:  0.8561999797821045
#
# 5000/5000 [==============================] - 70s 13ms/step - loss: 0.2850 - binary_accuracy: 0.9248 - val_loss: 0.5397 - val_binary_accuracy: 0.8566
# Run:  5 / Accuracy at epoch  16  is:  0.8565999865531921
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.2817 - binary_accuracy: 0.9290 - val_loss: 0.6384 - val_binary_accuracy: 0.8514
# Run:  5 / Accuracy at epoch  17  is:  0.8514000177383423
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.2794 - binary_accuracy: 0.9282 - val_loss: 0.5784 - val_binary_accuracy: 0.8574
# Run:  5 / Accuracy at epoch  18  is:  0.8574000000953674
#
# 5000/5000 [==============================] - 69s 13ms/step - loss: 0.2653 - binary_accuracy: 0.9358 - val_loss: 0.6684 - val_binary_accuracy: 0.8532
# Run:  5 / Accuracy at epoch  19  is:  0.8532000184059143
#
# Accuracies over epochs: [0.7563999891281128, 0.8119999766349792, 0.8109999895095825, 0.8137999773025513, 0.8256000280380249, 0.819599986076355, 0.8163999915122986, 0.8163999915122986, 0.8367999792098999, 0.8348000049591064, 0.8503999710083008, 0.8443999886512756, 0.8532000184059143, 0.8519999980926514, 0.8550000190734863, 0.8561999797821045, 0.8565999865531921, 0.8514000177383423, 0.8574000000953674, 0.8532000184059143]
#
#
#
#
#  Over all runs maximum accuracies are: [0.8533999919891357, 0.8547999858856201, 0.8569999933242798, 0.8574000000953674, 0.8582000136375427]
# The median is: 0.8569999933242798
#
#
#
# CNN Accuracy Score on Test set ->  ['0.8569999933242798 +/- 0.003600001335144043']

# %% [markdown]
# ## Now show compact results in a table.

# %%
print(" PREPRO FUNCTION    |  Test Accuracy   |",end = '')

print("\n")
for prepro_func in prepro_functions_dict_comb:
  #print(prepro_func,"\t\t\t",format(round(model_results[prepro_func][0],4),'.4f'),"\t\t",end='')
  result = model_results[prepro_func][0]
  # result = format(round(model_results[prepro_func][0],4),'.4f')
  print(f'{prepro_func:27}{ result :12}')
  print("\n")
# Out:
#  PREPRO FUNCTION    |  Test Accuracy   |
#
# DON                        0.8564000129699707 +/- 0.0026000142097473145
#
#
# LOW                        0.8574000000953674 +/- 0.0040000081062316895
#
#
# RSW                        0.8547999858856201 +/- 0.0015999674797058105
#
#
# STM                        0.8560000061988831 +/- 0.003000020980834961
#
#
# LOW_RSW                    0.8543999791145325 +/- 0.0029999613761901855
#
#
# LOW_STM                    0.8547999858856201 +/- 0.0012000203132629395
#
#
# RSW_LOW                    0.8546000123023987 +/- 0.002200007438659668
#
#
# RSW_STM                    0.8550000190734863 +/- 0.001600027084350586
#
#
# STM_LOW                    0.8539999723434448 +/- 0.0018000006675720215
#
#
# STM_RSW                    0.854200005531311 +/- 0.0023999810218811035
#
#
# LOW_STM_RSW                0.8551999926567078 +/- 0.0020000338554382324
#
#
# LOW_RSW_STM                0.8537999987602234 +/- 0.003000020980834961
#
#
# STM_LOW_RSW                0.8564000129699707 +/- 0.001399993896484375
#
#
# STM_RSW_LOW                0.8533999919891357 +/- 0.0034000277519226074
#
#
# RSW_LOW_STM                0.8550000190734863 +/- 0.0023999810218811035
#
#
# RSW_STM_LOW                0.8569999933242798 +/- 0.003600001335144043
