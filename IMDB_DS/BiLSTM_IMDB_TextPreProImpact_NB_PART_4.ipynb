# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/text_preprocessing_impact/blob/main/IMDB_DS/BiLSTM_IMDB_TextPreProImpact_NB_PART_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances.
# - - -
# BiLSTM ON IMDB DS EXPERIMENTS NOTEBOOK
# - - -
# Bidirectional Long Short-Term Memory Network on Internet Movie Database Dataset.
# Code by M. Siino.
#
# From the paper: "Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances." by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf
import nltk
import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from sklearn.linear_model import LogisticRegression
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer
from textblob import TextBlob
nltk.download('stopwords')
nltk.download('punkt')

os.environ['TF_CUDNN_DETERMINISTIC']='false'
os.environ['TF_DETERMINISTIC_OPS']='false'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

dataset = tf.keras.utils.get_file("aclImdb_v1", url,
                                    untar=True, cache_dir='.',
                                    cache_subdir='')

dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')

train_set_dir = os.path.join(dataset_dir, 'train')
test_set_dir = os.path.join(dataset_dir, 'test')

remove_dir = os.path.join(train_set_dir, 'unsup')
shutil.rmtree(remove_dir)

# %% [markdown]
# ## Generate training and test set.

# %%
# Generate full randomized training set.
batch_size = 1
seed = 1

train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train', 
    batch_size=batch_size,
    shuffle=False,
    seed=seed
    )

test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/test', 
    batch_size=batch_size,
    shuffle=False,
    seed=seed
    )

train_ds = train_ds.shuffle(25000,seed=1,reshuffle_each_iteration = False)
test_ds = test_ds.shuffle(25000,seed=1,reshuffle_each_iteration = False)

train_ds = train_ds.take(5000)
test_ds = test_ds.take(5000)

train_ds_size=len(train_ds)
test_ds_size=len(test_ds)
# Out:
# Found 25000 files belonging to 2 classes.
# Found 25000 files belonging to 2 classes.

# %% [markdown]
# ## Functions to pre-process source text. (A detailed discussion on our paper)

# %%
# Do-Nothing preprocessing function.
def DON(input_data):
  tag_open_CDATA_removed = tf.strings.regex_replace(input_data, '<\!\[CDATA\[', ' ')
  tag_closed_CDATA_removed = tf.strings.regex_replace(tag_open_CDATA_removed,'\]{1,}>', ' ')
  tag_author_lang_en_removed = tf.strings.regex_replace(tag_closed_CDATA_removed,'<author lang="en">', ' ')
  tag_closed_author_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'</author>', ' ')
  tag_open_documents_removed = tf.strings.regex_replace(tag_closed_author_removed,'<documents>\n(\t){0,2}', '')
  output_data = tf.strings.regex_replace(tag_open_documents_removed,'</documents>\n(\t){0,2}', ' ')
  return output_data

# Lowercasing preprocessing function.
def LOW(input_data):  
  return tf.strings.lower(DON(input_data))

# Removing Stop Words function.
def RSW(input_data):
  output_data = DON(input_data)

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:

      # input_string = input_string.numpy() [0]
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("Tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# Porter Stemmer preprocessing function.
def STM(input_data):
  output_data = DON(input_data)
  stemmer = PorterStemmer()

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      #print(input_string)
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:
      #input_string = input_string.numpy()[0]
      input_string = input_string.numpy()
      #print(input_string)
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# %% [markdown]
# ## Define the combined preprocessing functions. (The base functions are: DON, LOW, RSW and STM).

# %%
## SECTION WITH PAIRS OF PREPRO FUNCTIONS. APPLICATION ORDER MATTERS (...IN FOLLOWING SECTIONS TOO).
#...5
def LOW_RSW(input_data):
  return RSW(LOW(input_data))

# 6
def LOW_STM(input_data):
  return STM(LOW(input_data))

# 7
def RSW_LOW(input_data):
  return LOW(RSW(input_data))

# 8
def RSW_STM(input_data):
  return STM(RSW(input_data))

# 9
def STM_LOW(input_data):
  return LOW(STM(input_data))

# 10
def STM_RSW(input_data):
  return RSW(STM(input_data))
  
# 11
def LOW_STM_RSW(input_data):
  return RSW(STM(LOW(input_data)))

# 12
def LOW_RSW_STM(input_data):
  return STM(RSW(LOW(input_data)))

# 13
def STM_LOW_RSW(input_data):
  return RSW(LOW(STM(input_data)))

# 14
def STM_RSW_LOW(input_data):
  return LOW(RSW(STM(input_data)))

# 15
def RSW_LOW_STM(input_data):
  return STM(LOW(RSW(input_data)))

# 16
def RSW_STM_LOW(input_data):
  return LOW(STM(RSW(input_data)))

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(preprocessing_function,training_set):
  # Set a large sequence length to find the longest sample in the training set.
  sequence_length = 3000
  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    out=model(authorDocument)
    # Convert token list to numpy array.
    token_list = out.numpy()[0]
    token_list = np.trim_zeros(token_list,'b')
    if longest_sample_length < len(token_list):
      longest_sample_length = len(token_list)

  print("Length of the longest sample is:", longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Define a dictionary with -> function_names:prepro_function_caller. And a dictionary to store model results.

# %%
model_results = {}
prepro_functions_dict_base = {
    'DON':DON,
    'LOW':LOW,
    'RSW':RSW,
    'STM':STM
    }

# 3 prepro functions = 15 combs...+1 for do_nothing

prepro_functions_dict_comb = {
    # 1. Do nothing 
    #'DON': DON,
    # 2. Lowercasing 
    #'LOW':LOW,
    # 3. Removing Stopwords
    #'RSW':RSW, 
    # 4. Porter Stemming
    #'STM':STM,
    # 5. LOW->RSW
    #'LOW_RSW':LOW_RSW, 
    # 6. LOW->STM
    #'LOW_STM':LOW_STM,
    # 7. RSW->LOW
    #'RSW_LOW':RSW_LOW,
    # 8. RSW->STM
    #'RSW_STM':RSW_STM,
    # 9. STM->LOW
    #'STM_LOW':STM_LOW,
    # 10. STM->RSW
    #'STM_RSW':STM_RSW,
    # 11. LOW->STM->RSW
    #LOW_STM_RSW':LOW_STM_RSW,  
    # 12. LOW->RSW->STM
    #'LOW_RSW_STM':LOW_RSW_STM,
    # 13. STM->LOW->RSW
    #'STM_LOW_RSW':STM_LOW_RSW,
    # 14. STM->RSW->LOW
    #'STM_RSW_LOW':STM_RSW_LOW,
    # 15. RSW->LOW->STM
    'RSW_LOW_STM':RSW_LOW_STM,
    # 16. RSW->STM->LOW
    'RSW_STM_LOW':RSW_STM_LOW
}

for key in prepro_functions_dict_comb:
  print(key)
  model_results[key]=[]
# Out:
# RSW_LOW_STM
# RSW_STM_LOW

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Models definition and evaluation.

# %%
tf.random.set_seed(0)
TF_DISABLE_SEGMENT_REDUCTION_OP_DETERMINISM_EXCEPTIONS=True

# Reset model_results list.
for key in prepro_functions_dict_comb:
  model_results[key]=[]

for key in prepro_functions_dict_comb:
  runs_accuracy = []

  print("\n\n* * * * EVALUATION USING", key, "AS PREPROCESSING FUNCTION * * * *")

  # Preprocess training set to build a dictionary.
  vectorize_layer = preprocess_and_adapt_ts(prepro_functions_dict_comb[key],train_ds)

  max_features=len(vectorize_layer.get_vocabulary()) + 1
  print("Vocabulary size is:", max_features)

  for run in range(1,(num_runs+1)):
    epochs_accuracy=[]
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,  return_sequences=True)),
                                    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
                                    tf.keras.layers.Dense(64, activation='relu'),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer=opt, metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        print("Run: ",run,"/ Accuracy at epoch ",epoch," is: ", accuracy[0],"\n")
        epochs_accuracy.append(accuracy[0])

    print("Accuracies over epochs:",epochs_accuracy,"\n\n")
    runs_accuracy.append(max(epochs_accuracy))

  runs_accuracy.sort()
  print("\n\n Over all runs maximum accuracies are:", runs_accuracy)
  print("The median is:",runs_accuracy[2],"\n\n\n")
  
  if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
    max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
  else:
    max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
  final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
  model_results[key].append(final_result)
  print("BiLSTM Accuracy Score on Test set -> ",model_results[key])
# Out:
# * * * * EVALUATION USING RSW_LOW_STM AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 1540
# Vocabulary size is: 94013
# 5000/5000 [==============================] - 832s 164ms/step - loss: 0.7013 - binary_accuracy: 0.4940 - val_loss: 0.6952 - val_binary_accuracy: 0.4988
# Run:  1 / Accuracy at epoch  0  is:  0.49880000948905945
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.6860 - binary_accuracy: 0.5900 - val_loss: 0.5677 - val_binary_accuracy: 0.7256
# Run:  1 / Accuracy at epoch  1  is:  0.725600004196167
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.6210 - binary_accuracy: 0.7204 - val_loss: 0.6879 - val_binary_accuracy: 0.7226
# Run:  1 / Accuracy at epoch  2  is:  0.722599983215332
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.5817 - binary_accuracy: 0.7554 - val_loss: 0.4967 - val_binary_accuracy: 0.7892
# Run:  1 / Accuracy at epoch  3  is:  0.7892000079154968
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.5206 - binary_accuracy: 0.7944 - val_loss: 0.7069 - val_binary_accuracy: 0.8222
# Run:  1 / Accuracy at epoch  4  is:  0.8222000002861023
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.4700 - binary_accuracy: 0.8408 - val_loss: 0.8996 - val_binary_accuracy: 0.8340
# Run:  1 / Accuracy at epoch  5  is:  0.8339999914169312
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.4063 - binary_accuracy: 0.8784 - val_loss: 0.7896 - val_binary_accuracy: 0.8388
# Run:  1 / Accuracy at epoch  6  is:  0.8388000130653381
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.3654 - binary_accuracy: 0.9042 - val_loss: 0.7006 - val_binary_accuracy: 0.8482
# Run:  1 / Accuracy at epoch  7  is:  0.8482000231742859
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.3732 - binary_accuracy: 0.9274 - val_loss: 1.1005 - val_binary_accuracy: 0.8350
# Run:  1 / Accuracy at epoch  8  is:  0.8349999785423279
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.3216 - binary_accuracy: 0.9428 - val_loss: 1.4541 - val_binary_accuracy: 0.7774
# Run:  1 / Accuracy at epoch  9  is:  0.777400016784668
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.3082 - binary_accuracy: 0.9492 - val_loss: 1.2590 - val_binary_accuracy: 0.8064
# Run:  1 / Accuracy at epoch  10  is:  0.8064000010490417
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.2651 - binary_accuracy: 0.9584 - val_loss: 0.9103 - val_binary_accuracy: 0.8362
# Run:  1 / Accuracy at epoch  11  is:  0.8361999988555908
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.2601 - binary_accuracy: 0.9656 - val_loss: 1.7921 - val_binary_accuracy: 0.7652
# Run:  1 / Accuracy at epoch  12  is:  0.7652000188827515
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.2492 - binary_accuracy: 0.9680 - val_loss: 1.5314 - val_binary_accuracy: 0.8090
# Run:  1 / Accuracy at epoch  13  is:  0.8090000152587891
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.2667 - binary_accuracy: 0.9722 - val_loss: 2.0446 - val_binary_accuracy: 0.8102
# Run:  1 / Accuracy at epoch  14  is:  0.8101999759674072
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.2120 - binary_accuracy: 0.9772 - val_loss: 2.2077 - val_binary_accuracy: 0.8310
# Run:  1 / Accuracy at epoch  15  is:  0.8309999704360962
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.2117 - binary_accuracy: 0.9818 - val_loss: 1.5859 - val_binary_accuracy: 0.8222
# Run:  1 / Accuracy at epoch  16  is:  0.8222000002861023
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.1913 - binary_accuracy: 0.9830 - val_loss: 1.9629 - val_binary_accuracy: 0.8286
# Run:  1 / Accuracy at epoch  17  is:  0.8285999894142151
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.1895 - binary_accuracy: 0.9852 - val_loss: 2.5836 - val_binary_accuracy: 0.8146
# Run:  1 / Accuracy at epoch  18  is:  0.8145999908447266
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.1926 - binary_accuracy: 0.9884 - val_loss: 2.3515 - val_binary_accuracy: 0.8270
# Run:  1 / Accuracy at epoch  19  is:  0.8270000219345093
#
# Accuracies over epochs: [0.49880000948905945, 0.725600004196167, 0.722599983215332, 0.7892000079154968, 0.8222000002861023, 0.8339999914169312, 0.8388000130653381, 0.8482000231742859, 0.8349999785423279, 0.777400016784668, 0.8064000010490417, 0.8361999988555908, 0.7652000188827515, 0.8090000152587891, 0.8101999759674072, 0.8309999704360962, 0.8222000002861023, 0.8285999894142151, 0.8145999908447266, 0.8270000219345093]
#
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.7021 - binary_accuracy: 0.4902 - val_loss: 0.6982 - val_binary_accuracy: 0.4816
# Run:  2 / Accuracy at epoch  0  is:  0.48159998655319214
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.6983 - binary_accuracy: 0.5412 - val_loss: 0.6231 - val_binary_accuracy: 0.6576
# Run:  2 / Accuracy at epoch  1  is:  0.6575999855995178
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.6386 - binary_accuracy: 0.6916 - val_loss: 0.6006 - val_binary_accuracy: 0.7698
# Run:  2 / Accuracy at epoch  2  is:  0.7698000073432922
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.5772 - binary_accuracy: 0.7602 - val_loss: 0.5748 - val_binary_accuracy: 0.7954
# Run:  2 / Accuracy at epoch  3  is:  0.7954000234603882
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.5315 - binary_accuracy: 0.7998 - val_loss: 0.5991 - val_binary_accuracy: 0.8134
# Run:  2 / Accuracy at epoch  4  is:  0.8133999705314636
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.4499 - binary_accuracy: 0.8546 - val_loss: 0.8487 - val_binary_accuracy: 0.8368
# Run:  2 / Accuracy at epoch  5  is:  0.8367999792098999
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.3860 - binary_accuracy: 0.8936 - val_loss: 0.6074 - val_binary_accuracy: 0.8520
# Run:  2 / Accuracy at epoch  6  is:  0.8519999980926514
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.3680 - binary_accuracy: 0.9204 - val_loss: 0.7139 - val_binary_accuracy: 0.8324
# Run:  2 / Accuracy at epoch  7  is:  0.8324000239372253
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.3032 - binary_accuracy: 0.9330 - val_loss: 1.0089 - val_binary_accuracy: 0.8300
# Run:  2 / Accuracy at epoch  8  is:  0.8299999833106995
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.2760 - binary_accuracy: 0.9420 - val_loss: 1.0143 - val_binary_accuracy: 0.7994
# Run:  2 / Accuracy at epoch  9  is:  0.7993999719619751
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.2425 - binary_accuracy: 0.9598 - val_loss: 1.0938 - val_binary_accuracy: 0.7934
# Run:  2 / Accuracy at epoch  10  is:  0.79339998960495
#
# 5000/5000 [==============================] - 826s 165ms/step - loss: 0.2306 - binary_accuracy: 0.9660 - val_loss: 1.5144 - val_binary_accuracy: 0.7928
# Run:  2 / Accuracy at epoch  11  is:  0.7928000092506409
#
# 5000/5000 [==============================] - 829s 165ms/step - loss: 0.2150 - binary_accuracy: 0.9746 - val_loss: 2.3619 - val_binary_accuracy: 0.7480
# Run:  2 / Accuracy at epoch  12  is:  0.7480000257492065
#
# 5000/5000 [==============================] - 829s 165ms/step - loss: 0.2084 - binary_accuracy: 0.9784 - val_loss: 2.1584 - val_binary_accuracy: 0.7332
# Run:  2 / Accuracy at epoch  13  is:  0.7332000136375427
#
# 5000/5000 [==============================] - 829s 165ms/step - loss: 0.1774 - binary_accuracy: 0.9792 - val_loss: 1.5123 - val_binary_accuracy: 0.7658
# Run:  2 / Accuracy at epoch  14  is:  0.7657999992370605
#
# 5000/5000 [==============================] - 828s 165ms/step - loss: 0.2104 - binary_accuracy: 0.9804 - val_loss: 3.3008 - val_binary_accuracy: 0.7278
# Run:  2 / Accuracy at epoch  15  is:  0.7278000116348267
#
# 5000/5000 [==============================] - 829s 165ms/step - loss: 0.1984 - binary_accuracy: 0.9836 - val_loss: 2.7842 - val_binary_accuracy: 0.7490
# Run:  2 / Accuracy at epoch  16  is:  0.7490000128746033
#
# 5000/5000 [==============================] - 829s 165ms/step - loss: 0.1885 - binary_accuracy: 0.9830 - val_loss: 2.8359 - val_binary_accuracy: 0.7946
# Run:  2 / Accuracy at epoch  17  is:  0.7946000099182129
#
# 5000/5000 [==============================] - 827s 165ms/step - loss: 0.1378 - binary_accuracy: 0.9868 - val_loss: 2.1106 - val_binary_accuracy: 0.7674
# Run:  2 / Accuracy at epoch  18  is:  0.7674000263214111
#
# 5000/5000 [==============================] - 828s 165ms/step - loss: 0.1520 - binary_accuracy: 0.9904 - val_loss: 5.0433 - val_binary_accuracy: 0.7026
# Run:  2 / Accuracy at epoch  19  is:  0.7026000022888184
#
# Accuracies over epochs: [0.48159998655319214, 0.6575999855995178, 0.7698000073432922, 0.7954000234603882, 0.8133999705314636, 0.8367999792098999, 0.8519999980926514, 0.8324000239372253, 0.8299999833106995, 0.7993999719619751, 0.79339998960495, 0.7928000092506409, 0.7480000257492065, 0.7332000136375427, 0.7657999992370605, 0.7278000116348267, 0.7490000128746033, 0.7946000099182129, 0.7674000263214111, 0.7026000022888184]
#
#
# 5000/5000 [==============================] - 828s 164ms/step - loss: 0.7012 - binary_accuracy: 0.5026 - val_loss: 0.8516 - val_binary_accuracy: 0.5340
# Run:  3 / Accuracy at epoch  0  is:  0.5339999794960022
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.6756 - binary_accuracy: 0.6228 - val_loss: 0.5878 - val_binary_accuracy: 0.7174
# Run:  3 / Accuracy at epoch  1  is:  0.7174000144004822
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.6036 - binary_accuracy: 0.7320 - val_loss: 0.5250 - val_binary_accuracy: 0.7524
# Run:  3 / Accuracy at epoch  2  is:  0.7523999810218811
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.5716 - binary_accuracy: 0.7704 - val_loss: 0.5898 - val_binary_accuracy: 0.7930
# Run:  3 / Accuracy at epoch  3  is:  0.7929999828338623
#
# 5000/5000 [==============================] - 825s 164ms/step - loss: 0.5167 - binary_accuracy: 0.8154 - val_loss: 0.6276 - val_binary_accuracy: 0.8256
# Run:  3 / Accuracy at epoch  4  is:  0.8256000280380249
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.4377 - binary_accuracy: 0.8694 - val_loss: 0.8785 - val_binary_accuracy: 0.8330
# Run:  3 / Accuracy at epoch  5  is:  0.8330000042915344
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.3692 - binary_accuracy: 0.9012 - val_loss: 0.9797 - val_binary_accuracy: 0.8142
# Run:  3 / Accuracy at epoch  6  is:  0.8141999840736389
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.3430 - binary_accuracy: 0.9242 - val_loss: 0.7248 - val_binary_accuracy: 0.7910
# Run:  3 / Accuracy at epoch  7  is:  0.7910000085830688
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.3072 - binary_accuracy: 0.9368 - val_loss: 0.8520 - val_binary_accuracy: 0.8450
# Run:  3 / Accuracy at epoch  8  is:  0.8450000286102295
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.3014 - binary_accuracy: 0.9484 - val_loss: 1.4180 - val_binary_accuracy: 0.8012
# Run:  3 / Accuracy at epoch  9  is:  0.8011999726295471
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.2924 - binary_accuracy: 0.9524 - val_loss: 1.3068 - val_binary_accuracy: 0.8224
# Run:  3 / Accuracy at epoch  10  is:  0.8223999738693237
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.2588 - binary_accuracy: 0.9648 - val_loss: 1.3803 - val_binary_accuracy: 0.8064
# Run:  3 / Accuracy at epoch  11  is:  0.8064000010490417
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.2420 - binary_accuracy: 0.9720 - val_loss: 1.1356 - val_binary_accuracy: 0.7896
# Run:  3 / Accuracy at epoch  12  is:  0.7896000146865845
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.2582 - binary_accuracy: 0.9746 - val_loss: 1.4245 - val_binary_accuracy: 0.8130
# Run:  3 / Accuracy at epoch  13  is:  0.8130000233650208
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.1990 - binary_accuracy: 0.9800 - val_loss: 2.2244 - val_binary_accuracy: 0.8058
# Run:  3 / Accuracy at epoch  14  is:  0.8058000206947327
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.1890 - binary_accuracy: 0.9806 - val_loss: 2.6298 - val_binary_accuracy: 0.7730
# Run:  3 / Accuracy at epoch  15  is:  0.7730000019073486
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.1896 - binary_accuracy: 0.9826 - val_loss: 2.6425 - val_binary_accuracy: 0.7790
# Run:  3 / Accuracy at epoch  16  is:  0.7789999842643738
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.1661 - binary_accuracy: 0.9882 - val_loss: 3.3566 - val_binary_accuracy: 0.7908
# Run:  3 / Accuracy at epoch  17  is:  0.7907999753952026
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.1465 - binary_accuracy: 0.9896 - val_loss: 3.1967 - val_binary_accuracy: 0.8090
# Run:  3 / Accuracy at epoch  18  is:  0.8090000152587891
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.1154 - binary_accuracy: 0.9906 - val_loss: 2.6088 - val_binary_accuracy: 0.8076
# Run:  3 / Accuracy at epoch  19  is:  0.8076000213623047
#
# Accuracies over epochs: [0.5339999794960022, 0.7174000144004822, 0.7523999810218811, 0.7929999828338623, 0.8256000280380249, 0.8330000042915344, 0.8141999840736389, 0.7910000085830688, 0.8450000286102295, 0.8011999726295471, 0.8223999738693237, 0.8064000010490417, 0.7896000146865845, 0.8130000233650208, 0.8058000206947327, 0.7730000019073486, 0.7789999842643738, 0.7907999753952026, 0.8090000152587891, 0.8076000213623047]
#
#
# 5000/5000 [==============================] - 815s 161ms/step - loss: 0.7013 - binary_accuracy: 0.4990 - val_loss: 0.6997 - val_binary_accuracy: 0.5014
# Run:  4 / Accuracy at epoch  0  is:  0.5013999938964844
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.6852 - binary_accuracy: 0.6062 - val_loss: 0.5488 - val_binary_accuracy: 0.7350
# Run:  4 / Accuracy at epoch  1  is:  0.7350000143051147
#
# 5000/5000 [==============================] - 811s 162ms/step - loss: 0.6199 - binary_accuracy: 0.7180 - val_loss: 0.5267 - val_binary_accuracy: 0.7740
# Run:  4 / Accuracy at epoch  2  is:  0.7739999890327454
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.5621 - binary_accuracy: 0.7768 - val_loss: 0.6758 - val_binary_accuracy: 0.7402
# Run:  4 / Accuracy at epoch  3  is:  0.7401999831199646
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.5269 - binary_accuracy: 0.8068 - val_loss: 0.5983 - val_binary_accuracy: 0.8074
# Run:  4 / Accuracy at epoch  4  is:  0.8073999881744385
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.4594 - binary_accuracy: 0.8536 - val_loss: 0.8863 - val_binary_accuracy: 0.8322
# Run:  4 / Accuracy at epoch  5  is:  0.8321999907493591
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.4031 - binary_accuracy: 0.8866 - val_loss: 1.0558 - val_binary_accuracy: 0.8108
# Run:  4 / Accuracy at epoch  6  is:  0.8108000159263611
#
# 5000/5000 [==============================] - 816s 162ms/step - loss: 0.3716 - binary_accuracy: 0.9136 - val_loss: 0.9051 - val_binary_accuracy: 0.7996
# Run:  4 / Accuracy at epoch  7  is:  0.7996000051498413
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.3235 - binary_accuracy: 0.9348 - val_loss: 1.3405 - val_binary_accuracy: 0.8494
# Run:  4 / Accuracy at epoch  8  is:  0.849399983882904
#
# 5000/5000 [==============================] - 816s 162ms/step - loss: 0.2735 - binary_accuracy: 0.9500 - val_loss: 1.3782 - val_binary_accuracy: 0.8454
# Run:  4 / Accuracy at epoch  9  is:  0.8453999757766724
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.2249 - binary_accuracy: 0.9590 - val_loss: 1.9904 - val_binary_accuracy: 0.8184
# Run:  4 / Accuracy at epoch  10  is:  0.8184000253677368
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.2126 - binary_accuracy: 0.9716 - val_loss: 1.7607 - val_binary_accuracy: 0.8338
# Run:  4 / Accuracy at epoch  11  is:  0.8338000178337097
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.1838 - binary_accuracy: 0.9778 - val_loss: 2.2997 - val_binary_accuracy: 0.8056
# Run:  4 / Accuracy at epoch  12  is:  0.8055999875068665
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.1530 - binary_accuracy: 0.9836 - val_loss: 3.3617 - val_binary_accuracy: 0.7888
# Run:  4 / Accuracy at epoch  13  is:  0.7888000011444092
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.1603 - binary_accuracy: 0.9830 - val_loss: 2.2527 - val_binary_accuracy: 0.7936
# Run:  4 / Accuracy at epoch  14  is:  0.7936000227928162
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.1573 - binary_accuracy: 0.9862 - val_loss: 3.1045 - val_binary_accuracy: 0.8126
# Run:  4 / Accuracy at epoch  15  is:  0.8126000165939331
#
# 5000/5000 [==============================] - 821s 164ms/step - loss: 0.1430 - binary_accuracy: 0.9878 - val_loss: 3.5223 - val_binary_accuracy: 0.8010
# Run:  4 / Accuracy at epoch  16  is:  0.8009999990463257
#
# 5000/5000 [==============================] - 824s 164ms/step - loss: 0.1186 - binary_accuracy: 0.9922 - val_loss: 4.2395 - val_binary_accuracy: 0.7894
# Run:  4 / Accuracy at epoch  17  is:  0.7893999814987183
#
# 5000/5000 [==============================] - 824s 164ms/step - loss: 0.1164 - binary_accuracy: 0.9918 - val_loss: 4.0189 - val_binary_accuracy: 0.7758
# Run:  4 / Accuracy at epoch  18  is:  0.7757999897003174
#
# 5000/5000 [==============================] - 821s 164ms/step - loss: 0.0624 - binary_accuracy: 0.9950 - val_loss: 4.6276 - val_binary_accuracy: 0.8012
# Run:  4 / Accuracy at epoch  19  is:  0.8011999726295471
#
# Accuracies over epochs: [0.5013999938964844, 0.7350000143051147, 0.7739999890327454, 0.7401999831199646, 0.8073999881744385, 0.8321999907493591, 0.8108000159263611, 0.7996000051498413, 0.849399983882904, 0.8453999757766724, 0.8184000253677368, 0.8338000178337097, 0.8055999875068665, 0.7888000011444092, 0.7936000227928162, 0.8126000165939331, 0.8009999990463257, 0.7893999814987183, 0.7757999897003174, 0.8011999726295471]
#
#
# 5000/5000 [==============================] - 821s 163ms/step - loss: 0.7034 - binary_accuracy: 0.4946 - val_loss: 0.7295 - val_binary_accuracy: 0.5014
# Run:  5 / Accuracy at epoch  0  is:  0.5013999938964844
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.6788 - binary_accuracy: 0.6226 - val_loss: 0.5825 - val_binary_accuracy: 0.7352
# Run:  5 / Accuracy at epoch  1  is:  0.7351999878883362
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.6015 - binary_accuracy: 0.7372 - val_loss: 0.6883 - val_binary_accuracy: 0.7478
# Run:  5 / Accuracy at epoch  2  is:  0.7477999925613403
#
# 5000/5000 [==============================] - 824s 164ms/step - loss: 0.5357 - binary_accuracy: 0.7930 - val_loss: 0.6439 - val_binary_accuracy: 0.7996
# Run:  5 / Accuracy at epoch  3  is:  0.7996000051498413
#
# 5000/5000 [==============================] - 825s 164ms/step - loss: 0.4968 - binary_accuracy: 0.8158 - val_loss: 0.6383 - val_binary_accuracy: 0.8246
# Run:  5 / Accuracy at epoch  4  is:  0.8245999813079834
#
# 5000/5000 [==============================] - 823s 164ms/step - loss: 0.4254 - binary_accuracy: 0.8708 - val_loss: 0.6282 - val_binary_accuracy: 0.8362
# Run:  5 / Accuracy at epoch  5  is:  0.8361999988555908
#
# 5000/5000 [==============================] - 827s 165ms/step - loss: 0.3818 - binary_accuracy: 0.8952 - val_loss: 0.7172 - val_binary_accuracy: 0.8298
# Run:  5 / Accuracy at epoch  6  is:  0.829800009727478
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.3591 - binary_accuracy: 0.9166 - val_loss: 0.8264 - val_binary_accuracy: 0.8390
# Run:  5 / Accuracy at epoch  7  is:  0.8389999866485596
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.3398 - binary_accuracy: 0.9394 - val_loss: 0.6606 - val_binary_accuracy: 0.8414
# Run:  5 / Accuracy at epoch  8  is:  0.8414000272750854
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.3042 - binary_accuracy: 0.9518 - val_loss: 1.0382 - val_binary_accuracy: 0.8138
# Run:  5 / Accuracy at epoch  9  is:  0.8137999773025513
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.2839 - binary_accuracy: 0.9532 - val_loss: 1.4696 - val_binary_accuracy: 0.7860
# Run:  5 / Accuracy at epoch  10  is:  0.7860000133514404
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.2415 - binary_accuracy: 0.9630 - val_loss: 1.2488 - val_binary_accuracy: 0.8156
# Run:  5 / Accuracy at epoch  11  is:  0.8155999779701233
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.2295 - binary_accuracy: 0.9674 - val_loss: 2.0626 - val_binary_accuracy: 0.7446
# Run:  5 / Accuracy at epoch  12  is:  0.7445999979972839
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.2321 - binary_accuracy: 0.9744 - val_loss: 2.5938 - val_binary_accuracy: 0.7720
# Run:  5 / Accuracy at epoch  13  is:  0.7720000147819519
#
# 5000/5000 [==============================] - 821s 163ms/step - loss: 0.2112 - binary_accuracy: 0.9810 - val_loss: 4.8229 - val_binary_accuracy: 0.7198
# Run:  5 / Accuracy at epoch  14  is:  0.7197999954223633
#
# 5000/5000 [==============================] - 825s 164ms/step - loss: 0.1927 - binary_accuracy: 0.9814 - val_loss: 4.8831 - val_binary_accuracy: 0.6602
# Run:  5 / Accuracy at epoch  15  is:  0.6601999998092651
#
# 5000/5000 [==============================] - 841s 166ms/step - loss: 0.1751 - binary_accuracy: 0.9842 - val_loss: 10.1737 - val_binary_accuracy: 0.6636
# Run:  5 / Accuracy at epoch  16  is:  0.6636000275611877
#
# 5000/5000 [==============================] - 824s 164ms/step - loss: 0.1872 - binary_accuracy: 0.9864 - val_loss: 3.9773 - val_binary_accuracy: 0.7676
# Run:  5 / Accuracy at epoch  17  is:  0.7675999999046326
#
# 5000/5000 [==============================] - 823s 164ms/step - loss: 0.1675 - binary_accuracy: 0.9888 - val_loss: 6.5557 - val_binary_accuracy: 0.6834
# Run:  5 / Accuracy at epoch  18  is:  0.6833999752998352
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.1193 - binary_accuracy: 0.9898 - val_loss: 3.0805 - val_binary_accuracy: 0.8004
# Run:  5 / Accuracy at epoch  19  is:  0.8004000186920166
#
# Accuracies over epochs: [0.5013999938964844, 0.7351999878883362, 0.7477999925613403, 0.7996000051498413, 0.8245999813079834, 0.8361999988555908, 0.829800009727478, 0.8389999866485596, 0.8414000272750854, 0.8137999773025513, 0.7860000133514404, 0.8155999779701233, 0.7445999979972839, 0.7720000147819519, 0.7197999954223633, 0.6601999998092651, 0.6636000275611877, 0.7675999999046326, 0.6833999752998352, 0.8004000186920166]
#
#
#
#
#  Over all runs maximum accuracies are: [0.8414000272750854, 0.8450000286102295, 0.8482000231742859, 0.849399983882904, 0.8519999980926514]
# The median is: 0.8482000231742859
#
#
#
# BiLSTM Accuracy Score on Test set ->  ['0.8482000231742859 +/- 0.0067999958992004395']
#
#
# * * * * EVALUATION USING RSW_STM_LOW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 1540
# Vocabulary size is: 94013
# 5000/5000 [==============================] - 825s 164ms/step - loss: 0.7046 - binary_accuracy: 0.4854 - val_loss: 0.6939 - val_binary_accuracy: 0.4966
# Run:  1 / Accuracy at epoch  0  is:  0.4966000020503998
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.6900 - binary_accuracy: 0.5700 - val_loss: 0.6209 - val_binary_accuracy: 0.6600
# Run:  1 / Accuracy at epoch  1  is:  0.6600000262260437
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.6340 - binary_accuracy: 0.7042 - val_loss: 0.4967 - val_binary_accuracy: 0.7756
# Run:  1 / Accuracy at epoch  2  is:  0.775600016117096
#
# 5000/5000 [==============================] - 829s 165ms/step - loss: 0.5698 - binary_accuracy: 0.7636 - val_loss: 0.6673 - val_binary_accuracy: 0.7710
# Run:  1 / Accuracy at epoch  3  is:  0.7710000276565552
#
# 5000/5000 [==============================] - 830s 163ms/step - loss: 0.5257 - binary_accuracy: 0.8050 - val_loss: 0.7059 - val_binary_accuracy: 0.8118
# Run:  1 / Accuracy at epoch  4  is:  0.8118000030517578
#
# 5000/5000 [==============================] - 827s 165ms/step - loss: 0.4493 - binary_accuracy: 0.8542 - val_loss: 0.6216 - val_binary_accuracy: 0.8362
# Run:  1 / Accuracy at epoch  5  is:  0.8361999988555908
#
# 5000/5000 [==============================] - 821s 164ms/step - loss: 0.3783 - binary_accuracy: 0.8924 - val_loss: 0.9699 - val_binary_accuracy: 0.8132
# Run:  1 / Accuracy at epoch  6  is:  0.8131999969482422
#
# 5000/5000 [==============================] - 821s 163ms/step - loss: 0.3572 - binary_accuracy: 0.9114 - val_loss: 1.0984 - val_binary_accuracy: 0.8118
# Run:  1 / Accuracy at epoch  7  is:  0.8118000030517578
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.3193 - binary_accuracy: 0.9338 - val_loss: 0.9286 - val_binary_accuracy: 0.8292
# Run:  1 / Accuracy at epoch  8  is:  0.829200029373169
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.2856 - binary_accuracy: 0.9434 - val_loss: 1.4855 - val_binary_accuracy: 0.8158
# Run:  1 / Accuracy at epoch  9  is:  0.8158000111579895
#
# 5000/5000 [==============================] - 843s 168ms/step - loss: 0.2550 - binary_accuracy: 0.9538 - val_loss: 1.3186 - val_binary_accuracy: 0.7948
# Run:  1 / Accuracy at epoch  10  is:  0.7947999835014343
#
# 5000/5000 [==============================] - 825s 164ms/step - loss: 0.2275 - binary_accuracy: 0.9668 - val_loss: 1.5407 - val_binary_accuracy: 0.7570
# Run:  1 / Accuracy at epoch  11  is:  0.7570000290870667
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.2251 - binary_accuracy: 0.9720 - val_loss: 3.4479 - val_binary_accuracy: 0.6988
# Run:  1 / Accuracy at epoch  12  is:  0.6988000273704529
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.2152 - binary_accuracy: 0.9752 - val_loss: 1.5946 - val_binary_accuracy: 0.7870
# Run:  1 / Accuracy at epoch  13  is:  0.7870000004768372
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.2396 - binary_accuracy: 0.9744 - val_loss: 2.5420 - val_binary_accuracy: 0.7284
# Run:  1 / Accuracy at epoch  14  is:  0.7283999919891357
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.2245 - binary_accuracy: 0.9770 - val_loss: 2.0864 - val_binary_accuracy: 0.7904
# Run:  1 / Accuracy at epoch  15  is:  0.7904000282287598
#
# 5000/5000 [==============================] - 827s 165ms/step - loss: 0.2182 - binary_accuracy: 0.9798 - val_loss: 3.0403 - val_binary_accuracy: 0.7640
# Run:  1 / Accuracy at epoch  16  is:  0.7639999985694885
#
# 5000/5000 [==============================] - 825s 164ms/step - loss: 0.1879 - binary_accuracy: 0.9810 - val_loss: 2.0040 - val_binary_accuracy: 0.8332
# Run:  1 / Accuracy at epoch  17  is:  0.8331999778747559
#
# 5000/5000 [==============================] - 823s 164ms/step - loss: 0.1744 - binary_accuracy: 0.9858 - val_loss: 3.0922 - val_binary_accuracy: 0.7494
# Run:  1 / Accuracy at epoch  18  is:  0.7494000196456909
#
# 5000/5000 [==============================] - 825s 164ms/step - loss: 0.1601 - binary_accuracy: 0.9866 - val_loss: 2.4788 - val_binary_accuracy: 0.8010
# Run:  1 / Accuracy at epoch  19  is:  0.8009999990463257
#
# Accuracies over epochs: [0.4966000020503998, 0.6600000262260437, 0.775600016117096, 0.7710000276565552, 0.8118000030517578, 0.8361999988555908, 0.8131999969482422, 0.8118000030517578, 0.829200029373169, 0.8158000111579895, 0.7947999835014343, 0.7570000290870667, 0.6988000273704529, 0.7870000004768372, 0.7283999919891357, 0.7904000282287598, 0.7639999985694885, 0.8331999778747559, 0.7494000196456909, 0.8009999990463257]
#
#
# 5000/5000 [==============================] - 833s 165ms/step - loss: 0.7006 - binary_accuracy: 0.5112 - val_loss: 0.6185 - val_binary_accuracy: 0.6646
# Run:  2 / Accuracy at epoch  0  is:  0.6646000146865845
#
# 5000/5000 [==============================] - 828s 165ms/step - loss: 0.6381 - binary_accuracy: 0.6934 - val_loss: 0.5833 - val_binary_accuracy: 0.7842
# Run:  2 / Accuracy at epoch  1  is:  0.7842000126838684
#
# 5000/5000 [==============================] - 832s 166ms/step - loss: 0.5917 - binary_accuracy: 0.7558 - val_loss: 0.6297 - val_binary_accuracy: 0.8006
# Run:  2 / Accuracy at epoch  2  is:  0.800599992275238
#
# 5000/5000 [==============================] - 832s 166ms/step - loss: 0.5266 - binary_accuracy: 0.8010 - val_loss: 0.4986 - val_binary_accuracy: 0.8152
# Run:  2 / Accuracy at epoch  3  is:  0.8151999711990356
#
# 5000/5000 [==============================] - 834s 166ms/step - loss: 0.4569 - binary_accuracy: 0.8464 - val_loss: 0.7278 - val_binary_accuracy: 0.8244
# Run:  2 / Accuracy at epoch  4  is:  0.824400007724762
#
# 5000/5000 [==============================] - 832s 166ms/step - loss: 0.3986 - binary_accuracy: 0.8890 - val_loss: 0.8383 - val_binary_accuracy: 0.8020
# Run:  2 / Accuracy at epoch  5  is:  0.8019999861717224
#
# 5000/5000 [==============================] - 833s 166ms/step - loss: 0.3484 - binary_accuracy: 0.9186 - val_loss: 0.9360 - val_binary_accuracy: 0.8384
# Run:  2 / Accuracy at epoch  6  is:  0.8384000062942505
#
# 5000/5000 [==============================] - 832s 166ms/step - loss: 0.3163 - binary_accuracy: 0.9300 - val_loss: 1.0953 - val_binary_accuracy: 0.8112
# Run:  2 / Accuracy at epoch  7  is:  0.8112000226974487
#
# 5000/5000 [==============================] - 833s 166ms/step - loss: 0.2890 - binary_accuracy: 0.9478 - val_loss: 0.9323 - val_binary_accuracy: 0.7954
# Run:  2 / Accuracy at epoch  8  is:  0.7954000234603882
#
# 5000/5000 [==============================] - 832s 166ms/step - loss: 0.2607 - binary_accuracy: 0.9566 - val_loss: 1.1042 - val_binary_accuracy: 0.8262
# Run:  2 / Accuracy at epoch  9  is:  0.826200008392334
#
# 5000/5000 [==============================] - 832s 166ms/step - loss: 0.2666 - binary_accuracy: 0.9606 - val_loss: 2.5741 - val_binary_accuracy: 0.6966
# Run:  2 / Accuracy at epoch  10  is:  0.6966000199317932
#
# 5000/5000 [==============================] - 833s 166ms/step - loss: 0.2343 - binary_accuracy: 0.9686 - val_loss: 2.9080 - val_binary_accuracy: 0.7004
# Run:  2 / Accuracy at epoch  11  is:  0.7003999948501587
#
# 5000/5000 [==============================] - 833s 166ms/step - loss: 0.2094 - binary_accuracy: 0.9746 - val_loss: 1.3973 - val_binary_accuracy: 0.7974
# Run:  2 / Accuracy at epoch  12  is:  0.7973999977111816
#
# 5000/5000 [==============================] - 832s 166ms/step - loss: 0.2055 - binary_accuracy: 0.9792 - val_loss: 3.8690 - val_binary_accuracy: 0.7010
# Run:  2 / Accuracy at epoch  13  is:  0.7009999752044678
#
# 5000/5000 [==============================] - 832s 166ms/step - loss: 0.2044 - binary_accuracy: 0.9826 - val_loss: 3.0735 - val_binary_accuracy: 0.7294
# Run:  2 / Accuracy at epoch  14  is:  0.7293999791145325
#
# 5000/5000 [==============================] - 832s 166ms/step - loss: 0.1903 - binary_accuracy: 0.9862 - val_loss: 5.9987 - val_binary_accuracy: 0.6870
# Run:  2 / Accuracy at epoch  15  is:  0.6869999766349792
#
# 5000/5000 [==============================] - 832s 166ms/step - loss: 0.2010 - binary_accuracy: 0.9862 - val_loss: 6.9054 - val_binary_accuracy: 0.6854
# Run:  2 / Accuracy at epoch  16  is:  0.6854000091552734
#
# 5000/5000 [==============================] - 834s 166ms/step - loss: 0.1441 - binary_accuracy: 0.9898 - val_loss: 6.3593 - val_binary_accuracy: 0.7400
# Run:  2 / Accuracy at epoch  17  is:  0.7400000095367432
#
# 5000/5000 [==============================] - 833s 166ms/step - loss: 0.1847 - binary_accuracy: 0.9898 - val_loss: 3.3834 - val_binary_accuracy: 0.7492
# Run:  2 / Accuracy at epoch  18  is:  0.7491999864578247
#
# 5000/5000 [==============================] - 832s 166ms/step - loss: 0.1305 - binary_accuracy: 0.9912 - val_loss: 6.8009 - val_binary_accuracy: 0.6642
# Run:  2 / Accuracy at epoch  19  is:  0.6642000079154968
#
# Accuracies over epochs: [0.6646000146865845, 0.7842000126838684, 0.800599992275238, 0.8151999711990356, 0.824400007724762, 0.8019999861717224, 0.8384000062942505, 0.8112000226974487, 0.7954000234603882, 0.826200008392334, 0.6966000199317932, 0.7003999948501587, 0.7973999977111816, 0.7009999752044678, 0.7293999791145325, 0.6869999766349792, 0.6854000091552734, 0.7400000095367432, 0.7491999864578247, 0.6642000079154968]
#
#
# 5000/5000 [==============================] - 829s 164ms/step - loss: 0.7012 - binary_accuracy: 0.4996 - val_loss: 0.6933 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  0  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.6934 - binary_accuracy: 0.4736 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  1  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.6934 - binary_accuracy: 0.4824 - val_loss: 0.6932 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  2  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 821s 163ms/step - loss: 0.6934 - binary_accuracy: 0.4834 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  3  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.6934 - binary_accuracy: 0.4840 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  4  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  5  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  6  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  7  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 821s 163ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  8  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  9  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 821s 164ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  10  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 816s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  11  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  12  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4834 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  13  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.6935 - binary_accuracy: 0.4852 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  14  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  15  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  16  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  17  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.6935 - binary_accuracy: 0.4854 - val_loss: 0.6932 - val_binary_accuracy: 0.4986
# Run:  3 / Accuracy at epoch  18  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 816s 162ms/step - loss: 0.6935 - binary_accuracy: 0.4876 - val_loss: 0.6931 - val_binary_accuracy: 0.5014
# Run:  3 / Accuracy at epoch  19  is:  0.5013999938964844
#
# Accuracies over epochs: [0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.5013999938964844]
#
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.7019 - binary_accuracy: 0.4830 - val_loss: 0.6916 - val_binary_accuracy: 0.5072
# Run:  4 / Accuracy at epoch  0  is:  0.5072000026702881
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.6918 - binary_accuracy: 0.5846 - val_loss: 0.6406 - val_binary_accuracy: 0.6804
# Run:  4 / Accuracy at epoch  1  is:  0.680400013923645
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.6224 - binary_accuracy: 0.7240 - val_loss: 0.5502 - val_binary_accuracy: 0.7780
# Run:  4 / Accuracy at epoch  2  is:  0.777999997138977
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.5559 - binary_accuracy: 0.7816 - val_loss: 0.6071 - val_binary_accuracy: 0.8000
# Run:  4 / Accuracy at epoch  3  is:  0.800000011920929
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.5148 - binary_accuracy: 0.8070 - val_loss: 0.7612 - val_binary_accuracy: 0.8174
# Run:  4 / Accuracy at epoch  4  is:  0.8173999786376953
#
# 5000/5000 [==============================] - 816s 162ms/step - loss: 0.4468 - binary_accuracy: 0.8518 - val_loss: 0.5797 - val_binary_accuracy: 0.8384
# Run:  4 / Accuracy at epoch  5  is:  0.8384000062942505
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.4084 - binary_accuracy: 0.8866 - val_loss: 0.8780 - val_binary_accuracy: 0.8292
# Run:  4 / Accuracy at epoch  6  is:  0.829200029373169
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.3657 - binary_accuracy: 0.9156 - val_loss: 0.7266 - val_binary_accuracy: 0.8420
# Run:  4 / Accuracy at epoch  7  is:  0.8420000076293945
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.3298 - binary_accuracy: 0.9336 - val_loss: 1.3628 - val_binary_accuracy: 0.8312
# Run:  4 / Accuracy at epoch  8  is:  0.8312000036239624
#
# 5000/5000 [==============================] - 816s 162ms/step - loss: 0.3076 - binary_accuracy: 0.9402 - val_loss: 1.2490 - val_binary_accuracy: 0.8482
# Run:  4 / Accuracy at epoch  9  is:  0.8482000231742859
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.2861 - binary_accuracy: 0.9524 - val_loss: 0.8434 - val_binary_accuracy: 0.8426
# Run:  4 / Accuracy at epoch  10  is:  0.8425999879837036
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.2316 - binary_accuracy: 0.9642 - val_loss: 1.4000 - val_binary_accuracy: 0.8100
# Run:  4 / Accuracy at epoch  11  is:  0.8100000023841858
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.2191 - binary_accuracy: 0.9690 - val_loss: 1.0628 - val_binary_accuracy: 0.8332
# Run:  4 / Accuracy at epoch  12  is:  0.8331999778747559
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.1993 - binary_accuracy: 0.9726 - val_loss: 2.0928 - val_binary_accuracy: 0.7990
# Run:  4 / Accuracy at epoch  13  is:  0.7990000247955322
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.2188 - binary_accuracy: 0.9798 - val_loss: 2.6349 - val_binary_accuracy: 0.8024
# Run:  4 / Accuracy at epoch  14  is:  0.8023999929428101
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.2117 - binary_accuracy: 0.9800 - val_loss: 2.4461 - val_binary_accuracy: 0.8142
# Run:  4 / Accuracy at epoch  15  is:  0.8141999840736389
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.1936 - binary_accuracy: 0.9814 - val_loss: 2.3421 - val_binary_accuracy: 0.7800
# Run:  4 / Accuracy at epoch  16  is:  0.7799999713897705
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.1867 - binary_accuracy: 0.9800 - val_loss: 3.6099 - val_binary_accuracy: 0.7344
# Run:  4 / Accuracy at epoch  17  is:  0.7343999743461609
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.1698 - binary_accuracy: 0.9832 - val_loss: 4.9554 - val_binary_accuracy: 0.7472
# Run:  4 / Accuracy at epoch  18  is:  0.7472000122070312
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.1395 - binary_accuracy: 0.9878 - val_loss: 3.6556 - val_binary_accuracy: 0.8128
# Run:  4 / Accuracy at epoch  19  is:  0.8127999901771545
#
# Accuracies over epochs: [0.5072000026702881, 0.680400013923645, 0.777999997138977, 0.800000011920929, 0.8173999786376953, 0.8384000062942505, 0.829200029373169, 0.8420000076293945, 0.8312000036239624, 0.8482000231742859, 0.8425999879837036, 0.8100000023841858, 0.8331999778747559, 0.7990000247955322, 0.8023999929428101, 0.8141999840736389, 0.7799999713897705, 0.7343999743461609, 0.7472000122070312, 0.8127999901771545]
#
#
# 5000/5000 [==============================] - 817s 162ms/step - loss: 0.6996 - binary_accuracy: 0.5372 - val_loss: 0.6366 - val_binary_accuracy: 0.6610
# Run:  5 / Accuracy at epoch  0  is:  0.6610000133514404
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.6481 - binary_accuracy: 0.6764 - val_loss: 0.5685 - val_binary_accuracy: 0.7372
# Run:  5 / Accuracy at epoch  1  is:  0.7372000217437744
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.5875 - binary_accuracy: 0.7596 - val_loss: 0.6763 - val_binary_accuracy: 0.6710
# Run:  5 / Accuracy at epoch  2  is:  0.6710000038146973
#
# 5000/5000 [==============================] - 823s 164ms/step - loss: 0.5308 - binary_accuracy: 0.8010 - val_loss: 0.8045 - val_binary_accuracy: 0.7924
# Run:  5 / Accuracy at epoch  3  is:  0.7924000024795532
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.4809 - binary_accuracy: 0.8436 - val_loss: 0.5940 - val_binary_accuracy: 0.8332
# Run:  5 / Accuracy at epoch  4  is:  0.8331999778747559
#
# 5000/5000 [==============================] - 825s 164ms/step - loss: 0.3956 - binary_accuracy: 0.8836 - val_loss: 0.7137 - val_binary_accuracy: 0.8158
# Run:  5 / Accuracy at epoch  5  is:  0.8158000111579895
#
# 5000/5000 [==============================] - 829s 165ms/step - loss: 0.3472 - binary_accuracy: 0.9192 - val_loss: 0.8243 - val_binary_accuracy: 0.8518
# Run:  5 / Accuracy at epoch  6  is:  0.8518000245094299
#
# 5000/5000 [==============================] - 824s 164ms/step - loss: 0.3200 - binary_accuracy: 0.9352 - val_loss: 0.8002 - val_binary_accuracy: 0.8352
# Run:  5 / Accuracy at epoch  7  is:  0.8352000117301941
#
# 5000/5000 [==============================] - 826s 165ms/step - loss: 0.2947 - binary_accuracy: 0.9498 - val_loss: 0.8676 - val_binary_accuracy: 0.8260
# Run:  5 / Accuracy at epoch  8  is:  0.8259999752044678
#
# 5000/5000 [==============================] - 827s 165ms/step - loss: 0.2620 - binary_accuracy: 0.9572 - val_loss: 1.7748 - val_binary_accuracy: 0.7784
# Run:  5 / Accuracy at epoch  9  is:  0.7784000039100647
#
# 5000/5000 [==============================] - 830s 165ms/step - loss: 0.2205 - binary_accuracy: 0.9688 - val_loss: 1.2548 - val_binary_accuracy: 0.8174
# Run:  5 / Accuracy at epoch  10  is:  0.8173999786376953
#
# 5000/5000 [==============================] - 827s 165ms/step - loss: 0.1930 - binary_accuracy: 0.9776 - val_loss: 1.2279 - val_binary_accuracy: 0.8402
# Run:  5 / Accuracy at epoch  11  is:  0.8402000069618225
#
# 5000/5000 [==============================] - 828s 165ms/step - loss: 0.1894 - binary_accuracy: 0.9794 - val_loss: 1.9189 - val_binary_accuracy: 0.8116
# Run:  5 / Accuracy at epoch  12  is:  0.8116000294685364
#
# 5000/5000 [==============================] - 827s 165ms/step - loss: 0.1713 - binary_accuracy: 0.9828 - val_loss: 2.5798 - val_binary_accuracy: 0.8128
# Run:  5 / Accuracy at epoch  13  is:  0.8127999901771545
#
# 5000/5000 [==============================] - 841s 167ms/step - loss: 0.1561 - binary_accuracy: 0.9864 - val_loss: 2.1851 - val_binary_accuracy: 0.8216
# Run:  5 / Accuracy at epoch  14  is:  0.8216000199317932
#
# 5000/5000 [==============================] - 839s 165ms/step - loss: 0.1328 - binary_accuracy: 0.9896 - val_loss: 3.1447 - val_binary_accuracy: 0.8088
# Run:  5 / Accuracy at epoch  15  is:  0.8087999820709229
#
# 5000/5000 [==============================] - 825s 164ms/step - loss: 0.1241 - binary_accuracy: 0.9896 - val_loss: 2.9740 - val_binary_accuracy: 0.8010
# Run:  5 / Accuracy at epoch  16  is:  0.8009999990463257
#
# 5000/5000 [==============================] - 827s 165ms/step - loss: 0.1107 - binary_accuracy: 0.9908 - val_loss: 2.5878 - val_binary_accuracy: 0.8246
# Run:  5 / Accuracy at epoch  17  is:  0.8245999813079834
#
# 5000/5000 [==============================] - 828s 165ms/step - loss: 0.0903 - binary_accuracy: 0.9936 - val_loss: 2.9984 - val_binary_accuracy: 0.8132
# Run:  5 / Accuracy at epoch  18  is:  0.8131999969482422
#
# 5000/5000 [==============================] - 827s 165ms/step - loss: 0.0845 - binary_accuracy: 0.9946 - val_loss: 4.2630 - val_binary_accuracy: 0.8234
# Run:  5 / Accuracy at epoch  19  is:  0.8234000205993652
#
# Accuracies over epochs: [0.6610000133514404, 0.7372000217437744, 0.6710000038146973, 0.7924000024795532, 0.8331999778747559, 0.8158000111579895, 0.8518000245094299, 0.8352000117301941, 0.8259999752044678, 0.7784000039100647, 0.8173999786376953, 0.8402000069618225, 0.8116000294685364, 0.8127999901771545, 0.8216000199317932, 0.8087999820709229, 0.8009999990463257, 0.8245999813079834, 0.8131999969482422, 0.8234000205993652]
#
#
#
#
#  Over all runs maximum accuracies are: [0.5013999938964844, 0.8361999988555908, 0.8384000062942505, 0.8482000231742859, 0.8518000245094299]
# The median is: 0.8384000062942505
#
#
#
# BiLSTM Accuracy Score on Test set ->  ['0.8384000062942505 +/- 0.3370000123977661']

# %% [markdown]
# ## Now show compact results in a table.

# %%
print(" PREPRO FUNCTION    |  Test Accuracy   |",end = '')

print("\n")
for prepro_func in prepro_functions_dict_comb:
  #print(prepro_func,"\t\t\t",format(round(model_results[prepro_func][0],4),'.4f'),"\t\t",end='')
  result = format(round(model_results[prepro_func][0],4),'.4f')
  print(f'{prepro_func:27}{ result :12}')
  print("\n")
# Out:
#  PREPRO FUNCTION    |  Test Accuracy   |
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 4>()
#       3 print("\n")
#       4 for prepro_func in prepro_functions_dict_comb:
#       5   #print(prepro_func,"\t\t\t",format(round(model_results[prepro_func][0],4),'.4f'),"\t\t",end='')
# ----> 6   result = format(round(model_results[prepro_func][0],4),'.4f')
#       7   print(f'{prepro_func:27}{ result :12}')
#       8   print("\n")
#
# TypeError: type str doesn't define __round__ method
