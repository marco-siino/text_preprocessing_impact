# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/text_preprocessing_impact/blob/main/IMDB_DS/BiLSTM_IMDB_TextPreProImpact_NB_PART_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances.
# - - -
# BiLSTM ON IMDB DS EXPERIMENTS NOTEBOOK
# - - -
# Bidirectional Long Short-Term Memory Network on Internet Movie Database Dataset.
# Code by M. Siino.
#
# From the paper: "Text preprocessing worth the time: A comparative survey on the impact of common techniques on NLP model performances." by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf
import nltk
import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from sklearn.linear_model import LogisticRegression
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer
from textblob import TextBlob
nltk.download('stopwords')
nltk.download('punkt')

os.environ['TF_CUDNN_DETERMINISTIC']='false'
os.environ['TF_DETERMINISTIC_OPS']='false'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Domenico\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

dataset = tf.keras.utils.get_file("aclImdb_v1", url,
                                    untar=True, cache_dir='.',
                                    cache_subdir='')

dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')

train_set_dir = os.path.join(dataset_dir, 'train')
test_set_dir = os.path.join(dataset_dir, 'test')

remove_dir = os.path.join(train_set_dir, 'unsup')
shutil.rmtree(remove_dir)

# %% [markdown]
# ## Generate training and test set.

# %%
# Generate full randomized training set.
batch_size = 1
seed = 1

train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train', 
    batch_size=batch_size,
    shuffle=False,
    seed=seed
    )

test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/test', 
    batch_size=batch_size,
    shuffle=False,
    seed=seed
    )

train_ds = train_ds.shuffle(25000,seed=1,reshuffle_each_iteration = False)
test_ds = test_ds.shuffle(25000,seed=1,reshuffle_each_iteration = False)

train_ds = train_ds.take(5000)
test_ds = test_ds.take(5000)

train_ds_size=len(train_ds)
test_ds_size=len(test_ds)
# Out:
# Found 25000 files belonging to 2 classes.
# Found 25000 files belonging to 2 classes.

# %% [markdown]
# ## Functions to pre-process source text. (A detailed discussion on our paper)

# %%
# Do-Nothing preprocessing function.
def DON(input_data):
  tag_open_CDATA_removed = tf.strings.regex_replace(input_data, '<\!\[CDATA\[', ' ')
  tag_closed_CDATA_removed = tf.strings.regex_replace(tag_open_CDATA_removed,'\]{1,}>', ' ')
  tag_author_lang_en_removed = tf.strings.regex_replace(tag_closed_CDATA_removed,'<author lang="en">', ' ')
  tag_closed_author_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'</author>', ' ')
  tag_open_documents_removed = tf.strings.regex_replace(tag_closed_author_removed,'<documents>\n(\t){0,2}', '')
  output_data = tf.strings.regex_replace(tag_open_documents_removed,'</documents>\n(\t){0,2}', ' ')
  return output_data

# Lowercasing preprocessing function.
def LOW(input_data):  
  return tf.strings.lower(DON(input_data))

# Removing Stop Words function.
def RSW(input_data):
  output_data = DON(input_data)

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:

      # input_string = input_string.numpy() [0]
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [word for word in blob if word not in stopwords.words('english')]
    #print("Tolte le stopword inglesi diventa:")

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# Porter Stemmer preprocessing function.
def STM(input_data):
  output_data = DON(input_data)
  stemmer = PorterStemmer()

  #print("\n\nInput data è il seguente tensore:")
  #print(output_data)

  #print("Lo converto in stringa e diventa:")
  # Il seguente try per l'adattamento del ts. Nell'except caso della simulazione vera e propria.
  try:
    input_string=output_data[0]

  # # # # # # # Questo è il caso della chiamata a funzione per la simulazione vera e propria.  
  except:
    #print("\n\n****CASO DELLA SIMULAZIONE VERA E PROPRIA****\n\n")
    #print("\nQuesto è il contenuto di output data in caso di simulazione")
    #print(output_data)
    input_string=output_data
    
    try:
      input_string = input_string.numpy()
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      #print("\nEstraendo il contenuto del tensore risulta:")
      #print(input_string)
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))
    #print(output_string)  

    output_tensor=tf.constant(output_string)
    #print(output_tensor)

    return output_tensor

   # # # # # # # Questo è il caso dell'adattamento del TS.   
  else:
    
    try:
      #input_string = input_string.numpy()[0]
      input_string = input_string.numpy()
      #print(input_string)
    
    except:
      #print("This one is not a tensor!")
      return output_data

    else:
      input_string=(str(input_string))[2:-1]

    #print(input_string)
    blob = TextBlob(str(input_string)).words

    outputlist = [stemmer.stem(word) for word in blob]

    output_string = (' '.join(word for word in outputlist))

    output_tensor=tf.constant([[output_string]])
    #print(output_tensor)

    return output_tensor

  return output_data

# %% [markdown]
# ## Define the combined preprocessing functions. (The base functions are: DON, LOW, RSW and STM).

# %%
## SECTION WITH PAIRS OF PREPRO FUNCTIONS. APPLICATION ORDER MATTERS (...IN FOLLOWING SECTIONS TOO).
#...5
def LOW_RSW(input_data):
  return RSW(LOW(input_data))

# 6
def LOW_STM(input_data):
  return STM(LOW(input_data))

# 7
def RSW_LOW(input_data):
  return LOW(RSW(input_data))

# 8
def RSW_STM(input_data):
  return STM(RSW(input_data))

# 9
def STM_LOW(input_data):
  return LOW(STM(input_data))

# 10
def STM_RSW(input_data):
  return RSW(STM(input_data))
  
# 11
def LOW_STM_RSW(input_data):
  return RSW(STM(LOW(input_data)))

# 12
def LOW_RSW_STM(input_data):
  return STM(RSW(LOW(input_data)))

# 13
def STM_LOW_RSW(input_data):
  return RSW(LOW(STM(input_data)))

# 14
def STM_RSW_LOW(input_data):
  return LOW(RSW(STM(input_data)))

# 15
def RSW_LOW_STM(input_data):
  return STM(LOW(RSW(input_data)))

# 16
def RSW_STM_LOW(input_data):
  return LOW(STM(RSW(input_data)))

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(preprocessing_function,training_set):
  # Set a large sequence length to find the longest sample in the training set.
  sequence_length = 3000
  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    out=model(authorDocument)
    # Convert token list to numpy array.
    token_list = out.numpy()[0]
    token_list = np.trim_zeros(token_list,'b')
    if longest_sample_length < len(token_list):
      longest_sample_length = len(token_list)

  print("Length of the longest sample is:", longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=preprocessing_function,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Define a dictionary with -> function_names:prepro_function_caller. And a dictionary to store model results.

# %%
model_results = {}
prepro_functions_dict_base = {
    'DON':DON,
    'LOW':LOW,
    'RSW':RSW,
    'STM':STM
    }

# 3 prepro functions = 15 combs...+1 for do_nothing

prepro_functions_dict_comb = {
    # 1. Do nothing 
    #'DON': DON,
    # 2. Lowercasing 
    #'LOW':LOW,
    # 3. Removing Stopwords
    #'RSW':RSW, 
    # 4. Porter Stemming
    #'STM':STM,
    # 5. LOW->RSW
    #'LOW_RSW':LOW_RSW, 
    # 6. LOW->STM
    #'LOW_STM':LOW_STM,
    # 7. RSW->LOW
    #'RSW_LOW':RSW_LOW,
    # 8. RSW->STM
    #'RSW_STM':RSW_STM,
    # 9. STM->LOW
    #'STM_LOW':STM_LOW,
    # 10. STM->RSW
    #'STM_RSW':STM_RSW,
    # 11. LOW->STM->RSW
    'LOW_STM_RSW':LOW_STM_RSW,  
    # 12. LOW->RSW->STM
    'LOW_RSW_STM':LOW_RSW_STM,
    # 13. STM->LOW->RSW
    'STM_LOW_RSW':STM_LOW_RSW,
    # 14. STM->RSW->LOW
    'STM_RSW_LOW':STM_RSW_LOW,
    # 15. RSW->LOW->STM
    'RSW_LOW_STM':RSW_LOW_STM,
    # 16. RSW->STM->LOW
    'RSW_STM_LOW':RSW_STM_LOW
}

for key in prepro_functions_dict_comb:
  print(key)
  model_results[key]=[]
# Out:
# LOW_STM_RSW
# LOW_RSW_STM
# STM_LOW_RSW
# STM_RSW_LOW
# RSW_LOW_STM
# RSW_STM_LOW

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Models definition and evaluation.

# %%
tf.random.set_seed(0)
TF_DISABLE_SEGMENT_REDUCTION_OP_DETERMINISM_EXCEPTIONS=True

# Reset model_results list.
for key in prepro_functions_dict_comb:
  model_results[key]=[]

for key in prepro_functions_dict_comb:
  runs_accuracy = []

  print("\n\n* * * * EVALUATION USING", key, "AS PREPROCESSING FUNCTION * * * *")

  # Preprocess training set to build a dictionary.
  vectorize_layer = preprocess_and_adapt_ts(prepro_functions_dict_comb[key],train_ds)

  max_features=len(vectorize_layer.get_vocabulary()) + 1
  print("Vocabulary size is:", max_features)

  for run in range(1,(num_runs+1)):
    epochs_accuracy=[]
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,  return_sequences=True)),
                                    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
                                    tf.keras.layers.Dense(64, activation='relu'),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer=opt, metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        print("Run: ",run,"/ Accuracy at epoch ",epoch," is: ", accuracy[0],"\n")
        epochs_accuracy.append(accuracy[0])

    print("Accuracies over epochs:",epochs_accuracy,"\n\n")
    runs_accuracy.append(max(epochs_accuracy))

  runs_accuracy.sort()
  print("\n\n Over all runs maximum accuracies are:", runs_accuracy)
  print("The median is:",runs_accuracy[2],"\n\n\n")
  
  if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
    max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
  else:
    max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
  final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
  model_results[key].append(final_result)
  print("BiLSTM Accuracy Score on Test set -> ",model_results[key])
# Out:
# * * * * EVALUATION USING LOW_STM_RSW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 1533
# Vocabulary size is: 94013
# 5000/5000 [==============================] - 822s 162ms/step - loss: 0.7022 - binary_accuracy: 0.5054 - val_loss: 0.6673 - val_binary_accuracy: 0.5986
# Run:  1 / Accuracy at epoch  0  is:  0.5985999703407288
#
# 5000/5000 [==============================] - 808s 161ms/step - loss: 0.6890 - binary_accuracy: 0.6082 - val_loss: 0.5912 - val_binary_accuracy: 0.7116
# Run:  1 / Accuracy at epoch  1  is:  0.7116000056266785
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.6194 - binary_accuracy: 0.7188 - val_loss: 0.5697 - val_binary_accuracy: 0.7588
# Run:  1 / Accuracy at epoch  2  is:  0.7588000297546387
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.5756 - binary_accuracy: 0.7672 - val_loss: 0.5350 - val_binary_accuracy: 0.7694
# Run:  1 / Accuracy at epoch  3  is:  0.7694000005722046
#
# 5000/5000 [==============================] - 835s 166ms/step - loss: 0.5495 - binary_accuracy: 0.8052 - val_loss: 0.5636 - val_binary_accuracy: 0.8206
# Run:  1 / Accuracy at epoch  4  is:  0.8205999732017517
#
# 5000/5000 [==============================] - 831s 163ms/step - loss: 0.4753 - binary_accuracy: 0.8514 - val_loss: 0.4888 - val_binary_accuracy: 0.8310
# Run:  1 / Accuracy at epoch  5  is:  0.8309999704360962
#
# 5000/5000 [==============================] - 825s 164ms/step - loss: 0.3909 - binary_accuracy: 0.8940 - val_loss: 1.2092 - val_binary_accuracy: 0.8048
# Run:  1 / Accuracy at epoch  6  is:  0.8047999739646912
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.3184 - binary_accuracy: 0.9238 - val_loss: 0.8896 - val_binary_accuracy: 0.8400
# Run:  1 / Accuracy at epoch  7  is:  0.8399999737739563
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.2958 - binary_accuracy: 0.9398 - val_loss: 0.9395 - val_binary_accuracy: 0.8418
# Run:  1 / Accuracy at epoch  8  is:  0.8417999744415283
#
# 5000/5000 [==============================] - 821s 163ms/step - loss: 0.3023 - binary_accuracy: 0.9450 - val_loss: 1.3154 - val_binary_accuracy: 0.8186
# Run:  1 / Accuracy at epoch  9  is:  0.8185999989509583
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.2852 - binary_accuracy: 0.9540 - val_loss: 1.1652 - val_binary_accuracy: 0.8414
# Run:  1 / Accuracy at epoch  10  is:  0.8414000272750854
#
# 5000/5000 [==============================] - 823s 164ms/step - loss: 0.2718 - binary_accuracy: 0.9670 - val_loss: 1.6250 - val_binary_accuracy: 0.7554
# Run:  1 / Accuracy at epoch  11  is:  0.7554000020027161
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.2323 - binary_accuracy: 0.9728 - val_loss: 2.0702 - val_binary_accuracy: 0.7950
# Run:  1 / Accuracy at epoch  12  is:  0.7950000166893005
#
# 5000/5000 [==============================] - 821s 164ms/step - loss: 0.2058 - binary_accuracy: 0.9764 - val_loss: 2.0737 - val_binary_accuracy: 0.7516
# Run:  1 / Accuracy at epoch  13  is:  0.7516000270843506
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.2130 - binary_accuracy: 0.9782 - val_loss: 3.5568 - val_binary_accuracy: 0.7794
# Run:  1 / Accuracy at epoch  14  is:  0.7793999910354614
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.2090 - binary_accuracy: 0.9812 - val_loss: 3.4132 - val_binary_accuracy: 0.8046
# Run:  1 / Accuracy at epoch  15  is:  0.8046000003814697
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.2158 - binary_accuracy: 0.9840 - val_loss: 2.5321 - val_binary_accuracy: 0.7674
# Run:  1 / Accuracy at epoch  16  is:  0.7674000263214111
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.1999 - binary_accuracy: 0.9864 - val_loss: 2.5089 - val_binary_accuracy: 0.8334
# Run:  1 / Accuracy at epoch  17  is:  0.8334000110626221
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.1620 - binary_accuracy: 0.9866 - val_loss: 7.1137 - val_binary_accuracy: 0.7302
# Run:  1 / Accuracy at epoch  18  is:  0.7301999926567078
#
# 5000/5000 [==============================] - 821s 164ms/step - loss: 0.1523 - binary_accuracy: 0.9918 - val_loss: 3.7388 - val_binary_accuracy: 0.8198
# Run:  1 / Accuracy at epoch  19  is:  0.8198000192642212
#
# Accuracies over epochs: [0.5985999703407288, 0.7116000056266785, 0.7588000297546387, 0.7694000005722046, 0.8205999732017517, 0.8309999704360962, 0.8047999739646912, 0.8399999737739563, 0.8417999744415283, 0.8185999989509583, 0.8414000272750854, 0.7554000020027161, 0.7950000166893005, 0.7516000270843506, 0.7793999910354614, 0.8046000003814697, 0.7674000263214111, 0.8334000110626221, 0.7301999926567078, 0.8198000192642212]
#
#
# 5000/5000 [==============================] - 811s 161ms/step - loss: 0.7032 - binary_accuracy: 0.5026 - val_loss: 0.6992 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  0  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.6974 - binary_accuracy: 0.4956 - val_loss: 0.6931 - val_binary_accuracy: 0.5014
# Run:  2 / Accuracy at epoch  1  is:  0.5013999938964844
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4870 - val_loss: 0.6932 - val_binary_accuracy: 0.5014
# Run:  2 / Accuracy at epoch  2  is:  0.5013999938964844
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4836 - val_loss: 0.6932 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  3  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4840 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  4  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  5  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  6  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  7  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  8  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  9  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  10  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  11  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  12  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  13  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  14  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  15  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  16  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4836 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  17  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 816s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  18  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.6934 - binary_accuracy: 0.4838 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  2 / Accuracy at epoch  19  is:  0.4986000061035156
#
# Accuracies over epochs: [0.4986000061035156, 0.5013999938964844, 0.5013999938964844, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156, 0.4986000061035156]
#
#
# 5000/5000 [==============================] - 811s 161ms/step - loss: 0.7000 - binary_accuracy: 0.4940 - val_loss: 0.6849 - val_binary_accuracy: 0.5606
# Run:  3 / Accuracy at epoch  0  is:  0.5605999827384949
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.6829 - binary_accuracy: 0.6228 - val_loss: 0.5837 - val_binary_accuracy: 0.7056
# Run:  3 / Accuracy at epoch  1  is:  0.7056000232696533
#
# 5000/5000 [==============================] - 821s 163ms/step - loss: 0.6169 - binary_accuracy: 0.7178 - val_loss: 0.6176 - val_binary_accuracy: 0.7728
# Run:  3 / Accuracy at epoch  2  is:  0.7728000283241272
#
# 5000/5000 [==============================] - 826s 165ms/step - loss: 0.5703 - binary_accuracy: 0.7738 - val_loss: 0.5711 - val_binary_accuracy: 0.7864
# Run:  3 / Accuracy at epoch  3  is:  0.7864000201225281
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.5229 - binary_accuracy: 0.8092 - val_loss: 0.6180 - val_binary_accuracy: 0.8136
# Run:  3 / Accuracy at epoch  4  is:  0.8136000037193298
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.4766 - binary_accuracy: 0.8450 - val_loss: 0.5433 - val_binary_accuracy: 0.8258
# Run:  3 / Accuracy at epoch  5  is:  0.8258000016212463
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.3830 - binary_accuracy: 0.8880 - val_loss: 0.9777 - val_binary_accuracy: 0.7968
# Run:  3 / Accuracy at epoch  6  is:  0.7968000173568726
#
# 5000/5000 [==============================] - 821s 163ms/step - loss: 0.3460 - binary_accuracy: 0.9188 - val_loss: 0.8455 - val_binary_accuracy: 0.8122
# Run:  3 / Accuracy at epoch  7  is:  0.8122000098228455
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.3109 - binary_accuracy: 0.9338 - val_loss: 1.1528 - val_binary_accuracy: 0.8060
# Run:  3 / Accuracy at epoch  8  is:  0.8059999942779541
#
# 5000/5000 [==============================] - 821s 163ms/step - loss: 0.3017 - binary_accuracy: 0.9508 - val_loss: 1.2925 - val_binary_accuracy: 0.7982
# Run:  3 / Accuracy at epoch  9  is:  0.7982000112533569
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.2870 - binary_accuracy: 0.9524 - val_loss: 1.9236 - val_binary_accuracy: 0.7468
# Run:  3 / Accuracy at epoch  10  is:  0.7468000054359436
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.2611 - binary_accuracy: 0.9616 - val_loss: 1.4450 - val_binary_accuracy: 0.8046
# Run:  3 / Accuracy at epoch  11  is:  0.8046000003814697
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.2770 - binary_accuracy: 0.9620 - val_loss: 2.5813 - val_binary_accuracy: 0.7016
# Run:  3 / Accuracy at epoch  12  is:  0.7016000151634216
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.2499 - binary_accuracy: 0.9704 - val_loss: 2.4352 - val_binary_accuracy: 0.7634
# Run:  3 / Accuracy at epoch  13  is:  0.7634000182151794
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.2276 - binary_accuracy: 0.9774 - val_loss: 3.3788 - val_binary_accuracy: 0.7558
# Run:  3 / Accuracy at epoch  14  is:  0.7558000087738037
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.2043 - binary_accuracy: 0.9780 - val_loss: 3.4140 - val_binary_accuracy: 0.6688
# Run:  3 / Accuracy at epoch  15  is:  0.6687999963760376
#
# 5000/5000 [==============================] - 829s 165ms/step - loss: 0.1638 - binary_accuracy: 0.9856 - val_loss: 2.5484 - val_binary_accuracy: 0.7856
# Run:  3 / Accuracy at epoch  16  is:  0.7856000065803528
#
# 5000/5000 [==============================] - 833s 164ms/step - loss: 0.1824 - binary_accuracy: 0.9862 - val_loss: 3.2790 - val_binary_accuracy: 0.7614
# Run:  3 / Accuracy at epoch  17  is:  0.7613999843597412
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.1329 - binary_accuracy: 0.9902 - val_loss: 3.2139 - val_binary_accuracy: 0.8082
# Run:  3 / Accuracy at epoch  18  is:  0.8082000017166138
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.1272 - binary_accuracy: 0.9906 - val_loss: 8.6748 - val_binary_accuracy: 0.6992
# Run:  3 / Accuracy at epoch  19  is:  0.6991999745368958
#
# Accuracies over epochs: [0.5605999827384949, 0.7056000232696533, 0.7728000283241272, 0.7864000201225281, 0.8136000037193298, 0.8258000016212463, 0.7968000173568726, 0.8122000098228455, 0.8059999942779541, 0.7982000112533569, 0.7468000054359436, 0.8046000003814697, 0.7016000151634216, 0.7634000182151794, 0.7558000087738037, 0.6687999963760376, 0.7856000065803528, 0.7613999843597412, 0.8082000017166138, 0.6991999745368958]
#
#
# 5000/5000 [==============================] - 806s 160ms/step - loss: 0.7038 - binary_accuracy: 0.4978 - val_loss: 0.6931 - val_binary_accuracy: 0.4986
# Run:  4 / Accuracy at epoch  0  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 804s 160ms/step - loss: 0.6952 - binary_accuracy: 0.5150 - val_loss: 0.6663 - val_binary_accuracy: 0.6168
# Run:  4 / Accuracy at epoch  1  is:  0.6168000102043152
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.6654 - binary_accuracy: 0.6426 - val_loss: 0.6834 - val_binary_accuracy: 0.6432
# Run:  4 / Accuracy at epoch  2  is:  0.6431999802589417
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.5726 - binary_accuracy: 0.7472 - val_loss: 0.4421 - val_binary_accuracy: 0.8094
# Run:  4 / Accuracy at epoch  3  is:  0.8094000220298767
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.4474 - binary_accuracy: 0.8280 - val_loss: 0.5531 - val_binary_accuracy: 0.8180
# Run:  4 / Accuracy at epoch  4  is:  0.8180000185966492
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.3894 - binary_accuracy: 0.8734 - val_loss: 0.5035 - val_binary_accuracy: 0.8406
# Run:  4 / Accuracy at epoch  5  is:  0.8406000137329102
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.3507 - binary_accuracy: 0.8972 - val_loss: 0.8065 - val_binary_accuracy: 0.8092
# Run:  4 / Accuracy at epoch  6  is:  0.8091999888420105
#
# 5000/5000 [==============================] - 811s 162ms/step - loss: 0.3129 - binary_accuracy: 0.9208 - val_loss: 0.9659 - val_binary_accuracy: 0.7932
# Run:  4 / Accuracy at epoch  7  is:  0.7932000160217285
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.2864 - binary_accuracy: 0.9314 - val_loss: 0.9272 - val_binary_accuracy: 0.7866
# Run:  4 / Accuracy at epoch  8  is:  0.7865999937057495
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.2461 - binary_accuracy: 0.9456 - val_loss: 1.0625 - val_binary_accuracy: 0.7750
# Run:  4 / Accuracy at epoch  9  is:  0.7749999761581421
#
# 5000/5000 [==============================] - 809s 161ms/step - loss: 0.2455 - binary_accuracy: 0.9548 - val_loss: 1.3579 - val_binary_accuracy: 0.7928
# Run:  4 / Accuracy at epoch  10  is:  0.7928000092506409
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.2262 - binary_accuracy: 0.9646 - val_loss: 2.4659 - val_binary_accuracy: 0.7582
# Run:  4 / Accuracy at epoch  11  is:  0.7581999897956848
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.2703 - binary_accuracy: 0.9658 - val_loss: 3.7985 - val_binary_accuracy: 0.7176
# Run:  4 / Accuracy at epoch  12  is:  0.7175999879837036
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.2266 - binary_accuracy: 0.9742 - val_loss: 4.0023 - val_binary_accuracy: 0.6680
# Run:  4 / Accuracy at epoch  13  is:  0.6679999828338623
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.2622 - binary_accuracy: 0.9758 - val_loss: 4.0111 - val_binary_accuracy: 0.7316
# Run:  4 / Accuracy at epoch  14  is:  0.7315999865531921
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.2163 - binary_accuracy: 0.9818 - val_loss: 4.0803 - val_binary_accuracy: 0.7444
# Run:  4 / Accuracy at epoch  15  is:  0.7444000244140625
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.1852 - binary_accuracy: 0.9842 - val_loss: 5.7348 - val_binary_accuracy: 0.7194
# Run:  4 / Accuracy at epoch  16  is:  0.7193999886512756
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.1703 - binary_accuracy: 0.9850 - val_loss: 5.0129 - val_binary_accuracy: 0.6810
# Run:  4 / Accuracy at epoch  17  is:  0.6809999942779541
#
# 5000/5000 [==============================] - 811s 161ms/step - loss: 0.2002 - binary_accuracy: 0.9854 - val_loss: 4.8534 - val_binary_accuracy: 0.7682
# Run:  4 / Accuracy at epoch  18  is:  0.7681999802589417
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.1716 - binary_accuracy: 0.9878 - val_loss: 4.4237 - val_binary_accuracy: 0.7664
# Run:  4 / Accuracy at epoch  19  is:  0.7663999795913696
#
# Accuracies over epochs: [0.4986000061035156, 0.6168000102043152, 0.6431999802589417, 0.8094000220298767, 0.8180000185966492, 0.8406000137329102, 0.8091999888420105, 0.7932000160217285, 0.7865999937057495, 0.7749999761581421, 0.7928000092506409, 0.7581999897956848, 0.7175999879837036, 0.6679999828338623, 0.7315999865531921, 0.7444000244140625, 0.7193999886512756, 0.6809999942779541, 0.7681999802589417, 0.7663999795913696]
#
#
# 5000/5000 [==============================] - 806s 160ms/step - loss: 0.7019 - binary_accuracy: 0.5156 - val_loss: 0.6280 - val_binary_accuracy: 0.6554
# Run:  5 / Accuracy at epoch  0  is:  0.6553999781608582
#
# 5000/5000 [==============================] - 807s 161ms/step - loss: 0.6587 - binary_accuracy: 0.6592 - val_loss: 0.5799 - val_binary_accuracy: 0.7312
# Run:  5 / Accuracy at epoch  1  is:  0.7311999797821045
#
# 5000/5000 [==============================] - 811s 161ms/step - loss: 0.5982 - binary_accuracy: 0.7436 - val_loss: 0.5257 - val_binary_accuracy: 0.7666
# Run:  5 / Accuracy at epoch  2  is:  0.7666000127792358
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.5716 - binary_accuracy: 0.7654 - val_loss: 0.5471 - val_binary_accuracy: 0.7908
# Run:  5 / Accuracy at epoch  3  is:  0.7907999753952026
#
# 5000/5000 [==============================] - 813s 162ms/step - loss: 0.5040 - binary_accuracy: 0.8216 - val_loss: 0.5674 - val_binary_accuracy: 0.8240
# Run:  5 / Accuracy at epoch  4  is:  0.8240000009536743
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.3939 - binary_accuracy: 0.8794 - val_loss: 0.5698 - val_binary_accuracy: 0.8334
# Run:  5 / Accuracy at epoch  5  is:  0.8334000110626221
#
# 5000/5000 [==============================] - 816s 162ms/step - loss: 0.3443 - binary_accuracy: 0.9138 - val_loss: 0.8981 - val_binary_accuracy: 0.8330
# Run:  5 / Accuracy at epoch  6  is:  0.8330000042915344
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.3119 - binary_accuracy: 0.9286 - val_loss: 0.8188 - val_binary_accuracy: 0.8340
# Run:  5 / Accuracy at epoch  7  is:  0.8339999914169312
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.3216 - binary_accuracy: 0.9388 - val_loss: 0.9356 - val_binary_accuracy: 0.8390
# Run:  5 / Accuracy at epoch  8  is:  0.8389999866485596
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.3371 - binary_accuracy: 0.9466 - val_loss: 1.5349 - val_binary_accuracy: 0.7644
# Run:  5 / Accuracy at epoch  9  is:  0.7644000053405762
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.3049 - binary_accuracy: 0.9546 - val_loss: 1.7614 - val_binary_accuracy: 0.8088
# Run:  5 / Accuracy at epoch  10  is:  0.8087999820709229
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.2810 - binary_accuracy: 0.9672 - val_loss: 1.7914 - val_binary_accuracy: 0.7852
# Run:  5 / Accuracy at epoch  11  is:  0.7851999998092651
#
# 5000/5000 [==============================] - 816s 162ms/step - loss: 0.2997 - binary_accuracy: 0.9724 - val_loss: 1.7303 - val_binary_accuracy: 0.7914
# Run:  5 / Accuracy at epoch  12  is:  0.7914000153541565
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.2656 - binary_accuracy: 0.9756 - val_loss: 3.2503 - val_binary_accuracy: 0.7344
# Run:  5 / Accuracy at epoch  13  is:  0.7343999743461609
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.2454 - binary_accuracy: 0.9792 - val_loss: 1.6379 - val_binary_accuracy: 0.8218
# Run:  5 / Accuracy at epoch  14  is:  0.8217999935150146
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.2083 - binary_accuracy: 0.9820 - val_loss: 4.2237 - val_binary_accuracy: 0.7278
# Run:  5 / Accuracy at epoch  15  is:  0.7278000116348267
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.2036 - binary_accuracy: 0.9854 - val_loss: 3.1719 - val_binary_accuracy: 0.8000
# Run:  5 / Accuracy at epoch  16  is:  0.800000011920929
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.1739 - binary_accuracy: 0.9880 - val_loss: 4.2767 - val_binary_accuracy: 0.7750
# Run:  5 / Accuracy at epoch  17  is:  0.7749999761581421
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.1888 - binary_accuracy: 0.9874 - val_loss: 3.9783 - val_binary_accuracy: 0.7614
# Run:  5 / Accuracy at epoch  18  is:  0.7613999843597412
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.1498 - binary_accuracy: 0.9914 - val_loss: 8.2108 - val_binary_accuracy: 0.7866
# Run:  5 / Accuracy at epoch  19  is:  0.7865999937057495
#
# Accuracies over epochs: [0.6553999781608582, 0.7311999797821045, 0.7666000127792358, 0.7907999753952026, 0.8240000009536743, 0.8334000110626221, 0.8330000042915344, 0.8339999914169312, 0.8389999866485596, 0.7644000053405762, 0.8087999820709229, 0.7851999998092651, 0.7914000153541565, 0.7343999743461609, 0.8217999935150146, 0.7278000116348267, 0.800000011920929, 0.7749999761581421, 0.7613999843597412, 0.7865999937057495]
#
#
#
#
#  Over all runs maximum accuracies are: [0.5013999938964844, 0.8258000016212463, 0.8389999866485596, 0.8406000137329102, 0.8417999744415283]
# The median is: 0.8389999866485596
#
#
#
# BiLSTM Accuracy Score on Test set ->  ['0.8389999866485596 +/- 0.3375999927520752']
#
#
# * * * * EVALUATION USING LOW_RSW_STM AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 1476
# Vocabulary size is: 94013
# 5000/5000 [==============================] - 782s 155ms/step - loss: 0.7031 - binary_accuracy: 0.4994 - val_loss: 0.6949 - val_binary_accuracy: 0.4986
# Run:  1 / Accuracy at epoch  0  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 781s 156ms/step - loss: 0.6816 - binary_accuracy: 0.6172 - val_loss: 0.5586 - val_binary_accuracy: 0.7380
# Run:  1 / Accuracy at epoch  1  is:  0.7379999756813049
#
# 5000/5000 [==============================] - 799s 159ms/step - loss: 0.6122 - binary_accuracy: 0.7264 - val_loss: 0.5756 - val_binary_accuracy: 0.7760
# Run:  1 / Accuracy at epoch  2  is:  0.7760000228881836
#
# 5000/5000 [==============================] - 805s 158ms/step - loss: 0.5547 - binary_accuracy: 0.7780 - val_loss: 0.5517 - val_binary_accuracy: 0.8086
# Run:  1 / Accuracy at epoch  3  is:  0.8086000084877014
#
# 5000/5000 [==============================] - 795s 158ms/step - loss: 0.5367 - binary_accuracy: 0.8020 - val_loss: 0.5510 - val_binary_accuracy: 0.8118
# Run:  1 / Accuracy at epoch  4  is:  0.8118000030517578
#
# 5000/5000 [==============================] - 783s 156ms/step - loss: 0.4448 - binary_accuracy: 0.8610 - val_loss: 0.6599 - val_binary_accuracy: 0.8274
# Run:  1 / Accuracy at epoch  5  is:  0.8274000287055969
#
# 5000/5000 [==============================] - 786s 156ms/step - loss: 0.3586 - binary_accuracy: 0.9026 - val_loss: 0.6442 - val_binary_accuracy: 0.8474
# Run:  1 / Accuracy at epoch  6  is:  0.8474000096321106
#
# 5000/5000 [==============================] - 785s 156ms/step - loss: 0.3268 - binary_accuracy: 0.9224 - val_loss: 0.6378 - val_binary_accuracy: 0.8462
# Run:  1 / Accuracy at epoch  7  is:  0.8461999893188477
#
# 5000/5000 [==============================] - 785s 156ms/step - loss: 0.2927 - binary_accuracy: 0.9430 - val_loss: 0.8616 - val_binary_accuracy: 0.8502
# Run:  1 / Accuracy at epoch  8  is:  0.8501999974250793
#
# 5000/5000 [==============================] - 786s 157ms/step - loss: 0.2807 - binary_accuracy: 0.9516 - val_loss: 1.0183 - val_binary_accuracy: 0.8186
# Run:  1 / Accuracy at epoch  9  is:  0.8185999989509583
#
# 5000/5000 [==============================] - 785s 156ms/step - loss: 0.2665 - binary_accuracy: 0.9578 - val_loss: 1.0915 - val_binary_accuracy: 0.8066
# Run:  1 / Accuracy at epoch  10  is:  0.8065999746322632
#
# 5000/5000 [==============================] - 786s 156ms/step - loss: 0.2183 - binary_accuracy: 0.9670 - val_loss: 2.4591 - val_binary_accuracy: 0.7350
# Run:  1 / Accuracy at epoch  11  is:  0.7350000143051147
#
# 5000/5000 [==============================] - 785s 156ms/step - loss: 0.2047 - binary_accuracy: 0.9724 - val_loss: 1.7103 - val_binary_accuracy: 0.7988
# Run:  1 / Accuracy at epoch  12  is:  0.798799991607666
#
# 5000/5000 [==============================] - 794s 158ms/step - loss: 0.1939 - binary_accuracy: 0.9778 - val_loss: 0.8802 - val_binary_accuracy: 0.8434
# Run:  1 / Accuracy at epoch  13  is:  0.8434000015258789
#
# 5000/5000 [==============================] - 793s 158ms/step - loss: 0.1775 - binary_accuracy: 0.9818 - val_loss: 2.5869 - val_binary_accuracy: 0.7604
# Run:  1 / Accuracy at epoch  14  is:  0.7603999972343445
#
# 5000/5000 [==============================] - 788s 157ms/step - loss: 0.1788 - binary_accuracy: 0.9860 - val_loss: 2.1241 - val_binary_accuracy: 0.8296
# Run:  1 / Accuracy at epoch  15  is:  0.8295999765396118
#
# 5000/5000 [==============================] - 784s 156ms/step - loss: 0.1851 - binary_accuracy: 0.9860 - val_loss: 3.3832 - val_binary_accuracy: 0.7906
# Run:  1 / Accuracy at epoch  16  is:  0.7906000018119812
#
# 5000/5000 [==============================] - 784s 156ms/step - loss: 0.1510 - binary_accuracy: 0.9888 - val_loss: 2.7271 - val_binary_accuracy: 0.8286
# Run:  1 / Accuracy at epoch  17  is:  0.8285999894142151
#
# 5000/5000 [==============================] - 785s 156ms/step - loss: 0.1382 - binary_accuracy: 0.9914 - val_loss: 4.4292 - val_binary_accuracy: 0.7780
# Run:  1 / Accuracy at epoch  18  is:  0.777999997138977
#
# 5000/5000 [==============================] - 811s 162ms/step - loss: 0.1070 - binary_accuracy: 0.9920 - val_loss: 4.9168 - val_binary_accuracy: 0.7730
# Run:  1 / Accuracy at epoch  19  is:  0.7730000019073486
#
# Accuracies over epochs: [0.4986000061035156, 0.7379999756813049, 0.7760000228881836, 0.8086000084877014, 0.8118000030517578, 0.8274000287055969, 0.8474000096321106, 0.8461999893188477, 0.8501999974250793, 0.8185999989509583, 0.8065999746322632, 0.7350000143051147, 0.798799991607666, 0.8434000015258789, 0.7603999972343445, 0.8295999765396118, 0.7906000018119812, 0.8285999894142151, 0.777999997138977, 0.7730000019073486]
#
#
# 5000/5000 [==============================] - 787s 154ms/step - loss: 0.7060 - binary_accuracy: 0.5096 - val_loss: 0.6514 - val_binary_accuracy: 0.6414
# Run:  2 / Accuracy at epoch  0  is:  0.6413999795913696
#
# 5000/5000 [==============================] - 775s 154ms/step - loss: 0.6636 - binary_accuracy: 0.6664 - val_loss: 0.7111 - val_binary_accuracy: 0.6712
# Run:  2 / Accuracy at epoch  1  is:  0.6711999773979187
#
# 5000/5000 [==============================] - 779s 155ms/step - loss: 0.6168 - binary_accuracy: 0.7174 - val_loss: 0.5431 - val_binary_accuracy: 0.7474
# Run:  2 / Accuracy at epoch  2  is:  0.7473999857902527
#
# 5000/5000 [==============================] - 788s 157ms/step - loss: 0.5750 - binary_accuracy: 0.7714 - val_loss: 0.5022 - val_binary_accuracy: 0.7984
# Run:  2 / Accuracy at epoch  3  is:  0.7983999848365784
#
# 5000/5000 [==============================] - 796s 159ms/step - loss: 0.5089 - binary_accuracy: 0.8206 - val_loss: 0.5800 - val_binary_accuracy: 0.8184
# Run:  2 / Accuracy at epoch  4  is:  0.8184000253677368
#
# 5000/5000 [==============================] - 795s 158ms/step - loss: 0.4287 - binary_accuracy: 0.8686 - val_loss: 0.7314 - val_binary_accuracy: 0.8330
# Run:  2 / Accuracy at epoch  5  is:  0.8330000042915344
#
# 5000/5000 [==============================] - 786s 157ms/step - loss: 0.3575 - binary_accuracy: 0.9048 - val_loss: 0.8354 - val_binary_accuracy: 0.8182
# Run:  2 / Accuracy at epoch  6  is:  0.8181999921798706
#
# 5000/5000 [==============================] - 780s 155ms/step - loss: 0.3063 - binary_accuracy: 0.9254 - val_loss: 0.8152 - val_binary_accuracy: 0.8402
# Run:  2 / Accuracy at epoch  7  is:  0.8402000069618225
#
# 5000/5000 [==============================] - 783s 156ms/step - loss: 0.2891 - binary_accuracy: 0.9398 - val_loss: 0.7786 - val_binary_accuracy: 0.8422
# Run:  2 / Accuracy at epoch  8  is:  0.842199981212616
#
# 5000/5000 [==============================] - 782s 156ms/step - loss: 0.2609 - binary_accuracy: 0.9544 - val_loss: 1.4512 - val_binary_accuracy: 0.8286
# Run:  2 / Accuracy at epoch  9  is:  0.8285999894142151
#
# 5000/5000 [==============================] - 782s 156ms/step - loss: 0.2448 - binary_accuracy: 0.9612 - val_loss: 1.4405 - val_binary_accuracy: 0.8238
# Run:  2 / Accuracy at epoch  10  is:  0.8238000273704529
#
# 5000/5000 [==============================] - 780s 155ms/step - loss: 0.2249 - binary_accuracy: 0.9704 - val_loss: 1.1589 - val_binary_accuracy: 0.8342
# Run:  2 / Accuracy at epoch  11  is:  0.8342000246047974
#
# 5000/5000 [==============================] - 781s 156ms/step - loss: 0.1923 - binary_accuracy: 0.9792 - val_loss: 1.7019 - val_binary_accuracy: 0.8202
# Run:  2 / Accuracy at epoch  12  is:  0.8202000260353088
#
# 5000/5000 [==============================] - 781s 155ms/step - loss: 0.2063 - binary_accuracy: 0.9812 - val_loss: 2.9810 - val_binary_accuracy: 0.8028
# Run:  2 / Accuracy at epoch  13  is:  0.8027999997138977
#
# 5000/5000 [==============================] - 781s 156ms/step - loss: 0.1735 - binary_accuracy: 0.9850 - val_loss: 2.6547 - val_binary_accuracy: 0.8170
# Run:  2 / Accuracy at epoch  14  is:  0.8169999718666077
#
# 5000/5000 [==============================] - 782s 156ms/step - loss: 0.1489 - binary_accuracy: 0.9874 - val_loss: 3.6045 - val_binary_accuracy: 0.7934
# Run:  2 / Accuracy at epoch  15  is:  0.79339998960495
#
# 5000/5000 [==============================] - 783s 156ms/step - loss: 0.1346 - binary_accuracy: 0.9910 - val_loss: 1.8739 - val_binary_accuracy: 0.8174
# Run:  2 / Accuracy at epoch  16  is:  0.8173999786376953
#
# 5000/5000 [==============================] - 781s 156ms/step - loss: 0.1303 - binary_accuracy: 0.9904 - val_loss: 3.0542 - val_binary_accuracy: 0.8206
# Run:  2 / Accuracy at epoch  17  is:  0.8205999732017517
#
# 5000/5000 [==============================] - 783s 156ms/step - loss: 0.1081 - binary_accuracy: 0.9928 - val_loss: 3.5182 - val_binary_accuracy: 0.8314
# Run:  2 / Accuracy at epoch  18  is:  0.8313999772071838
#
# 5000/5000 [==============================] - 784s 156ms/step - loss: 0.1098 - binary_accuracy: 0.9924 - val_loss: 3.0322 - val_binary_accuracy: 0.8026
# Run:  2 / Accuracy at epoch  19  is:  0.8026000261306763
#
# Accuracies over epochs: [0.6413999795913696, 0.6711999773979187, 0.7473999857902527, 0.7983999848365784, 0.8184000253677368, 0.8330000042915344, 0.8181999921798706, 0.8402000069618225, 0.842199981212616, 0.8285999894142151, 0.8238000273704529, 0.8342000246047974, 0.8202000260353088, 0.8027999997138977, 0.8169999718666077, 0.79339998960495, 0.8173999786376953, 0.8205999732017517, 0.8313999772071838, 0.8026000261306763]
#
#
# 5000/5000 [==============================] - 770s 153ms/step - loss: 0.6996 - binary_accuracy: 0.4884 - val_loss: 0.6912 - val_binary_accuracy: 0.5094
# Run:  3 / Accuracy at epoch  0  is:  0.5094000101089478
#
# 5000/5000 [==============================] - 778s 155ms/step - loss: 0.6999 - binary_accuracy: 0.5110 - val_loss: 0.6890 - val_binary_accuracy: 0.5310
# Run:  3 / Accuracy at epoch  1  is:  0.531000018119812
#
# 5000/5000 [==============================] - 796s 159ms/step - loss: 0.6948 - binary_accuracy: 0.5830 - val_loss: 0.6376 - val_binary_accuracy: 0.7046
# Run:  3 / Accuracy at epoch  2  is:  0.7045999765396118
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.6245 - binary_accuracy: 0.7106 - val_loss: 0.5703 - val_binary_accuracy: 0.7208
# Run:  3 / Accuracy at epoch  3  is:  0.72079998254776
#
# 5000/5000 [==============================] - 793s 158ms/step - loss: 0.5630 - binary_accuracy: 0.7692 - val_loss: 0.5567 - val_binary_accuracy: 0.7880
# Run:  3 / Accuracy at epoch  4  is:  0.7879999876022339
#
# 5000/5000 [==============================] - 792s 158ms/step - loss: 0.5065 - binary_accuracy: 0.8194 - val_loss: 0.6271 - val_binary_accuracy: 0.8250
# Run:  3 / Accuracy at epoch  5  is:  0.824999988079071
#
# 5000/5000 [==============================] - 787s 157ms/step - loss: 0.4484 - binary_accuracy: 0.8648 - val_loss: 0.5430 - val_binary_accuracy: 0.8290
# Run:  3 / Accuracy at epoch  6  is:  0.8289999961853027
#
# 5000/5000 [==============================] - 795s 158ms/step - loss: 0.3804 - binary_accuracy: 0.8976 - val_loss: 0.7804 - val_binary_accuracy: 0.8448
# Run:  3 / Accuracy at epoch  7  is:  0.8447999954223633
#
# 5000/5000 [==============================] - 790s 157ms/step - loss: 0.3707 - binary_accuracy: 0.9208 - val_loss: 0.8267 - val_binary_accuracy: 0.8304
# Run:  3 / Accuracy at epoch  8  is:  0.8303999900817871
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.3262 - binary_accuracy: 0.9378 - val_loss: 1.4797 - val_binary_accuracy: 0.8416
# Run:  3 / Accuracy at epoch  9  is:  0.8416000008583069
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.3131 - binary_accuracy: 0.9518 - val_loss: 1.0862 - val_binary_accuracy: 0.8328
# Run:  3 / Accuracy at epoch  10  is:  0.8327999711036682
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.2643 - binary_accuracy: 0.9570 - val_loss: 1.3386 - val_binary_accuracy: 0.8348
# Run:  3 / Accuracy at epoch  11  is:  0.8348000049591064
#
# 5000/5000 [==============================] - 788s 157ms/step - loss: 0.2780 - binary_accuracy: 0.9674 - val_loss: 1.6611 - val_binary_accuracy: 0.8262
# Run:  3 / Accuracy at epoch  12  is:  0.826200008392334
#
# 5000/5000 [==============================] - 786s 156ms/step - loss: 0.2291 - binary_accuracy: 0.9774 - val_loss: 1.7863 - val_binary_accuracy: 0.8038
# Run:  3 / Accuracy at epoch  13  is:  0.8037999868392944
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.2152 - binary_accuracy: 0.9780 - val_loss: 1.7434 - val_binary_accuracy: 0.8410
# Run:  3 / Accuracy at epoch  14  is:  0.8410000205039978
#
# 5000/5000 [==============================] - 787s 157ms/step - loss: 0.1858 - binary_accuracy: 0.9840 - val_loss: 3.5242 - val_binary_accuracy: 0.8062
# Run:  3 / Accuracy at epoch  15  is:  0.8062000274658203
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.1880 - binary_accuracy: 0.9838 - val_loss: 4.0730 - val_binary_accuracy: 0.7962
# Run:  3 / Accuracy at epoch  16  is:  0.7961999773979187
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.1801 - binary_accuracy: 0.9866 - val_loss: 3.0230 - val_binary_accuracy: 0.8094
# Run:  3 / Accuracy at epoch  17  is:  0.8094000220298767
#
# 5000/5000 [==============================] - 800s 159ms/step - loss: 0.1406 - binary_accuracy: 0.9926 - val_loss: 6.1430 - val_binary_accuracy: 0.7684
# Run:  3 / Accuracy at epoch  18  is:  0.7684000134468079
#
# 5000/5000 [==============================] - 788s 157ms/step - loss: 0.1385 - binary_accuracy: 0.9910 - val_loss: 4.0859 - val_binary_accuracy: 0.8334
# Run:  3 / Accuracy at epoch  19  is:  0.8334000110626221
#
# Accuracies over epochs: [0.5094000101089478, 0.531000018119812, 0.7045999765396118, 0.72079998254776, 0.7879999876022339, 0.824999988079071, 0.8289999961853027, 0.8447999954223633, 0.8303999900817871, 0.8416000008583069, 0.8327999711036682, 0.8348000049591064, 0.826200008392334, 0.8037999868392944, 0.8410000205039978, 0.8062000274658203, 0.7961999773979187, 0.8094000220298767, 0.7684000134468079, 0.8334000110626221]
#
#
# 5000/5000 [==============================] - 785s 156ms/step - loss: 0.7079 - binary_accuracy: 0.4886 - val_loss: 0.6932 - val_binary_accuracy: 0.4970
# Run:  4 / Accuracy at epoch  0  is:  0.4970000088214874
#
# 5000/5000 [==============================] - 788s 157ms/step - loss: 0.6979 - binary_accuracy: 0.4938 - val_loss: 0.6932 - val_binary_accuracy: 0.4986
# Run:  4 / Accuracy at epoch  1  is:  0.4986000061035156
#
# 5000/5000 [==============================] - 788s 157ms/step - loss: 0.6942 - binary_accuracy: 0.4982 - val_loss: 0.6931 - val_binary_accuracy: 0.4982
# Run:  4 / Accuracy at epoch  2  is:  0.498199999332428
#
# 5000/5000 [==============================] - 787s 157ms/step - loss: 0.6774 - binary_accuracy: 0.6028 - val_loss: 0.5779 - val_binary_accuracy: 0.6994
# Run:  4 / Accuracy at epoch  3  is:  0.699400007724762
#
# 5000/5000 [==============================] - 799s 159ms/step - loss: 0.6157 - binary_accuracy: 0.7514 - val_loss: 0.6040 - val_binary_accuracy: 0.7878
# Run:  4 / Accuracy at epoch  4  is:  0.7878000140190125
#
# 5000/5000 [==============================] - 801s 157ms/step - loss: 0.5234 - binary_accuracy: 0.8256 - val_loss: 0.6558 - val_binary_accuracy: 0.8266
# Run:  4 / Accuracy at epoch  5  is:  0.8266000151634216
#
# 5000/5000 [==============================] - 791s 158ms/step - loss: 0.4469 - binary_accuracy: 0.8732 - val_loss: 0.4813 - val_binary_accuracy: 0.8324
# Run:  4 / Accuracy at epoch  6  is:  0.8324000239372253
#
# 5000/5000 [==============================] - 790s 157ms/step - loss: 0.4110 - binary_accuracy: 0.9054 - val_loss: 0.6116 - val_binary_accuracy: 0.8414
# Run:  4 / Accuracy at epoch  7  is:  0.8414000272750854
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.4064 - binary_accuracy: 0.9186 - val_loss: 0.8049 - val_binary_accuracy: 0.8308
# Run:  4 / Accuracy at epoch  8  is:  0.8307999968528748
#
# 5000/5000 [==============================] - 790s 157ms/step - loss: 0.2834 - binary_accuracy: 0.9412 - val_loss: 0.8365 - val_binary_accuracy: 0.8366
# Run:  4 / Accuracy at epoch  9  is:  0.8366000056266785
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.2673 - binary_accuracy: 0.9528 - val_loss: 0.8252 - val_binary_accuracy: 0.8422
# Run:  4 / Accuracy at epoch  10  is:  0.842199981212616
#
# 5000/5000 [==============================] - 790s 157ms/step - loss: 0.2301 - binary_accuracy: 0.9628 - val_loss: 1.1106 - val_binary_accuracy: 0.8452
# Run:  4 / Accuracy at epoch  11  is:  0.8452000021934509
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.2436 - binary_accuracy: 0.9728 - val_loss: 1.0923 - val_binary_accuracy: 0.8298
# Run:  4 / Accuracy at epoch  12  is:  0.829800009727478
#
# 5000/5000 [==============================] - 790s 157ms/step - loss: 0.2398 - binary_accuracy: 0.9742 - val_loss: 1.4035 - val_binary_accuracy: 0.8428
# Run:  4 / Accuracy at epoch  13  is:  0.8428000211715698
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.2417 - binary_accuracy: 0.9820 - val_loss: 1.6834 - val_binary_accuracy: 0.8380
# Run:  4 / Accuracy at epoch  14  is:  0.8379999995231628
#
# 5000/5000 [==============================] - 787s 157ms/step - loss: 0.1958 - binary_accuracy: 0.9808 - val_loss: 4.0716 - val_binary_accuracy: 0.7120
# Run:  4 / Accuracy at epoch  15  is:  0.7120000123977661
#
# 5000/5000 [==============================] - 786s 157ms/step - loss: 0.1798 - binary_accuracy: 0.9874 - val_loss: 2.5683 - val_binary_accuracy: 0.8324
# Run:  4 / Accuracy at epoch  16  is:  0.8324000239372253
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.1653 - binary_accuracy: 0.9888 - val_loss: 5.4327 - val_binary_accuracy: 0.7508
# Run:  4 / Accuracy at epoch  17  is:  0.7508000135421753
#
# 5000/5000 [==============================] - 787s 157ms/step - loss: 0.1605 - binary_accuracy: 0.9902 - val_loss: 2.8833 - val_binary_accuracy: 0.8260
# Run:  4 / Accuracy at epoch  18  is:  0.8259999752044678
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.1226 - binary_accuracy: 0.9914 - val_loss: 4.7058 - val_binary_accuracy: 0.7890
# Run:  4 / Accuracy at epoch  19  is:  0.7889999747276306
#
# Accuracies over epochs: [0.4970000088214874, 0.4986000061035156, 0.498199999332428, 0.699400007724762, 0.7878000140190125, 0.8266000151634216, 0.8324000239372253, 0.8414000272750854, 0.8307999968528748, 0.8366000056266785, 0.842199981212616, 0.8452000021934509, 0.829800009727478, 0.8428000211715698, 0.8379999995231628, 0.7120000123977661, 0.8324000239372253, 0.7508000135421753, 0.8259999752044678, 0.7889999747276306]
#
#
# 5000/5000 [==============================] - 785s 156ms/step - loss: 0.7031 - binary_accuracy: 0.5318 - val_loss: 0.6370 - val_binary_accuracy: 0.6622
# Run:  5 / Accuracy at epoch  0  is:  0.6621999740600586
#
# 5000/5000 [==============================] - 784s 156ms/step - loss: 0.6449 - binary_accuracy: 0.6874 - val_loss: 0.5703 - val_binary_accuracy: 0.6782
# Run:  5 / Accuracy at epoch  1  is:  0.6782000064849854
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.5807 - binary_accuracy: 0.7544 - val_loss: 0.5533 - val_binary_accuracy: 0.7516
# Run:  5 / Accuracy at epoch  2  is:  0.7516000270843506
#
# 5000/5000 [==============================] - 790s 157ms/step - loss: 0.5579 - binary_accuracy: 0.7830 - val_loss: 0.5925 - val_binary_accuracy: 0.7902
# Run:  5 / Accuracy at epoch  3  is:  0.7901999950408936
#
# 5000/5000 [==============================] - 797s 159ms/step - loss: 0.5136 - binary_accuracy: 0.8218 - val_loss: 0.5650 - val_binary_accuracy: 0.8200
# Run:  5 / Accuracy at epoch  4  is:  0.8199999928474426
#
# 5000/5000 [==============================] - 790s 157ms/step - loss: 0.4271 - binary_accuracy: 0.8758 - val_loss: 0.6730 - val_binary_accuracy: 0.8414
# Run:  5 / Accuracy at epoch  5  is:  0.8414000272750854
#
# 5000/5000 [==============================] - 791s 157ms/step - loss: 0.3600 - binary_accuracy: 0.9062 - val_loss: 0.8517 - val_binary_accuracy: 0.8312
# Run:  5 / Accuracy at epoch  6  is:  0.8312000036239624
#
# 5000/5000 [==============================] - 796s 159ms/step - loss: 0.3123 - binary_accuracy: 0.9340 - val_loss: 0.7568 - val_binary_accuracy: 0.8454
# Run:  5 / Accuracy at epoch  7  is:  0.8453999757766724
#
# 5000/5000 [==============================] - 791s 157ms/step - loss: 0.3229 - binary_accuracy: 0.9424 - val_loss: 0.8852 - val_binary_accuracy: 0.8402
# Run:  5 / Accuracy at epoch  8  is:  0.8402000069618225
#
# 5000/5000 [==============================] - 788s 157ms/step - loss: 0.2980 - binary_accuracy: 0.9552 - val_loss: 0.9474 - val_binary_accuracy: 0.8392
# Run:  5 / Accuracy at epoch  9  is:  0.8392000198364258
#
# 5000/5000 [==============================] - 788s 157ms/step - loss: 0.2613 - binary_accuracy: 0.9632 - val_loss: 1.4911 - val_binary_accuracy: 0.8096
# Run:  5 / Accuracy at epoch  10  is:  0.8095999956130981
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.2347 - binary_accuracy: 0.9692 - val_loss: 2.3519 - val_binary_accuracy: 0.7512
# Run:  5 / Accuracy at epoch  11  is:  0.7512000203132629
#
# 5000/5000 [==============================] - 796s 159ms/step - loss: 0.2000 - binary_accuracy: 0.9738 - val_loss: 1.6634 - val_binary_accuracy: 0.8280
# Run:  5 / Accuracy at epoch  12  is:  0.828000009059906
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.2275 - binary_accuracy: 0.9786 - val_loss: 1.9355 - val_binary_accuracy: 0.8078
# Run:  5 / Accuracy at epoch  13  is:  0.8077999949455261
#
# 5000/5000 [==============================] - 790s 157ms/step - loss: 0.1910 - binary_accuracy: 0.9838 - val_loss: 2.8610 - val_binary_accuracy: 0.7696
# Run:  5 / Accuracy at epoch  14  is:  0.769599974155426
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.1635 - binary_accuracy: 0.9846 - val_loss: 1.7288 - val_binary_accuracy: 0.8366
# Run:  5 / Accuracy at epoch  15  is:  0.8366000056266785
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.1535 - binary_accuracy: 0.9874 - val_loss: 2.4863 - val_binary_accuracy: 0.7930
# Run:  5 / Accuracy at epoch  16  is:  0.7929999828338623
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.2199 - binary_accuracy: 0.9880 - val_loss: 2.5178 - val_binary_accuracy: 0.8216
# Run:  5 / Accuracy at epoch  17  is:  0.8216000199317932
#
# 5000/5000 [==============================] - 789s 157ms/step - loss: 0.1086 - binary_accuracy: 0.9896 - val_loss: 2.7863 - val_binary_accuracy: 0.8164
# Run:  5 / Accuracy at epoch  18  is:  0.8163999915122986
#
# 5000/5000 [==============================] - 790s 157ms/step - loss: 0.1495 - binary_accuracy: 0.9890 - val_loss: 2.4951 - val_binary_accuracy: 0.8162
# Run:  5 / Accuracy at epoch  19  is:  0.8162000179290771
#
# Accuracies over epochs: [0.6621999740600586, 0.6782000064849854, 0.7516000270843506, 0.7901999950408936, 0.8199999928474426, 0.8414000272750854, 0.8312000036239624, 0.8453999757766724, 0.8402000069618225, 0.8392000198364258, 0.8095999956130981, 0.7512000203132629, 0.828000009059906, 0.8077999949455261, 0.769599974155426, 0.8366000056266785, 0.7929999828338623, 0.8216000199317932, 0.8163999915122986, 0.8162000179290771]
#
#
#
#
#  Over all runs maximum accuracies are: [0.842199981212616, 0.8447999954223633, 0.8452000021934509, 0.8453999757766724, 0.8501999974250793]
# The median is: 0.8452000021934509
#
#
#
# BiLSTM Accuracy Score on Test set ->  ['0.8452000021934509 +/- 0.004999995231628418']
#
#
# * * * * EVALUATION USING STM_LOW_RSW AS PREPROCESSING FUNCTION * * * *
# Length of the longest sample is: 1533
# Vocabulary size is: 94013
# 5000/5000 [==============================] - 804s 159ms/step - loss: 0.6976 - binary_accuracy: 0.5446 - val_loss: 0.6423 - val_binary_accuracy: 0.7144
# Run:  1 / Accuracy at epoch  0  is:  0.7143999934196472
#
# 5000/5000 [==============================] - 802s 160ms/step - loss: 0.6145 - binary_accuracy: 0.7166 - val_loss: 0.5641 - val_binary_accuracy: 0.7652
# Run:  1 / Accuracy at epoch  1  is:  0.7652000188827515
#
# 5000/5000 [==============================] - 830s 165ms/step - loss: 0.5542 - binary_accuracy: 0.7804 - val_loss: 0.6011 - val_binary_accuracy: 0.8018
# Run:  1 / Accuracy at epoch  2  is:  0.801800012588501
#
# 5000/5000 [==============================] - 829s 163ms/step - loss: 0.5139 - binary_accuracy: 0.8092 - val_loss: 0.9106 - val_binary_accuracy: 0.8048
# Run:  1 / Accuracy at epoch  3  is:  0.8047999739646912
#
# ...
# Run:  2 / Accuracy at epoch  0  is:  0.5013999938964844
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.7024 - binary_accuracy: 0.5106 - val_loss: 0.6926 - val_binary_accuracy: 0.5014
# Run:  2 / Accuracy at epoch  1  is:  0.5013999938964844
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.6708 - binary_accuracy: 0.6390 - val_loss: 0.5636 - val_binary_accuracy: 0.7310
# Run:  2 / Accuracy at epoch  2  is:  0.7310000061988831
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.5983 - binary_accuracy: 0.7436 - val_loss: 0.5176 - val_binary_accuracy: 0.7722
# Run:  2 / Accuracy at epoch  3  is:  0.7721999883651733
#
# 5000/5000 [==============================] - 815s 162ms/step - loss: 0.5361 - binary_accuracy: 0.7944 - val_loss: 0.5665 - val_binary_accuracy: 0.7908
# Run:  2 / Accuracy at epoch  4  is:  0.7907999753952026
#
# 5000/5000 [==============================] - 811s 162ms/step - loss: 0.4943 - binary_accuracy: 0.8216 - val_loss: 0.5294 - val_binary_accuracy: 0.8264
# Run:  2 / Accuracy at epoch  5  is:  0.8263999819755554
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.4469 - binary_accuracy: 0.8586 - val_loss: 0.8916 - val_binary_accuracy: 0.8334
# Run:  2 / Accuracy at epoch  6  is:  0.8334000110626221
#
# 5000/5000 [==============================] - 811s 161ms/step - loss: 0.3759 - binary_accuracy: 0.8984 - val_loss: 0.7870 - val_binary_accuracy: 0.8476
# Run:  2 / Accuracy at epoch  7  is:  0.847599983215332
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.3294 - binary_accuracy: 0.9238 - val_loss: 0.8115 - val_binary_accuracy: 0.8340
# Run:  2 / Accuracy at epoch  8  is:  0.8339999914169312
#
# 5000/5000 [==============================] - 808s 161ms/step - loss: 0.3248 - binary_accuracy: 0.9336 - val_loss: 0.8038 - val_binary_accuracy: 0.8478
# Run:  2 / Accuracy at epoch  9  is:  0.8478000164031982
#
# 5000/5000 [==============================] - 811s 161ms/step - loss: 0.2708 - binary_accuracy: 0.9470 - val_loss: 0.7114 - val_binary_accuracy: 0.8482
# Run:  2 / Accuracy at epoch  10  is:  0.8482000231742859
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.2533 - binary_accuracy: 0.9576 - val_loss: 0.8621 - val_binary_accuracy: 0.8352
# Run:  2 / Accuracy at epoch  11  is:  0.8352000117301941
#
# 5000/5000 [==============================] - 811s 161ms/step - loss: 0.2455 - binary_accuracy: 0.9662 - val_loss: 1.0694 - val_binary_accuracy: 0.8428
# Run:  2 / Accuracy at epoch  12  is:  0.8428000211715698
#
# 5000/5000 [==============================] - 811s 161ms/step - loss: 0.2114 - binary_accuracy: 0.9734 - val_loss: 1.5216 - val_binary_accuracy: 0.8204
# Run:  2 / Accuracy at epoch  13  is:  0.8203999996185303
#
# 5000/5000 [==============================] - 809s 161ms/step - loss: 0.2224 - binary_accuracy: 0.9744 - val_loss: 1.7428 - val_binary_accuracy: 0.8166
# Run:  2 / Accuracy at epoch  14  is:  0.8166000247001648
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.1925 - binary_accuracy: 0.9828 - val_loss: 1.8965 - val_binary_accuracy: 0.8370
# Run:  2 / Accuracy at epoch  15  is:  0.8370000123977661
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.1703 - binary_accuracy: 0.9832 - val_loss: 1.7384 - val_binary_accuracy: 0.8114
# Run:  2 / Accuracy at epoch  16  is:  0.8113999962806702
#
# 5000/5000 [==============================] - 811s 161ms/step - loss: 0.1918 - binary_accuracy: 0.9816 - val_loss: 2.1142 - val_binary_accuracy: 0.8088
# Run:  2 / Accuracy at epoch  17  is:  0.8087999820709229
#
# 5000/5000 [==============================] - 811s 162ms/step - loss: 0.1834 - binary_accuracy: 0.9876 - val_loss: 2.6119 - val_binary_accuracy: 0.8046
# Run:  2 / Accuracy at epoch  18  is:  0.8046000003814697
#
# 5000/5000 [==============================] - 833s 164ms/step - loss: 0.1610 - binary_accuracy: 0.9868 - val_loss: 4.3175 - val_binary_accuracy: 0.8064
# Run:  2 / Accuracy at epoch  19  is:  0.8064000010490417
#
# Accuracies over epochs: [0.5013999938964844, 0.5013999938964844, 0.7310000061988831, 0.7721999883651733, 0.7907999753952026, 0.8263999819755554, 0.8334000110626221, 0.847599983215332, 0.8339999914169312, 0.8478000164031982, 0.8482000231742859, 0.8352000117301941, 0.8428000211715698, 0.8203999996185303, 0.8166000247001648, 0.8370000123977661, 0.8113999962806702, 0.8087999820709229, 0.8046000003814697, 0.8064000010490417]
#
#
# 5000/5000 [==============================] - 803s 159ms/step - loss: 0.7039 - binary_accuracy: 0.5066 - val_loss: 0.6433 - val_binary_accuracy: 0.6476
# Run:  3 / Accuracy at epoch  0  is:  0.647599995136261
#
# 5000/5000 [==============================] - 804s 160ms/step - loss: 0.6657 - binary_accuracy: 0.6604 - val_loss: 0.5792 - val_binary_accuracy: 0.7636
# Run:  3 / Accuracy at epoch  1  is:  0.7635999917984009
#
# 5000/5000 [==============================] - 809s 161ms/step - loss: 0.6106 - binary_accuracy: 0.7354 - val_loss: 0.6352 - val_binary_accuracy: 0.7654
# Run:  3 / Accuracy at epoch  2  is:  0.7653999924659729
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.5469 - binary_accuracy: 0.7830 - val_loss: 0.4761 - val_binary_accuracy: 0.7942
# Run:  3 / Accuracy at epoch  3  is:  0.7942000031471252
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.4745 - binary_accuracy: 0.8304 - val_loss: 0.5630 - val_binary_accuracy: 0.8330
# Run:  3 / Accuracy at epoch  4  is:  0.8330000042915344
#
# 5000/5000 [==============================] - 809s 161ms/step - loss: 0.3991 - binary_accuracy: 0.8838 - val_loss: 0.6861 - val_binary_accuracy: 0.8338
# Run:  3 / Accuracy at epoch  5  is:  0.8338000178337097
#
# 5000/5000 [==============================] - 807s 161ms/step - loss: 0.3592 - binary_accuracy: 0.9092 - val_loss: 1.0079 - val_binary_accuracy: 0.8200
# Run:  3 / Accuracy at epoch  6  is:  0.8199999928474426
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.3304 - binary_accuracy: 0.9238 - val_loss: 0.7987 - val_binary_accuracy: 0.8334
# Run:  3 / Accuracy at epoch  7  is:  0.8334000110626221
#
# 5000/5000 [==============================] - 809s 161ms/step - loss: 0.3004 - binary_accuracy: 0.9404 - val_loss: 0.7859 - val_binary_accuracy: 0.8464
# Run:  3 / Accuracy at epoch  8  is:  0.8464000225067139
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.2741 - binary_accuracy: 0.9490 - val_loss: 2.0034 - val_binary_accuracy: 0.7888
# Run:  3 / Accuracy at epoch  9  is:  0.7888000011444092
#
# 5000/5000 [==============================] - 809s 161ms/step - loss: 0.2719 - binary_accuracy: 0.9570 - val_loss: 1.4626 - val_binary_accuracy: 0.7802
# Run:  3 / Accuracy at epoch  10  is:  0.7802000045776367
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.2622 - binary_accuracy: 0.9620 - val_loss: 1.9327 - val_binary_accuracy: 0.7928
# Run:  3 / Accuracy at epoch  11  is:  0.7928000092506409
#
# 5000/5000 [==============================] - 809s 161ms/step - loss: 0.2578 - binary_accuracy: 0.9614 - val_loss: 2.8190 - val_binary_accuracy: 0.7300
# Run:  3 / Accuracy at epoch  12  is:  0.7300000190734863
#
# 5000/5000 [==============================] - 809s 161ms/step - loss: 0.2541 - binary_accuracy: 0.9612 - val_loss: 2.2471 - val_binary_accuracy: 0.7190
# Run:  3 / Accuracy at epoch  13  is:  0.718999981880188
#
# 5000/5000 [==============================] - 809s 161ms/step - loss: 0.2638 - binary_accuracy: 0.9662 - val_loss: 2.7502 - val_binary_accuracy: 0.7906
# Run:  3 / Accuracy at epoch  14  is:  0.7906000018119812
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.2480 - binary_accuracy: 0.9754 - val_loss: 4.0370 - val_binary_accuracy: 0.7688
# Run:  3 / Accuracy at epoch  15  is:  0.7688000202178955
#
# 5000/5000 [==============================] - 812s 162ms/step - loss: 0.2403 - binary_accuracy: 0.9726 - val_loss: 4.0650 - val_binary_accuracy: 0.7198
# Run:  3 / Accuracy at epoch  16  is:  0.7197999954223633
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.2439 - binary_accuracy: 0.9786 - val_loss: 3.2248 - val_binary_accuracy: 0.7058
# Run:  3 / Accuracy at epoch  17  is:  0.7057999968528748
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.2101 - binary_accuracy: 0.9812 - val_loss: 7.1559 - val_binary_accuracy: 0.6846
# Run:  3 / Accuracy at epoch  18  is:  0.6845999956130981
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.2009 - binary_accuracy: 0.9830 - val_loss: 7.8041 - val_binary_accuracy: 0.7222
# Run:  3 / Accuracy at epoch  19  is:  0.7221999764442444
#
# Accuracies over epochs: [0.647599995136261, 0.7635999917984009, 0.7653999924659729, 0.7942000031471252, 0.8330000042915344, 0.8338000178337097, 0.8199999928474426, 0.8334000110626221, 0.8464000225067139, 0.7888000011444092, 0.7802000045776367, 0.7928000092506409, 0.7300000190734863, 0.718999981880188, 0.7906000018119812, 0.7688000202178955, 0.7197999954223633, 0.7057999968528748, 0.6845999956130981, 0.7221999764442444]
#
#
# 5000/5000 [==============================] - 822s 164ms/step - loss: 0.3730 - binary_accuracy: 0.9026 - val_loss: 0.6544 - val_binary_accuracy: 0.8436
# Run:  4 / Accuracy at epoch  6  is:  0.8435999751091003
#
# 5000/5000 [==============================] - 819s 163ms/step - loss: 0.3397 - binary_accuracy: 0.9206 - val_loss: 0.6467 - val_binary_accuracy: 0.8334
# Run:  4 / Accuracy at epoch  7  is:  0.8334000110626221
#
# 5000/5000 [==============================] - 818s 163ms/step - loss: 0.3070 - binary_accuracy: 0.9308 - val_loss: 0.9116 - val_binary_accuracy: 0.8356
# Run:  4 / Accuracy at epoch  8  is:  0.8356000185012817
#
# 5000/5000 [==============================] - 820s 163ms/step - loss: 0.2886 - binary_accuracy: 0.9456 - val_loss: 0.8809 - val_binary_accuracy: 0.8326
# Run:  4 / Accuracy at epoch  9  is:  0.8325999975204468
#
# 5000/5000 [==============================] - 817s 163ms/step - loss: 0.2454 - binary_accuracy: 0.9636 - val_loss: 1.6169 - val_binary_accuracy: 0.8198
# Run:  4 / Accuracy at epoch  10  is:  0.8198000192642212
#
# 5000/5000 [==============================] - 816s 162ms/step - loss: 0.2497 - binary_accuracy: 0.9658 - val_loss: 0.6438 - val_binary_accuracy: 0.8406
# Run:  4 / Accuracy at epoch  11  is:  0.8406000137329102
#
# 5000/5000 [==============================] - 821s 164ms/step - loss: 0.2070 - binary_accuracy: 0.9738 - val_loss: 1.5403 - val_binary_accuracy: 0.8358
# Run:  4 / Accuracy at epoch  12  is:  0.8357999920845032
#
# 5000/5000 [==============================] - 816s 163ms/step - loss: 0.2013 - binary_accuracy: 0.9764 - val_loss: 1.8621 - val_binary_accuracy: 0.8210
# Run:  4 / Accuracy at epoch  13  is:  0.8209999799728394
#
# 5000/5000 [==============================] - 867s 173ms/step - loss: 0.1974 - binary_accuracy: 0.9818 - val_loss: 2.0255 - val_binary_accuracy: 0.8264
# Run:  4 / Accuracy at epoch  14  is:  0.8263999819755554
#
# 5000/5000 [==============================] - 841s 168ms/step - loss: 0.1953 - binary_accuracy: 0.9802 - val_loss: 2.1626 - val_binary_accuracy: 0.8248
# Run:  4 / Accuracy at epoch  15  is:  0.8248000144958496
#
# 5000/5000 [==============================] - 842s 168ms/step - loss: 0.1788 - binary_accuracy: 0.9818 - val_loss: 1.8694 - val_binary_accuracy: 0.8184
# Run:  4 / Accuracy at epoch  16  is:  0.8184000253677368
#
# 5000/5000 [==============================] - 848s 169ms/step - loss: 0.1673 - binary_accuracy: 0.9842 - val_loss: 3.3192 - val_binary_accuracy: 0.8240
# Run:  4 / Accuracy at epoch  17  is:  0.8240000009536743
#
# 5000/5000 [==============================] - 848s 169ms/step - loss: 0.1281 - binary_accuracy: 0.9902 - val_loss: 2.9200 - val_binary_accuracy: 0.8222
# Run:  4 / Accuracy at epoch  18  is:  0.8222000002861023
#
# 5000/5000 [==============================] - 835s 166ms/step - loss: 0.1412 - binary_accuracy: 0.9894 - val_loss: 3.6209 - val_binary_accuracy: 0.8192
# Run:  4 / Accuracy at epoch  19  is:  0.8191999793052673
#
# Accuracies over epochs: [0.4986000061035156, 0.6467999815940857, 0.7534000277519226, 0.772599995136261, 0.8240000009536743, 0.8335999846458435, 0.8435999751091003, 0.8334000110626221, 0.8356000185012817, 0.8325999975204468, 0.8198000192642212, 0.8406000137329102, 0.8357999920845032, 0.8209999799728394, 0.8263999819755554, 0.8248000144958496, 0.8184000253677368, 0.8240000009536743, 0.8222000002861023, 0.8191999793052673]
#
#
# 5000/5000 [==============================] - 831s 164ms/step - loss: 0.7045 - binary_accuracy: 0.5070 - val_loss: 0.6900 - val_binary_accuracy: 0.5448
# Run:  5 / Accuracy at epoch  0  is:  0.5447999835014343
#
# 5000/5000 [==============================] - 831s 165ms/step - loss: 0.6700 - binary_accuracy: 0.6340 - val_loss: 0.5610 - val_binary_accuracy: 0.7378
# Run:  5 / Accuracy at epoch  1  is:  0.7378000020980835
#
# 5000/5000 [==============================] - 863s 168ms/step - loss: 0.5881 - binary_accuracy: 0.7428 - val_loss: 0.7136 - val_binary_accuracy: 0.7730
# Run:  5 / Accuracy at epoch  2  is:  0.7730000019073486
#
# 5000/5000 [==============================] - 833s 166ms/step - loss: 0.5404 - binary_accuracy: 0.7938 - val_loss: 0.5230 - val_binary_accuracy: 0.7750
# Run:  5 / Accuracy at epoch  3  is:  0.7749999761581421
#
# 5000/5000 [==============================] - 835s 166ms/step - loss: 0.4859 - binary_accuracy: 0.8348 - val_loss: 0.4729 - val_binary_accuracy: 0.8230
# Run:  5 / Accuracy at epoch  4  is:  0.8230000138282776
#
# 5000/5000 [==============================] - 834s 166ms/step - loss: 0.4017 - binary_accuracy: 0.8818 - val_loss: 0.7066 - val_binary_accuracy: 0.8396
# Run:  5 / Accuracy at epoch  5  is:  0.8396000266075134
#
# 5000/5000 [==============================] - 835s 166ms/step - loss: 0.3614 - binary_accuracy: 0.9022 - val_loss: 0.7708 - val_binary_accuracy: 0.8368
# Run:  5 / Accuracy at epoch  6  is:  0.8367999792098999
#
# 5000/5000 [==============================] - 833s 166ms/step - loss: 0.3332 - binary_accuracy: 0.9230 - val_loss: 0.8548 - val_binary_accuracy: 0.8250
# Run:  5 / Accuracy at epoch  7  is:  0.824999988079071
#
# 5000/5000 [==============================] - 835s 166ms/step - loss: 0.3107 - binary_accuracy: 0.9392 - val_loss: 1.4261 - val_binary_accuracy: 0.8196
# Run:  5 / Accuracy at epoch  8  is:  0.819599986076355
#
# 5000/5000 [==============================] - 831s 165ms/step - loss: 0.3031 - binary_accuracy: 0.9572 - val_loss: 1.8731 - val_binary_accuracy: 0.7810
# Run:  5 / Accuracy at epoch  9  is:  0.781000018119812
#
# 5000/5000 [==============================] - 829s 165ms/step - loss: 0.2972 - binary_accuracy: 0.9642 - val_loss: 3.2139 - val_binary_accuracy: 0.7904
# Run:  5 / Accuracy at epoch  10  is:  0.7904000282287598
#
# 5000/5000 [==============================] - 814s 162ms/step - loss: 0.2875 - binary_accuracy: 0.9688 - val_loss: 2.3035 - val_binary_accuracy: 0.7908
# Run:  5 / Accuracy at epoch  11  is:  0.7907999753952026
#
# 5000/5000 [==============================] - 811s 162ms/step - loss: 0.2614 - binary_accuracy: 0.9744 - val_loss: 1.8934 - val_binary_accuracy: 0.7926
# Run:  5 / Accuracy at epoch  12  is:  0.7925999760627747
#
# 5000/5000 [==============================] - 811s 161ms/step - loss: 0.2559 - binary_accuracy: 0.9800 - val_loss: 3.4591 - val_binary_accuracy: 0.7678
# Run:  5 / Accuracy at epoch  13  is:  0.767799973487854
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.1964 - binary_accuracy: 0.9870 - val_loss: 1.8497 - val_binary_accuracy: 0.8002
# Run:  5 / Accuracy at epoch  14  is:  0.8001999855041504
#
# 5000/5000 [==============================] - 810s 161ms/step - loss: 0.1980 - binary_accuracy: 0.9878 - val_loss: 2.6107 - val_binary_accuracy: 0.8052
# Run:  5 / Accuracy at epoch  15  is:  0.8051999807357788
#
# 4381/5000 [=========================>....] - ETA: 1:10 - loss: 0.1876 - binary_accuracy: 0.9854

# %% [markdown]
# ## Now show compact results in a table.

# %%
print(" PREPRO FUNCTION    |  Test Accuracy   |",end = '')

print("\n")
for prepro_func in prepro_functions_dict_comb:
  #print(prepro_func,"\t\t\t",format(round(model_results[prepro_func][0],4),'.4f'),"\t\t",end='')
  result = format(round(model_results[prepro_func][0],4),'.4f')
  print(f'{prepro_func:27}{ result :12}')
  print("\n")
